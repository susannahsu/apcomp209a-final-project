# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 45px" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png"> CS109A Introduction to Data Science:
# ## APCOMP 209a Final Project
#
# **Harvard University**<br/>
# **Fall 2023**<br/>
# **Instructors**: Pavlos Protopapas and Kevin Rader<br/>
# **Group Members**: Davide Bray, Regina Lin, Shang Wang, Susannah Su
#
# <hr style="height:2.4pt">

# %%
# RUN THIS CELL 
import requests
from IPython.core.display import HTML
styles = requests.get(
    "https://raw.githubusercontent.com/Harvard-IACS/2021-CS109A/master/"
    "themes/static/css/cs109.css"
).text
HTML(styles)
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #63ACBE;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #f8b4ab;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# }
#
# div.exercise-r {
# 	background-color: #ffd0d0;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# }
#
#
# span.sub-q {
# 	font-weight: bold;
# }
# div.theme {
# 	background-color: #63ACBE;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
#     padding-top: 5px;
#     padding-bottom: 5px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
# header {
#    padding-top: 35px;
#     padding-bottom: 35px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# span.emph {
# 	color: #601A4A;
# 	font-weight: bold;
# }
#
# </style>

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import re
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import xgboost as xgb
import lightgbm as lgb
import pickle
import time

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.utils import resample
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor, VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Disable scientific notation
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %% [markdown]
# <a id="contents"></a>
#
# # Notebook Contents

# %% [markdown]
# - [**Data Description**](#data_sescription)
# - [**Problem Statement**](#problem_statement)
# - [**Project Organization**](#project_organization)

# %% [markdown]
# <a id="data_description"></a>
#
# # Data Description
# [Return to contents](#contents)

# %% [markdown]
#  (From Kaggle, see https://www.kaggle.com/datasets/cnic92/200-financial-indicators-of-us-stocks-20142018?select=2018_Financial_Data.csv)
#
#  There are in total 5 datasets: `2014_Financial_Data.csv`, `2015_Financial_Data.csv`, `2016_Financial_Data.csv`, `2017_Financial_Data.csv`, `2018_Financial_Data.csv`.
#
# Each dataset contains 200+ financial indicators, that are commonly found in the 10-K filings each publicly traded company releases yearly, for a plethora of US stocks (on average, 4k stocks are listed in each dataset).
#
# The dataset was built by the author leveraging Financial Modeling Prep API and pandas_datareader.
#
# #### Important remarks regarding the datasets
# 1. Some financial indicator values are missing (`nan` cells), so the user can select the best technique to clean each dataset (`dropna`, `fillna`, etc.).
# 2. There are outliers, meaning extreme values that are probably caused by mistypings. Also in this case, the user can choose how to clean each dataset (have a look at the 1% - 99% percentile values).
# 3. The third-to-last column, `Sector`, lists the sector of each stock. Indeed, in the US stock market each company is part of a sector that classifies it in a macro-area. Since all the sectors have been collected (Basic Materials, Communication Services, Consumer Cyclical, Consumer Defensive, Energy, Financial Services, Healthcare, Industrial, Real Estate, Technology and Utilities), the user has the option to perform per-sector analyses and comparisons.
# 4. The second-to-last column, `PRICE VAR [%]`, lists the percent price variation of each stock for the year. For example, if we consider the dataset `2015_Financial_Data.csv`, we will have:
#     - 200+ financial indicators for the year 2015;
#     - percent price variation for the year 2016 (meaning from the first trading day on Jan 2016 to the last trading day on Dec 2016).
#
# 5. The last column, `class`, lists a binary classification for each stock, where
#     - for each stock, if the `PRICE VAR [%]` value is positive, `class = 1`. From a trading perspective, the `1` identifies those stocks that an hypothetical trader should **BUY** at the start of the year and sell at the end of the year for a profit.
#     - for each stock, if the `PRICE VAR [%]` value is negative, `class = 0`. From a trading perspective, the `0` identifies those stocks that an hypothetical trader should **NOT BUY**, since their value will decrease, meaning a loss of capital.
#
# The columns `PRICE VAR [%]` and `class` make possible to use the datasets for both classification and regression tasks:
# - If the we wish to train a machine learning model so that it learns to classify those stocks that in buy-worthy and not buy-worthy, it is possible to get the targets from the class column;
# - If the we wish to train a machine learning model so that it learns to predict the future value of a stock, it is possible to get the targets from the `PRICE VAR [%]` column.

# %% [markdown]
# <a id="problem_statement"></a>
#
# # Problem Statement
#
# [Return to contents](#contents)

# %% [markdown]
# This project seeks to develop a machine learning model that predicts stock price variations using a range of financial indicators, without relying on individual stock identifiers (tickers). The aim is to uncover general patterns in the stock market that transcend company-specific characteristics, thereby creating a broadly applicable predictive tool. The challenge involves accurately capturing the complex dynamics of the market using available financial data, and ensuring that the model is robust and generalizable across various stocks and market conditions.
#
# The project will begin with a simple baseline model, then advance to more sophisticated algorithms to improve prediction accuracy. Success will be measured by the model's ability to reliably predict stock price changes, providing a valuable asset for investors and analysts in making informed financial decisions. This endeavor is poised to enhance understanding and forecasting of market behaviors using machine learning techniques.

# %% [markdown]
# <a id="project_organization"></a>
#
# # Project Organization
#
# [Return to contents](#contents)

# %% [markdown]
# ## Part 0: Data Preprocessing & Feature Selection / Exploratory Data Analysis

# %% [markdown]
# #### Overview
# This foundational part focuses on preparing the dataset for various analyses and model building in the subsequent parts. The processes conducted here are crucial for ensuring the quality and effectiveness of the models and analyses.
#
# #### Methodology
# 1. **Basic Processing**
# * Load the dataset and rename the columns for clarity.
# * Separate predictors and target variables (`price_var20xx`, `class20xx`, `xx` correspond to the year).
# * General information on predictors based on industry knowledge and relevance.
#
# 2. **EDA**
# * Statistical summary of datasets to understand distributions and central tendencies.
# * Correlation analysis to identify highly correlated features.
# * Identification of trends and patterns specific to categorical variables.
#
# 3. **Examine Missingness**
# * Preliminary examination of nullness.
# * Identifying the Patterns of Missing Data.
#
# 4. **Handling Outliers**
# * Dropping large outliers in skewed y variable
#
# 5. **Further Preparation for Pipeline**
# * Train-test splitting first to prevent data leakage.
# * Scaling of features to normalize data.
# * K-NN imputation to handle missing values without making assumptions about the underlying distribution of the variables

# %% [markdown]
# ## Part 1: Baseline Model Selection and Evaluation

# %% [markdown]
# #### Objective
# To establish a simple yet effective baseline model for predicting stock performance.
#
# #### Methodology
# 1. **Model Selection and Building**
# * Start with a simple mean/median model as a baseline.
#     - Mean/median prediction model
#     - Multiple linear regression
#     - Single decision tree
# * Train the model on our dataset and perform an initial evaluation using $MSE$.
#
# 2. **Cross Validations**
# * Implement basic cross-validation (like k-fold CV) to assess the model’s performance more reliably.
#
# 3. **Interim Interpretation**
# * Provide an initial interpretation of the model's performance, focusing on its strengths and limitations based on the evaluation metrics.
# * Select the baseline model.

# %% [markdown]
# ## Part 2: More Complex Models

# %% [markdown]
# #### Objective
# The objective of this stage is to explore and evaluate more sophisticated machine learning models beyond the baseline model. These models are expected to capture complex patterns and relationships in the data that the baseline model might miss. The goal is to improve prediction accuracy and reliability in forecasting stock performance, while also gaining deeper insights into how different financial indicators influence stock prices.
#
# #### Methodology
# 1. **Selection of More Complex Models and Building**
# * Identify a set of more complex models:
#     - Ridge regression
#     - LASSO regression
#     - Elastic net regression
#     - Random forest regressors
#     - Gradient boosting
# * Train the model on our dataset and perform an initial evaluation using $MSE$.
#
# 2. **Cross Validations**
# * Implement basic cross-validation (like k-fold CV) to assess the model’s performance more reliably.
# * Include a basic hyperparameter tuning to find a reasonably good configuration for each model, while avoiding extensive optimization at this stage.
#
# 3. **Performance Evaluation and Final Model Selection**
# * Evaluate the tuned models using $MSE$.
# * Compare the complex models with the baseline model.
# * Select the final model.

# %% [markdown]
# ## Part 3: Selected Model Tuning

# %% [markdown]
# #### Objective
#
#
# #### Methodology

# %% [markdown]
# <a id="project_organization"></a>
#
# # Part 0: Data Preprocessing & Feature Selection / Exploratory Data Analysis
#
# [Return to contents](#contents)

# %% [markdown]
# ## 0.1 Basic Processing

# %%
# Load raw data
df2014 = pd.read_csv('data/2014_Financial_Data.csv')
df2015 = pd.read_csv('data/2015_Financial_Data.csv')
df2016 = pd.read_csv('data/2016_Financial_Data.csv')
df2017 = pd.read_csv('data/2017_Financial_Data.csv')
df2018 = pd.read_csv('data/2018_Financial_Data.csv')

# %%
# Inspect how does it look like -- 
# The "Unnamed: 0" column is probably stock ticker
df2014.head()
# Out:
#   Unnamed: 0          Revenue  Revenue Growth  Cost of Revenue  \
# 0         PG 74401000000.0000         -0.0713 39030000000.0000
# 1       VIPS  3734148046.4966          1.1737  2805625443.9780
# 2         KR 98375000000.0000          0.0182 78138000000.0000
# 3        RAD 25526413000.0000          0.0053 18202679000.0000
# 4        GIS 17909600000.0000          0.0076 11539800000.0000
#
#       Gross Profit   R&D Expenses     SG&A Expense  Operating Expenses  \
# 0 35371000000.0000         0.0000 21461000000.0000    21461000000.0000
# 1   928522602.5186 108330319.6642   344141427.1876      793926703.2612
# 2 20237000000.0000         0.0000 15196000000.0000    17512000000.0000
# 3  7323734000.0000         0.0000  6561162000.0000     6586482000.0000
# 4  6369800000.0000         0.0000  3474300000.0000     3412400000.0000
#
#    Operating Income  Interest Expense  Earnings before Tax  \
# 0  13910000000.0000    709000000.0000     14494000000.0000
# 1    134595899.2573     12148692.2829       175382305.4569
# 2   2725000000.0000    443000000.0000      2270000000.0000
# 3    737252000.0000    424591000.0000       250218000.0000
# 4   2957400000.0000    302400000.0000      2707700000.0000
#
#    Income Tax Expense  Net Income - Non-Controlling int  \
# 0     2851000000.0000                    142000000.0000
# 1       39559573.7811                    -14319179.8515
# 2      751000000.0000                     12000000.0000
# 3         804000.0000                            0.0000
# 4      883300000.0000                     36900000.0000
#
#    Net Income - Discontinued ops       Net Income  Preferred Dividends  \
# 0               -1127000000.0000 11643000000.0000               0.0000
# 1                         0.0000   135822731.6758               0.0000
# 2                         0.0000  1519000000.0000               0.0000
# 3                         0.0000   249414000.0000        33998000.0000
# 4                         0.0000  1824400000.0000               0.0000
#
#     Net Income Com    EPS  EPS Diluted  Weighted Average Shs Out  \
# 0 11643000000.0000 4.1900       4.0100           2705960276.0000
# 1   135822731.6758 0.2396       0.2260                       NaN
# 2  1519000000.0000 1.4700       1.4500           1033052512.0000
# 3   215416000.0000 4.6000       4.6000             48326279.0000
DebtToCapitalization  totalDebtToCapitalization  interestCoverage  \
# 0                        0.2206                     0.3360           21.4429
# 1                        0.6015                     0.6015           15.4363
# 2                        0.6419                     0.6775            6.1242
# 3                        1.5881                     1.5801            1.5893
# 4                        0.4957                     0.5735            9.9540
#
#    cashFlowToDebtRatio  companyEquityMultiplier  operatingCashFlowPerShare  \
# 0               0.3941                   2.0616                     5.1582
# 1               0.8463                   6.6367                    35.6714
# 2               0.3159                   5.4385                     3.4757
# 3               0.1219                      NaN                    14.5272
# 4               0.2892                   3.5419                     4.1351
#
#    freeCashFlowPerShare  cashPerShare  payoutRatio  \
# 0                3.9640        3.1626       0.5840
# 1               22.9760       52.3827       0.0000
# 2                0.8370        0.3901       0.2090
# 3                0.5570        3.0295       0.0000
# 4                3.6240        1.4114       0.5340
#
#    operatingCashFlowSalesRatio  freeCashFlowOperatingCashFlowRatio  \
# 0                       0.1876                              0.7243
# 1                       0.1411                              0.4994
# 2                       0.0363                              0.3479
# 3                       0.0275                              0.5244
# 4                       0.1419                              0.7415
#
#    cashFlowCoverageRatios  shortTermCoverageRatios  \
# 0                  0.3941                   0.8944
# 1                  0.8463                      NaN
# 2                  0.3159                   2.1563
# 3                  0.1219                  14.2768
# 4                  0.2892                   1.0756
#
#    capitalExpenditureCoverageRatios  dividendpaidAndCapexCoverageRatios  \
# 0                            3.6273                              1.2973
# 1                            1.9975                              1.9975
# 2                            1.5335                              1.3488
# 3                            2.1028                              2.1028
# 4                            3.8682                              1.5492
#
#    dividendPayoutRatio  Revenue per Share  Net Income per Share  \
# 0               0.5936            27.4952                4.3027
# 1              -0.0000           252.8778                9.1980
# 2               0.2100            95.6955                1.4776
# 3              -0.0000           528.2098                5.1610
# 4               0.5390            29.1454                2.9690
#
#    Operating Cash Flow per Share  Free Cash Flow per Share  Cash per Share  \
# 0                         5.1582                    3.9640          3.1626
# 1                        35.6714                   22.9760         52.3827
# 2                         3.4757                    0.8370          0.3901
# 3                        14.5272                    0.5570          3.0295
# 4                         4.1351                    3.6240          1.4114
#
#    Book Value per Share  Tangible Book Value per Share  \
# 0               25.8600                        22.0690
# 1                0.7278                         4.4939
# 2                5.2370                        25.7240
# 3              -43.7380                       134.7850
# 4               10.6340                        15.4290
#
#    Shareholders Equity per Share  Interest Debt per Share        Market Cap  \
# 0                        25.8600                  13.0885 212661418090.8400
# 1                        27.9248                  42.1474   6253200000.0000
# 2                         5.2374                  11.0019  18274698937.2800
# 3                       -43.7381                 119.1307   6359738316.4000
# 4                        10.6345                  14.2977  33330057253.4400
#
#    Enterprise Value  PE ratio  Price to Sales Ratio  POCF ratio  PFCF ratio  \
# 0 237392418090.8400   18.7566                2.8583     15.2358     21.0348
# 1               NaN   81.5526                0.0443         NaN      1.3589
# 2  29183698937.2800   12.0340                0.1858      5.1147     14.6302
# 3  11970475316.4000   28.6087                0.2491      9.0589     17.2736
# 4  41248557253.4400   18.7034                1.8610     13.1169     17.6902
#
#    PB ratio  PTB ratio  EV to Sales  Enterprise Value over EBITDA  \
# 0    3.0391     0.0000       3.1907                       12.9411
# 1       NaN        NaN          NaN                           NaN
# 2    3.3579     7.0982       0.2967                        6.6086
# 3    0.0000     0.0000       0.4689                       11.0987
# 4    5.1004     0.0000       2.3032                       11.4723
#
#    EV to Operating cash flow  EV to Free cash flow  Earnings Yield  \
# 0                    17.0076               23.4810          0.0533
# 1                        NaN                   NaN          0.0123
# 2                     8.1678               23.4784          0.0831
# 3                    17.0508               32.5129          0.0350
# 4                    16.2332               21.8930          0.0535
#
#    Free Cash Flow Yield  Debt to Equity  Debt to Assets  Net Debt to EBITDA  \
# 0                0.0475          0.5061          0.2455              1.3482
# 1                   NaN          1.5093          0.2274                 NaN
# 2                0.0680          2.1007          0.3863              2.4703
# 3                0.0579         -2.7237          0.8290              5.2021
# 4                0.0565          1.3445          0.3796              2.2023
#
#    Current ratio  Interest Coverage  Income Quality  Dividend Yield  \
# 0         0.9370            21.4429          1.1988          0.0311
# 1         0.2102            15.4363          3.8782          0.0000
# 2         0.8250             6.1242          2.3522          0.0174
# 3         1.7090             1.5893          3.2590          0.0000
# 4         0.8100             9.9540          1.3928          0.0286
#
#    Payout Ratio  SG&A to Revenue  R&D to Revenue  Intangibles to Total Assets  \
# 0        0.5840           0.2885          0.0000                       0.5860
# 1        0.0000           0.0922          0.0290                       0.0697
# 2        0.2090           0.1545          0.0000                       0.0969
# 3        0.0000           0.2570          0.0000                       0.0621
# 4        0.5340           0.1940          0.0000                       0.5904
#
#    Capex to Operating Cash Flow  Capex to Revenue  Capex to Depreciation  \
# 0                        0.2757            0.0517                -1.2251
# 1                        0.5006            0.0706                -4.5345
# 2                        0.6521            0.0237                -1.3682
# 3                        0.4756            0.0131                -0.8269
# 4                        0.2585            0.0367                -1.1221
#
#    Stock-based compensation to Revenue  Graham Number   ROIC  \
# 0                               0.0048        49.3756 0.0753
# 1                               0.0097            NaN 0.0000
# 2                               0.0011        13.2000 0.0859
# 3                              -0.0004         0.0000 0.1062
# 4                               0.0022        26.3414 0.1041
#
#    Return on Tangible Assets  Graham Net-Net  Working Capital  \
# 0                     0.5765         -0.2007 -2109000000.0000
# 1                     0.0403          0.0534  3065163000.0000
# 2                     0.1011         -0.8239 -1875000000.0000
# 3                     0.0668         -0.7506  1777673000.0000
# 4                     0.6265         -0.3229 -1030000000.0000
#
#    Tangible Asset Value  Net Current Asset Value  Invested Capital  \
# 0      59719000000.0000        -42673000000.0000  52852000000.0000
# 1       2546028576.0413          -166696641.9115    755350984.8240
# 2      26444000000.0000        -15056000000.0000  26648000000.0000
# 3       6513644000.0000         -4773448000.0000   9616929000.0000
# 4       9480900000.0000        -10762700000.0000  11975900000.0000
#
#    Average Receivables  Average Payables  Average Inventory  \
# 0      6447000000.0000   8619000000.0000    6834000000.0000
# 1                  NaN               NaN                NaN
# 2      1083500000.0000   4682500000.0000    5398500000.0000
# 3       939269000.0000   1338531500.0000    3074345000.0000
# 4      1465000000.0000   1517250000.0000    1552450000.0000
#
#    Days Sales Outstanding  Days Payables Outstanding  \
# 0                 31.3287                    41.5084
# 1                  1.1431                    97.7945
# 2                  4.1407                    18.1099
# 3                 13.5706                    18.4802
# 4                 30.2360                    32.8385
#
#    Days of Inventory on Hand  Receivables Turnover  Payables Turnover  \
# 0                   -63.2087               11.5404             1.5648
# 1                   -75.3670                   NaN                NaN
# 2                   -26.3971               90.7937             4.9593
# 3                   -60.0346               27.1769             4.9289
# 4                   -49.3233               12.2250             2.8234
#
#    Inventory Turnover     ROE  Capex per Share  Gross Profit Growth  \
# 0             10.8869  0.1664          -1.4220              -0.1185
# 1                 NaN  0.3294         -17.8582               1.2489
# 2             18.2227  0.2821          -2.2665               0.0173
# 3              8.3030 -0.1180          -6.9087               0.0007
# 4             11.5363  0.2792          -1.0690              -0.0084
#
#    EBIT Growth  Operating Income Growth  Net Income Growth  EPS Growth  \
# 0      -0.0001                   0.0067             0.0293      0.0371
# 1       1.6142                   1.9463             1.5649      1.4625
# 2      -0.0145                  -0.0141             0.0147      0.0576
# 3       0.2904                   0.1113             1.0043      0.9167
# 4       0.0332                   0.0370            -0.0166      0.0140
#
#    EPS Diluted Growth  Weighted Average Shares Growth  \
# 0              0.0389                         -0.0127
# 1              1.4646                          0.0184
# 2              0.0469                         -0.0356
# 3              0.9167                          0.0694
# 4              0.0143                         -0.0468
#
#    Weighted Average Shares Diluted Growth  Dividends per Share Growth  \
# 0                                     NaN                      0.0699
# 1                                  0.0195                      0.0000
# 2                                 -0.0317                      0.2429
# 3                                     NaN                      0.0000
# 4                                     NaN                      0.1742
#
#    Operating Cash Flow growth  Free Cash Flow growth  \
# 0                     -0.0615                -0.0695
# 1                      0.2134                -0.3626
# 2                      0.2095                 0.3935
# 3                     -0.1434                -0.2691
# 4                     -0.1316                -0.1936
#
#    10Y Revenue Growth (per Share)  5Y Revenue Growth (per Share)  \
# 0                          0.0323                         0.0088
# 1                             NaN                            NaN
# 2                          0.1027                         0.1038
# 3                         -0.0195                        -0.0290
# 4                          0.0704                         0.0567
#
#    3Y Revenue Growth (per Share)  10Y Operating CF Growth (per Share)  \
# 0                        -0.0182                               0.0355
# 1                            NaN                                  NaN
# 2                         0.1399                               0.0889
# 3                        -0.0230                               0.0513
# 4                         0.0773                               0.0782
#
#    5Y Operating CF Growth (per Share)  3Y Operating CF Growth (per Share)  \
# 0                              0.0015                              0.0260
# 1                                 NaN                                 NaN
# 2                              0.0937                              0.0946
# 3                              0.1164                              0.1777
# 4                              0.0828                              0.1991
#
#    10Y Net Income Growth (per Share)  5Y Net Income Growth (per Share)  \
# 0                             0.0603                           -0.0137
# 1                                NaN                               NaN
# 2                             0.2272                            0.0906
# 3                             0.0480                            0.0000
# 4                             0.0776                            0.0841
#
#    3Y Net Income Growth (per Share)  \
# 0                            0.0060
# 1                               NaN
# 2                            0.1892
# 3                            0.0000
# 4                            0.0177
#
#    10Y Shareholders Equity Growth (per Share)  \
# 0                                      0.1442
# 1                                         NaN
# 2                                      0.0676
# 3                                      0.0000
# 4                                      0.0427
#
#    5Y Shareholders Equity Growth (per Share)  \
# 0                                     0.0353
# 1                                        NaN
# 2                                     0.0558
# 3                                     0.0000
# 4                                     0.0623
#
#    3Y Shareholders Equity Growth (per Share)  \
# 0                                     0.0201
# 1                                        NaN
# 2                                     0.0789
# 3                                     0.0000
# 4                                     0.0217
#
#    10Y Dividend per Share Growth (per Share)  \
# 0                                     0.1013
# 1                                        NaN
# 2                                     0.0000
# 3                                     0.0000
# 4                                     0.1092
#
#    5Y Dividend per Share Growth (per Share)  \
# 0                                    0.0834
# 1                                       NaN
# 2                                    0.1215
# 3                                    0.0000
# 4                                    0.1250
#
#    3Y Dividend per Share Growth (per Share)  Receivables growth  \
# 0                                    0.0751             -0.0187
# 1                                       NaN                 NaN
# 2                                    0.1633              0.0618
# 3                                    0.0000              0.0211
# 4                                    0.1144              0.0257
#
#    Inventory Growth  Asset Growth  Book Value per Share Growth  Debt Growth  \
# 0           -0.0217        0.0359                       0.0316       0.1228
# 1               NaN           NaN                          NaN          NaN
# 2            0.0981        0.1886                       0.3268       0.2738
# 3           -0.0510       -0.0189                       0.1963      -0.0458
# 4            0.0090        0.0215                       0.0274       0.1025
#
#    R&D Expense Growth  SG&A Expenses Growth              Sector  \
# 0              0.0000               -0.1746  Consumer Defensive
# 1              1.6484                1.7313  Consumer Defensive
# 2              0.0000                0.0234  Consumer Defensive
# 3              0.0000               -0.0060  Consumer Defensive
# 4              0.0000               -0.0220  Consumer Defensive
#
#    2015 PRICE VAR [%]  Class
# 0             -9.3233      0
# 1            -25.5122      0
# 2             33.1183      1
# 3              2.7523      1
# 4             12.8977      1

# %%
# Check that the df of different years all have same columns
# They do (except the 2nd to last column which is our potential response variable) -- they all have 225 columns
print(df2014.columns, '\n')
print(df2015.columns, '\n')
print(df2016.columns, '\n')
print(df2017.columns, '\n')
print(df2018.columns, '\n')
# Out:
# Index(['Unnamed: 0', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2015 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)
#
# Index(['Unnamed: 0', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2016 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)
#
# Index(['Unnamed: 0', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2017 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)
#
# Index(['Unnamed: 0', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2018 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)
#
# Index(['Unnamed: 0', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2019 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)

# %%
# Rename the only different column names before we concatenate the dataframes

df2014.rename(columns={'2015 PRICE VAR [%]': 'price_var_next_yr_%'}, inplace=True)
df2015.rename(columns={'2016 PRICE VAR [%]': 'price_var_next_yr_%'}, inplace=True)
df2016.rename(columns={'2017 PRICE VAR [%]': 'price_var_next_yr_%'}, inplace=True)
df2017.rename(columns={'2018 PRICE VAR [%]': 'price_var_next_yr_%'}, inplace=True)
df2018.rename(columns={'2019 PRICE VAR [%]': 'price_var_next_yr_%'}, inplace=True)

df2014.head()
# Out:
#   Unnamed: 0          Revenue  Revenue Growth  Cost of Revenue  \
# 0         PG 74401000000.0000         -0.0713 39030000000.0000
# 1       VIPS  3734148046.4966          1.1737  2805625443.9780
# 2         KR 98375000000.0000          0.0182 78138000000.0000
# 3        RAD 25526413000.0000          0.0053 18202679000.0000
# 4        GIS 17909600000.0000          0.0076 11539800000.0000
#
#       Gross Profit   R&D Expenses     SG&A Expense  Operating Expenses  \
# 0 35371000000.0000         0.0000 21461000000.0000    21461000000.0000
# 1   928522602.5186 108330319.6642   344141427.1876      793926703.2612
# 2 20237000000.0000         0.0000 15196000000.0000    17512000000.0000
# 3  7323734000.0000         0.0000  6561162000.0000     6586482000.0000
# 4  6369800000.0000         0.0000  3474300000.0000     3412400000.0000
#
#    Operating Income  Interest Expense  Earnings before Tax  \
# 0  13910000000.0000    709000000.0000     14494000000.0000
# 1    134595899.2573     12148692.2829       175382305.4569
# 2   2725000000.0000    443000000.0000      2270000000.0000
# 3    737252000.0000    424591000.0000       250218000.0000
# 4   2957400000.0000    302400000.0000      2707700000.0000
#
#    Income Tax Expense  Net Income - Non-Controlling int  \
# 0     2851000000.0000                    142000000.0000
# 1       39559573.7811                    -14319179.8515
# 2      751000000.0000                     12000000.0000
# 3         804000.0000                            0.0000
# 4      883300000.0000                     36900000.0000
#
#    Net Income - Discontinued ops       Net Income  Preferred Dividends  \
# 0               -1127000000.0000 11643000000.0000               0.0000
# 1                         0.0000   135822731.6758               0.0000
# 2                         0.0000  1519000000.0000               0.0000
# 3                         0.0000   249414000.0000        33998000.0000
# 4                         0.0000  1824400000.0000               0.0000
#
#     Net Income Com    EPS  EPS Diluted  Weighted Average Shs Out  \
# 0 11643000000.0000 4.1900       4.0100           2705960276.0000
# 1   135822731.6758 0.2396       0.2260                       NaN
# 2  1519000000.0000 1.4700       1.4500           1033052512.0000
# 3   215416000.0000 4.6000       4.6000             48326279.0000
# 4  1824400000.0000 2.9000       2.8300            614492206.0000
#
#    Weighted Average Shs Out (Dil)  Dividend per Share  Gross Margin  \
# 0                 2705960276.0000              2.4480        0.4754
# 1                   18293619.9548              0.0000        0.2487
# 2                 1028000000.0000              0.3070        0.2057
# 3                   48326279.0000              0.0000        0.2869
# 4                  614492206.0000              1.5500        0.3557
#
#    EBITDA Margin  EBIT Margin  Profit Margin  Free Cash Flow margin  \
# 0         0.2470       0.2043         0.1560                 0.1359
# 1         0.0107       0.0502         0.0058                 0.0704
# 2         0.0450       0.0276         0.0150                 0.0126
# 3         0.0420       0.0264         0.0080                 0.0144
# 4         0.2010       0.1681         0.1020                 0.1052
#
#             EBITDA             EBIT  Consolidated Income  \
ossProfitMargin  operatingProfitMargin  pretaxProfitMargin  \
# 0    0.8033             0.4754                 1.0000              0.1870
# 1    0.7744             0.2487                 1.0000              0.0360
# 2    0.6692             0.2057                 1.0000              0.0277
# 3    0.9968             0.2869                 1.0000              0.0289
# 4    0.6738             0.3557                 1.0000              0.1651
#
#    netProfitMargin  effectiveTaxRate  returnOnAssets  returnOnEquity  \
# 0           0.1565            0.1967          0.5765          0.1664
# 1           0.0364            0.2256          0.0403          0.3294
# 2           0.0154            0.3308          0.1011          0.2821
# 3           0.0098            0.0032          0.0668         -0.1180
# 4           0.1019            0.3262          0.6265          0.2792
#
#    returnOnCapitalEmployed  nIperEBT  eBTperEBIT  eBITperRevenue  \
# 0                   0.0753    0.8033      0.9534          0.2043
# 1                   0.0000    0.7744      0.9352          0.0502
# 2                   0.0859    0.6692      0.8367          0.0276
# 3                   0.1062    0.9968      0.3708          0.0264
# 4                   0.1041    0.6738      0.8995          0.1681
#
#    payablesTurnover  inventoryTurnover  fixedAssetTurnover  assetTurnover  \
# 0            1.5648            10.8869              3.3358         0.5157
# 1               NaN                NaN             12.1004         1.3645
# 2            4.9593            18.2227              5.8234         3.3597
# 3            4.9289             8.3030             13.0415         3.6756
# 4            2.8234            11.5363              4.5434         0.7738
#
#    currentRatio  quickRatio  cashRatio  daysOfSalesOutstanding  \
# 0        0.9370      0.5062     0.2538                -63.2087
# 1        0.2102      0.8500     0.4718                -75.3670
# 2        0.8250      0.1417     0.0375                -26.3971
# 3        1.7090      0.4369     0.0584                -60.0346
# 4        0.8100      0.4335     0.1599                -49.3233
#
#    daysOfInventoryOutstanding  operatingCycle  daysOfPayablesOutstanding  \
# 0                     31.3287             NaN                    41.5084
# 1                      1.1431             NaN                    97.7945
# 2                      4.1407             NaN                    18.1099
# 3                     13.5706             NaN                    18.4802
# 4                     30.2360             NaN                    32.8385
#
#    cashConversionCycle  debtRatio  debtEquityRatio  \
# 0                  NaN     0.2455           0.5061
# 1                  NaN     0.2274           1.5093
# 2                  NaN     0.3863           2.1007
# 3                  NaN     0.8290          -2.7237
# 4                  NaN     0.3796           1.3445
#
#    longtermDebtToCapitalization  totalDebtToCapitalization  interestCoverage  \
# 0                        0.2206                     0.3360           21.4429
# 1                        0.6015                     0.6015           15.4363
# 2                        0.6419                     0.6775            6.1242
# 3                        1.5881                     1.5801            1.5893
# 4                        0.4957                     0.5735            9.9540
#
#    cashFlowToDebtRatio  companyEquityMultiplier  operatingCashFlowPerShare  \
# 0               0.3941                   2.0616                     5.1582
# 1               0.8463                   6.6367                    35.6714
# 2               0.3159                   5.4385                     3.4757
# 3               0.1219                      NaN                    14.5272
# 4               0.2892                   3.5419                     4.1351
#
#    freeCashFlowPerShare  cashPerShare  payoutRatio  \
# 0                3.9640        3.1626       0.5840
# 1               22.9760       52.3827       0.0000
# 2                0.8370        0.3901       0.2090
# 3                0.5570        3.0295       0.0000
# 4                3.6240        1.4114       0.5340
#
#    operatingCashFlowSalesRatio  freeCashFlowOperatingCashFlowRatio  \
# 0                       0.1876                              0.7243
# 1                       0.1411                              0.4994
# 2                       0.0363                              0.3479
# 3                       0.0275                              0.5244
# 4                       0.1419                              0.7415
#
#    cashFlowCoverageRatios  shortTermCoverageRatios  \
# 0                  0.3941                   0.8944
# 1                  0.8463                      NaN
# 2                  0.3159                   2.1563
# 3                  0.1219                  14.2768
# 4                  0.2892                   1.0756
#
#    capitalExpenditureCoverageRatios  dividendpaidAndCapexCoverageRatios  \
# 0                            3.6273                              1.2973
# 1                            1.9975                              1.9975
# 2                            1.5335                              1.3488
# 3                            2.1028                              2.1028
# 4                            3.8682                              1.5492
#
#    dividendPayoutRatio  Revenue per Share  Net Income per Share  \
# 0               0.5936            27.4952                4.3027
# 1              -0.0000           252.8778                9.1980
# 2               0.2100            95.6955                1.4776
# 3              -0.0000           528.2098                5.1610
# 4               0.5390            29.1454                2.9690
#
#    Operating Cash Flow per Share  Free Cash Flow per Share  Cash per Share  \
# 0                         5.1582                    3.9640          3.1626
# 1                        35.6714                   22.9760         52.3827
# 2                         3.4757                    0.8370          0.3901
# 3                        14.5272                    0.5570          3.0295
# 4                         4.1351                    3.6240          1.4114
#
#    Book Value per Share  Tangible Book Value per Share  \
# 0               25.8600                        22.0690
# 1                0.7278                         4.4939
# 2                5.2370                        25.7240
# 3              -43.7380                       134.7850
# 4               10.6340                        15.4290
#
#    Shareholders Equity per Share  Interest Debt per Share        Market Cap  \
# 0                        25.8600                  13.0885 212661418090.8400
# 1                        27.9248                  42.1474   6253200000.0000
# 2                         5.2374                  11.0019  18274698937.2800
# 3                       -43.7381                 119.1307   6359738316.4000
# 4                        10.6345                  14.2977  33330057253.4400
#
#    Enterprise Value  PE ratio  Price to Sales Ratio  POCF ratio  PFCF ratio  \
# 0 237392418090.8400   18.7566                2.8583     15.2358     21.0348
# 1               NaN   81.5526                0.0443         NaN      1.3589
# 2  29183698937.2800   12.0340                0.1858      5.1147     14.6302
# 3  11970475316.4000   28.6087                0.2491      9.0589     17.2736
# 4  41248557253.4400   18.7034                1.8610     13.1169     17.6902
#
#    PB ratio  PTB ratio  EV to Sales  Enterprise Value over EBITDA  \
# 0    3.0391     0.0000       3.1907                       12.9411
# 1       NaN        NaN          NaN                           NaN
# 2    3.3579     7.0982       0.2967                        6.6086
# 3    0.0000     0.0000       0.4689                       11.0987
# 4    5.1004     0.0000       2.3032                       11.4723
#
#    EV to Operating cash flow  EV to Free cash flow  Earnings Yield  \
# 0                    17.0076               23.4810          0.0533
# 1                        NaN                   NaN          0.0123
# 2                     8.1678               23.4784          0.0831
# 3                    17.0508               32.5129          0.0350
# 4                    16.2332               21.8930          0.0535
#
#    Free Cash Flow Yield  Debt to Equity  Debt to Assets  Net Debt to EBITDA  \
# 0                0.0475          0.5061          0.2455              1.3482
# 1                   NaN          1.5093          0.2274                 NaN
# 2                0.0680          2.1007          0.3863              2.4703
# 3                0.0579         -2.7237          0.8290              5.2021
# 4                0.0565          1.3445          0.3796              2.2023
#
#    Current ratio  Interest Coverage  Income Quality  Dividend Yield  \
# 0         0.9370            21.4429          1.1988          0.0311
# 1         0.2102            15.4363          3.8782          0.0000
# 2         0.8250             6.1242          2.3522          0.0174
# 3         1.7090             1.5893          3.2590          0.0000
# 4         0.8100             9.9540          1.3928          0.0286
#
#    Payout Ratio  SG&A to Revenue  R&D to Revenue  Intangibles to Total Assets  \
# 0        0.5840           0.2885          0.0000                       0.5860
# 1        0.0000           0.0922          0.0290                       0.0697
# 2        0.2090           0.1545          0.0000                       0.0969
# 3        0.0000           0.2570          0.0000                       0.0621
# 4        0.5340           0.1940          0.0000                       0.5904
#
#    Capex to Operating Cash Flow  Capex to Revenue  Capex to Depreciation  \
# 0                        0.2757            0.0517                -1.2251
# 1                        0.5006            0.0706                -4.5345
# 2                        0.6521            0.0237                -1.3682
# 3                        0.4756            0.0131                -0.8269
# 4                        0.2585            0.0367                -1.1221
#
#    Stock-based compensation to Revenue  Graham Number   ROIC  \
# 0                               0.0048        49.3756 0.0753
# 1                               0.0097            NaN 0.0000
# 2                               0.0011        13.2000 0.0859
# 3                              -0.0004         0.0000 0.1062
# 4                               0.0022        26.3414 0.1041
#
#    Return on Tangible Assets  Graham Net-Net  Working Capital  \
# 0                     0.5765         -0.2007 -2109000000.0000
# 1                     0.0403          0.0534  3065163000.0000
# 2                     0.1011         -0.8239 -1875000000.0000
# 3                     0.0668         -0.7506  1777673000.0000
# 4                     0.6265         -0.3229 -1030000000.0000
#
#    Tangible Asset Value  Net Current Asset Value  Invested Capital  \
# 0      59719000000.0000        -42673000000.0000  52852000000.0000
# 1       2546028576.0413          -166696641.9115    755350984.8240
# 2      26444000000.0000        -15056000000.0000  26648000000.0000
# 3       6513644000.0000         -4773448000.0000   9616929000.0000
# 4       9480900000.0000        -10762700000.0000  11975900000.0000
#
#    Average Receivables  Average Payables  Average Inventory  \
# 0      6447000000.0000   8619000000.0000    6834000000.0000
# 1                  NaN               NaN                NaN
# 2      1083500000.0000   4682500000.0000    5398500000.0000
# 3       939269000.0000   1338531500.0000    3074345000.0000
# 4      1465000000.0000   1517250000.0000    1552450000.0000
#
#    Days Sales Outstanding  Days Payables Outstanding  \
# 0                 31.3287                    41.5084
# 1                  1.1431                    97.7945
# 2                  4.1407                    18.1099
# 3                 13.5706                    18.4802
# 4                 30.2360                    32.8385
#
#    Days of Inventory on Hand  Receivables Turnover  Payables Turnover  \
# 0                   -63.2087               11.5404             1.5648
# 1                   -75.3670                   NaN                NaN
# 2                   -26.3971               90.7937             4.9593
# 3                   -60.0346               27.1769             4.9289
# 4                   -49.3233               12.2250             2.8234
#
#    Inventory Turnover     ROE  Capex per Share  Gross Profit Growth  \
# 0             10.8869  0.1664          -1.4220              -0.1185
# 1                 NaN  0.3294         -17.8582               1.2489
# 2             18.2227  0.2821          -2.2665               0.0173
# 3              8.3030 -0.1180          -6.9087               0.0007
# 4             11.5363  0.2792          -1.0690              -0.0084
#
#    EBIT Growth  Operating Income Growth  Net Income Growth  EPS Growth  \
# 0      -0.0001                   0.0067             0.0293      0.0371
# 1       1.6142                   1.9463             1.5649      1.4625
# 2      -0.0145                  -0.0141             0.0147      0.0576
# 3       0.2904                   0.1113             1.0043      0.9167
# 4       0.0332                   0.0370            -0.0166      0.0140
#
#    EPS Diluted Growth  Weighted Average Shares Growth  \
# 0              0.0389                         -0.0127
# 1              1.4646                          0.0184
# 2              0.0469                         -0.0356
# 3              0.9167                          0.0694
# 4              0.0143                         -0.0468
#
#    Weighted Average Shares Diluted Growth  Dividends per Share Growth  \
# 0                                     NaN                      0.0699
# 1                                  0.0195                      0.0000
# 2                                 -0.0317                      0.2429
# 3                                     NaN                      0.0000
# 4                                     NaN                      0.1742
#
#    Operating Cash Flow growth  Free Cash Flow growth  \
# 0                     -0.0615                -0.0695
# 1                      0.2134                -0.3626
# 2                      0.2095                 0.3935
# 3                     -0.1434                -0.2691
# 4                     -0.1316                -0.1936
#
#    10Y Revenue Growth (per Share)  5Y Revenue Growth (per Share)  \
# 0                          0.0323                         0.0088
# 1                             NaN                            NaN
# 2                          0.1027                         0.1038
# 3                         -0.0195                        -0.0290
# 4                          0.0704                         0.0567
#
#    3Y Revenue Growth (per Share)  10Y Operating CF Growth (per Share)  \
# 0                        -0.0182                               0.0355
# 1                            NaN                                  NaN
# 2                         0.1399                               0.0889
# 3                        -0.0230                               0.0513
# 4                         0.0773                               0.0782
#
#    5Y Operating CF Growth (per Share)  3Y Operating CF Growth (per Share)  \
# 0                              0.0015                              0.0260
# 1                                 NaN                                 NaN
# 2                              0.0937                              0.0946
# 3                              0.1164                              0.1777
# 4                              0.0828                              0.1991
#
#    10Y Net Income Growth (per Share)  5Y Net Income Growth (per Share)  \
# 0                             0.0603                           -0.0137
# 1                                NaN                               NaN
# 2                             0.2272                            0.0906
# 3                             0.0480                            0.0000
# 4                             0.0776                            0.0841
#
#    3Y Net Income Growth (per Share)  \
# 0                            0.0060
# 1                               NaN
# 2                            0.1892
# 3                            0.0000
# 4                            0.0177
#
#    10Y Shareholders Equity Growth (per Share)  \
# 0                                      0.1442
# 1                                         NaN
# 2                                      0.0676
# 3                                      0.0000
# 4                                      0.0427
#
#    5Y Shareholders Equity Growth (per Share)  \
# 0                                     0.0353
# 1                                        NaN
# 2                                     0.0558
# 3                                     0.0000
# 4                                     0.0623
#
#    3Y Shareholders Equity Growth (per Share)  \
# 0                                     0.0201
# 1                                        NaN
# 2                                     0.0789
# 3                                     0.0000
# 4                                     0.0217
#
#    10Y Dividend per Share Growth (per Share)  \
# 0                                     0.1013
# 1                                        NaN
# 2                                     0.0000
# 3                                     0.0000
# 4                                     0.1092
#
#    5Y Dividend per Share Growth (per Share)  \
# 0                                    0.0834
# 1                                       NaN
# 2                                    0.1215
# 3                                    0.0000
# 4                                    0.1250
#
#    3Y Dividend per Share Growth (per Share)  Receivables growth  \
# 0                                    0.0751             -0.0187
# 1                                       NaN                 NaN
# 2                                    0.1633              0.0618
# 3                                    0.0000              0.0211
# 4                                    0.1144              0.0257
#
#    Inventory Growth  Asset Growth  Book Value per Share Growth  Debt Growth  \
# 0           -0.0217        0.0359                       0.0316       0.1228
# 1               NaN           NaN                          NaN          NaN
# 2            0.0981        0.1886                       0.3268       0.2738
# 3           -0.0510       -0.0189                       0.1963      -0.0458
# 4            0.0090        0.0215                       0.0274       0.1025
#
#    R&D Expense Growth  SG&A Expenses Growth              Sector  \
# 0              0.0000               -0.1746  Consumer Defensive
# 1              1.6484                1.7313  Consumer Defensive
# 2              0.0000                0.0234  Consumer Defensive
# 3              0.0000               -0.0060  Consumer Defensive
# 4              0.0000               -0.0220  Consumer Defensive
#
#    price_var_next_yr_%  Class
# 0              -9.3233      0
# 1             -25.5122      0
# 2              33.1183      1
# 3               2.7523      1
# 4              12.8977      1

# %%
# Rename the first column as 'ticker'
df2014.rename(columns={'Unnamed: 0': 'Ticker'}, inplace=True)
df2015.rename(columns={'Unnamed: 0': 'Ticker'}, inplace=True)
df2016.rename(columns={'Unnamed: 0': 'Ticker'}, inplace=True)
df2017.rename(columns={'Unnamed: 0': 'Ticker'}, inplace=True)
df2018.rename(columns={'Unnamed: 0': 'Ticker'}, inplace=True)

df2014.head()
# Out:
#   Ticker          Revenue  Revenue Growth  Cost of Revenue     Gross Profit  \
# 0     PG 74401000000.0000         -0.0713 39030000000.0000 35371000000.0000
# 1   VIPS  3734148046.4966          1.1737  2805625443.9780   928522602.5186
# 2     KR 98375000000.0000          0.0182 78138000000.0000 20237000000.0000
# 3    RAD 25526413000.0000          0.0053 18202679000.0000  7323734000.0000
# 4    GIS 17909600000.0000          0.0076 11539800000.0000  6369800000.0000
#
#     R&D Expenses     SG&A Expense  Operating Expenses  Operating Income  \
# 0         0.0000 21461000000.0000    21461000000.0000  13910000000.0000
# 1 108330319.6642   344141427.1876      793926703.2612    134595899.2573
# 2         0.0000 15196000000.0000    17512000000.0000   2725000000.0000
# 3         0.0000  6561162000.0000     6586482000.0000    737252000.0000
# 4         0.0000  3474300000.0000     3412400000.0000   2957400000.0000
# 3                   41155000.0000      -364924000.0000
# 4                   29300000.0000      -561800000.0000
#
#    Issuance (repayment) of debt  Issuance (buybacks) of shares  \
# 0               3543000000.0000               -3911000000.0000
# 1                619326767.8398                   1767839.8450
# 2               2093000000.0000                -413000000.0000
# 3               -295435000.0000                  33217000.0000
# 4                801100000.0000               -1637200000.0000
#
#    Dividend payments  Financing Cash Flow  Effect of forex changes on cash  \
# 0   -6911000000.0000     -7279000000.0000                    39000000.0000
# 1             0.0000       621913626.0898                   -15648692.2829
# 2    -319000000.0000      1361000000.0000                           0.0000
# 3             0.0000      -320168000.0000                           0.0000
# 4    -983300000.0000     -1824100000.0000                   -29200000.0000
#
#    Net cash flow / Change in cash   Free Cash Flow  Net Cash/Marketcap  \
# 0                 2618000000.0000 10110000000.0000             -0.1163
# 1                  446316919.5996   263041007.4265              0.0956
# 2                  163000000.0000  1243000000.0000             -0.5969
# 3                   16954000.0000   368176000.0000             -0.8822
# 4                  125900000.0000  1884100000.0000             -0.2376
#
#    priceBookValueRatio  priceToBookRatio  priceToSalesRatio  \
# 0               3.0391            0.0000             2.8583
# 1                  NaN               NaN             0.0443
# 2               3.3579            7.0982             0.1858
# 3               0.0000            0.0000             0.2491
# 4               5.1004            0.0000             1.8610
#
#    priceEarningsRatio  priceToFreeCashFlowsRatio  \
# 0             18.7566                    21.0348
# 1             81.5526                     1.3589
# 2             12.0340                    14.6302
# 3             28.6087                    17.2736
# 4             18.7034                    17.6902
#
#    priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# 0                         15.2358             12.9775
# 1                             NaN              0.6786
# 2                          5.1147              0.0000
# 3                          9.0589              0.0000
# 4                         13.1169             10.9524
#
#    priceEarningsToGrowthRatio  priceSalesRatio  dividendYield  \
# 0                     15.5578           2.4346         0.0382
# 1                      2.6318           0.0957        -0.0000
# 2                      0.0000           0.0000            NaN
# 3                      0.0000           0.0000            NaN
# 4                     15.2543           1.5539         0.0353
#
#    enterpriseValueMultiple  priceFairValue  ebitperRevenue  ebtperEBIT  \
# 0                  11.4211          2.5886          0.2043      0.9534
# 1                   7.1365          0.8669          0.0502      0.9352
# 2                   2.2767          0.0000          0.0276      0.8367
# 3                   5.4280             NaN          0.0264      0.3708
# 4                   9.7680          4.2587          0.1681      0.8995
#
#    niperEBT  grossProfitMargin  operatingProfitMargin  pretaxProfitMargin  \
# 0    0.8033             0.4754                 1.0000              0.1870
# 1    0.7744             0.2487                 1.0000              0.0360
# 2    0.6692             0.2057                 1.0000              0.0277
# 3    0.9968             0.2869                 1.0000              0.0289
# 4    0.6738             0.3557                 1.0000              0.1651
#
#    netProfitMargin  effectiveTaxRate  returnOnAssets  returnOnEquity  \
# 0           0.1565            0.1967          0.5765          0.1664
# 1           0.0364            0.2256          0.0403          0.3294
# 2           0.0154            0.3308          0.1011          0.2821
# 3           0.0098            0.0032          0.0668         -0.1180
# 4           0.1019            0.3262          0.6265          0.2792
#
#    returnOnCapitalEmployed  nIperEBT  eBTperEBIT  eBITperRevenue  \
# 0                   0.0753    0.8033      0.9534          0.2043
# 1                   0.0000    0.7744      0.9352          0.0502
# 2                   0.0859    0.6692      0.8367          0.0276
# 3                   0.1062    0.9968      0.3708          0.0264
# 4                   0.1041    0.6738      0.8995          0.1681
#
#    payablesTurnover  inventoryTurnover  fixedAssetTurnover  assetTurnover  \
# 0            1.5648            10.8869              3.3358         0.5157
# 1               NaN                NaN             12.1004         1.3645
# 2            4.9593            18.2227              5.8234         3.3597
# 3            4.9289             8.3030             13.0415         3.6756
# 4            2.8234            11.5363              4.5434         0.7738
#
#    currentRatio  quickRatio  cashRatio  daysOfSalesOutstanding  \
# 0        0.9370      0.5062     0.2538                -63.2087
# 1        0.2102      0.8500     0.4718                -75.3670
# 2        0.8250      0.1417     0.0375                -26.3971
# 3        1.7090      0.4369     0.0584                -60.0346
# 4        0.8100      0.4335     0.1599                -49.3233
#
#    daysOfInventoryOutstanding  operatingCycle  daysOfPayablesOutstanding  \
# 0                     31.3287             NaN                    41.5084
# 1                      1.1431             NaN                    97.7945
# 2                      4.1407             NaN                    18.1099
# 3                     13.5706             NaN                    18.4802
# 4                     30.2360             NaN                    32.8385
#
#    cashConversionCycle  debtRatio  debtEquityRatio  \
# 0                  NaN     0.2455           0.5061
# 1                  NaN     0.2274           1.5093
# 2                  NaN     0.3863           2.1007
# 3                  NaN     0.8290          -2.7237
# 4                  NaN     0.3796           1.3445
#
#    longtermDebtToCapitalization  totalDebtToCapitalization  interestCoverage  \
# 0                        0.2206                     0.3360           21.4429
# 1                        0.6015                     0.6015           15.4363
# 2                        0.6419                     0.6775            6.1242
# 3                        1.5881                     1.5801            1.5893
# 4                        0.4957                     0.5735            9.9540
#
#    cashFlowToDebtRatio  companyEquityMultiplier  operatingCashFlowPerShare  \
# 0               0.3941                   2.0616                     5.1582
# 1               0.8463                   6.6367                    35.6714
# 2               0.3159                   5.4385                     3.4757
# 3               0.1219                      NaN                    14.5272
# 4               0.2892                   3.5419                     4.1351
#
#    freeCashFlowPerShare  cashPerShare  payoutRatio  \
# 0                3.9640        3.1626       0.5840
# 1               22.9760       52.3827       0.0000
# 2                0.8370        0.3901       0.2090
# 3                0.5570        3.0295       0.0000
# 4                3.6240        1.4114       0.5340
#
#    operatingCashFlowSalesRatio  freeCashFlowOperatingCashFlowRatio  \
# 0                       0.1876                              0.7243
# 1                       0.1411                              0.4994
# 2                       0.0363                              0.3479
# 3                       0.0275                              0.5244
# 4                       0.1419                              0.7415
#
#    cashFlowCoverageRatios  shortTermCoverageRatios  \
# 0                  0.3941                   0.8944
# 1                  0.8463                      NaN
# 2                  0.3159                   2.1563
# 3                  0.1219                  14.2768
# 4                  0.2892                   1.0756
#
#    capitalExpenditureCoverageRatios  dividendpaidAndCapexCoverageRatios  \
# 0                            3.6273                              1.2973
# 1                            1.9975                              1.9975
# 2                            1.5335                              1.3488
# 3                            2.1028                              2.1028
# 4                            3.8682                              1.5492
#
#    dividendPayoutRatio  Revenue per Share  Net Income per Share  \
# 0               0.5936            27.4952                4.3027
# 1              -0.0000           252.8778                9.1980
# 2               0.2100            95.6955                1.4776
# 3              -0.0000           528.2098                5.1610
# 4               0.5390            29.1454                2.9690
#
#    Operating Cash Flow per Share  Free Cash Flow per Share  Cash per Share  \
# 0                         5.1582                    3.9640          3.1626
# 1                        35.6714                   22.9760         52.3827
# 2                         3.4757                    0.8370          0.3901
# 3                        14.5272                    0.5570          3.0295
# 4                         4.1351                    3.6240          1.4114
#
#    Book Value per Share  Tangible Book Value per Share  \
# 0               25.8600                        22.0690
# 1                0.7278                         4.4939
# 2                5.2370                        25.7240
# 3              -43.7380                       134.7850
# 4               10.6340                        15.4290
#
#    Shareholders Equity per Share  Interest Debt per Share        Market Cap  \
# 0                        25.8600                  13.0885 212661418090.8400
# 1                        27.9248                  42.1474   6253200000.0000
# 2                         5.2374                  11.0019  18274698937.2800
# 3                       -43.7381                 119.1307   6359738316.4000
# 4                        10.6345                  14.2977  33330057253.4400
#
#    Enterprise Value  PE ratio  Price to Sales Ratio  POCF ratio
standing  \
# 0                 31.3287                    41.5084
# 1                  1.1431                    97.7945
# 2                  4.1407                    18.1099
# 3                 13.5706                    18.4802
# 4                 30.2360                    32.8385
#
#    Days of Inventory on Hand  Receivables Turnover  Payables Turnover  \
# 0                   -63.2087               11.5404             1.5648
# 1                   -75.3670                   NaN                NaN
# 2                   -26.3971               90.7937             4.9593
# 3                   -60.0346               27.1769             4.9289
# 4                   -49.3233               12.2250             2.8234
#
#    Inventory Turnover     ROE  Capex per Share  Gross Profit Growth  \
# 0             10.8869  0.1664          -1.4220              -0.1185
# 1                 NaN  0.3294         -17.8582               1.2489
# 2             18.2227  0.2821          -2.2665               0.0173
# 3              8.3030 -0.1180          -6.9087               0.0007
# 4             11.5363  0.2792          -1.0690              -0.0084
#
#    EBIT Growth  Operating Income Growth  Net Income Growth  EPS Growth  \
# 0      -0.0001                   0.0067             0.0293      0.0371
# 1       1.6142                   1.9463             1.5649      1.4625
# 2      -0.0145                  -0.0141             0.0147      0.0576
# 3       0.2904                   0.1113             1.0043      0.9167
# 4       0.0332                   0.0370            -0.0166      0.0140
#
#    EPS Diluted Growth  Weighted Average Shares Growth  \
# 0              0.0389                         -0.0127
# 1              1.4646                          0.0184
# 2              0.0469                         -0.0356
# 3              0.9167                          0.0694
# 4              0.0143                         -0.0468
#
#    Weighted Average Shares Diluted Growth  Dividends per Share Growth  \
# 0                                     NaN                      0.0699
# 1                                  0.0195                      0.0000
# 2                                 -0.0317                      0.2429
# 3                                     NaN                      0.0000
# 4                                     NaN                      0.1742
#
#    Operating Cash Flow growth  Free Cash Flow growth  \
# 0                     -0.0615                -0.0695
# 1                      0.2134                -0.3626
# 2                      0.2095                 0.3935
# 3                     -0.1434                -0.2691
# 4                     -0.1316                -0.1936
#
#    10Y Revenue Growth (per Share)  5Y Revenue Growth (per Share)  \
# 0                          0.0323                         0.0088
# 1                             NaN                            NaN
# 2                          0.1027                         0.1038
# 3                         -0.0195                        -0.0290
# 4                          0.0704                         0.0567
#
#    3Y Revenue Growth (per Share)  10Y Operating CF Growth (per Share)  \
# 0                        -0.0182                               0.0355
# 1                            NaN                                  NaN
# 2                         0.1399                               0.0889
# 3                        -0.0230                               0.0513
# 4                         0.0773                               0.0782
#
#    5Y Operating CF Growth (per Share)  3Y Operating CF Growth (per Share)  \
# 0                              0.0015                              0.0260
# 1                                 NaN                                 NaN
# 2                              0.0937                              0.0946
# 3                              0.1164                              0.1777
# 4                              0.0828                              0.1991
#
#    10Y Net Income Growth (per Share)  5Y Net Income Growth (per Share)  \
# 0                             0.0603                           -0.0137
# 1                                NaN                               NaN
# 2                             0.2272                            0.0906
# 3                             0.0480                            0.0000
# 4                             0.0776                            0.0841
#
#    3Y Net Income Growth (per Share)  \
# 0                            0.0060
# 1                               NaN
# 2                            0.1892
# 3                            0.0000
# 4                            0.0177
#
#    10Y Shareholders Equity Growth (per Share)  \
# 0                                      0.1442
# 1                                         NaN
# 2                                      0.0676
# 3                                      0.0000
# 4                                      0.0427
#
#    5Y Shareholders Equity Growth (per Share)  \
# 0                                     0.0353
# 1                                        NaN
# 2                                     0.0558
# 3                                     0.0000
# 4                                     0.0623
#
#    3Y Shareholders Equity Growth (per Share)  \
# 0                                     0.0201
# 1                                        NaN
# 2                                     0.0789
# 3                                     0.0000
# 4                                     0.0217
#
#    10Y Dividend per Share Growth (per Share)  \
# 0                                     0.1013
# 1                                        NaN
# 2                                     0.0000
# 3                                     0.0000
# 4                                     0.1092
#
#    5Y Dividend per Share Growth (per Share)  \
# 0                                    0.0834
# 1                                       NaN
# 2                                    0.1215
# 3                                    0.0000
# 4                                    0.1250
#
#    3Y Dividend per Share Growth (per Share)  Receivables growth  \
# 0                                    0.0751             -0.0187
# 1                                       NaN                 NaN
# 2                                    0.1633              0.0618
# 3                                    0.0000              0.0211
# 4                                    0.1144              0.0257
#
#    Inventory Growth  Asset Growth  Book Value per Share Growth  Debt Growth  \
# 0           -0.0217        0.0359                       0.0316       0.1228
# 1               NaN           NaN                          NaN          NaN
# 2            0.0981        0.1886                       0.3268       0.2738
# 3           -0.0510       -0.0189                       0.1963      -0.0458
# 4            0.0090        0.0215                       0.0274       0.1025
#
#    R&D Expense Growth  SG&A Expenses Growth              Sector  \
# 0              0.0000               -0.1746  Consumer Defensive
# 1              1.6484                1.7313  Consumer Defensive
# 2              0.0000                0.0234  Consumer Defensive
# 3              0.0000               -0.0060  Consumer Defensive
# 4              0.0000               -0.0220  Consumer Defensive
#
#    price_var_next_yr_%  Class
# 0              -9.3233      0
# 1             -25.5122      0
# 2              33.1183      1
# 3               2.7523      1
# 4              12.8977      1

# %% [markdown]
# ### Concatenating Annual Financial Dataframes

# %% [markdown]
# We now continue pre-processing by combining annual financial dataframes into one and adding year as a new predictor.

# %%
# Add a new column indicating year
df2014.insert(0, 'Year', '2014')
df2015.insert(0, 'Year', '2015')
df2016.insert(0, 'Year', '2016')
df2017.insert(0, 'Year', '2017')
df2018.insert(0, 'Year', '2018')

df2014.head()
# Out:
#    Year Ticker          Revenue  Revenue Growth  Cost of Revenue  \
# 0  2014     PG 74401000000.0000         -0.0713 39030000000.0000
# 1  2014   VIPS  3734148046.4966          1.1737  2805625443.9780
# 2  2014     KR 98375000000.0000          0.0182 78138000000.0000
# 3  2014    RAD 25526413000.0000          0.0053 18202679000.0000
# 4  2014    GIS 17909600000.0000          0.0076 11539800000.0000
#
#       Gross Profit   R&D Expenses     SG&A Expense  Operating Expenses  \
# 0 35371000000.0000         0.0000 21461000000.0000    21461000000.0000
# 1   928522602.5186 108330319.6642   344141427.1876      793926703.2612
# 2 20237000000.0000         0.0000 15196000000.0000    17512000000.0000
# 3  7323734000.0000         0.0000  6561162000.0000     6586482000.0000
# 4  6369800000.0000         0.0000  3474300000.0000     3412400000.0000
#
#    Operating Income  Interest Expense  Earnings before Tax  \
# 0  13910000000.0000    709000000.0000     14494000000.0000
# 1    134595899.2573     12148692.2829       175382305.4569
# 2   2725000000.0000    443000000.0000      2270000000.0000
# 3    737252000.0000    424591000.0000       250218000.0000
# 4   2957400000.0000    302400000.0000      2707700000.0000
#
#    Income Tax Expense  Net Income - Non-Controlling int  \
# 0     2851000000.0000                    142000000.0000
# 1       39559573.7811                    -14319179.8515
# 2      751000000.0000                     12000000.0000
# 3         804000.0000                            0.0000
# 4      883300000.0000                     36900000.0000
#
#    Net Income - Discontinued ops       Net Income  Preferred Dividends  \
# 0               -1127000000.0000 11643000000.0000               0.0000
# 1                         0.0000   135822731.6758               0.0000
# 2                         0.0000  1519000000.0000               0.0000
# 3                         0.0000   249414000.0000        33998000.0000
# 4                         0.0000  1824400000.0000               0.0000
#
#     Net Income Com    EPS  EPS Diluted  Weighted Average Shs Out  \
# 0 11643000000.0000 4.1900       4.0100           2705960276.0000
# 1   135822731.6758 0.2396       0.2260                       NaN
# 2  1519000000.0000 1.4700       1.4500           1033052512.0000
# 3   215416000.0000 4.6000       4.6000             48326279.0000
# 4  1824400000.0000 2.9000       2.8300            614492206.0000
#
#
#    priceEarningsRatio  priceToFreeCashFlowsRatio  \
# 0             18.7566                    21.0348
# 1             81.5526                     1.3589
# 2             12.0340                    14.6302
# 3             28.6087                    17.2736
# 4             18.7034                    17.6902
#
#    priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# 0                         15.2358             12.9775
# 1                             NaN              0.6786
# 2                          5.1147              0.0000
# 3                          9.0589              0.0000
# 4                         13.1169             10.9524
#
#    priceEarningsToGrowthRatio  priceSalesRatio  dividendYield  \
# 0                     15.5578           2.4346         0.0382
# 1                      2.6318           0.0957        -0.0000
# 2                      0.0000           0.0000            NaN
# 3                      0.0000           0.0000            NaN
# 4                     15.2543           1.5539         0.0353
#
#    enterpriseValueMultiple  priceFairValue  ebitperRevenue  ebtperEBIT  \
# 0                  11.4211          2.5886          0.2043      0.9534
# 1                   7.1365          0.8669          0.0502      0.9352
# 2                   2.2767          0.0000          0.0276      0.8367
# 3                   5.4280             NaN          0.0264      0.3708
# 4                   9.7680          4.2587          0.1681      0.8995
#
#    niperEBT  grossProfitMargin  operatingProfitMargin  pretaxProfitMargin  \
# 0    0.8033             0.4754                 1.0000              0.1870
# 1    0.7744             0.2487                 1.0000              0.0360
# 2    0.6692             0.2057                 1.0000              0.0277
# 3    0.9968             0.2869                 1.0000              0.0289
# 4    0.6738             0.3557                 1.0000              0.1651
#
#    netProfitMargin  effectiveTaxRate  returnOnAssets  returnOnEquity  \
# 0           0.1565            0.1967          0.5765          0.1664
# 1           0.0364            0.2256          0.0403          0.3294
# 2           0.0154            0.3308          0.1011          0.2821
# 3           0.0098            0.0032          0.0668         -0.1180
# 4           0.1019            0.3262          0.6265          0.2792
#
#    returnOnCapitalEmployed  nIperEBT  eBTperEBIT  eBITperRevenue  \
# 0                   0.0753    0.8033      0.9534          0.2043
# 1                   0.0000    0.7744      0.9352          0.0502
# 2                   0.0859    0.6692      0.8367          0.0276
# 3                   0.1062    0.9968      0.3708          0.0264
# 4                   0.1041    0.6738      0.8995          0.1681
#
#    payablesTurnover  inventoryTurnover  fixedAssetTurnover  assetTurnover  \
# 0            1.5648            10.8869              3.3358         0.5157
# 1               NaN                NaN             12.1004         1.3645
# 2            4.9593            18.2227              5.8234         3.3597
# 3            4.9289             8.3030             13.0415         3.6756
# 4            2.8234            11.5363              4.5434         0.7738
#
#    currentRatio  quickRatio  cashRatio  daysOfSalesOutstanding  \
# 0        0.9370      0.5062     0.2538                -63.2087
# 1        0.2102      0.8500     0.4718                -75.3670
# 2        0.8250      0.1417     0.0375                -26.3971
# 3        1.7090      0.4369     0.0584                -60.0346
# 4        0.8100      0.4335     0.1599                -49.3233
#
#    daysOfInventoryOutstanding  operatingCycle  daysOfPayablesOutstanding  \
# 0                     31.3287             NaN                    41.5084
# 1                      1.1431             NaN                    97.7945
# 2                      4.1407             NaN                    18.1099
# 3                     13.5706             NaN                    18.4802
# 4                     30.2360             NaN                    32.8385
#
#    cashConversionCycle  debtRatio  debtEquityRatio  \
# 0                  NaN     0.2455           0.5061
# 1                  NaN     0.2274           1.5093
# 2                  NaN     0.3863           2.1007
# 3                  NaN     0.8290          -2.7237
# 4                  NaN     0.3796           1.3445
#
#    longtermDebtToCapitalization  totalDebtToCapitalization  interestCoverage  \
# 0                        0.2206                     0.3360           21.4429
# 1                        0.6015                     0.6015           15.4363
# 2                        0.6419                     0.6775            6.1242
# 3                        1.5881                     1.5801            1.5893
# 4                        0.4957                     0.5735            9.9540
#
#    cashFlowToDebtRatio  companyEquityMultiplier  operatingCashFlowPerShare  \
# 0               0.3941                   2.0616                     5.1582
# 1               0.8463                   6.6367                    35.6714
# 2               0.3159                   5.4385                     3.4757
# 3               0.1219                      NaN                    14.5272
# 4               0.2892                   3.5419                     4.1351
#
#    freeCashFlowPerShare  cashPerShare  payoutRatio  \
# 0                3.9640        3.1626       0.5840
# 1               22.9760       52.3827       0.0000
# 2                0.8370        0.3901       0.2090
# 3                0.5570        3.0295       0.0000
# 4                3.6240        1.4114       0.5340
#
#    operatingCashFlowSalesRatio  freeCashFlowOperatingCashFlowRatio  \
# 0                       0.1876                              0.7243
# 1                       0.1411                              0.4994
# 2                       0.0363                              0.3479
# 3                       0.0275                              0.5244
# 4                       0.1419                              0.7415
#
#    cashFlowCoverageRatios  shortTermCoverageRatios  \
# 0                  0.3941                   0.8944
# 1                  0.8463                      NaN
# 2                  0.3159                   2.1563
# 3                  0.1219                  14.2768
# 4                  0.2892                   1.0756
#
#    capitalExpenditureCoverageRatios  dividendpaidAndCapexCoverageRatios  \
# 0                            3.6273                              1.2973
# 1                            1.9975                              1.9975
# 2                            1.5335                              1.3488
# 3                            2.1028                              2.1028
# 4                            3.8682                              1.5492
#
#    dividendPayoutRatio  Revenue per Share  Net Income per Share  \
# 0               0.5936            27.4952                4.3027
# 1              -0.0000           252.8778                9.1980
# 2               0.2100            95.6955                1.4776
# 3              -0.0000           528.2098                5.1610
# 4               0.5390            29.1454                2.9690
#
#    Operating Cash Flow per Share  Free Cash Flow per Share  Cash per Share  \
# 0                         5.1582                    3.9640          3.1626
# 1                        35.6714                   22.9760         52.3827
# 2                         3.4757                    0.8370          0.3901
# 3                        14.5272                    0.5570          3.0295
# 4                         4.1351                    3.6240          1.4114
#
#    Book Value per Share  Tangible Book Value per Share  \
# 0               25.8600                        22.0690
# 1                0.7278                         4.4939
# 2                5.2370                        25.7240
# 3              -43.7380                       134.7850
# 4               10.6340                        15.4290
#
#    Shareholders Equity per Share  Interest Debt per Share        Market Cap  \
# 0                        25.8600                  13.0885 212661418090.8400
# 1                        27.9248                  42.1474   6253200000.0000
# 2                         5.2374                  11.0019  18274698937.2800
# 3                       -43.7381                 119.1307   6359738316.4000
# 4                        10.6345                  14.2977  33330057253.4400
#
#    Enterprise Value  PE ratio  Price to Sales Ratio  POCF ratio  PFCF ratio  \
# 0 237392418090.8400   18.7566                2.8583     15.2358     21.0348
# 1               NaN   81.5526                0.0443         NaN      1.3589
# 2  29183698937.2800   12.0340                0.1858      5.1147     14.6302
# 3  11970475316.4000   28.6087                0.2491      9.0589     17.2736
# 4  41248557253.4400   18.7034                1.8610     13.1169     17.6902
#
#    PB ratio  PTB ratio  EV to Sales  Enterprise Value over EBITDA  \
# 0    3.0391     0.0000       3.1907                       12.9411
# 1       NaN        NaN          NaN                           NaN
# 2    3.3579     7.0982       0.2967                        6.6086
# 3    0.0000     0.0000       0.4689                       11.0987
# 4    5.1004     0.0000       2.3032                       11.4723
#
#    EV to Operating cash flow  EV to Free cash flow  Earnings Yield  \
# 0                    17.0076               23.4810          0.0533
# 1                        NaN                   NaN          0.0123
# 2                     8.1678               23.4784          0.0831
# 3                    17.0508               32.5129          0.0350
# 4                    16.2332               21.8930          0.0535
#
#    Free Cash Flow Yield  Debt to Equity  Debt to Assets  Net Debt to EBITDA  \
# 0                0.0475          0.5061          0.2455              1.3482
# 1                   NaN          1.5093          0.2274                 NaN
# 2                0.0680          2.1007          0.3863              2.4703
# 3                0.0579         -2.7237          0.8290              5.2021
# 4                0.0565          1.3445          0.3796              2.2023
#
#    Current ratio  Interest Coverage  Income Quality  Dividend Yield  \
# 0         0.9370            21.4429          1.1988          0.0311
# 1         0.2102            15.4363          3.8782          0.0000
# 2         0.8250             6.1242          2.3522          0.0174
# 3         1.7090             1.5893          3.2590          0.0000
# 4         0.8100             9.9540          1.3928          0.0286
#
#    Payout Ratio  SG&A to Revenue  R&D to Revenue  Intangibles to Total Assets  \
# 0        0.5840           0.2885          0.0000                       0.5860
# 1        0.0000           0.0922          0.0290                       0.0697
# 2        0.2090           0.1545          0.0000                       0.0969
# 3        0.0000           0.2570          0.0000                       0.0621
# 4        0.5340           0.1940          0.0000                       0.5904
#
#    Capex to Operating Cash Flow  Capex to Revenue  Capex to Depreciation  \
# 0                        0.2757            0.0517                -1.2251
# 1                        0.5006            0.0706                -4.5345
# 2                        0.6521            0.0237                -1.3682
# 3                        0.4756            0.0131                -0.8269
# 4                        0.2585            0.0367                -1.1221
#
#    Stock-based compensation to Revenue  Graham Number   ROIC  \
# 0                               0.0048        49.3756 0.0753
# 1                               0.0097            NaN 0.0000
# 2                               0.0011        13.2000 0.0859
# 3                              -0.0004         0.0000 0.1062
# 4                               0.0022        26.3414 0.1041
#
#    Return on Tangible Assets  Graham Net-Net  Working Capital  \
# 0                     0.5765         -0.2007 -2109000000.0000
# 1                     0.0403          0.0534  3065163000.0000
# 2                     0.1011         -0.8239 -1875000000.0000
# 3                     0.0668         -0.7506  1777673000.0000
# 4                     0.6265         -0.3229 -1030000000.0000
#
#    Tangible Asset Value  Net Current Asset Value  Invested Capital  \
# 0      59719000000.0000        -42673000000.0000  52852000000.0000
# 1       2546028576.0413          -166696641.9115    755350984.8240
# 2      26444000000.0000        -15056000000.0000  26648000000.0000
# 3       6513644000.0000         -4773448000.0000   9616929000.0000
# 4       9480900000.0000        -10762700000.0000  11975900000.0000
#
#    Average Receivables  Average Payables  Average Inventory  \
# 0      6447000000.0000   8619000000.0000    6834000000.0000
# 1                  NaN               NaN                NaN
# 2      1083500000.0000   4682500000.0000    5398500000.0000
# 3       939269000.0000   1338531500.0000    3074345000.0000
# 4      1465000000.0000   1517250000.0000    1552450000.0000
#
#    Days Sales Outstanding  Days Payables Outstanding  \
# 0                 31.3287                    41.5084
# 1                  1.1431                    97.7945
# 2                  4.1407                    18.1099
# 3                 13.5706                    18.4802
# 4                 30.2360                    32.8385
#
#    Days of Inventory on Hand  Receivables Turnover  Payables Turnover  \
# 0                   -63.2087               11.5404             1.5648
# 1                   -75.3670                   NaN                NaN
# 2                   -26.3971               90.7937             4.9593
# 3                   -60.0346               27.1769             4.9289
# 4                   -49.3233               12.2250             2.8234
#
#    Inventory Turnover     ROE  Capex per Share  Gross Profit Growth  \
# 0             10.8869  0.1664          -1.4220              -0.1185
# 1                 NaN  0.3294         -17.8582               1.2489
# 2             18.2227  0.2821          -2.2665               0.0173
# 3              8.3030 -0.1180          -6.9087               0.0007
# 4             11.5363  0.2792          -1.0690              -0.0084
#
#    EBIT Growth  Operating Income Growth  Net Income Growth  EPS Growth  \
# 0      -0.0001                   0.0067             0.0293      0.0371
# 1       1.6142                   1.9463             1.5649      1.4625
# 2      -0.0145                  -0.0141             0.0147      0.0576
# 3       0.2904                   0.1113             1.0043      0.9167
# 4       0.0332                   0.0370            -0.0166      0.0140
#
#    EPS Diluted Growth  Weighted Average Shares Growth  \
# 0              0.0389                         -0.0127
# 1              1.4646                          0.0184
# 2              0.0469                         -0.0356
# 3              0.9167                          0.0694
# 4              0.0143                         -0.0468
#
#    Weighted Average Shares Diluted Growth  Dividends per Share Growth  \
# 0                                     NaN                      0.0699
# 1                                  0.0195                      0.0000
# 2                                 -0.0317                      0.2429
# 3                                     NaN                      0.0000
# 4                                     NaN                      0.1742
#
#    Operating Cash Flow growth  Free Cash Flow growth  \
# 0                     -0.0615                -0.0695
# 1                      0.2134                -0.3626
# 2                      0.2095                 0.3935
# 3                     -0.1434                -0.2691
# 4                     -0.1316                -0.1936
#
#    10Y Revenue Growth (per Share)  5Y Revenue Growth (per Share)  \
# 0                          0.0323                         0.0088
# 1                             NaN                            NaN
# 2                          0.1027                         0.1038
# 3                         -0.0195                        -0.0290
# 4                          0.0704                         0.0567
#
#    3Y Revenue Growth (per Share)  10Y Operating CF Growth (per Share)  \
# 0                        -0.0182                               0.0355
# 1                            NaN                                  NaN
# 2                         0.1399                               0.0889
# 3                        -0.0230                               0.0513
# 4                         0.0773                               0.0782
#
#    5Y Operating CF Growth (per Share)  3Y Operating CF Growth (per Share)  \
# 0                              0.0015                              0.0260
# 1                                 NaN                                 NaN
# 2                              0.0937                              0.0946
# 3                              0.1164                              0.1777
# 4                              0.0828                              0.1991
#
#    10Y Net Income Growth (per Share)  5Y Net Income Growth (per Share)  \
# 0                             0.0603                           -0.0137
# 1                                NaN                               NaN
# 2                             0.2272                            0.0906
# 3                             0.0480                            0.0000
# 4                             0.0776                            0.0841
#
#    3Y Net Income Growth (per Share)  \
# 0                            0.0060
# 1                               NaN
# 2                            0.1892
# 3                            0.0000
# 4                            0.0177
#
#    10Y Shareholders Equity Growth (per Share)  \
# 0                                      0.1442
# 1                                         NaN
# 2                                      0.0676
# 3                                      0.0000
# 4                                      0.0427
#
#    5Y Shareholders Equity Growth (per Share)  \
# 0                                     0.0353
# 1                                        NaN
# 2                                     0.0558
# 3                                     0.0000
# 4                                     0.0623
#
#    3Y Shareholders Equity Growth (per Share)  \
# 0                                     0.0201
# 1                                        NaN
# 2                                     0.0789
# 3                                     0.0000
# 4                                     0.0217
#
#    10Y Dividend per Share Growth (per Share)  \
# 0                                     0.1013
# 1                                        NaN
# 2                                     0.0000
# 3                                     0.0000
# 4                                     0.1092
#
#    5Y Dividend per Share Growth (per Share)  \
# 0                                    0.0834
# 1                                       NaN
# 2                                    0.1215
# 3                                    0.0000
# 4                                    0.1250
#
#    3Y Dividend per Share Growth (per Share)  Receivables growth  \
# 0                                    0.0751             -0.0187
# 1                                       NaN                 NaN
# 2                                    0.1633              0.0618
# 3                                    0.0000              0.0211
# 4                                    0.1144              0.0257
#
#    Inventory Growth  Asset Growth  Book Value per Share Growth  Debt Growth  \
# 0           -0.0217        0.0359                       0.0316       0.1228
# 1               NaN           NaN                          NaN          NaN
# 2            0.0981        0.1886                       0.3268       0.2738
# 3           -0.0510       -0.0189                       0.1963      -0.0458
# 4            0.0090        0.0215                       0.0274       0.1025
#
#    R&D Expense Growth  SG&A Expenses Growth              Sector  \
# 0              0.0000               -0.1746  Consumer Defensive
# 1              1.6484                1.7313  Consumer Defensive
# 2              0.0000                0.0234  Consumer Defensive
# 3              0.0000               -0.0060  Consumer Defensive
# 4              0.0000               -0.0220  Consumer Defensive
#
#    price_var_next_yr_%  Class
# 0              -9.3233      0
# 1             -25.5122      0
# 2              33.1183      1
# 3               2.7523      1
# 4              12.8977      1

# %%
# Concatenating dataframes vertically
df = pd.concat([df2014, df2015, df2016, df2017, df2018], axis=0)
df = df.reset_index(drop=True)

# %%
df.tail()
# Out:
#        Year Ticker       Revenue  Revenue Growth  Cost of Revenue  \
# 22072  2018   YRIV        0.0000          0.0000           0.0000
# 22073  2018   YTEN   556000.0000         -0.4110           0.0000
# 22074  2018   ZKIN 54884381.0000          0.2210    36593792.0000
# 22075  2018    ZOM        0.0000          0.0000           0.0000
# 22076  2018   ZYME 53019000.0000          0.0243           0.0000
# 22073              1181000.0000        -8754000.0000          -42000.0000
# 22074                    0.0000        -2234995.0000         -467138.0000
# 22075              5658959.0000       -11147528.0000         -618997.0000
# 22076             13441000.0000        24177000.0000         -803000.0000
#
#        Acquisitions and disposals  Investment purchases and sales  \
# 22072                      0.0000                          0.0000
# 22073                      0.0000                   -2746000.0000
# 22074                      0.0000                          0.0000
# 22075                      0.0000                          0.0000
# 22076                      0.0000                 -105626000.0000
#
#        Investing Cash flow  Issuance (repayment) of debt  \
# 22072            9064.0000                  6355109.0000
# 22073        -2788000.0000                        0.0000
# 22074         -710275.0000                  4192705.0000
# 22075         -618997.0000                  8282496.0000
# 22076      -109046000.0000                   -11000.0000
#
#        Issuance (buybacks) of shares  Dividend payments  Financing Cash Flow  \
# 22072                         0.0000             0.0000         6355109.0000
# 22073                    124000.0000             0.0000          118000.0000
# 22074                   -380000.0000             0.0000         -986029.0000
# 22075                   1976147.0000             0.0000        10258643.0000
# 22076                  91667000.0000             0.0000        91431000.0000
#
#        Effect of forex changes on cash  Net cash flow / Change in cash  \
# 22072                       -2295.0000                      62382.0000
# 22073                      -25000.0000                  -11449000.0000
# 22074                      335413.0000                   -3595886.0000
# 22075                           0.0000                   -1507882.0000
# 22076                     -303000.0000                    6259000.0000
#
#        Free Cash Flow  Net Cash/Marketcap  priceBookValueRatio  \
# 22072   -6290432.0000             -0.1717               3.9828
# 22073   -8796000.0000             -0.0437               1.4604
# 22074   -2702133.0000                 NaN                  NaN
# 22075  -11766525.0000              0.0166              32.3417
# 22076   23374000.0000              0.4265               2.6027
#
#        priceToBookRatio  priceToSalesRatio  priceEarningsRatio  \
# 22072            1.7686             0.0000              0.0000
# 22073            1.4604            14.9666              0.0000
# 22074               NaN             0.7619              6.1538
# 22075           32.4576             0.0000              0.0000
# 22076            2.8153             8.8510              0.0000
#
#        priceToFreeCashFlowsRatio  priceToOperatingCashFlowsRatio  \
# 22072                     0.0000                       -108.4577
# 22073                     0.0000                         -0.9506
# 22074                     0.0000                             NaN
# 22075                     0.0000                        -10.4597
# 22076                    18.2699                         19.4099
#
#        priceCashFlowRatio  priceEarningsToGrowthRatio  priceSalesRatio  \
# 22072                 NaN                         NaN              NaN
# 22073                 NaN                         NaN          14.8273
# 22074                 NaN                      6.2057           0.7935
# 22075                 NaN                         NaN              NaN
# 22076             17.6631                         NaN           8.0545
#
#        dividendYield  enterpriseValueMultiple  priceFairValue  ebitperRevenue  \
# 22072        -0.0000                      NaN          3.9833             NaN
# 22073        -0.0000                      NaN          1.4468        -16.4928
# 22074        -0.0000                   5.0913          1.1758          0.1759
# 22075        -0.0000                      NaN         31.4278             NaN
# 22076        -0.0000                      NaN          2.3660         -0.6454
#
#        ebtperEBIT  niperEBT  grossProfitMargin  operatingProfitMargin  \
# 22072         NaN       NaN                NaN                    NaN
# 22073         NaN       NaN             1.0000                 1.0000
# 22074      0.8717    0.8339             0.3333                 1.0000
# 22075         NaN       NaN                NaN                    NaN
# 22076         NaN       NaN             1.0000                 1.0000
#
#        pretaxProfitMargin  netProfitMargin  effectiveTaxRate  returnOnAssets  \
# 22072                 NaN              NaN               NaN             NaN
# 22073            -16.6799         -16.4928               NaN         -0.8423
# 22074              0.1752           0.1279            0.1661          0.2228
# 22075                 NaN              NaN               NaN         -7.5619
# 22076             -0.6248          -0.6895               NaN         -0.2021
#
#        returnOnEquity  returnOnCapitalEmployed  nIperEBT  eBTperEBIT  \
# 22072         -0.0800                      NaN       NaN         NaN
# 22073         -1.6093                  -0.9562       NaN         NaN
# 22074          0.1895                   0.1269    0.8339      0.8717
# 22075         -4.5523                  -6.0612       NaN         NaN
# 22076         -0.2025                  -1.4567       NaN         NaN
#
#        eBITperRevenue  payablesTurnover  inventoryTurnover  \
# 22072             NaN            0.0000             0.0000
# 22073        -16.4928            1.3990             0.0000
# 22074          0.1759               NaN             3.9427
# 22075             NaN            0.0000             0.0000
# 22076         -0.6454            2.5761             0.0000
#
#        fixedAssetTurnover  assetTurnover  currentRatio  quickRatio  cashRatio  \
# 22072              0.0000         0.0000           NaN      0.0021     0.0021
# 22073              0.0904         0.0429        3.8860      3.8154     2.0445
# 22074              8.7390         0.7184        1.6440      1.1897     0.1963
# 22075              0.0000         0.0000        1.6250      0.8390     0.8164
# 22076              8.1769         0.2170        6.8150      6.7204     1.4075
#
#        daysOfSalesOutstanding  daysOfInventoryOutstanding  operatingCycle  \
# 22072                  0.0000                      0.0000             NaN
# 22073                  0.0000                    105.0360             NaN
# 22074               -177.4658                    250.1009             NaN
# 22075                  0.0000                      0.0000             NaN
# 22076                  0.0000                      9.3283             NaN
#
#        daysOfPayablesOutstanding  cashConversionCycle  debtRatio  \
# 22072                     0.0000                  NaN     0.3041
# 22073                    76.8076                  NaN     0.4988
# 22074                    35.6784                  NaN     0.2522
# 22075                     0.0000                  NaN     0.0000
# 22076                    92.2706                  NaN     0.0000
#
#        debtEquityRatio  longtermDebtToCapitalization  \
# 22072           0.6850                        0.3684
# 22073           1.1346                        0.4966
# 22074           0.5202                        0.0000
# 22075           0.0000                        0.0000
# 22076           0.0000                        0.0000
#
#        totalDebtToCapitalization  interestCoverage  cashFlowToDebtRatio  \
# 22072                     0.4065           -0.3406              -0.0537
# 22073                     0.5315            0.0000              -1.3541
# 22074                     0.3422            7.7919              -0.1160
# 22075                     0.0000            0.0000                  NaN
# 22076                     0.0000         -206.1386                  NaN
#
#        companyEquityMultiplier  operatingCashFlowPerShare  \
# 22072                   2.2522                    -0.0365
# 22073                   2.2745                    -0.8814
# 22074                   2.0625                    -0.1642
# 22075                   1.6499                    -0.1193
# 22076                   1.3539                     0.8311
#
#        freeCashFlowPerShare  cashPerShare  payoutRatio  \
# 22072               -0.0365        0.0007       0.0000
# 22073               -2.4960        0.3378       0.0000
# 22074               -0.1985        0.5645       0.0000
# 22075               -0.1260        0.0208       0.0000
# 22076                0.8035        1.4508       0.0000
#
#        operatingCashFlowSalesRatio  freeCashFlowOperatingCashFlowRatio  \
# 22072                          NaN                                 NaN
# 22073                     -15.7446                                 NaN
# 22074                      -0.0407                                 NaN
# 22075                          NaN                                 NaN
# 22076                       0.4560                              0.9668
#
#        cashFlowCoverageRatios  shortTermCoverageRatios  \
# 22072                 -0.0537                  -0.3611
# 22073                 -1.3541                 -10.3720
# 22074                 -0.1160                  -0.1160
# 22075                     NaN                      NaN
# 22076                     NaN                      NaN
#
#        capitalExpenditureCoverageRatios  dividendpaidAndCapexCoverageRatios  \
#
weighted Average Shares Diluted Growth  Dividends per Share Growth  \
# 22072                                     NaN                      0.0000
# 22073                                  2.0203                      0.0000
# 22074                                  0.2420                      0.0000
# 22075                                  0.0691                      0.0000
# 22076                                  0.3644                      0.0000
#
#        Operating Cash Flow growth  Free Cash Flow growth  \
# 22072                     -2.0649                -2.0605
# 22073                     -0.0673                -0.0716
# 22074                     -2.9498                -3.7263
# 22075                     -0.5716                -0.6197
# 22076                    109.3973                14.0145
#
#        10Y Revenue Growth (per Share)  5Y Revenue Growth (per Share)  \
# 22072                             NaN                            NaN
# 22073                         -0.3488                        -0.6145
# 22074                             NaN                            NaN
# 22075                             NaN                            NaN
# 22076                             NaN                            NaN
#
#        3Y Revenue Growth (per Share)  10Y Operating CF Growth (per Share)  \
# 22072                         0.0000                                  NaN
# 22073                        -0.5301                               0.0000
# 22074                         0.0123                                  NaN
# 22075                            NaN                                  NaN
# 22076                         0.2858                                  NaN
#
#        5Y Operating CF Growth (per Share)  3Y Operating CF Growth (per Share)  \
# 22072                                 NaN                              0.0000
# 22073                              0.0000                              0.0000
# 22074                                 NaN                              0.0000
# 22075                                 NaN                                 NaN
# 22076                                 NaN                              0.0000
#
#        10Y Net Income Growth (per Share)  5Y Net Income Growth (per Share)  \
# 22072                                NaN                               NaN
# 22073                             0.0000                            0.0000
# 22074                                NaN                               NaN
# 22075                                NaN                               NaN
# 22076                                NaN                               NaN
#
#        3Y Net Income Growth (per Share)  \
# 22072                            0.0000
# 22073                            0.0000
# 22074                           -0.0251
# 22075                               NaN
# 22076                            0.0000
#
#        10Y Shareholders Equity Growth (per Share)  \
# 22072                                         NaN
# 22073                                     -0.4288
# 22074                                         NaN
# 22075                                         NaN
# 22076                                         NaN
#
#        5Y Shareholders Equity Growth (per Share)  \
# 22072                                        NaN
# 22073                                    -0.5618
# 22074                                        NaN
# 22075                                        NaN
# 22076                                        NaN
#
#        3Y Shareholders Equity Growth (per Share)  \
# 22072                                    -0.1237
# 22073                                    -0.5207
# 22074                                     0.7411
# 22075                                        NaN
# 22076                                     0.5649
#
#        10Y Dividend per Share Growth (per Share)  \
# 22072                                        NaN
# 22073                                     0.0000
# 22074                                        NaN
# 22075                                        NaN
# 22076                                        NaN
#
#        5Y Dividend per Share Growth (per Share)  \
# 22072                                       NaN
# 22073                                    0.0000
# 22074                                       NaN
# 22075                                       NaN
# 22076                                       NaN
#
#        3Y Dividend per Share Growth (per Share)  Receivables growth  \
# 22072                                    0.0000              0.0000
# 22073                                    0.0000              0.3445
# 22074                                    0.0000              0.1605
# 22075                                       NaN              0.8980
# 22076                                    0.0000             -0.4185
#
#        Inventory Growth  Asset Growth  Book Value per Share Growth  \
# 22072            0.0000       -0.0508                      -0.1409
# 22073            0.0000       -0.2323                      -0.8602
# 22074            0.7706        0.2489                       0.4074
# 22075            0.0000        0.1568                      -0.2200
# 22076            0.0000        0.8519                       0.1325
#
#        Debt Growth  R&D Expense Growth  SG&A Expenses Growth           Sector  \
# 22072      -0.0152              0.0000               -0.2602      Real Estate
# 22073       0.0000              0.0352               -0.0993  Basic Materials
# 22074      -0.0968              0.2415                0.8987  Basic Materials
# 22075       0.0000              2.7499                0.1457      Industrials
# 22076       0.0000              0.3577                0.5880       Healthcare
#
#        price_var_next_yr_%  Class
# 22072             -90.9621      0
# 22073             -77.9221      0
# 22074             -17.8344      0
# 22075             -73.5200      0
# 22076             209.4622      1

# %% [markdown]
# ### Final Visual Clean Up

# %% [markdown]
# We drop the response variable 'Class" because we decide to pursue a regression analysis with the response "price_var_next_yr_%" and we do not need the "Ticker" as a predictor.

# %%
df = df.drop(columns=['Ticker', 'Class'])

# %%
# Function to convert camel case to snake case and handle pre-existing underscores
def camel_to_snake(name):
    # Insert an underscore between lowercase followed by uppercase
    s1 = re.sub('([a-z])([A-Z])', r'\1_\2', name)
    # Handle pre-existing underscores (avoid double underscores)
    s2 = re.sub('_+', '_', s1)
    return s2.lower()

# %%
# Then convert any camelCase to snake_case
df.columns = [camel_to_snake(col) for col in df.columns]

# %%
# Renaming columns to follow industry practice
df.columns = [col.replace(' ', '_').lower() for col in df.columns]

# %%
df.head()
# Out:
#    year          revenue  revenue_growth  cost_of_revenue     gross_profit  \
# 0  2014 74401000000.0000         -0.0713 39030000000.0000 35371000000.0000
# 1  2014  3734148046.4966          1.1737  2805625443.9780   928522602.5186
# 2  2014 98375000000.0000          0.0182 78138000000.0000 20237000000.0000
# 3  2014 25526413000.0000          0.0053 18202679000.0000  7323734000.0000
# 4  2014 17909600000.0000          0.0076 11539800000.0000  6369800000.0000
#
#     r&d_expenses     sg&a_expense  operating_expenses  operating_income  \
# 0         0.0000 21461000000.0000    21461000000.0000  13910000000.0000
# 1 108330319.6642   344141427.1876      793926703.2612    134595899.2573
# 2         0.0000 15196000000.0000    17512000000.0000   2725000000.0000
# 3         0.0000  6561162000.0000     6586482000.0000    737252000.0000
# 4         0.0000  3474300000.0000     3412400000.0000   2957400000.0000
#
#    interest_expense  earnings_before_tax  income_tax_expense  \
# 0    709000000.0000     14494000000.0000     2851000000.0000
# 1     12148692.2829       175382305.4569       39559573.7811
# 2    443000000.0000      2270000000.0000      751000000.0000
# 3    424591000.0000       250218000.0000         804000.0000
# 4    302400000.0000      2707700000.0000      883300000.0000
#
#    net_income_-_non-controlling_int  net_income_-_discontinued_ops  \
# 0                    142000000.0000               -1127000000.0000
# 1                    -14319179.8515                         0.0000
# 2                     12000000.0000                         0.0000
# 3                            0.0000                         0.0000
# 4                     36900000.0000                         0.0000
#
#         net_income  preferred_dividends   net_income_com    eps  eps_diluted  \
# 0 11643000000.0000               0.0000 11643000000.0000 4.1900       4.0100
# 1   135822731.6758               0.0000   135822731.6758 0.2396       0.2260
# 2  1519000000.0000               0.0000  1519000000.0000 1.4700       1.4500
# 3   249414000.0000        33998000.0000   215416000.0000 4.6000       4.6000
# 4  1824400000.0000               0.0000  1824400000.0000 2.9000       2.8300
#
#    weighted_average_shs_out  weighted_average_shs_out_(dil)  \
# 0           2705960276.0000                 2705960276.0000
# 1                       NaN                   18293619.9548
# 2           1033052512.0000                 1028000000.0000
# 3             48326279.0000                   48326279.0000
# 4            614492206.0000                  614492206.0000
#
#    dividend_per_share  gross_margin  ebitda_margin  ebit_margin  \
# 0              2.4480        0.4754         0.2470       0.2043
# 1              0.0000        0.2487         0.0107       0.0502
# 2              0.3070        0.2057         0.0450       0.0276
# 3              0.0000        0.2869         0.0420       0.0264
# 4              1.5500        0.3557         0.2010       0.1681
#
#    profit_margin  free_cash_flow_margin           ebitda             ebit  \
# 0            -7662000000.0000             84990000000.0000
# 1               -1729254.1169                 4285437.5202
# 2             -464000000.0000             10981000000.0000
# 3              -37334000.0000             -7515848000.0000
# 4            -1340300000.0000             11787200000.0000
#
#    total_shareholders_equity     investments         net_debt    other_assets  \
# 0           69976000000.0000 2128000000.0000 24731000000.0000 7786000000.0000
# 1             412354536.6484  671378753.6325              NaN             NaN
# 2            5384000000.0000          0.0000 10909000000.0000 1662000000.0000
# 3           -2113702000.0000          0.0000  5610737000.0000  195709000.0000
# 4            6534800000.0000          0.0000  7918500000.0000  483200000.0000
#
#    other_liabilities  depreciation_&_amortization  stock-based_compensation  \
# 0    9659000000.0000              3141000000.0000            360000000.0000
# 1     639046012.2700                58154827.2522             36405230.8686
# 2    4167000000.0000              1703000000.0000            107000000.0000
# 3    1165859000.0000               403741000.0000            -10471000.0000
# 4    1449900000.0000               585400000.0000             39200000.0000
#
#    operating_cash_flow  capital_expenditure  acquisitions_and_disposals  \
# 0     13958000000.0000     -3848000000.0000              -24000000.0000
# 1       526745560.2196      -263704552.7930             -192255247.0132
# 2      3573000000.0000     -2330000000.0000            -2344000000.0000
# 3       702046000.0000      -333870000.0000                      0.0000
# 4      2541000000.0000      -656900000.0000               66700000.0000
#
#    investment_purchases_and_sales  investing_cash_flow  \
# 0                 -805000000.0000     -4100000000.0000
# 1                 -212644656.1188      -686693574.4269
# 2                          0.0000     -4771000000.0000
# 3                   41155000.0000      -364924000.0000
# 4                   29300000.0000      -561800000.0000
#
#    issuance_(repayment)_of_debt  issuance_(buybacks)_of_shares  \
# 0               3543000000.0000               -3911000000.0000
# 1                619326767.8398                   1767839.8450
# 2               2093000000.0000                -413000000.0000
# 3               -295435000.0000                  33217000.0000
# 4                801100000.0000               -1637200000.0000
#
#    dividend_payments  financing_cash_flow  effect_of_forex_changes_on_cash  \
# 0   -6911000000.0000     -7279000000.0000                    39000000.0000
# 1             0.0000       621913626.0898                   -15648692.2829
# 2    -319000000.0000      1361000000.0000                           0.0000
# 3             0.0000      -320168000.0000                           0.0000
# 4    -983300000.0000     -1824100000.0000                   -29200000.0000
#
#    net_cash_flow_/_change_in_cash   free_cash_flow  net_cash/marketcap  \
# 0                 2618000000.0000 10110000000.0000             -0.1163
# 1                  446316919.5996   263041007.4265              0.0956
# 2                  163000000.0000  1243000000.0000             -0.5969
# 3                   16954000.0000   368176000.0000             -0.8822
# 4                  125900000.0000  1884100000.0000             -0.2376
#
#    price_book_value_ratio  price_to_book_ratio  price_to_sales_ratio  \
# 0                  3.0391               0.0000                2.8583
# 1                     NaN                  NaN                0.0443
# 2                  3.3579               7.0982                0.1858
# 3                  0.0000               0.0000                0.2491
# 4                  5.1004               0.0000                1.8610
#
#    price_earnings_ratio  price_to_free_cash_flows_ratio  \
# 0               18.7566                         21.0348
# 1               81.5526                          1.3589
# 2               12.0340                         14.6302
# 3               28.6087                         17.2736
# 4               18.7034                         17.6902
#
#    price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# 0                              15.2358                12.9775
# 1                                  NaN                 0.6786
# 2                               5.1147                 0.0000
# 3                               9.0589                 0.0000
# 4                              13.1169                10.9524
#
#    price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# 0                         15.5578             2.4346          0.0382
# 1                          2.6318             0.0957         -0.0000
# 2                          0.0000             0.0000             NaN
# 3                          0.0000             0.0000             NaN
# 4                         15.2543             1.5539          0.0353
#
#    enterprise_value_multiple  price_fair_value  ebitper_revenue  ebtper_ebit  \
# 0                    11.4211            2.5886           0.2043       0.9534
# 1                     7.1365            0.8669           0.0502       0.9352
# 2                     2.2767            0.0000           0.0276       0.8367
# 3                     5.4280               NaN           0.0264       0.3708
# 4                     9.7680            4.2587           0.1681       0.8995
#
#    niper_ebt  gross_profit_margin  operating_profit_margin  \
# 0     0.8033               0.4754                   1.0000
# 1     0.7744               0.2487                   1.0000
# 2     0.6692               0.2057                   1.0000
# 3     0.9968               0.2869                   1.0000
# 4     0.6738               0.3557                   1.0000
#
#    pretax_profit_margin  net_profit_margin  effective_tax_rate  \
# 0                0.1870             0.1565              0.1967
# 1                0.0360             0.0364              0.2256
# 2                0.0277             0.0154              0.3308
# 3                0.0289             0.0098              0.0032
# 4                0.1651             0.1019              0.3262
#
#    return_on_assets  return_on_equity  return_on_capital_employed  n_iper_ebt  \
# 0            0.5765            0.1664                      0.0753      0.8033
# 1            0.0403            0.3294                      0.0000      0.7744
# 2            0.1011            0.2821                      0.0859      0.6692
# 3            0.0668           -0.1180                      0.1062      0.9968
# 4            0.6265            0.2792                      0.1041      0.6738
#
#    e_btper_ebit  e_bitper_revenue  payables_turnover  inventory_turnover  \
# 0        0.9534            0.2043             1.5648             10.8869
# 1        0.9352            0.0502                NaN                 NaN
# 2        0.8367            0.0276             4.9593             18.2227
# 3        0.3708            0.0264             4.9289              8.3030
# 4        0.8995            0.1681             2.8234             11.5363
#
#    fixed_asset_turnover  asset_turnover  current_ratio  quick_ratio  \
# 0                3.3358          0.5157         0.9370       0.5062
# 1               12.1004          1.3645         0.2102       0.8500
# 2                5.8234          3.3597         0.8250       0.1417
# 3               13.0415          3.6756         1.7090       0.4369
# 4                4.5434          0.7738         0.8100       0.4335
#
#    cash_ratio  days_of_sales_outstanding  days_of_inventory_outstanding  \
# 0      0.2538                   -63.2087                        31.3287
# 1      0.4718                   -75.3670                         1.1431
# 2      0.0375                   -26.3971                         4.1407
# 3      0.0584                   -60.0346                        13.5706
# 4      0.1599                   -49.3233                        30.2360
#
#    operating_cycle  days_of_payables_outstanding  cash_conversion_cycle  \
# 0              NaN                       41.5084                    NaN
# 1              NaN                       97.7945                    NaN
# 2              NaN                       18.1099                    NaN
# 3              NaN                       18.4802                    NaN
# 4              NaN                       32.8385                    NaN
#
#    debt_ratio  debt_equity_ratio  longterm_debt_to_capitalization  \
# 0      0.2455             0.5061                           0.2206
# 1      0.2274             1.5093                           0.6015
# 2      0.3863             2.1007                           0.6419
# 3      0.8290            -2.7237                           1.5881
# 4      0.3796             1.3445                           0.4957
#
#    total_debt_to_capitalization  interest_coverage  cash_flow_to_debt_ratio  \
# 0                        0.3360            21.4429                   0.3941
# 1                        0.6015            15.4363                   0.8463
# 2                        0.6775             6.1242                   0.3159
# 3                        1.5801             1.5893                   0.1219
# 4                        0.5735             9.9540                   0.2892
#
#    company_equity_multiplier  operating_cash_flow_per_share  \
# 0                     2.0616                         5.1582
# 1                     6.6367                        35.6714
# 2                     5.4385                         3.4757
# 3                        NaN                        14.5272
# 4                     3.5419                         4.1351
#
#    free_cash_flow_per_share  cash_per_share  payout_ratio  \
# 0                    3.9640          3.1626        0.5840
# 1                   22.9760         52.3827        0.0000
# 2                    0.8370          0.3901        0.2090
# 3                    0.5570          3.0295        0.0000
# 4                    3.6240          1.4114        0.5340
#
#    operating_cash_flow_sales_ratio  free_cash_flow_operating_cash_flow_ratio  \
# 0                           0.1876                                    0.7243
# 1                           0.1411                                    0.4994
# 2                           0.0363                                    0.3479
# 3                           0.0275                                    0.5244
# 4                           0.1419                                    0.7415
#
#    cash_flow_coverage_ratios  short_term_coverage_ratios  \
# 0                     0.3941                      0.8944
# 1                     0.8463                         NaN
# 2                     0.3159                      2.1563
# 3                     0.1219                     14.2768
# 4                     0.2892                      1.0756
#
#    capital_expenditure_coverage_ratios  \
# 0                               3.6273
# 1                               1.9975
# 2                               1.5335
# 3                               2.1028
# 4                               3.8682
#
#    dividendpaid_and_capex_coverage_ratios  dividend_payout_ratio  \
# 0                                  1.2973                 0.5936
# 1                                  1.9975                -0.0000
# 2                                  1.3488                 0.2100
# 3                                  2.1028                -0.0000
# 4                                  1.5492                 0.5390
#
#    revenue_per_share  net_income_per_share  operating_cash_flow_per_share  \
# 0            27.4952                4.3027                         5.1582
# 1           252.8778                9.1980                        35.6714
# 2            95.6955                1.4776                         3.4757
# 3           528.2098                5.1610                        14.5272
# 4            29.1454                2.9690                         4.1351
#
#    free_cash_flow_per_share  cash_per_share  book_value_per_share  \
# 0                    3.9640          3.1626               25.8600
# 1                   22.9760         52.3827                0.7278
# 2                    0.8370          0.3901                5.2370
# 3                    0.5570          3.0295              -43.7380
# 4                    3.6240          1.4114               10.6340
#
#    tangible_book_value_per_share  shareholders_equity_per_share  \
# 0                        22.0690                        25.8600
# 1                         4.4939                        27.9248
# 2                        25.7240                         5.2374
# 3                       134.7850                       -43.7381
# 4                        15.4290                        10.6345
#
#    interest_debt_per_share        market_cap  enterprise_value  pe_ratio  \
# 0                  13.0885 212661418090.8400 237392418090.8400   18.7566
# 1                  42.1474   6253200000.0000               NaN   81.5526
# 2                  11.0019  18274698937.2800  29183698937.2800   12.0340
# 3                 119.1307   6359738316.4000  11970475316.4000   28.6087
# 4                  14.2977  33330057253.4400  41248557253.4400   18.7034
#
#    price_to_sales_ratio  pocf_ratio  pfcf_ratio  pb_ratio  ptb_ratio  \
# 0                2.8583     15.2358     21.0348    3.0391     0.0000
# 1                0.0443         NaN      1.3589       NaN        NaN
# 2                0.1858      5.1147     14.6302    3.3579     7.0982
# 3                0.2491      9.0589     17.2736    0.0000     0.0000
# 4                1.8610     13.1169     17.6902    5.1004     0.0000
#
#    ev_to_sales  enterprise_value_over_ebitda  ev_to_operating_cash_flow  \
# 0       3.1907                       12.9411                    17.0076
# 1          NaN                           NaN                        NaN
# 2       0.2967                        6.6086                     8.1678
# 3       0.4689                       11.0987                    17.0508
# 4       2.3032                       11.4723                    16.2332
#
#    ev_to_free_cash_flow  earnings_yield  free_cash_flow_yield  debt_to_equity  \
# 0               23.4810          0.0533                0.0475          0.5061
# 1                   NaN          0.0123                   NaN          1.5093
# 2               23.4784          0.0831                0.0680          2.1007
# 3               32.5129          0.0350                0.0579         -2.7237
# 4               21.8930          0.0535                0.0565          1.3445
#
#    debt_to_assets  net_debt_to_ebitda  current_ratio  interest_coverage  \
# 0          0.2455              1.3482         0.9370            21.4429
# 1          0.2274                 NaN         0.2102            15.4363
# 2          0.3863              2.4703         0.8250             6.1242
# 3          0.8290              5.2021         1.7090             1.5893
# 4          0.3796              2.2023         0.8100             9.9540
#
#    income_quality  dividend_yield  payout_ratio  sg&a_to_revenue  \
# 0          1.1988          0.0311        0.5840           0.2885
# 1          3.8782          0.0000        0.0000           0.0922
# 2          2.3522          0.0174        0.2090           0.1545
# 3          3.2590          0.0000        0.0000           0.2570
# 4          1.3928          0.0286        0.5340           0.1940
#
#    r&d_to_revenue  intangibles_to_total_assets  capex_to_operating_cash_flow  \
# 0          0.0000                       0.5860                        0.2757
# 1          0.0290                       0.0697                        0.5006
# 2          0.0000                       0.0969                        0.6521
# 3          0.0000                       0.0621                        0.4756
# 4          0.0000                       0.5904                        0.2585
#
#    capex_to_revenue  capex_to_depreciation  \
# 0            0.0517                -1.2251
# 1            0.0706                -4.5345
# 2            0.0237                -1.3682
# 3            0.0131                -0.8269
# 4            0.0367                -1.1221
#
#    stock-based_compensation_to_revenue  graham_number   roic  \
# 0                               0.0048        49.3756 0.0753
# 1                               0.0097            NaN 0.0000
# 2                               0.0011        13.2000 0.0859
# 3                              -0.0004         0.0000 0.1062
# 4                               0.0022        26.3414 0.1041
#
#    return_on_tangible_assets  graham_net-net  working_capital  \
# 0                     0.5765         -0.2007 -2109000000.0000
# 1                     0.0403          0.0534  3065163000.0000
# 2                     0.1011         -0.8239 -1875000000.0000
# 3                     0.0668         -0.7506  1777673000.0000
# 4                     0.6265         -0.3229 -1030000000.0000
#
#    tangible_asset_value  net_current_asset_value  invested_capital  \
# 0      59719000000.0000        -42673000000.0000  52852000000.0000
# 1       2546028576.0413          -166696641.9115    755350984.8240
# 2      26444000000.0000        -15056000000.0000  26648000000.0000
# 3       6513644000.0000         -4773448000.0000   9616929000.0000
# 4       9480900000.0000        -10762700000.0000  11975900000.0000
#
#    average_receivables  average_payables  average_inventory  \
# 0      6447000000.0000   8619000000.0000    6834000000.0000
# 1                  NaN               NaN                NaN
# 2      1083500000.0000   4682500000.0000    5398500000.0000
# 3       939269000.0000   1338531500.0000    3074345000.0000
# 4      1465000000.0000   1517250000.0000    1552450000.0000
#
#    days_sales_outstanding  days_payables_outstanding  \
# 0                 31.3287                    41.5084
# 1                  1.1431                    97.7945
# 2                  4.1407                    18.1099
# 3                 13.5706                    18.4802
# 4                 30.2360                    32.8385
#
#    days_of_inventory_on_hand  receivables_turnover  payables_turnover  \
# 0                   -63.2087               11.5404             1.5648
# 1                   -75.3670                   NaN                NaN
# 2                   -26.3971               90.7937             4.9593
# 3                   -60.0346               27.1769             4.9289
# 4                   -49.3233               12.2250             2.8234
#
#    inventory_turnover     roe  capex_per_share  gross_profit_growth  \
# 0             10.8869  0.1664          -1.4220              -0.1185
# 1                 NaN  0.3294         -17.8582               1.2489
# 2             18.2227  0.2821          -2.2665               0.0173
# 3              8.3030 -0.1180          -6.9087               0.0007
# 4             11.5363  0.2792          -1.0690              -0.0084
#
#    ebit_growth  operating_income_growth  net_income_growth  eps_growth  \
# 0      -0.0001                   0.0067             0.0293      0.0371
# 1       1.6142                   1.9463             1.5649      1.4625
# 2      -0.0145                  -0.0141             0.0147      0.0576
# 3       0.2904                   0.1113             1.0043      0.9167
# 4       0.0332                   0.0370            -0.0166      0.0140
#
#    eps_diluted_growth  weighted_average_shares_growth  \
# 0              0.0389                         -0.0127
# 1              1.4646                          0.0184
# 2              0.0469                         -0.0356
# 3              0.9167                          0.0694
# 4              0.0143                         -0.0468
#
#    weighted_average_shares_diluted_growth  dividends_per_share_growth  \
# 0                                     NaN                      0.0699
# 1                                  0.0195                      0.0000
# 2                                 -0.0317                      0.2429
# 3                                     NaN                      0.0000
# 4                                     NaN                      0.1742
#
#    operating_cash_flow_growth  free_cash_flow_growth  \
# 0                     -0.0615                -0.0695
# 1                      0.2134                -0.3626
# 2                      0.2095                 0.3935
# 3                     -0.1434                -0.2691
# 4                     -0.1316                -0.1936
#
#    10y_revenue_growth_(per_share)  5y_revenue_growth_(per_share)  \
# 0                          0.0323                         0.0088
# 1                             NaN                            NaN
# 2                          0.1027                         0.1038
# 3                         -0.0195                        -0.0290
# 4                          0.0704                         0.0567
#
#    3y_revenue_growth_(per_share)  10y_operating_cf_growth_(per_share)  \
# 0                        -0.0182                               0.0355
# 1                            NaN                                  NaN
# 2                         0.1399                               0.0889
# 3                        -0.0230                               0.0513
# 4                         0.0773                               0.0782
#
#    5y_operating_cf_growth_(per_share)  3y_operating_cf_growth_(per_share)  \
# 0                              0.0015                              0.0260
# 1                                 NaN                                 NaN
# 2                              0.0937                              0.0946
# 3                              0.1164                              0.1777
# 4                              0.0828                              0.1991
#
#    10y_net_income_growth_(per_share)  5y_net_income_growth_(per_share)  \
# 0                             0.0603                           -0.0137
# 1                                NaN                               NaN
# 2                             0.2272                            0.0906
# 3                             0.0480                            0.0000
# 4                             0.0776                            0.0841
#
#    3y_net_income_growth_(per_share)  \
# 0                            0.0060
# 1                               NaN
# 2                            0.1892
# 3                            0.0000
# 4                            0.0177
#
#    10y_shareholders_equity_growth_(per_share)  \
# 0                                      0.1442
# 1                                         NaN
# 2                                      0.0676
# 3                                      0.0000
# 4                                      0.0427
#
#    5y_shareholders_equity_growth_(per_share)  \
# 0                                     0.0353
# 1                                        NaN
# 2                                     0.0558
# 3                                     0.0000
# 4                                     0.0623
#
#    3y_shareholders_equity_growth_(per_share)  \
# 0                                     0.0201
# 1                                        NaN
# 2                                     0.0789
# 3                                     0.0000
# 4                                     0.0217
#
#    10y_dividend_per_share_growth_(per_share)  \
# 0                                     0.1013
# 1                                        NaN
# 2                                     0.0000
# 3                                     0.0000
# 4                                     0.1092
#
#    5y_dividend_per_share_growth_(per_share)  \
# 0                                    0.0834
# 1                                       NaN
# 2                                    0.1215
# 3                                    0.0000
# 4                                    0.1250
#
#    3y_dividend_per_share_growth_(per_share)  receivables_growth  \
# 0                                    0.0751             -0.0187
# 1                                       NaN                 NaN
# 2                                    0.1633              0.0618
# 3                                    0.0000              0.0211
# 4                                    0.1144              0.0257
#
#    inventory_growth  asset_growth  book_value_per_share_growth  debt_growth  \
# 0           -0.0217        0.0359                       0.0316       0.1228
# 1               NaN           NaN                          NaN          NaN
# 2            0.0981        0.1886                       0.3268       0.2738
# 3           -0.0510       -0.0189                       0.1963      -0.0458
# 4            0.0090        0.0215                       0.0274       0.1025
#
#    r&d_expense_growth  sg&a_expenses_growth              sector  \
# 0              0.0000               -0.1746  Consumer Defensive
# 1              1.6484                1.7313  Consumer Defensive
# 2              0.0000                0.0234  Consumer Defensive
# 3              0.0000               -0.0060  Consumer Defensive
# 4              0.0000               -0.0220  Consumer Defensive
#
#    price_var_next_yr_%
# 0              -9.3233
# 1             -25.5122
# 2              33.1183
# 3               2.7523
# 4              12.8977

# %%
df.shape
# Out:
# (22077, 224)

# %% [markdown]
# ### An Informative Description of Predictors

# %% [markdown]
# From investopedia: https://www.investopedia.com/articles/basics/04/100804.asp

# %% [markdown]
# Stock prices are ultimately determined by supply and demand, which are influenced by both fundamental and technical factors.

# %% [markdown]
# Fundamental factors relate to a company's financial performance, especially earnings. The earnings per share (EPS) represents the owner's proportional share of earnings. The P/E ratio expresses the valuation multiple, i.e. how much an investor is willing to pay for those future earnings. Earnings can also be measured by cash flow per share or dividends per share. The valuation multiple depends on the expected earnings growth rate and the discount rate, which represents inflation and the perceived riskiness of the stock. Higher expected growth leads to a higher multiple, while higher risk or inflation leads to a lower multiple.

# %% [markdown]
# Technical factors are from external market conditions that drive supply and demand. Historically, low inflation boosts multiples while high inflation lowers them. Deflation hurts pricing power. Stocks tend to move with the overall market and their industry peers, and stocks compete with other asset classes like bonds and commodities. Regarding investors, middle-aged investors tend to invest more in stocks. Furthermore, stocks build momentum or revert to the mean. Large cap stocks have high liquidity while small caps often have a liquidity discount. Finally, unforeseen positive or negative events impact sentiment, and psychology often weighs more heavily than fundamentals in the short term. Behavioral finance aims to explain irrational market behavior.

# %% [markdown]
# ### Reconciliation

# %% [markdown]
# While technicals often dominate in the short run, fundamentals determine long-term prices. Different investors weigh the factors differently, but both play a critical role in the complicated dynamics of supply, demand, and human psychology. In our previous submissions, we manually pre-selected factors based on research, but we have since refrained from this method as it introduces biases into our model. It is also tediously unreasonable to plot each individual predictor and manually select from them, thus we will select predictors based on missingness in the next section. In other words, we will drop predictors with too many missing values because imputing values for factors with too much missing data will also introduce biases into our model.

# %% [markdown]
# Additionally, we can evidentially see that many of our factors are highly correlated and must be dealt with for a robust model. We attempted to eliminate correlated values using PCA to reduce dimensionality, but our results did not end up improving our resulting analysis. When we refine our final model, we will include further methods to deal with these correlated predictors and refine our model.

# %% [markdown]
# ## 0.2 EDA

# %% [markdown]
# ### Descriptive Statistics

# count           17084.0000            19794.0000            19801.0000
# mean            20344.7910               88.0457               37.8410
# std           1294364.7518             3499.3178              853.4735
# min                 0.0000                0.0000                0.0000
# 25%                 0.6205                0.7284                0.0000
# 50%                 1.7595                1.8767               12.9515
# 75%                 4.3034                4.2930               23.4224
# max         108458749.3333           377315.7961           105828.7129
#
#        price_to_free_cash_flows_ratio  price_to_operating_cash_flows_ratio  \
# count                      19800.0000                           18857.0000
# mean                          36.4551                              53.9708
# std                          645.7327                            4242.6494
# min                            0.0000                         -108768.6767
# 25%                            0.0000                               1.5864
# 50%                            8.8684                               8.9787
# 75%                           20.2903                              15.9277
# max                        60328.7741                          554659.9637
#
#        price_cash_flow_ratio  price_earnings_to_growth_ratio  \
# count             15013.0000                      12998.0000
# mean                 63.9418                         58.4074
# std                4537.2221                        954.0307
# min                   0.0000                          0.0000
# 25%                   5.8910                         11.2259
# 50%                  10.5648                         17.9773
# 75%                  17.1832                         28.9686
# max              554582.1706                     100419.2880
#
#        price_sales_ratio  dividend_yield  enterprise_value_multiple  \
# count         18720.0000      18779.0000                 15133.0000
# mean             78.0221          0.2861                    36.4548
# std            3429.4966          8.3325                   571.1146
# min               0.0000         -0.0000                     0.0000
# 25%               0.6978         -0.0000                     8.7193
# 50%               1.7537          0.0000                    12.6615
# 75%               3.9015          0.0251                    18.8631
# max          377315.7961        527.9266                 47022.6180
#
#        price_fair_value  ebitper_revenue  ebtper_ebit  niper_ebt  \
# count        18503.0000       19215.0000   14070.0000 13482.0000
# mean         11170.9484          -7.7510       0.6345     0.8642
# std         867520.6729         224.4291      21.4788     9.5351
# min              0.0000      -24242.0000    -983.2077  -206.0833
# 25%              0.9991          -0.0026       0.6888     0.6341
# 50%              1.7706           0.0864       0.9013     0.7316
# 75%              3.5096           0.2168       1.0000     0.8936
# max       94309693.2157        1056.4658    2263.8701   845.5556
#
#        gross_profit_margin  operating_profit_margin  pretax_profit_margin  \
# count           19215.0000               19215.0000            19215.0000
# mean                0.4922                   1.0000               -8.0553
# std                 2.0235                   0.0000              225.9548
# min              -223.4828                   1.0000           -24577.0000
# 25%                 0.2820                   1.0000               -0.0118
# 50%                 0.4855                   1.0000                0.0874
# 75%                 0.8196                   1.0000                0.2159
# max                34.8107                   1.0000              198.6842
#
#        net_profit_margin  effective_tax_rate  return_on_assets  \
# count         19215.0000          13482.0000        15542.0000
# mean             -7.7811             -2.0034           -0.0650
# std             224.6995            244.6405            8.3628
# min          -24414.0000         -28384.6154         -344.4375
# 25%              -0.0319              0.0778           -0.1560
# 50%               0.0476              0.2593            0.0435
# 75%               0.1385              0.3578            0.1692
# max            1056.4658            207.0833          345.6310
#
#        return_on_equity  return_on_capital_employed  n_iper_ebt  e_btper_ebit  \
# count        19739.0000                  15568.0000  13482.0000    14070.0000
# mean          1645.9404                     -0.1155      0.8642        0.6345
# std         114822.1261                     35.2591      9.5351       21.4788
# min         -34772.4596                   -616.6446   -206.0833     -983.2077
# 25%             -0.0663                     -0.0153      0.6341        0.6888
# 50%              0.0712                      0.0353      0.7316        0.9013
# 75%              0.1460                      0.0932      0.8936        1.0000
# max       11141141.6667                   3863.9037    845.5556     2263.8701
#
#        e_bitper_revenue  payables_turnover  inventory_turnover  \
# count        19215.0000         17166.0000          19565.0000
# mean            -7.7510             6.2140             31.6242
# std            224.4291            79.5712            727.3355
# min         -24242.0000           -41.0958              0.0000
# 25%             -0.0026             0.8053              0.0000
# 50%              0.0864             2.6148              3.2234
# 75%              0.2168             5.1141             10.4659
# max           1056.4658          8650.3158          95827.7103
#
#        fixed_asset_turnover  asset_turnover  current_ratio  quick_ratio  \
# count            18943.0000      19933.0000     19012.0000   19019.0000
# mean                90.5674          0.6912         7.1177      71.8738
# std               4343.2768          1.2521       183.9803    5133.2711
# min               -383.6006         -0.1251        -1.4393       0.0000
# 25%                  1.0759          0.1196         0.9500       0.6262
# 50%                  4.0791          0.4763         1.7580       1.2179
# 75%                 10.5283          0.9595         3.1930       2.4270
# max             446511.8571        134.3659     20590.4700  486211.2845
#
#        cash_ratio  days_of_sales_outstanding  days_of_inventory_outstanding  \
# count  19019.0000                 19835.0000                     20168.0000
# mean      19.0004                  -402.0755                       602.3590
# std     1686.6688                 37239.2327                     39376.9571
# min        0.0000              -5182867.0185                   -473104.3422
# 25%        0.1416                   -69.7278                        10.7449
# 50%        0.4605                    -5.3436                        45.7230
# 75%        1.2424                     0.0000                        73.3080
# max   164465.7863                   975.8069                   3900070.8470
#
#        operating_cycle  days_of_payables_outstanding  cash_conversion_cycle  \
# count          19.0000                    19840.0000                19.0000
# mean          176.3765                      340.3942                43.8574
# std           220.1073                     9865.9658               131.6433
# min            68.4745                  -207232.4715              -262.6048
# 25%           105.3371                       10.2747                38.0042
# 50%           121.3161                       26.7157                55.6014
# 75%           156.0130                       55.5966                79.0934
# max          1077.7422                  1043413.3302               375.9980
#
#        debt_ratio  debt_equity_ratio  longterm_debt_to_capitalization  \
# count  19763.0000         19763.0000                       19688.0000
# mean       0.2729             0.5628                           0.3593
# std        1.1354            26.6573                           1.2292
# min       -0.4536         -2586.4359                          -1.9310
# 25%        0.0323             0.0089                           0.0000
# 50%        0.1951             0.4340                           0.2634
# 75%        0.3891             1.0774                           0.5054
# max      133.6571          2131.5128                          91.0381
#
#        total_debt_to_capitalization  interest_coverage  \
# count                    19785.0000         19890.0000
# mean                         0.4531           -32.1976
# std                          7.5196          3781.2633
# min                         -2.7361       -223603.0000
# 25%                          0.0223             0.0000
# 50%                          0.3099             0.8185
# 75%                          0.5434             6.2999
# max                       1040.0474        361207.3684
#
#        cash_flow_to_debt_ratio  company_equity_multiplier  \
# count               15801.0000                 18742.0000
# mean                   67.1736                  1232.5749
# std                  6929.1478                 82998.6409
# min                -40783.9404                     0.2747
# 25%                     0.0646                     1.5633
# 50%                     0.2142                     2.2817
# 75%                     0.5012                     4.1128
# max                863187.7715               8740761.3333
#
#        operating_cash_flow_per_share  free_cash_flow_per_share  \
# count                     19652.0000                19653.0000
# mean                      22904.8088                 1507.1829
# std                      763234.3879               405433.7599
# min                   -24942284.4156            -35588921.2830
# 25%                           0.0622                   -0.4392
# 50%                           1.7064                    0.6610
# 75%                           4.2395                    2.4427
# max                    45351079.1630             31932634.4532
#
#        cash_per_share  payout_ratio  operating_cash_flow_sales_ratio  \
# count      19648.0000    19687.0000                       19215.0000
# mean       83671.8302        0.3233                         -11.8965
# std      3097123.5149        5.9618                       11384.2230
# min            0.0000     -137.1540                    -1432432.4324
# 25%            0.6936        0.0000                           0.0272
# 50%            2.0399        0.0000                           0.1217
# 75%            5.5049        0.3420                           0.2817
# max    212722714.1558      479.5700                      377383.5920
#
#        free_cash_flow_operating_cash_flow_ratio  cash_flow_coverage_ratios  \
# count                                15489.0000                 15801.0000
# mean                                    -0.6983                    67.1736
# std                                     95.6137                  6929.1478
# min                                 -11849.1722                -40783.9404
# 25%                                      0.2662                     0.0646
# 50%                                      0.6893                     0.2142
# 75%                                      0.8867                     0.5012
# max                                     47.6529                863187.7715
#
#        short_term_coverage_ratios  capital_expenditure_coverage_ratios  \
# count                  11333.0000                           18428.0000
# mean                     254.5973                             -13.6074
# std                    10450.2959                            2438.3686
# min                   -16336.6667                          -46880.0000
# 25%                        0.3480                               0.3001
# 50%                        2.4075                               1.9817
# 75%                       10.3567                               5.5048
# max                   863187.7715                          313315.6667
#
#        dividendpaid_and_capex_coverage_ratios  dividend_payout_ratio  \
# count                              19157.0000             12998.0000
# mean                                 -33.9373                 0.8212
# std                                  764.9737                10.6937
# min                               -46880.0000                -0.0000
# 25%                                    0.2565                 0.0000
# 50%                                    1.3934                 0.2320
# 75%                                    2.9291                 0.5489
# max                                64384.9132               746.7015
#
#        revenue_per_share  net_income_per_share  operating_cash_flow_per_share  \
# count         19634.0000            19632.0000                     19664.0000
# mean         151639.5713            12909.9363                     22890.8338
# std         4206785.5524           485543.6331                    763001.6673
# min              -3.1677        -12724877.5000                 -24942284.4156
# 25%               3.5092               -0.4063                         0.0606
# 50%              11.1269                0.7174                         1.7052
# 75%              32.2060                2.2391                         4.2389
# max       226232494.8637         29790471.6736                  45351079.1630
#
#        free_cash_flow_per_share  cash_per_share  book_value_per_share  \
# count                19665.0000      19647.0000            19646.0000
# mean                  1506.2623      83676.0889            57141.1634
# std                 405310.0343    3097202.2796          4686263.3059
# min              -35588921.2830          0.0000          -642647.3910
# 25%                     -0.4400          0.6937                3.4799
# 50%                      0.6610          2.0403               10.0150
# 75%                      2.4422          5.5051               19.9605
# max               31932634.4532  212722714.1558        616362318.8410
#
#        tangible_book_value_per_share  shareholders_equity_per_share  \
# count                     19646.0000                     19647.0000
# mean                     108896.1331                    202814.8394
# std                     8442215.6725                   4956871.3173
# min                           0.0000                   -660561.1875
# 25%                           7.1240                         3.5843
# 50%                          19.9695                        10.6871
# 75%                          54.0725                        21.5993
# max                  1095289855.0700                 258351241.9284
#
#        interest_debt_per_share          market_cap   enterprise_value  \
# count               19646.0000          19006.0000         17037.0000
# mean               319578.2413    30560346775.2489    8478816748.5960
# std               8965197.1183  1432506118466.1589   32731994168.2619
# min                   -20.0091              0.0000 -148754786733.0000
# 25%                     0.3443      197617044.7650     219909584.8800
# 50%                     6.1585      913560431.1150    1174284190.9100
# 75%                    18.7427     3882652181.0200    4899351328.5200
# max             419924840.9012 96192000000000.0000 1145830982760.0000
#
#          pe_ratio  price_to_sales_ratio   pocf_ratio  pfcf_ratio  \
# count  19829.0000            19822.0000   18880.0000  19828.0000
# mean      37.9037               87.9540      53.9166     36.4268
# std      852.9069             3496.8482    4240.0646    645.2775
# min        0.0000                0.0000 -108768.6767      0.0000
# 25%        0.0000                0.7288       1.5861      0.0000
# 50%       12.9515                1.8767       8.9771      8.8680
# 75%       23.4250                4.2913      15.9333     20.2903
# max   105828.7129           377315.7961  554659.9637  60328.7741
#
#             pb_ratio      ptb_ratio  ev_to_sales  \
# count     17100.0000     17100.0000   17030.0000
# mean      20328.1694     20325.9089      53.7153
# std     1293759.2812   1293759.1712    1675.3461
# min           0.0000         0.0000   -4324.8114
# 25%           1.0998         0.6191       0.9143
# 50%           1.9043         1.7591       2.3357
# 75%           3.6961         4.3034       5.5737
# max   108458749.3333 108458749.3333  185096.2978
#
#        enterprise_value_over_ebitda  ev_to_operating_cash_flow  \
# count                    17034.0000                 17034.0000
# mean                        21.7311                    40.0733
# std                        308.2015                  4017.1286
# min                          0.0000                -94684.1767
# 25%                          2.2759                     2.9592
# 50%                          9.9278                    12.0540
# 75%                         15.4848                    20.0707
# max                      35296.1960                512579.0405
#
#        ev_to_free_cash_flow  earnings_yield  free_cash_flow_yield  \
# count            17034.0000      19829.0000            18880.0000
# mean               -19.4791         -0.2151               -1.7353
# std               3988.3977        219.1828              191.1059
# min            -467933.3193     -21375.0000           -25896.7081
# 25%                 -4.9619         -0.0453               -0.0429
# 50%                 12.6146          0.0313                0.0336
# 75%                 25.6351          0.0601                0.0734
# max              84994.8903      12673.4414              293.8176
#
#        debt_to_equity  debt_to_assets  net_debt_to_ebitda  current_ratio  \
# count      19763.0000      19763.0000          14362.0000     15561.0000
# mean           0.5628          0.2729              2.8823         6.5790
# std           26.6573          1.1354            236.6003       190.4740
# min        -2586.4359         -0.4536          -9616.0000        -1.4393
# 25%            0.0089          0.0323             -0.4537         1.1570
# 50%            0.4340          0.1951              1.1271         1.9040
# 75%            1.0774          0.3891              3.1634         3.3450
# max         2131.5128        133.6571          22776.5294     20590.4700
#
#        interest_coverage  income_quality  dividend_yield  payout_ratio  \
# count         19920.0000      19857.0000      19831.0000    19708.0000
# mean            -32.0775          2.8212          0.0204        0.3231
# std            3778.4276        136.3167          0.1432        5.9586
# min         -223603.0000      -2719.5000          0.0000     -137.1540
# 25%               0.0000          0.3791          0.0000        0.0000
# 50%               0.8168          1.1945          0.0000        0.0000
# 75%               6.2957          2.0410          0.0217        0.3420
# max          361207.3684      17675.5000         14.5500      479.5700
#
#        sg&a_to_revenue  r&d_to_revenue  intangibles_to_total_assets  \
# count       19853.0000      19800.0000                   19880.0000
# mean            3.5099          4.4451                       0.1547
# 50%                      -5.3736                5.9433             2.6148
# 75%                       0.0000                9.8811             5.1141
# max                     975.8069           164428.5000          8650.3158
#
#        inventory_turnover           roe  capex_per_share  gross_profit_growth  \
# count          19565.0000    19737.0000       19664.0000           20069.0000
# mean              31.6242     1646.1073      -18800.3150              18.9515
# std              727.3355   114827.9427      662354.2550            2380.5577
# min                0.0000   -34772.4596   -73354000.0000           -5536.4833
# 25%                0.0000       -0.0662          -1.6052              -0.0240
# 50%                3.2234        0.0712          -0.4575               0.0625
# 75%               10.4659        0.1460          -0.0775               0.2123
# max            95827.7103 11141141.6667     1255872.9715          336767.8000
#
#        ebit_growth  operating_income_growth  net_income_growth  eps_growth  \
# count   19736.0000               20109.0000         19695.0000  19894.0000
# mean        0.8077                   0.4620            -2.2304      0.2834
# std       233.2634                 188.4220           248.9596     37.7488
# min    -16888.0000              -18881.0000        -33777.0000  -2125.0000
# 25%        -0.2931                  -0.2700            -0.4077     -0.3229
# 50%         0.0591                   0.0569             0.0611      0.0976
# 75%         0.4195                   0.3699             0.5313      0.5833
# max     20598.4286               13545.3387          3159.0000   4378.0492
#
#        eps_diluted_growth  weighted_average_shares_growth  \
# count          19884.0000                      19269.0000
# mean            1995.8130                         13.2090
# std           281395.5581                       1611.2690
# min            -2125.0000                         -0.9999
# 25%               -0.3194                         -0.0048
# 50%                0.0985                          0.0085
# 75%                0.5833                          0.0840
# max         39679767.0417                     223089.5000
#
#        weighted_average_shares_diluted_growth  dividends_per_share_growth  \
# count                              18155.0000                  19608.0000
# mean                                 189.6110                      0.1582
# std                                25075.1199                      3.5024
# min                                   -1.0000                     -1.0000
# 25%                                   -0.0037                      0.0000
# 50%                                    0.0097                      0.0000
# 75%                                    0.0960                      0.0417
# max                              3378329.4723                    372.5714
#
#        operating_cash_flow_growth  free_cash_flow_growth  \
# count                  20014.0000             19603.0000
# mean                      64.1096                -3.5446
# std                     5239.6282               603.6085
# min                   -18001.0000            -83431.4286
# 25%                       -0.2811                -0.4762
# 50%                        0.0457                 0.0268
# 75%                        0.4079                 0.5871
# max                   455999.0000              8030.3333
#
#        10y_revenue_growth_(per_share)  5y_revenue_growth_(per_share)  \
# count                      12545.0000                     15676.0000
# mean                           0.0211                         0.0282
# std                            0.1563                         0.2358
# min                           -1.0000                        -1.0000
# 25%                           -0.0156                        -0.0237
# 50%                            0.0325                         0.0379
# 75%                            0.0811                         0.1012
# max                            1.7470                         8.9762
#
#        3y_revenue_growth_(per_share)  10y_operating_cf_growth_(per_share)  \
# count                     17611.0000                           12599.0000
# mean                          0.0407                               0.0378
# std                           0.5080                               0.1153
# min                          -1.0000                              -0.7618
# 25%                          -0.0344                               0.0000
# 50%                           0.0330                               0.0119
# 75%                           0.1049                               0.0865
# max                          43.9195                               1.7327
#
#        5y_operating_cf_growth_(per_share)  3y_operating_cf_growth_(per_share)  \
# count                          15713.0000                          17644.0000
# mean                               0.0473                              0.0642
# std                                0.1977                              0.3163
# min                               -1.0000                             -1.0000
# 25%                                0.0000                             -0.0044
# 50%                                0.0000                              0.0000
# 75%                                0.1066                              0.1250
# max                                4.1862                              9.6961
#
#        10y_net_income_growth_(per_share)  5y_net_income_growth_(per_share)  \
# count                         12545.0000                        15676.0000
# mean                              0.0308                            0.0569
# std                               0.1110                            0.2042
# min                              -1.0000                           -1.0000
# 25%                               0.0000                            0.0000
# 50%                               0.0000                            0.0000
# 75%                               0.0722                            0.1051
# max                               1.3372                            4.4761
#
#        3y_net_income_growth_(per_share)  \
# count                        17611.0000
# mean                             0.0724
# std                              0.3754
# min                             -1.0000
# 25%                              0.0000
# 50%                              0.0000
# 75%                              0.1126
# max                             17.0282
#
#        10y_shareholders_equity_growth_(per_share)  \
# count                                  12397.0000
# mean                                       0.0335
# std                                        0.1266
# min                                       -0.7137
# 25%                                       -0.0082
# 50%                                        0.0361
# 75%                                        0.0887
# max                                        2.4510
#
#        5y_shareholders_equity_growth_(per_share)  \
# count                                 15467.0000
# mean                                      0.0392
# std                                       0.2039
# min                                      -0.8874
# 25%                                      -0.0155
# 50%                                       0.0315
# 75%                                       0.0957
# max                                       6.0316
#
#        3y_shareholders_equity_growth_(per_share)  \
# count                                 17434.0000
# mean                                      0.0476
# std                                       0.3866
# min                                      -0.9810
# 25%                                      -0.0311
# 50%                                       0.0264
# 75%                                       0.1003
# max                                      20.0367
#
#        10y_dividend_per_share_growth_(per_share)  \
# count                                 12900.0000
# mean                                     -0.0262
# std                                       0.2296
# min                                      -1.0000
# 25%                                       0.0000
# 50%                                       0.0000
# 75%                                       0.0283
# max                                       0.9128
#
#        5y_dividend_per_share_growth_(per_share)  \
# count                                16299.0000
# mean                                    -0.0006
# std                                      0.2299
# min                                     -1.0000
# 25%                                      0.0000
# 50%                                      0.0000
# 75%                                      0.0353
# max                                      2.9811
#
#        3y_dividend_per_share_growth_(per_share)  receivables_growth  \
# count                                18264.0000          19952.0000
# mean                                     0.0123             10.9782
# std                                      0.2631           1101.0982
# min                                     -1.0000             -1.0000
# 25%                                      0.0000             -0.0511
# 50%                                      0.0000              0.0095
# 75%                                      0.0400              0.2006
# max                                      5.4005         153332.3333
#
#        inventory_growth  asset_growth  book_value_per_share_growth  \
# count        19650.0000    19690.0000                   19213.0000
# mean             0.1589        1.1342                       0.7832
# std              3.2682       45.3811                      66.5240
# min             -1.0000       -1.0000                   -3963.1312
# 25%              0.0000       -0.0311                      -0.1038
# 50%              0.0000        0.0480                       0.0324
# 75%              0.0584        0.1768                       0.1421
# max            293.4730     5468.4264                    7039.3259
#
#        debt_growth  r&d_expense_growth  sg&a_expenses_growth  \
# count   19462.0000          19598.0000            19655.0000
# mean        3.7339              0.2956                0.3651
# std       174.8647             12.9741               15.0301
# min        -1.0510             -2.6622               -2.3699
# 25%        -0.0675              0.0000               -0.0137
# 50%         0.0000              0.0000                0.0610
# 75%         0.1501              0.0000                0.1854
# max     17646.8235           1542.6110             2042.0000
#
#        price_var_next_yr_%
# count           22077.0000
# mean              269.8893
# std             19346.1736
# min              -100.3972
# 25%               -19.4741
# 50%                 3.9091
# 75%                27.5057
# max           2418600.9153

# %% [markdown]
# ### Correlation Between Predictors

# %%
corr_pred = df.drop(columns=['sector'])
correlation_matrix = corr_pred.corr()
# Create a heatmap using Seaborn
plt.figure(figsize=(12, 8))
sns.set(font_scale=.4) 
sns.heatmap(correlation_matrix, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Plot for Predictor Values')
plt.show()

# %% [markdown]
# We plot a correlation heatmap as seen above, to determine confounding variables which may yield multicollinearity that we will need to drop before modeling. This provides us with a visual representation of how strongly variables are correlated with each other. Positive values, colored red, indicate a positive correlation, while negative values (in blue) indicate
# a negative correlation. Gray values are close to zero, and suggest a weak or no correlation. Though the plot is difficult to interpret due to having many features, we observe a significant orange hue in the top-left corner, indicating a positive correlation ranging from 0.5 to 0.75. Additionally, there is a blue stripe near the top left, signifying a negative correlation in the range of -0.25 to -0.5. This tells us that financial metrics such as revenue, net income, profit margin, etc. are very correlated, which makes sense logically. The negatively correlated variables correspond with other metrics such as depreciation, investing cash flow, etc. that correlate negatively with revenue and positive metrics. In our final model, we will definitely need to further reduce financial metrics that give similar information.

# %% [markdown]
# ### Examining Imbalance Issues

# %%
df.dtypes
# Out:
# year                                           object
# revenue                                       float64
# revenue_growth                                float64
# cost_of_revenue                               float64
# gross_profit                                  float64
# r&d_expenses                                  float64
# sg&a_expense                                  float64
# operating_expenses                            float64
# operating_income                              float64
# interest_expense                              float64
# earnings_before_tax                           float64
# income_tax_expense                            float64
# net_income_-_non-controlling_int              float64
# net_income_-_discontinued_ops                 float64
# net_income                                    float64
# preferred_dividends                           float64
# net_income_com                                float64
# eps                                           float64
# eps_diluted                                   float64
# weighted_average_shs_out                      float64
# weighted_average_shs_out_(dil)                float64
# dividend_per_share                            float64
# gross_margin                                  float64
# ebitda_margin                                 float64
# ebit_margin                                   float64
# profit_margin                                 float64
# free_cash_flow_margin                         float64
# ebitda                                        float64
# ebit                                          float64
# consolidated_income                           float64
# earnings_before_tax_margin                    float64
# net_profit_margin                             float64
# cash_and_cash_equivalents                     float64
# short-term_investments                        float64
# cash_and_short-term_investments               float64
# receivables                                   float64
# inventories                                   float64
# total_current_assets                          float64
# property,_plant_&_equipment_net               float64
# goodwill_and_intangible_assets                float64
# long-term_investments                         float64
# tax_assets                                    float64
# total_non-current_assets                      float64
# total_assets                                  float64
# payables                                      float64
# short-term_debt                               float64
# total_current_liabilities                     float64
# long-term_debt                                float64
# total_debt                                    float64
# deferred_revenue                              float64
# tax_liabilities                               float64
# deposit_liabilities                           float64
# total_non-current_liabilities                 float64
# total_liabilities                             float64
# other_comprehensive_income                    float64
# retained_earnings_(deficit)                   float64
# total_shareholders_equity                     float64
# investments                                   float64
# net_debt                                      float64
# other_assets                                  float64
# other_liabilities                             float64
# depreciation_&_amortization                   float64
# stock-based_compensation                      float64
# operating_cash_flow                           float64
# capital_expenditure                           float64
# acquisitions_and_disposals                    float64
# investment_purchases_and_sales                float64
# investing_cash_flow                           float64
# issuance_(repayment)_of_debt                  float64
# issuance_(buybacks)_of_shares                 float64
# dividend_payments                             float64
# financing_cash_flow                           float64
# effect_of_forex_changes_on_cash               float64
# net_cash_flow_/_change_in_cash                float64
# free_cash_flow                                float64
# net_cash/marketcap                            float64
# price_book_value_ratio                        float64
# price_to_book_ratio                           float64
# price_to_sales_ratio                          float64
# price_earnings_ratio                          float64
# price_to_free_cash_flows_ratio                float64
# price_to_operating_cash_flows_ratio           float64
# price_cash_flow_ratio                         float64
# price_earnings_to_growth_ratio                float64
# price_sales_ratio                             float64
# dividend_yield                                float64
# enterprise_value_multiple                     float64
# price_fair_value                              float64
# ebitper_revenue                               float64
# ebtper_ebit                                   float64
# niper_ebt                                     float64
# gross_profit_margin                           float64
# operating_profit_margin                       float64
# pretax_profit_margin                          float64
# net_profit_margin                             float64
# effective_tax_rate                            float64
# return_on_assets                              float64
# return_on_equity                              float64
# return_on_capital_employed                    float64
# n_iper_ebt                                    float64
# e_btper_ebit                                  float64
# e_bitper_revenue                              float64
# payables_turnover                             float64
# inventory_turnover                            float64
# fixed_asset_turnover                          float64
# asset_turnover                                float64
# current_ratio                                 float64
# quick_ratio                                   float64
# cash_ratio                                    float64
# days_of_sales_outstanding                     float64
# days_of_inventory_outstanding                 float64
# operating_cycle                               float64
# days_of_payables_outstanding                  float64
# cash_conversion_cycle                         float64
# debt_ratio                                    float64
# debt_equity_ratio                             float64
# longterm_debt_to_capitalization               float64
# total_debt_to_capitalization                  float64
# interest_coverage                             float64
# cash_flow_to_debt_ratio                       float64
# company_equity_multiplier                     float64
# operating_cash_flow_per_share                 float64
# free_cash_flow_per_share                      float64
# cash_per_share                                float64
# payout_ratio                                  float64
# operating_cash_flow_sales_ratio               float64
# free_cash_flow_operating_cash_flow_ratio      float64
# cash_flow_coverage_ratios                     float64
# short_term_coverage_ratios                    float64
# capital_expenditure_coverage_ratios           float64
# dividendpaid_and_capex_coverage_ratios        float64
# dividend_payout_ratio                         float64
# revenue_per_share                             float64
# net_income_per_share                          float64
# operating_cash_flow_per_share                 float64
# free_cash_flow_per_share                      float64
# cash_per_share                                float64
# book_value_per_share                          float64
# tangible_book_value_per_share                 float64
# shareholders_equity_per_share                 float64
# interest_debt_per_share                       float64
# market_cap                                    float64
# enterprise_value                              float64
# pe_ratio                                      float64
# price_to_sales_ratio                          float64
# pocf_ratio                                    float64
# pfcf_ratio                                    float64
# pb_ratio                                      float64
# ptb_ratio                                     float64
# ev_to_sales                                   float64
# enterprise_value_over_ebitda                  float64
# ev_to_operating_cash_flow                     float64
# ev_to_free_cash_flow                          float64
# earnings_yield                                float64
# free_cash_flow_yield                          float64
# debt_to_equity                                float64
# debt_to_assets                                float64
# net_debt_to_ebitda                            float64
# current_ratio                                 float64
# interest_coverage                             float64
# income_quality                                float64
# dividend_yield                                float64
# payout_ratio                                  float64
# sg&a_to_revenue                               float64
# r&d_to_revenue                                float64
# intangibles_to_total_assets                   float64
# capex_to_operating_cash_flow                  float64
# capex_to_revenue                              float64
# capex_to_depreciation                         float64
# stock-based_compensation_to_revenue           float64
# graham_number                                 float64
# roic                                          float64
# return_on_tangible_assets                     float64
# graham_net-net                                float64
# working_capital                               float64
# tangible_asset_value                          float64
# net_current_asset_value                       float64
# invested_capital                              float64
# average_receivables                           float64
# average_payables                              float64
# average_inventory                             float64
# days_sales_outstanding                        float64
# days_payables_outstanding                     float64
# days_of_inventory_on_hand                     float64
# receivables_turnover                          float64
# payables_turnover                             float64
# inventory_turnover                            float64
# roe                                           float64
# capex_per_share                               float64
# gross_profit_growth                           float64
# ebit_growth                                   float64
# operating_income_growth                       float64
# net_income_growth                             float64
# eps_growth                                    float64
# eps_diluted_growth                            float64
# weighted_average_shares_growth                float64
# weighted_average_shares_diluted_growth        float64
# dividends_per_share_growth                    float64
# operating_cash_flow_growth                    float64
# free_cash_flow_growth                         float64
# 10y_revenue_growth_(per_share)                float64
# 5y_revenue_growth_(per_share)                 float64
# 3y_revenue_growth_(per_share)                 float64
# 10y_operating_cf_growth_(per_share)           float64
# 5y_operating_cf_growth_(per_share)            float64
# 3y_operating_cf_growth_(per_share)            float64
# 10y_net_income_growth_(per_share)             float64
# 5y_net_income_growth_(per_share)              float64
# 3y_net_income_growth_(per_share)              float64
# 10y_shareholders_equity_growth_(per_share)    float64
# 5y_shareholders_equity_growth_(per_share)     float64
# 3y_shareholders_equity_growth_(per_share)     float64
# 10y_dividend_per_share_growth_(per_share)     float64
# 5y_dividend_per_share_growth_(per_share)      float64
# 3y_dividend_per_share_growth_(per_share)      float64
# receivables_growth                            float64
# inventory_growth                              float64
# asset_growth                                  float64
# book_value_per_share_growth                   float64
# debt_growth                                   float64
# r&d_expense_growth                            float64
# sg&a_expenses_growth                          float64
# sector                                         object
# price_var_next_yr_%                           float64
# dtype: object

# %% [markdown]
# It looks like only the predictors `year` and `sector` are categorical variables that might introduce imabalance issues. Let's invistigate then.

# %%
def calculate_class_distribution_summary(df):
    """
    Generate a summary table showing the distribution of classes for categorical columns.

    Parameters:
    - df (pandas.DataFrame): The DataFrame for which to calculate class distributions.

    Returns:
    - pandas.DataFrame: A DataFrame containing the class distribution summary.
    """
    class_summary = pd.DataFrame()

    # Loop over categorical columns and calculate class distribution
    for col in df.select_dtypes(include=['object', 'category']).columns:
        # Get class distribution for the current column
        dist = df[col].value_counts(normalize=True).reset_index()
        dist.columns = ['Class', 'Percentage']
        dist['Feature'] = col
        dist['Count'] = df[col].value_counts().reset_index(drop=True)
        
        # Append to the summary DataFrame
        class_summary = pd.concat([class_summary, dist], ignore_index=True)

    return class_summary

# %%
predictors_cat_sum = calculate_class_distribution_summary(df)
print(predictors_cat_sum)
# Out:
#                      Class  Percentage Feature  Count
# 0                     2017      0.2247    year   4960
# 1                     2016      0.2173    year   4797
# 2                     2018      0.1989    year   4392
# 3                     2015      0.1866    year   4120
# 4                     2014      0.1725    year   3808
# 5       Financial Services      0.2138  sector   4720
# 6               Healthcare      0.1497  sector   3305
# 7               Technology      0.1416  sector   3126
# 8              Industrials      0.1254  sector   2768
# 9        Consumer Cyclical      0.1119  sector   2471
# 10         Basic Materials      0.0609  sector   1344
# 11             Real Estate      0.0562  sector   1241
# 12                  Energy      0.0551  sector   1217
# 13      Consumer Defensive      0.0418  sector    922
# 14               Utilities      0.0235  sector    518
# 15  Communication Services      0.0202  sector    445

# %%
predictors_cat_sum.plot.bar(x='Class', y= 'Percentage', rot = 80)
plt.ylabel("Percentage")
plt.title('Class Distribution Summary')
# Out:
# Text(0.5, 1.0, 'Class Distribution Summary')

# %% [markdown]
# We notice that sector distribution does show some imbalance, which is common in real-world datasets where some categories (in our case, sectors like Financial Services, Healthcare, and
# Technology) are more prevalent than others (like Utilities and Communication Services).

# %% [markdown]
# ## 0.3 Handling Missingingness

# %% [markdown]
# ### Examine Nullness (Preliminary)

# %% [markdown]
# From below we see that our data set does have quite a few missing values. We will handle the missingness using imputation methods later.
#
# We can also use the `missingno` (missing "no") library to visualize the patterns of missing data.
#
# **Interpretation Strategies:**
# * Randomness: If the missingness appears random without a discernible pattern across the matrix plot, it may suggest that the data is Missing Completely At Random (MCAR).
# * Patterns or Bands: Systematic patterns or bands in the matrix plot may suggest that the data is Missing At Random (MAR) where missingness is systematic and related to other observed variables.
# * Blocks: If you see blocks of white in the matrix plot, this suggests that there might be groups of data that are Missing Not At Random (MNAR), indicating a potential inherent problem with the data collection process.
# * Correlation in Heatmap: High correlation in the heatmap suggests that the missingness of one variable is not independent of another, which is common with MAR or MNAR.

# %%
#Check for total null values in individual dataframes
df2014.isnull().sum()
# Out:
# Year                                             0
# Ticker                                           0
# Revenue                                         44
# Revenue Growth                                 236
# Cost of Revenue                                 74
# Gross Profit                                    52
# R&D Expenses                                   136
# SG&A Expense                                    59
# Operating Expenses                              63
# Operating Income                                55
# Interest Expense                                63
# Earnings before Tax                             80
# Income Tax Expense                              66
# Net Income - Non-Controlling int               149
# Net Income - Discontinued ops                  149
# Net Income                                      23
# Preferred Dividends                            149
# Net Income Com                                  15
# EPS                                             72
# EPS Diluted                                     84
# Weighted Average Shs Out                       236
# Weighted Average Shs Out (Dil)                 110
# Dividend per Share                             149
# Gross Margin                                    47
# EBITDA Margin                                  202
# EBIT Margin                                     50
# Profit Margin                                  201
# Free Cash Flow margin                          159
# EBITDA                                          64
# EBIT                                             4
# Consolidated Income                             23
# Earnings Before Tax Margin                      47
# Net Profit Margin                               57
# Cash and cash equivalents                       58
# Short-term investments                         933
# Cash and short-term investments                930
# Receivables                                     59
# Inventories                                    115
# Total current assets                           871
# Property, Plant & Equipment Net                 88
# Goodwill and Intangible Assets                  35
# Long-term investments                          912
# Tax assets                                     133
# Total non-current assets                       908
# Total assets                                    33
# Payables                                        90
# Short-term debt                                898
# Total current liabilities                      879
# Long-term debt                                 854
# Total debt                                      78
# Deferred revenue                               136
# Tax Liabilities                                131
# Deposit Liabilities                            183
# Total non-current liabilities                  911
# Total liabilities                               39
# Other comprehensive income                      73
# Retained earnings (deficit)                    164
# Total shareholders equity                       33
# Investments                                    124
# Net Debt                                      1277
# Other Assets                                  1274
# Other Liabilities                              830
# Depreciation & Amortization                     43
# Stock-based compensation                        68
# Operating Cash Flow                             40
# Capital Expenditure                             52
# Acquisitions and disposals                     124
# Investment purchases and sales                  22
# Investing Cash flow                             25
# Issuance (repayment) of debt                    61
# Issuance (buybacks) of shares                  108
# Dividend payments                              142
# Financing Cash Flow                             11
# Effect of forex changes on cash                 83
# Net cash flow / Change in cash                  15
# Free Cash Flow                                  47
# Net Cash/Marketcap                             349
# priceBookValueRatio                            659
# priceToBookRatio                               659
# priceToSalesRatio                              181
# priceEarningsRatio                             181
# priceToFreeCashFlowsRatio                      181
# priceToOperatingCashFlowsRatio                 338
# priceCashFlowRatio                            1053
# priceEarningsToGrowthRatio                    1296
# priceSalesRatio                                396
# dividendYield                                  688
# enterpriseValueMultiple                        944
# priceFairValue                                 428
# ebitperRevenue                                 346
# ebtperEBIT                                    1118
# niperEBT                                      1243
# grossProfitMargin                              346
# operatingProfitMargin                          346
# pretaxProfitMargin                             346
# netProfitMargin                                346
# effectiveTaxRate                              1243
# returnOnAssets                                 995
# returnOnEquity                                 192
# returnOnCapitalEmployed                        987
# nIperEBT                                      1243
# eBTperEBIT                                    1118
# eBITperRevenue                                 346
# payablesTurnover                               781
# inventoryTurnover                              306
# fixedAssetTurnover                             345
# assetTurnover                                  173
# currentRatio                                   967
# quickRatio                                     972
# cashRatio                                      972
# daysOfSalesOutstanding                         182
# daysOfInventoryOutstanding                     181
# operatingCycle                                3807
# daysOfPayablesOutstanding                      181
# cashConversionCycle                           3807
# debtRatio                                      185
# debtEquityRatio                                185
# longtermDebtToCapitalization                   282
# totalDebtToCapitalization                      269
# interestCoverage                               172
# cashFlowToDebtRatio                           1596
# companyEquityMultiplier                        376
# operatingCashFlowPerShare                      230
# freeCashFlowPerShare                           229
# cashPerShare                                   232
# payoutRatio                                    207
# operatingCashFlowSalesRatio                    346
# freeCashFlowOperatingCashFlowRatio            1016
# cashFlowCoverageRatios                        1596
# shortTermCoverageRatios                       1956
# capitalExpenditureCoverageRatios               421
# dividendpaidAndCapexCoverageRatios             293
# dividendPayoutRatio                           1296
# Revenue per Share                              227
# Net Income per Share                           227
# Operating Cash Flow per Share                  218
# Free Cash Flow per Share                       217
# Cash per Share                                 232
# Book Value per Share                           231
# Tangible Book Value per Share                  231
# Shareholders Equity per Share                  232
# Interest Debt per Share                        231
# Market Cap                                     298
# Enterprise Value                               654
# PE ratio                                       154
# Price to Sales Ratio                           154
# POCF ratio                                     315
# PFCF ratio                                     154
# PB ratio                                       644
# PTB ratio                                      644
# EV to Sales                                    654
# Enterprise Value over EBITDA                   654
# EV to Operating cash flow                      654
# EV to Free cash flow                           654
# Earnings Yield                                 154
# Free Cash Flow Yield                           315
# Debt to Equity                                 185
# Debt to Assets                                 185
# Net Debt to EBITDA                            1424
# Current ratio                                  988
# Interest Coverage                              144
# Income Quality                                 156
# Dividend Yield                                 154
# Payout Ratio                                   186
# SG&A to Revenue                                156
# R&D to Revenue                                 162
# Intangibles to Total Assets                    173
# Capex to Operating Cash Flow                   144
# Capex to Revenue                               156
# Capex to Depreciation                          158
# Stock-based compensation to Revenue            165
# Graham Number                                  644
# ROIC                                           987
# Return on Tangible Assets                      995
# Graham Net-Net                                 315
# Working Capital                                987
# Tangible Asset Value                           173
# Net Current Asset Value                        958
# Invested Capital                               185
# Average Receivables                            288
# Average Payables                               288
# Average Inventory                              288
# Days Sales Outstanding                         182
# Days Payables Outstanding                      182
# Days of Inventory on Hand                      183
# Receivables Turnover                           306
# Payables Turnover                              781
# Inventory Turnover                             306
# ROE                                            193
# Capex per Share                                218
# Gross Profit Growth                            231
# EBIT Growth                                    231
# Operating Income Growth                        231
# Net Income Growth                              243
# EPS Growth                                     282
# EPS Diluted Growth                             293
# Weighted Average Shares Growth                 336
# Weighted Average Shares Diluted Growth        1049
# Dividends per Share Growth                     237
# Operating Cash Flow growth                     232
# Free Cash Flow growth                          238
# 10Y Revenue Growth (per Share)                1547
# 5Y Revenue Growth (per Share)                 1037
# 3Y Revenue Growth (per Share)                  733
# 10Y Operating CF Growth (per Share)           1536
# 5Y Operating CF Growth (per Share)            1031
# 3Y Operating CF Growth (per Share)             726
# 10Y Net Income Growth (per Share)             1547
# 5Y Net Income Growth (per Share)              1037
# 3Y Net Income Growth (per Share)               733
# 10Y Shareholders Equity Growth (per Share)    1585
# 5Y Shareholders Equity Growth (per Share)     1064
# 3Y Shareholders Equity Growth (per Share)      796
# 10Y Dividend per Share Growth (per Share)     1465
# 5Y Dividend per Share Growth (per Share)       952
# 3Y Dividend per Share Growth (per Share)       600
# Receivables growth                             290
# Inventory Growth                               290
# Asset Growth                                   290
# Book Value per Share Growth                    369
# Debt Growth                                    302
# R&D Expense Growth                             247
# SG&A Expenses Growth                           243
# Sector                                           0
# price_var_next_yr_%                              0
# Class                                            0
# dtype: int64

# %%
df2015.isnull().sum()
# Out:
# Year                                             0
# Ticker                                           0
# Revenue                                         67
# Revenue Growth                                 340
# Cost of Revenue                                193
# Gross Profit                                    65
# R&D Expenses                                   265
# SG&A Expense                                   170
# Operating Expenses                             174
# Operating Income                                42
# Interest Expense                               175
# Earnings before Tax                            103
# Income Tax Expense                             151
# Net Income - Non-Controlling int               287
# Net Income - Discontinued ops                  287
# Net Income                                     165
# Preferred Dividends                            287
# Net Income Com                                 119
# EPS                                             96
# EPS Diluted                                     90
# Weighted Average Shs Out                       117
# Weighted Average Shs Out (Dil)                 250
# Dividend per Share                             287
# Gross Margin                                    73
# EBITDA Margin                                  341
# EBIT Margin                                    174
# Profit Margin                                  341
# Free Cash Flow margin                          293
# EBITDA                                         198
# EBIT                                           122
# Consolidated Income                            166
# Earnings Before Tax Margin                      71
# Net Profit Margin                              191
# Cash and cash equivalents                       65
# Short-term investments                         237
# Cash and short-term investments                175
# Receivables                                     43
# Inventories                                    188
# Total current assets                           199
# Property, Plant & Equipment Net                155
# Goodwill and Intangible Assets                 119
# Long-term investments                          207
# Tax assets                                     233
# Total non-current assets                      1029
# Total assets                                    88
# Payables                                       158
# Short-term debt                                236
# Total current liabilities                      200
# Long-term debt                                  60
# Total debt                                     186
# Deferred revenue                               234
# Tax Liabilities                                232
# Deposit Liabilities                            282
# Total non-current liabilities                 1033
# Total liabilities                              109
# Other comprehensive income                     180
# Retained earnings (deficit)                     45
# Total shareholders equity                      103
# Investments                                    203
# Net Debt                                      1432
# Other Assets                                  1428
# Other Liabilities                              173
# Depreciation & Amortization                    141
# Stock-based compensation                       185
# Operating Cash Flow                             64
# Capital Expenditure                            132
# Acquisitions and disposals                     232
# Investment purchases and sales                 147
# Investing Cash flow                            119
# Issuance (repayment) of debt                   164
# Issuance (buybacks) of shares                  213
# Dividend payments                              250
# Financing Cash Flow                             26
# Effect of forex changes on cash                192
# Net cash flow / Change in cash                  36
# Free Cash Flow                                 168
# Net Cash/Marketcap                             480
# priceBookValueRatio                            799
# priceToBookRatio                               799
# priceToSalesRatio                              280
# priceEarningsRatio                             279
# priceToFreeCashFlowsRatio                      279
# priceToOperatingCashFlowsRatio                 455
# priceCashFlowRatio                            1197
# priceEarningsToGrowthRatio                    1647
# priceSalesRatio                                502
# dividendYield                                  501
# enterpriseValueMultiple                       1224
# priceFairValue                                 553
# ebitperRevenue                                 393
# ebtperEBIT                                    1425
# niperEBT                                      1557
# grossProfitMargin                              393
# operatingProfitMargin                          393
# pretaxProfitMargin                             393
# netProfitMargin                                393
# effectiveTaxRate                              1557
# returnOnAssets                                1130
# returnOnEquity                                 303
# returnOnCapitalEmployed                       1125
# nIperEBT                                      1557
# eBTperEBIT                                    1425
# eBITperRevenue                                 393
# payablesTurnover                               908
# inventoryTurnover                              393
# fixedAssetTurnover                             438
# assetTurnover                                  249
# currentRatio                                   307
# quickRatio                                     304
# cashRatio                                      304
# daysOfSalesOutstanding                         281
# daysOfInventoryOutstanding                     216
# operatingCycle                                4118
# daysOfPayablesOutstanding                      281
# cashConversionCycle                           4118
# debtRatio                                      303
# debtEquityRatio                                303
# longtermDebtToCapitalization                   307
# totalDebtToCapitalization                      282
# interestCoverage                               251
# cashFlowToDebtRatio                            939
# companyEquityMultiplier                        490
# operatingCashFlowPerShare                      334
# freeCashFlowPerShare                           334
# cashPerShare                                   334
# payoutRatio                                    315
# operatingCashFlowSalesRatio                    393
# freeCashFlowOperatingCashFlowRatio            1091
# cashFlowCoverageRatios                         939
# shortTermCoverageRatios                       1925
# capitalExpenditureCoverageRatios               523
# dividendpaidAndCapexCoverageRatios             383
# dividendPayoutRatio                           1647
# Revenue per Share                              339
# Net Income per Share                           339
# Operating Cash Flow per Share                  334
# Free Cash Flow per Share                       334
# Cash per Share                                 335
# Book Value per Share                           335
# Tangible Book Value per Share                  335
# Shareholders Equity per Share                  335
# Interest Debt per Share                        336
# Market Cap                                     439
# Enterprise Value                               811
# PE ratio                                       279
# Price to Sales Ratio                           280
# POCF ratio                                     455
# PFCF ratio                                     279
# PB ratio                                       799
# PTB ratio                                      799
# EV to Sales                                    812
# Enterprise Value over EBITDA                   811
# EV to Operating cash flow                      811
# EV to Free cash flow                           811
# Earnings Yield                                 279
# Free Cash Flow Yield                           455
# Debt to Equity                                 303
# Debt to Assets                                 303
# Net Debt to EBITDA                            1596
# Current ratio                                 1126
# Interest Coverage                              251
# Income Quality                                 283
# Dividend Yield                                 279
# Payout Ratio                                   315
# SG&A to Revenue                                284
# R&D to Revenue                                 295
# Intangibles to Total Assets                    255
# Capex to Operating Cash Flow                   250
# Capex to Revenue                               280
# Capex to Depreciation                          284
# Stock-based compensation to Revenue            299
# Graham Number                                  800
# ROIC                                          1125
# Return on Tangible Assets                     1130
# Graham Net-Net                                 458
# Working Capital                               1125
# Tangible Asset Value                           255
# Net Current Asset Value                        299
# Invested Capital                               303
# Average Receivables                            371
# Average Payables                               371
# Average Inventory                              372
# Days Sales Outstanding                         198
# Days Payables Outstanding                      282
# Days of Inventory on Hand                      282
# Receivables Turnover                           392
# Payables Turnover                              908
# Inventory Turnover                             393
# ROE                                            304
# Capex per Share                                334
# Gross Profit Growth                            314
# EBIT Growth                                    318
# Operating Income Growth                        314
# Net Income Growth                              347
# EPS Growth                                     385
# EPS Diluted Growth                             397
# Weighted Average Shares Growth                 432
# Weighted Average Shares Diluted Growth        1089
# Dividends per Share Growth                     345
# Operating Cash Flow growth                     315
# Free Cash Flow growth                          346
# 10Y Revenue Growth (per Share)                1737
# 5Y Revenue Growth (per Share)                 1214
# 3Y Revenue Growth (per Share)                  819
# 10Y Operating CF Growth (per Share)           1726
# 5Y Operating CF Growth (per Share)            1207
# 3Y Operating CF Growth (per Share)             812
# 10Y Net Income Growth (per Share)             1737
# 5Y Net Income Growth (per Share)              1214
# 3Y Net Income Growth (per Share)               819
# 10Y Shareholders Equity Growth (per Share)    1766
# 5Y Shareholders Equity Growth (per Share)     1252
# 3Y Shareholders Equity Growth (per Share)      867
# 10Y Dividend per Share Growth (per Share)     1646
# 5Y Dividend per Share Growth (per Share)      1104
# 3Y Dividend per Share Growth (per Share)       675
# Receivables growth                             368
# Inventory Growth                               369
# Asset Growth                                   369
# Book Value per Share Growth                    458
# Debt Growth                                    399
# R&D Expense Growth                             351
# SG&A Expenses Growth                           347
# Sector                                           0
# price_var_next_yr_%                              0
# Class                                            0
# dtype: int64

# %%
df2016.isnull().sum()
# Out:
# Year                                             0
# Ticker                                           0
# Revenue                                        489
# Revenue Growth                                 649
# Cost of Revenue                                640
# Gross Profit                                   492
# R&D Expenses                                   713
# SG&A Expense                                   613
# Operating Expenses                             620
# Operating Income                               465
# Interest Expense                               620
# Earnings before Tax                            531
# Income Tax Expense                             596
# Net Income - Non-Controlling int               738
# Net Income - Discontinued ops                  738
# Net Income                                     606
# Preferred Dividends                            738
# Net Income Com                                 558
# EPS                                            522
# EPS Diluted                                    515
# Weighted Average Shs Out                       527
# Weighted Average Shs Out (Dil)                 690
# Dividend per Share                             738
# Gross Margin                                   499
# EBITDA Margin                                  794
# EBIT Margin                                    621
# Profit Margin                                  794
# Free Cash Flow margin                          745
# EBITDA                                         643
# EBIT                                           564
# Consolidated Income                            607
# Earnings Before Tax Margin                     497
# Net Profit Margin                              637
# Cash and cash equivalents                      493
# Short-term investments                         642
# Cash and short-term investments                584
# Receivables                                    466
# Inventories                                    637
# Total current assets                           615
# Property, Plant & Equipment Net                603
# Goodwill and Intangible Assets                 561
# Long-term investments                          631
# Tax assets                                     678
# Total non-current assets                      1508
# Total assets                                   528
# Payables                                       606
# Short-term debt                                651
# Total current liabilities                      615
# Long-term debt                                 463
# Total debt                                     623
# Deferred revenue                               678
# Tax Liabilities                                675
# Deposit Liabilities                            730
# Total non-current liabilities                 1511
# Total liabilities                              551
# Other comprehensive income                     617
# Retained earnings (deficit)                    454
# Total shareholders equity                      546
# Investments                                    653
# Net Debt                                      1945
# Other Assets                                  1935
# Other Liabilities                              580
# Depreciation & Amortization                    585
# Stock-based compensation                       630
# Operating Cash Flow                            486
# Capital Expenditure                            576
# Acquisitions and disposals                     684
# Investment purchases and sales                 589
# Investing Cash flow                            555
# Issuance (repayment) of debt                   610
# Issuance (buybacks) of shares                  665
# Dividend payments                              703
# Financing Cash Flow                            446
# Effect of forex changes on cash                639
# Net cash flow / Change in cash                 457
# Free Cash Flow                                 613
# Net Cash/Marketcap                             954
# priceBookValueRatio                           1296
# priceToBookRatio                              1296
# priceToSalesRatio                              732
# priceEarningsRatio                             731
# priceToFreeCashFlowsRatio                      731
# priceToOperatingCashFlowsRatio                 927
# priceCashFlowRatio                            1708
# priceEarningsToGrowthRatio                    2214
# priceSalesRatio                                965
# dividendYield                                  964
# enterpriseValueMultiple                       1751
# priceFairValue                                1057
# ebitperRevenue                                 851
# ebtperEBIT                                    1987
# niperEBT                                      2089
# grossProfitMargin                              851
# operatingProfitMargin                          851
# pretaxProfitMargin                             851
# netProfitMargin                                851
# effectiveTaxRate                              2089
# returnOnAssets                                1607
# returnOnEquity                                 746
# returnOnCapitalEmployed                       1602
# nIperEBT                                      2089
# eBTperEBIT                                    1987
# eBITperRevenue                                 851
# payablesTurnover                              1342
# inventoryTurnover                              748
# fixedAssetTurnover                             906
# assetTurnover                                  700
# currentRatio                                   721
# quickRatio                                     719
# cashRatio                                      719
# daysOfSalesOutstanding                         726
# daysOfInventoryOutstanding                     640
# operatingCycle                                4792
# daysOfPayablesOutstanding                      726
# cashConversionCycle                           4792
# debtRatio                                      740
# debtEquityRatio                                740
# longtermDebtToCapitalization                   764
# totalDebtToCapitalization                      740
# interestCoverage                               705
# cashFlowToDebtRatio                           1388
# companyEquityMultiplier                       1000
# operatingCashFlowPerShare                      768
# freeCashFlowPerShare                           768
# cashPerShare                                   770
# payoutRatio                                    768
# operatingCashFlowSalesRatio                    851
# freeCashFlowOperatingCashFlowRatio            1590
# cashFlowCoverageRatios                        1388
# shortTermCoverageRatios                       2417
# capitalExpenditureCoverageRatios              1020
# dividendpaidAndCapexCoverageRatios             868
# dividendPayoutRatio                           2214
# Revenue per Share                              774
# Net Income per Share                           774
# Operating Cash Flow per Share                  768
# Free Cash Flow per Share                       768
# Cash per Share                                 770
# Book Value per Share                           771
# Tangible Book Value per Share                  771
# Shareholders Equity per Share                  770
# Interest Debt per Share                        771
# Market Cap                                     899
# Enterprise Value                              1308
# PE ratio                                       730
# Price to Sales Ratio                           731
# POCF ratio                                     927
# PFCF ratio                                     730
# PB ratio                                      1295
# PTB ratio                                     1295
# EV to Sales                                   1309
# Enterprise Value over EBITDA                  1308
# EV to Operating cash flow                     1308
# EV to Free cash flow                          1308
# Earnings Yield                                 730
# Free Cash Flow Yield                           927
# Debt to Equity                                 740
# Debt to Assets                                 740
# Net Debt to EBITDA                            2115
# Current ratio                                 1603
# Interest Coverage                              703
# Income Quality                                 726
# Dividend Yield                                 730
# Payout Ratio                                   768
# SG&A to Revenue                                726
# R&D to Revenue                                 740
# Intangibles to Total Assets                    708
# Capex to Operating Cash Flow                   696
# Capex to Revenue                               724
# Capex to Depreciation                          729
# Stock-based compensation to Revenue            744
# Graham Number                                 1296
# ROIC                                          1602
# Return on Tangible Assets                     1607
# Graham Net-Net                                 918
# Working Capital                               1602
# Tangible Asset Value                           708
# Net Current Asset Value                        719
# Invested Capital                               740
# Average Receivables                            640
# Average Payables                               725
# Average Inventory                              725
# Days Sales Outstanding                         620
# Days Payables Outstanding                      726
# Days of Inventory on Hand                      726
# Receivables Turnover                           664
# Payables Turnover                             1342
# Inventory Turnover                             748
# ROE                                            746
# Capex per Share                                768
# Gross Profit Growth                            634
# EBIT Growth                                    719
# Operating Income Growth                        629
# Net Income Growth                              752
# EPS Growth                                     671
# EPS Diluted Growth                             671
# Weighted Average Shares Growth                 868
# Weighted Average Shares Diluted Growth         830
# Dividends per Share Growth                     772
# Operating Cash Flow growth                     652
# Free Cash Flow growth                          775
# 10Y Revenue Growth (per Share)                2273
# 5Y Revenue Growth (per Share)                 1680
# 3Y Revenue Growth (per Share)                 1273
# 10Y Operating CF Growth (per Share)           2260
# 5Y Operating CF Growth (per Share)            1672
# 3Y Operating CF Growth (per Share)            1263
# 10Y Net Income Growth (per Share)             2273
# 5Y Net Income Growth (per Share)              1680
# 3Y Net Income Growth (per Share)              1273
# 10Y Shareholders Equity Growth (per Share)    2286
# 5Y Shareholders Equity Growth (per Share)     1741
# 3Y Shareholders Equity Growth (per Share)     1303
# 10Y Dividend per Share Growth (per Share)     2210
# 5Y Dividend per Share Growth (per Share)      1545
# 3Y Dividend per Share Growth (per Share)      1130
# Receivables growth                             640
# Inventory Growth                               725
# Asset Growth                                   722
# Book Value per Share Growth                    873
# Debt Growth                                    796
# R&D Expense Growth                             772
# SG&A Expenses Growth                           756
# Sector                                           0
# price_var_next_yr_%                              0
# Class                                            0
# dtype: int64

# %%
df2017.isnull().sum()
# Out:
# Year                                             0
# Ticker                                           0
# Revenue                                        525
# Revenue Growth                                 724
# Cost of Revenue                                679
# Gross Profit                                   534
# R&D Expenses                                   787
# SG&A Expense                                   661
# Operating Expenses                             661
# Operating Income                               504
# Interest Expense                               677
# Earnings before Tax                            579
# Income Tax Expense                             635
# Net Income - Non-Controlling int               835
# Net Income - Discontinued ops                  835
# Net Income                                     620
# Preferred Dividends                            835
# Net Income Com                                 582
# EPS                                            546
# EPS Diluted                                    540
# Weighted Average Shs Out                       548
# Weighted Average Shs Out (Dil)                 687
# Dividend per Share                             835
# Gross Margin                                   529
# EBITDA Margin                                  802
# EBIT Margin                                    655
# Profit Margin                                  802
# Free Cash Flow margin                          840
# EBITDA                                         666
# EBIT                                           592
# Consolidated Income                            620
# Earnings Before Tax Margin                     529
# Net Profit Margin                              661
# Cash and cash equivalents                      514
# Short-term investments                         721
# Cash and short-term investments                667
# Receivables                                    499
# Inventories                                    694
# Total current assets                           652
# Property, Plant & Equipment Net                644
# Goodwill and Intangible Assets                 580
# Long-term investments                          702
# Tax assets                                     727
# Total non-current assets                      1536
# Total assets                                   548
# Payables                                       642
# Short-term debt                                707
# Total current liabilities                      650
# Long-term debt                                 501
# Total debt                                     653
# Deferred revenue                               728
# Tax Liabilities                                724
# Deposit Liabilities                            827
# Total non-current liabilities                 1538
# Total liabilities                              570
# Other comprehensive income                     648
# Retained earnings (deficit)                    483
# Total shareholders equity                      566
# Investments                                    729
# Net Debt                                      1951
# Other Assets                                  1911
# Other Liabilities                              600
# Depreciation & Amortization                    613
# Stock-based compensation                       666
# Operating Cash Flow                            520
# Capital Expenditure                            619
# Acquisitions and disposals                     776
# Investment purchases and sales                 609
# Investing Cash flow                            580
# Issuance (repayment) of debt                   658
# Issuance (buybacks) of shares                  737
# Dividend payments                              814
# Financing Cash Flow                            470
# Effect of forex changes on cash                706
# Net cash flow / Change in cash                 486
# Free Cash Flow                                 644
# Net Cash/Marketcap                            1075
# priceBookValueRatio                           1409
# priceToBookRatio                              1409
# priceToSalesRatio                              835
# priceEarningsRatio                             833
# priceToFreeCashFlowsRatio                      833
# priceToOperatingCashFlowsRatio                1039
# priceCashFlowRatio                            1850
# priceEarningsToGrowthRatio                    2264
# priceSalesRatio                               1042
# dividendYield                                  886
# enterpriseValueMultiple                       1800
# priceFairValue                                1076
# ebitperRevenue                                 925
# ebtperEBIT                                    2036
# niperEBT                                      2145
# grossProfitMargin                              925
# operatingProfitMargin                          925
# pretaxProfitMargin                             925
# netProfitMargin                                925
# effectiveTaxRate                              2145
# returnOnAssets                                1697
# returnOnEquity                                 841
# returnOnCapitalEmployed                       1693
# nIperEBT                                      2145
# eBTperEBIT                                    2036
# eBITperRevenue                                 925
# payablesTurnover                              1402
# inventoryTurnover                              826
# fixedAssetTurnover                            1001
# assetTurnover                                  792
# currentRatio                                   819
# quickRatio                                     814
# cashRatio                                      814
# daysOfSalesOutstanding                         817
# daysOfInventoryOutstanding                     727
# operatingCycle                                4955
# daysOfPayablesOutstanding                      815
# cashConversionCycle                           4955
# debtRatio                                      835
# debtEquityRatio                                835
# longtermDebtToCapitalization                   809
# totalDebtToCapitalization                      792
# interestCoverage                               813
# cashFlowToDebtRatio                           1468
# companyEquityMultiplier                       1031
# operatingCashFlowPerShare                      842
# freeCashFlowPerShare                           841
# cashPerShare                                   842
# payoutRatio                                    844
# operatingCashFlowSalesRatio                    925
# freeCashFlowOperatingCashFlowRatio            1731
# cashFlowCoverageRatios                        1468
# shortTermCoverageRatios                       2520
# capitalExpenditureCoverageRatios              1117
# dividendpaidAndCapexCoverageRatios             961
# dividendPayoutRatio                           2264
# Revenue per Share                              847
# Net Income per Share                           848
# Operating Cash Flow per Share                  842
# Free Cash Flow per Share                       841
# Cash per Share                                 842
# Book Value per Share                           842
# Tangible Book Value per Share                  842
# Shareholders Equity per Share                  842
# Interest Debt per Share                        842
# Market Cap                                    1007
# Enterprise Value                              1423
# PE ratio                                       833
# Price to Sales Ratio                           835
# POCF ratio                                    1039
# PFCF ratio                                     833
# PB ratio                                      1409
# PTB ratio                                     1409
# EV to Sales                                   1425
# Enterprise Value over EBITDA                  1424
# EV to Operating cash flow                     1424
# EV to Free cash flow                          1424
# Earnings Yield                                 833
# Free Cash Flow Yield                          1039
# Debt to Equity                                 835
# Debt to Assets                                 835
# Net Debt to EBITDA                            2201
# Current ratio                                 1694
# Interest Coverage                              813
# Income Quality                                 819
# Dividend Yield                                 832
# Payout Ratio                                   844
# SG&A to Revenue                                820
# R&D to Revenue                                 832
# Intangibles to Total Assets                    815
# Capex to Operating Cash Flow                   792
# Capex to Revenue                               815
# Capex to Depreciation                          818
# Stock-based compensation to Revenue            839
# Graham Number                                 1411
# ROIC                                          1693
# Return on Tangible Assets                     1697
# Graham Net-Net                                1027
# Working Capital                               1693
# Tangible Asset Value                           815
# Net Current Asset Value                        811
# Invested Capital                               835
# Average Receivables                            705
# Average Payables                               811
# Average Inventory                              813
# Days Sales Outstanding                         710
# Days Payables Outstanding                      815
# Days of Inventory on Hand                      817
# Receivables Turnover                           719
# Payables Turnover                             1402
# Inventory Turnover                             826
# ROE                                            841
# Capex per Share                                842
# Gross Profit Growth                            704
# EBIT Growth                                    825
# Operating Income Growth                        685
# Net Income Growth                              810
# EPS Growth                                     714
# EPS Diluted Growth                             707
# Weighted Average Shares Growth                 897
# Weighted Average Shares Diluted Growth         772
# Dividends per Share Growth                     852
# Operating Cash Flow growth                     722
# Free Cash Flow growth                          852
# 10Y Revenue Growth (per Share)                2322
# 5Y Revenue Growth (per Share)                 1621
# 3Y Revenue Growth (per Share)                 1209
# 10Y Operating CF Growth (per Share)           2310
# 5Y Operating CF Growth (per Share)            1613
# 3Y Operating CF Growth (per Share)            1201
# 10Y Net Income Growth (per Share)             2322
# 5Y Net Income Growth (per Share)              1621
# 3Y Net Income Growth (per Share)              1209
# 10Y Shareholders Equity Growth (per Share)    2348
# 5Y Shareholders Equity Growth (per Share)     1670
# 3Y Shareholders Equity Growth (per Share)     1245
# 10Y Dividend per Share Growth (per Share)     2274
# 5Y Dividend per Share Growth (per Share)      1469
# 3Y Dividend per Share Growth (per Share)      1083
# Receivables growth                             703
# Inventory Growth                               811
# Asset Growth                                   792
# Book Value per Share Growth                    893
# Debt Growth                                    854
# R&D Expense Growth                             850
# SG&A Expenses Growth                           828
# Sector                                           0
# price_var_next_yr_%                              0
# Class                                            0
# dtype: int64

# %%
df2018.isnull().sum()
# Out:
# Year                                             0
# Ticker                                           0
# Revenue                                         46
# Revenue Growth                                 139
# Cost of Revenue                                185
# Gross Profit                                    64
# R&D Expenses                                   237
# SG&A Expense                                   166
# Operating Expenses                             184
# Operating Income                                35
# Interest Expense                               184
# Earnings before Tax                             71
# Income Tax Expense                             140
# Net Income - Non-Controlling int               250
# Net Income - Discontinued ops                  250
# Net Income                                     151
# Preferred Dividends                            250
# Net Income Com                                 117
# EPS                                             65
# EPS Diluted                                     63
# Weighted Average Shs Out                        66
# Weighted Average Shs Out (Dil)                 200
# Dividend per Share                             250
# Gross Margin                                    51
# EBITDA Margin                                  308
# EBIT Margin                                    174
# Profit Margin                                  306
# Free Cash Flow margin                          254
# EBITDA                                         183
# EBIT                                           143
# Consolidated Income                            151
# Earnings Before Tax Margin                      51
# Net Profit Margin                              176
# Cash and cash equivalents                       49
# Short-term investments                         179
# Cash and short-term investments                119
# Receivables                                     38
# Inventories                                    197
# Total current assets                           185
# Property, Plant & Equipment Net                169
# Goodwill and Intangible Assets                 142
# Long-term investments                          181
# Tax assets                                     212
# Total non-current assets                      1041
# Total assets                                   108
# Payables                                       174
# Short-term debt                                214
# Total current liabilities                      184
# Long-term debt                                  30
# Total debt                                     168
# Deferred revenue                               210
# Tax Liabilities                                209
# Deposit Liabilities                            248
# Total non-current liabilities                 1043
# Total liabilities                              127
# Other comprehensive income                     158
# Retained earnings (deficit)                     21
# Total shareholders equity                      124
# Investments                                    209
# Net Debt                                       254
# Other Assets                                   208
# Other Liabilities                              159
# Depreciation & Amortization                    146
# Stock-based compensation                       184
# Operating Cash Flow                             58
# Capital Expenditure                            144
# Acquisitions and disposals                     217
# Investment purchases and sales                 147
# Investing Cash flow                            126
# Issuance (repayment) of debt                   175
# Issuance (buybacks) of shares                  219
# Dividend payments                              247
# Financing Cash Flow                             19
# Effect of forex changes on cash                174
# Net cash flow / Change in cash                  24
# Free Cash Flow                                 167
# Net Cash/Marketcap                             498
# priceBookValueRatio                            830
# priceToBookRatio                               830
# priceToSalesRatio                              255
# priceEarningsRatio                             252
# priceToFreeCashFlowsRatio                      253
# priceToOperatingCashFlowsRatio                 461
# priceCashFlowRatio                            1256
# priceEarningsToGrowthRatio                    1658
# priceSalesRatio                                452
# dividendYield                                  259
# enterpriseValueMultiple                       1225
# priceFairValue                                 460
# ebitperRevenue                                 347
# ebtperEBIT                                    1441
# niperEBT                                      1561
# grossProfitMargin                              347
# operatingProfitMargin                          347
# pretaxProfitMargin                             347
# netProfitMargin                                347
# effectiveTaxRate                              1561
# returnOnAssets                                1106
# returnOnEquity                                 256
# returnOnCapitalEmployed                       1102
# nIperEBT                                      1561
# eBTperEBIT                                    1441
# eBITperRevenue                                 347
# payablesTurnover                               478
# inventoryTurnover                              239
# fixedAssetTurnover                             444
# assetTurnover                                  230
# currentRatio                                   251
# quickRatio                                     249
# cashRatio                                      249
# daysOfSalesOutstanding                         236
# daysOfInventoryOutstanding                     145
# operatingCycle                                4386
# daysOfPayablesOutstanding                      234
# cashConversionCycle                           4386
# debtRatio                                      251
# debtEquityRatio                                251
# longtermDebtToCapitalization                   227
# totalDebtToCapitalization                      209
# interestCoverage                               246
# cashFlowToDebtRatio                            885
# companyEquityMultiplier                        438
# operatingCashFlowPerShare                      251
# freeCashFlowPerShare                           252
# cashPerShare                                   251
# payoutRatio                                    256
# operatingCashFlowSalesRatio                    347
# freeCashFlowOperatingCashFlowRatio            1160
# cashFlowCoverageRatios                         885
# shortTermCoverageRatios                       1926
# capitalExpenditureCoverageRatios               568
# dividendpaidAndCapexCoverageRatios             415
# dividendPayoutRatio                           1658
# Revenue per Share                              256
# Net Income per Share                           257
# Operating Cash Flow per Share                  251
# Free Cash Flow per Share                       252
# Cash per Share                                 251
# Book Value per Share                           252
# Tangible Book Value per Share                  252
# Shareholders Equity per Share                  251
# Interest Debt per Share                        251
# Market Cap                                     428
# Enterprise Value                               844
# PE ratio                                       252
# Price to Sales Ratio                           255
# POCF ratio                                     461
# PFCF ratio                                     253
# PB ratio                                       830
# PTB ratio                                      830
# EV to Sales                                    847
# Enterprise Value over EBITDA                   846
# EV to Operating cash flow                      846
# EV to Free cash flow                           846
# Earnings Yield                                 252
# Free Cash Flow Yield                           461
# Debt to Equity                                 251
# Debt to Assets                                 251
# Net Debt to EBITDA                             379
# Current ratio                                 1105
# Interest Coverage                              246
# Income Quality                                 236
# Dividend Yield                                 251
# Payout Ratio                                   256
# SG&A to Revenue                                238
# R&D to Revenue                                 248
# Intangibles to Total Assets                    246
# Capex to Operating Cash Flow                   228
# Capex to Revenue                               234
# Capex to Depreciation                          236
# Stock-based compensation to Revenue            256
# Graham Number                                  832
# ROIC                                          1102
# Return on Tangible Assets                     1106
# Graham Net-Net                                 448
# Working Capital                               1103
# Tangible Asset Value                           246
# Net Current Asset Value                        244
# Invested Capital                               252
# Average Receivables                            125
# Average Payables                               231
# Average Inventory                              233
# Days Sales Outstanding                         129
# Days Payables Outstanding                      234
# Days of Inventory on Hand                      236
# Receivables Turnover                           132
# Payables Turnover                              478
# Inventory Turnover                             239
# ROE                                            256
# Capex per Share                                251
# Gross Profit Growth                            125
# EBIT Growth                                    248
# Operating Income Growth                        109
# Net Income Growth                              230
# EPS Growth                                     131
# EPS Diluted Growth                             125
# Weighted Average Shares Growth                 275
# Weighted Average Shares Diluted Growth         182
# Dividends per Share Growth                     263
# Operating Cash Flow growth                     142
# Free Cash Flow growth                          263
# 10Y Revenue Growth (per Share)                1653
# 5Y Revenue Growth (per Share)                  849
# 3Y Revenue Growth (per Share)                  432
# 10Y Operating CF Growth (per Share)           1646
# 5Y Operating CF Growth (per Share)             841
# 3Y Operating CF Growth (per Share)             431
# 10Y Net Income Growth (per Share)             1653
# 5Y Net Income Growth (per Share)               849
# 3Y Net Income Growth (per Share)               432
# 10Y Shareholders Equity Growth (per Share)    1695
# 5Y Shareholders Equity Growth (per Share)      883
# 3Y Shareholders Equity Growth (per Share)      432
# 10Y Dividend per Share Growth (per Share)     1582
# 5Y Dividend per Share Growth (per Share)       708
# 3Y Dividend per Share Growth (per Share)       325
# Receivables growth                             124
# Inventory Growth                               232
# Asset Growth                                   214
# Book Value per Share Growth                    271
# Debt Growth                                    264
# R&D Expense Growth                             259
# SG&A Expenses Growth                           248
# Sector                                           0
# price_var_next_yr_%                              0
# Class                                            0
# dtype: int64

# %%
# Check the percentage of missing data in each column of combined dataframe
missing = df.isnull().mean() * 100
print(missing)
# Out:
# year                                          0.0000
# revenue                                       5.3042
# revenue_growth                                9.4578
# cost_of_revenue                               8.0219
# gross_profit                                  5.4672
# r&d_expenses                                  9.6843
# sg&a_expense                                  7.5599
# operating_expenses                            7.7094
# operating_income                              4.9871
# interest_expense                              7.7864
# earnings_before_tax                           6.1784
# income_tax_expense                            7.1930
# net_income_-_non-controlling_int             10.2324
# net_income_-_discontinued_ops                10.2324
# net_income                                    7.0888
# preferred_dividends                          10.2324
# net_income_com                                6.3007
# eps                                           5.8930
# eps_diluted                                   5.8522
# weighted_average_shs_out                      6.7672
# weighted_average_shs_out_(dil)                8.7738
# dividend_per_share                           10.2324
# gross_margin                                  5.4310
# ebitda_margin                                11.0839
# ebit_margin                                   7.5826
# profit_margin                                11.0703
# free_cash_flow_margin                        10.3773
# ebitda                                        7.9449
# ebit                                          6.4547
# consolidated_income                           7.0979
# earnings_before_tax_margin                    5.4129
# net_profit_margin                             7.8000
# cash_and_cash_equivalents                     5.3404
# short-term_investments                       12.2843
# cash_and_short-term_investments              11.2108
# receivables                                   5.0052
# inventories                                   8.2937
# total_current_assets                         11.4237
# property,_plant_&_equipment_net               7.5146
# goodwill_and_intangible_assets                6.5090
# long-term_investments                        11.9264
# tax_assets                                    8.9822
# total_non-current_assets                     27.2773
# total_assets                                  5.9111
# payables                                      7.5644
# short-term_debt                              12.2571
# total_current_liabilities                    11.4508
# long-term_debt                                8.6425
# total_debt                                    7.7366
# deferred_revenue                              8.9958
# tax_liabilities                               8.9278
# deposit_liabilities                          10.2822
# total_non-current_liabilities                27.3407
# total_liabilities                             6.3233
# other_comprehensive_income                    7.5916
# retained_earnings_(deficit)                   5.2860
# total_shareholders_equity                     6.2146
# investments                                   8.6878
# net_debt                                     31.0685
# other_assets                                 30.6020
# other_liabilities                            10.6083
# depreciation_&_amortization                   6.9212
# stock-based_compensation                      7.8498
# operating_cash_flow                           5.2906
# capital_expenditure                           6.8986
# acquisitions_and_disposals                    9.2087
# investment_purchases_and_sales                6.8578
# investing_cash_flow                           6.3641
# issuance_(repayment)_of_debt                  7.5554
# issuance_(buybacks)_of_shares                 8.7965
# dividend_payments                             9.7658
# financing_cash_flow                           4.4028
# effect_of_forex_changes_on_cash               8.1261
# net_cash_flow_/_change_in_cash                4.6111
# free_cash_flow                                7.4240
# net_cash/marketcap                           15.2013
# price_book_value_ratio                       22.6163
# price_to_book_ratio                          22.6163
# price_to_sales_ratio                         10.3411
# price_earnings_ratio                         10.3094
# price_to_free_cash_flows_ratio               10.3139
# price_to_operating_cash_flows_ratio          14.5853
# price_cash_flow_ratio                        31.9971
# price_earnings_to_growth_ratio               41.1242
# price_sales_ratio                            15.2059
# dividend_yield                               14.9386
# enterprise_value_multiple                    31.4535
# price_fair_value                             16.1888
# ebitper_revenue                              12.9637
# ebtper_ebit                                  36.2685
# niper_ebt                                    38.9319
# gross_profit_margin                          12.9637
# operating_profit_margin                      12.9637
# pretax_profit_margin                         12.9637
# net_profit_margin                            12.9637
# effective_tax_rate                           38.9319
# return_on_assets                             29.6009
# return_on_equity                             10.5902
# return_on_capital_employed                   29.4832
# n_iper_ebt                                   38.9319
# e_btper_ebit                                 36.2685
# e_bitper_revenue                             12.9637
# payables_turnover                            22.2449
# inventory_turnover                           11.3784
# fixed_asset_turnover                         14.1958
# asset_turnover                                9.7115
# current_ratio                                13.8832
# quick_ratio                                  13.8515
# cash_ratio                                   13.8515
# days_of_sales_outstanding                    10.1554
# days_of_inventory_outstanding                 8.6470
# operating_cycle                              99.9139
# days_of_payables_outstanding                 10.1327
# cash_conversion_cycle                        99.9139
# debt_ratio                                   10.4815
# debt_equity_ratio                            10.4815
# longterm_debt_to_capitalization              10.8212
# total_debt_to_capitalization                 10.3818
# interest_coverage                             9.9062
# cash_flow_to_debt_ratio                      28.4278
# company_equity_multiplier                    15.1062
# operating_cash_flow_per_share                10.9843
# free_cash_flow_per_share                     10.9798
# cash_per_share                               11.0024
# payout_ratio                                 10.8257
# operating_cash_flow_sales_ratio              12.9637
# free_cash_flow_operating_cash_flow_ratio     29.8410
# cash_flow_coverage_ratios                    28.4278
# short_term_coverage_ratios                   48.6660
# capital_expenditure_coverage_ratios          16.5285
# dividendpaid_and_capex_coverage_ratios       13.2264
# dividend_payout_ratio                        41.1242
# revenue_per_share                            11.0658
# net_income_per_share                         11.0749
# operating_cash_flow_per_share                10.9299
# free_cash_flow_per_share                     10.9254
# cash_per_share                               11.0069
# book_value_per_share                         11.0115
# tangible_book_value_per_share                11.0115
# shareholders_equity_per_share                11.0069
# interest_debt_per_share                      11.0115
# market_cap                                   13.9104
# enterprise_value                             22.8292
# pe_ratio                                     10.1825
# price_to_sales_ratio                         10.2143
# pocf_ratio                                   14.4811
# pfcf_ratio                                   10.1871
# pb_ratio                                     22.5438
# ptb_ratio                                    22.5438
# ev_to_sales                                  22.8609
# enterprise_value_over_ebitda                 22.8428
# ev_to_operating_cash_flow                    22.8428
# ev_to_free_cash_flow                         22.8428
# earnings_yield                               10.1825
# free_cash_flow_yield                         14.4811
# debt_to_equity                               10.4815
# debt_to_assets                               10.4815
# net_debt_to_ebitda                           34.9459
# current_ratio                                29.5149
# interest_coverage                             9.7703
# income_quality                               10.0557
# dividend_yield                               10.1735
# payout_ratio                                 10.7306
# sg&a_to_revenue                              10.0738
# r&d_to_revenue                               10.3139
# intangibles_to_total_assets                   9.9515
# capex_to_operating_cash_flow                  9.5575
# capex_to_revenue                             10.0059
# capex_to_depreciation                        10.0784
# stock-based_compensation_to_revenue          10.4317
# graham_number                                22.5710
# roic                                         29.4832
# return_on_tangible_assets                    29.6009
# graham_net-net                               14.3407
# working_capital                              29.4877
# tangible_asset_value                          9.9515
# net_current_asset_value                      13.7292
# invested_capital                             10.4860
# average_receivables                           9.6435
# average_payables                             10.9888
# average_inventory                            11.0115
# days_sales_outstanding                        8.3299
# days_payables_outstanding                    10.1418
# days_of_inventory_on_hand                    10.1644
# receivables_turnover                         10.0240
# payables_turnover                            22.2449
# inventory_turnover                           11.3784
# roe                                          10.5993
# capex_per_share                              10.9299
# gross_profit_growth                           9.0954
# ebit_growth                                  10.6038
# operating_income_growth                       8.9143
# net_income_growth                            10.7895
# eps_growth                                    9.8881
# eps_diluted_growth                            9.9334
# weighted_average_shares_growth               12.7191
# weighted_average_shares_diluted_growth       17.7651
# dividends_per_share_growth                   11.1836
# operating_cash_flow_growth                    9.3446
# free_cash_flow_growth                        11.2062
# 10y_revenue_growth_(per_share)               43.1762
# 5y_revenue_growth_(per_share)                28.9940
# 3y_revenue_growth_(per_share)                20.2292
# 10y_operating_cf_growth_(per_share)          42.9316
# 5y_operating_cf_growth_(per_share)           28.8264
# 3y_operating_cf_growth_(per_share)           20.0797
# 10y_net_income_growth_(per_share)            43.1762
# 5y_net_income_growth_(per_share)             28.9940
# 3y_net_income_growth_(per_share)             20.2292
# 10y_shareholders_equity_growth_(per_share)   43.8465
# 5y_shareholders_equity_growth_(per_share)    29.9407
# 3y_shareholders_equity_growth_(per_share)    21.0309
# 10y_dividend_per_share_growth_(per_share)    41.5681
# 5y_dividend_per_share_growth_(per_share)     26.1720
# 3y_dividend_per_share_growth_(per_share)     17.2714
# receivables_growth                            9.6254
# inventory_growth                             10.9933
# asset_growth                                 10.8122
# book_value_per_share_growth                  12.9728
# debt_growth                                  11.8449
# r&d_expense_growth                           11.2289
# sg&a_expenses_growth                         10.9707
# sector                                        0.0000
# price_var_next_yr_%                           0.0000
# dtype: float64

# %% [markdown]
# ### Dropping Predictors >10% Missing

# %% [markdown]
# Our first intervention will consist of dropping all the predictors with more than 10% of missing values. This strategy allows us to avoid excessive imputation, which would introduce a bias.
#
# After dropping, we have significantly fewer predictors left.

# %%
df_dropped = df.dropna(axis=1, thresh=int(0.9*df.shape[0]))

# %%
df_dropped.shape
# Out:
# (22077, 73)

# %%
# Separate predictors and response variable + one-hot encode 'sector'
X = df_dropped.drop(columns=['price_var_next_yr_%'])
X = pd.get_dummies(X, drop_first=True)
y = df_dropped['price_var_next_yr_%']

# %%
X.head()
# Out:
#            revenue  revenue_growth  cost_of_revenue     gross_profit  \
# 0 74401000000.0000         -0.0713 39030000000.0000 35371000000.0000
# 1  3734148046.4966          1.1737  2805625443.9780   928522602.5186
# 2 98375000000.0000          0.0182 78138000000.0000 20237000000.0000
# 3 25526413000.0000          0.0053 18202679000.0000  7323734000.0000
# 4 17909600000.0000          0.0076 11539800000.0000  6369800000.0000
#
#     r&d_expenses     sg&a_expense  operating_expenses  operating_income  \
# 0         0.0000 21461000000.0000    21461000000.0000  13910000000.0000
# 1 108330319.6642   344141427.1876      793926703.2612    134595899.2573
# 2  1629000000.0000   23886000000.0000             -464000000.0000
# 3           0.0000    9058573000.0000              -37334000.0000
# 4  1666000000.0000   15156200000.0000            -1340300000.0000
#
#    retained_earnings_(deficit)  total_shareholders_equity     investments  \
# 0             84990000000.0000           69976000000.0000 2128000000.0000
# 1                 4285437.5202             412354536.6484  671378753.6325
# 2             10981000000.0000            5384000000.0000          0.0000
# 3             -7515848000.0000           -2113702000.0000          0.0000
# 4             11787200000.0000            6534800000.0000          0.0000
#
#    depreciation_&_amortization  stock-based_compensation  operating_cash_flow  \
# 0              3141000000.0000            360000000.0000     13958000000.0000
# 1                58154827.2522             36405230.8686       526745560.2196
# 2              1703000000.0000            107000000.0000      3573000000.0000
# 3               403741000.0000            -10471000.0000       702046000.0000
# 4               585400000.0000             39200000.0000      2541000000.0000
#
#    capital_expenditure  acquisitions_and_disposals  \
# 0     -3848000000.0000              -24000000.0000
# 1      -263704552.7930             -192255247.0132
# 2     -2330000000.0000            -2344000000.0000
# 3      -333870000.0000                      0.0000
# 4      -656900000.0000               66700000.0000
#
#    investment_purchases_and_sales  investing_cash_flow  \
# 0                 -805000000.0000     -4100000000.0000
# 1                 -212644656.1188      -686693574.4269
# 2                          0.0000     -4771000000.0000
# 3                   41155000.0000      -364924000.0000
# 4                   29300000.0000      -561800000.0000
#
#    issuance_(repayment)_of_debt  issuance_(buybacks)_of_shares  \
# 0               3543000000.0000               -3911000000.0000
# 1                619326767.8398                   1767839.8450
# 2               2093000000.0000                -413000000.0000
# 3               -295435000.0000                  33217000.0000
# 4                801100000.0000               -1637200000.0000
#
#    dividend_payments  financing_cash_flow  effect_of_forex_changes_on_cash  \
# 0   -6911000000.0000     -7279000000.0000                    39000000.0000
# 1             0.0000       621913626.0898                   -15648692.2829
# 2    -319000000.0000      1361000000.0000                           0.0000
# 3             0.0000      -320168000.0000                           0.0000
# 4    -983300000.0000     -1824100000.0000                   -29200000.0000
#
#    net_cash_flow_/_change_in_cash   free_cash_flow  asset_turnover  \
# 0                 2618000000.0000 10110000000.0000          0.5157
# 1                  446316919.5996   263041007.4265          1.3645
# 2                  163000000.0000  1243000000.0000          3.3597
# 3                   16954000.0000   368176000.0000          3.6756
# 4                  125900000.0000  1884100000.0000          0.7738
#
#    days_of_inventory_outstanding  interest_coverage  interest_coverage  \
# 0                        31.3287            21.4429            21.4429
# 1                         1.1431            15.4363            15.4363
# 2                         4.1407             6.1242             6.1242
# 3                        13.5706             1.5893             1.5893
# 4                        30.2360             9.9540             9.9540
#
#    intangibles_to_total_assets  capex_to_operating_cash_flow  \
# 0                       0.5860                        0.2757
# 1                       0.0697                        0.5006
# 2                       0.0969                        0.6521
# 3                       0.0621                        0.4756
# 4                       0.5904                        0.2585
#
#    tangible_asset_value  average_receivables  days_sales_outstanding  \
# 0      59719000000.0000      6447000000.0000                 31.3287
# 1       2546028576.0413                  NaN                  1.1431
# 2      26444000000.0000      1083500000.0000                  4.1407
# 3       6513644000.0000       939269000.0000                 13.5706
# 4       9480900000.0000      1465000000.0000                 30.2360
#
#    gross_profit_growth  operating_income_growth  eps_growth  \
# 0              -0.1185                   0.0067      0.0371
# 1               1.2489                   1.9463      1.4625
# 2               0.0173                  -0.0141      0.0576
# 3               0.0007                   0.1113      0.9167
# 4              -0.0084                   0.0370      0.0140
#
#    eps_diluted_growth  operating_cash_flow_growth  receivables_growth  \
# 0              0.0389                     -0.0615             -0.0187
# 1              1.4646                      0.2134                 NaN
# 2              0.0469                      0.2095              0.0618
# 3              0.9167                     -0.1434              0.0211
# 4              0.0143                     -0.1316              0.0257
#
#    year_2015  year_2016  year_2017  year_2018  sector_Communication Services  \
# 0      False      False      False      False                          False
# 1      False      False      False      False                          False
# 2      False      False      False      False                          False
# 3      False      False      False      False                          False
# 4      False      False      False      False                          False
#
#    sector_Consumer Cyclical  sector_Consumer Defensive  sector_Energy  \
# 0                     False                       True          False
# 1                     False                       True          False
# 2                     False                       True          False
# 3                     False                       True          False
# 4                     False                       True          False
#
#    sector_Financial Services  sector_Healthcare  sector_Industrials  \
# 0                      False              False               False
# 1                      False              False               False
# 2                      False              False               False
# 3                      False              False               False
# 4                      False              False               False
#
#    sector_Real Estate  sector_Technology  sector_Utilities
# 0               False              False             False
# 1               False              False             False
# 2               False              False             False
# 3               False              False             False
# 4               False              False             False

# %%
y.head()
# Out:
# 0    -9.3233
# 1   -25.5122
# 2    33.1183
# 3     2.7523
# 4    12.8977
# Name: price_var_next_yr_%, dtype: float64

# %% [markdown]
# ### Dropping Duplicate Columns

# %%
# Check for duplicate column names
duplicate_columns = X.columns[X.columns.duplicated()]
print("Duplicate columns:", duplicate_columns)
# Out:
# Duplicate columns: Index(['interest_coverage'], dtype='object')

# %%
X = X.drop(columns=duplicate_columns)

# %% [markdown]
# #### Identifying the Patterns of Missing Data

# %% [markdown]
# ### Deeper Understanding of Missingness

# %% [markdown]
# We use the `missingno` (missing "no") library to visualize the patterns of missing data. Specifically, white cells indicate missing data.

# %%
# Visualize the missingness pattern
msno.matrix(X)

plt.title('Missing Values Matrix')
plt.xticks(ticks=range(len(X.columns)), labels=X.columns, rotation=90)  # Set the x-axis ticks to column names
plt.show()

# %% [markdown]
# We can see that there are clearly patterns in the white lines indicating the location
# of missing values. The sparkline at right summarizes the general shape of the data completeness and
# points out the rows with the maximum and minimum nullity in the dataset. We notice that the features
# with the most clusters of white spaces include net debt to ebitda, free cash flow yield, current ratio, net
# debt, and return on assets. Additionally, we see that there are three general groups of white lines that span
# across all of the variables, signifying companies are missing data across all features. These companies
# with high-missing-value columns across all years may be dropped. Given the missing data seems not to be
# MCAR, mean or median imputation methods may not be suitable. Mode imputation is also not applicable
# as most features are numerical. Therefore, we can use kNN imputation to replace missing values using the
# k-nearest neighbor mean for each feature.

# %% [markdown]
# We now try to gain a better insight on the number of missing values by leveraging the missingno bar plot. Each horizontal bar represents each predictor's non-null values, whose number is reported aside.

# %%
def non_missing_ratio_summary(df):
    """
    Calculate the ratio of non-missing (non-NA) data for each column in the DataFrame.

    Parameters:
    - df (pandas.DataFrame): The DataFrame for which to calculate the non-missing ratios.

    Returns:
    - pandas.DataFrame: A DataFrame containing the non-missing ratios for each column.
    """
    # Calculate the total number of data points (number of rows)
    total_data_points = len(df)

    # Calculate the count of non-missing values for each column
    non_missing_counts = df.count()

    # Calculate the ratio of non-missing data points for each column
    non_missing_ratios = non_missing_counts / total_data_points

    # Create a summary DataFrame
    summary_df = pd.DataFrame({
        'Non_Missing_Count': non_missing_counts,
        'Non_Missing_Ratio': non_missing_ratios
    })

    return summary_df

# %%
predictors_non_miss_summary = non_missing_ratio_summary(X)
msno.bar(X, fontsize= 10, color="seagreen", sort="descending")
plt.title("Percentage of Non-Missing Data by Column")
plt.ylabel("Percentage of Non-Missing Values")
plt.xlabel("Count of Data Values")
plt.show()

# %% [markdown]
# From the visualization above, we see that the bars at the bottom, including sector and year have no missing data while operating income, operating cash flow have very few missing values. The bars near the top, including net debt to ebitda, net debt, return on asset, and current ratio have the most number of missing values. We will keep in mind that the uppermost ones will have
# 10-15% of values imputed which could introduce biases into our model.

# %% [markdown]
# Finally, we utilize the msno heatmap to examine correlation between missing values.

# %%
msno.heatmap(X, fontsize=9)
plt.title("Nullity Correlation Heatmap: -1 (Negative Correlation), 0 (No Correlation), 1 (Positive Correlation)")
# Out:
# Text(0.5, 1.0, 'Nullity Correlation Heatmap: -1 (Negative Correlation), 0 (No Correlation), 1 (Positive Correlation)')

# %% [markdown]
# From the visualization, we see that the nullity correlations range between 0.2 and 1. Certain correlations, including EPS and dividend per share, return on equity, and net debt to EBITDA, remain close to 1. We can conclude that our data is most likely MNAR or MAR.

# %% [markdown]
# ## 0.4 Handling Outliers

# %% [markdown]
# We first take a closer look at our response variable, "price_var_next_yr_%" and notice that our y variable has a long tail.

# %%
# y has a long tail, we will drop the outliers
y.describe()
# Out:
# count     22077.0000
# mean        269.8893
# std       19346.1736
# min        -100.3972
# 25%         -19.4741
# 50%           3.9091
# 75%          27.5057
# max     2418600.9153
# Name: price_var_next_yr_%, dtype: float64

# %%
y.quantile(1)
# Out:
# 2418600.915311456

# %%
y.quantile(0.98)
# Out:
# 141.7316788052473

# %%
y[y<y.quantile(0.98)].hist()
plt.title("Histogram of Price Variation Next Year with 98 Percent of Data")
plt.ylabel("Count")
plt.xlabel("Percentage of Price Var Next Year")
# Out:
# Text(0.5, 0, 'Percentage of Price Var Next Year')

# %% [markdown]
# We observe that y has a long tail and we proceed with dropping the outliers. We end up using the 98% of the data.

# %%
indx = y < y.quantile(0.98)

# %% [markdown]
# ## 0.5 Pipeline Preparation

# %% [markdown]
# ### Train Test Set Split

# %% [markdown]
# We split the data into training and testing sets first to ensure that the model is evaluated on data it hasn't seen during training.

# %%
X_train, X_test, y_train, y_test = train_test_split(X[indx], y[indx], 
                                                    test_size=0.2, shuffle=True, random_state=123)

# %% [markdown]
# ### Data Scaling & Imputation

# %% [markdown]
# In each algorithm below, we scale the data (numerical predictors) as they are on very different scales. Since K-NN is a distance based algorithm, scaling before imputing is better.

# %% [markdown]
# # Part 1: Basic Model Selection

# %% [markdown]
# We propose using Ordinary Least Squares (OLS) as our baseline model, with potential adjustments through Lasso or Ridge regularization to mitigate overfitting. We chose OLS over more complex models like decision trees due to its simplicity and lower risk of overfitting, but we remain open to exploring other models based on the results and insights we gain during the initial phases.
#
# Our implementation plan for the OLS model involves the following steps:
# 1. Data Preprocessing: We employ a KNN Imputer with n_neighbors=1 to handle missing values in our dataset. This aims to impute missing values with a degree of uncertainty.
# 2. Feature Scaling: We use the Standard Scaler to normalize our features, an essential step for linear models to ensure that all variables are on the same scale.
# 3. Model Training: We train our processed training set using Linear Regression.
# 4. Prediction and Clipping: Post-training, the model is used to predict outcomes on the test set (X_test). We apply clipping to the predictions to keep them within a realistic range (in this case, -150 to 150.
# 5. Evaluation: The performance of the baseline model is assessed using R^2 and MSE scores.

# %%
# Load the saved models and their training times
with open('models_info.pkl', 'rb') as file:
    loaded_models_info = pickle.load(file)

lr = loaded_models_info['linear_regression']['model']
ridge = loaded_models_info['ridge_regression']['model']
lasso = loaded_models_info['lasso_regression']['model']
rf = loaded_models_info['random_forest']['model']

lr_time = loaded_models_info['linear_regression']['training_time']
ridge_time = loaded_models_info['ridge_regression']['training_time']
lasso_time = loaded_models_info['lasso_regression']['training_time']
rf_time = loaded_models_info['random_forest']['training_time']

# %% [markdown]
# ## Linear Regression

# %%
y_test.describe()
# Out:
# count   4327.0000
# mean       3.5837
# std       39.0724
# min      -99.9512
# 25%      -20.3958
# 50%        3.2790
# 75%       24.8248
# max      141.6989
# Name: price_var_next_yr_%, dtype: float64

# %%
y_train.describe()
# Out:
# count   17308.0000
# mean        3.3708
# std        38.8718
# min      -100.3972
# 25%       -20.1050
# 50%         3.2290
# 75%        25.9774
# max       141.6667
# Name: price_var_next_yr_%, dtype: float64

# %%
# n_neighbors=1 to impute with uncertainty
# Need to scale for linear regression

# lr = Pipeline([('imputer', KNNImputer(n_neighbors=1)),
#                ('scaler', StandardScaler()),
#                ('model', LinearRegression())])
# lr.fit(X_train, y_train)

# %%
y_test_lr_pred = lr.predict(X_test)
y_test_lr_pred = np.clip(y_test_lr_pred, -150, 150)  # Since max of y_test and y_train are both under 150
lr_r2 = r2_score(y_test, y_test_lr_pred)
mse_lr = mean_squared_error(y_test, y_test_lr_pred)
print(f"R^2 score of baseline simple linear regression: {lr_r2:.4f}")
print(f"MSE of baseline simple linear regression: {mse_lr:.4f}")
# Out:
# R^2 score of baseline simple linear regression: 0.1380
# MSE of baseline simple linear regression: 1315.6851

# %% [markdown]
# # Part 2: More Complex Models

# %% [markdown]
# ## Ridge Regression

# %%
# n_neighbors=1 to impute with uncertainty
# Need to scale for ridge regression

# ridge = Pipeline([('imputer', KNNImputer(n_neighbors=1)),
#                   ('scaler', StandardScaler()),
#                   ('model', Ridge(alpha=1.0))])
# ridge.fit(X_train, y_train)

# %%
y_test_ridge_pred = ridge.predict(X_test)
y_test_ridge_pred = np.clip(y_test_ridge_pred, -150, 150)
ridge_r2 = r2_score(y_test, y_test_ridge_pred)
mse_ridge = mean_squared_error(y_test, y_test_ridge_pred)
print(f"R^2 score of baseline Ridge regression: {ridge_r2:.4f}")
print(f"MSE of baseline simple Ridge regression: {mse_ridge:.4f}")
# Out:
# R^2 score of baseline Ridge regression: 0.1381
# MSE of baseline simple Ridge regression: 1315.4889

# %% [markdown]
# ## Lasso Regression

# %%
# n_neighbors=1 to impute with uncertainty
# Need to scale for lasso regression

# lasso = Pipeline([('imputer', KNNImputer(n_neighbors=1)),
#                   ('scaler', StandardScaler()),
#                   ('model', Lasso(alpha=1.0))])
# lasso.fit(X_train, y_train)

# %%
y_test_lasso_pred = lasso.predict(X_test)
y_test_lasso_pred = np.clip(y_test_lasso_pred, -150, 150)
lasso_r2 = r2_score(y_test, y_test_lasso_pred)
mse_lasso = mean_squared_error(y_test, y_test_lasso_pred)
print(f"R^2 score of baseline Lasso regression: {lasso_r2:.4f}")
print(f"MSE of baseline simple Lasso regression: {mse_lasso:.4f}")
# Out:
# R^2 score of baseline Lasso regression: 0.1344
# MSE of baseline simple Lasso regression: 1321.1090

# %% [markdown]
# ## Random Forest

# %%
# n_neighbors=1 to impute with uncertainty
# Don't need to scale for random forest

# rf = Pipeline([('imputer', KNNImputer(n_neighbors=1)),
#                ('model', RandomForestRegressor(max_depth=12, random_state=123))])
# rf.fit(X_train, y_train)

# %%
rf_acc = rf.score(X_test, y_test)

y_test_rf_pred = rf.predict(X_test)
mse_rf = mean_squared_error(y_test, y_test_rf_pred)
print(f"Accuracy of baseline random forest: {rf_acc:.4f}")
print(f"MSE of baseline random forest: {mse_rf:.4f}")
# Out:
# Accuracy of baseline random forest: 0.2427
# MSE of baseline random forest: 1155.9393

# %% [markdown]
# ## 2.1 Evaluation

# %%
# models = {
#     'linear_regression': Pipeline([('imputer', KNNImputer(n_neighbors=1)),
#                                    ('scaler', StandardScaler()),
#                                    ('model', LinearRegression())]),
#     'ridge_regression': Pipeline([('imputer', KNNImputer(n_neighbors=1)),
#                                   ('scaler', StandardScaler()),
#                                   ('model', Ridge(alpha=1.0))]),
#     'lasso_regression': Pipeline([('imputer', KNNImputer(n_neighbors=1)),
#                                   ('scaler', StandardScaler()),
#                                   ('model', Lasso(alpha=1.0))]),
#     'random_forest': Pipeline([('imputer', KNNImputer(n_neighbors=1)),
#                                ('model', RandomForestRegressor(max_depth=12, random_state=123))])
# }

# # Dictionary to store models and their training times
# models_info = {}

# # Train each model and record its training time
# for model_name, model in models.items():
#     start_time = time.time()
#     model.fit(X_train, y_train)
#     end_time = time.time()
    
#     models_info[model_name] = {
#         'model': model,
#         'training_time': end_time - start_time
#     }

# # Pickle the dictionary containing all models and their training times
# with open('models_info.pkl', 'wb') as file:
#     pickle.dump(models_info, file)

# print("All models and their training times are saved.")

# %%
# Print R^2 and MSE for each model
print(f"\n{'Model':<20} {'R^2 Score':<20} {'MSE':<20} {'Training Time (s)':<20}")
print("-" * 120)
print(f"{'Linear Regression':<20} {lr_r2:.4f} {'':<13} {mse_lr:.4f} {'':<10} {lr_time:.4f}")
print(f"{'Ridge Regression':<20} {ridge_r2:.4f} {'':<13} {mse_ridge:.4f} {'':<10} {ridge_time:.4f}")
print(f"{'Lasso Regression':<20} {lasso_r2:.4f} {'':<13} {mse_lasso:.4f} {'':<10} {lasso_time:.4f}")
print(f"{'Random Forest':<20} {rf_acc:.4f} {'':<13} {mse_rf:.4f} {'':<10} {rf_time:.4f}")
# Out:
# Model                R^2 Score            MSE                  Training Time (s)
# ------------------------------------------------------------------------------------------------------------------------
# Linear Regression    0.1380               1315.6851            17.2078
# Ridge Regression     0.1381               1315.4889            17.5852
# Lasso Regression     0.1344               1321.1090            17.4716
# Random Forest        0.2427               1155.9393            71.9160

# %% [markdown]
# If we take a closer look at the metrics, we notice a very low $R^2$ score for each model, which makes that specific metric less relevant toward model selection. We also observe fairly similar MSEs, with a lower value characterizing the Random forest, which is the preferred model according to the reported metric. Moving a step further, with the goal of selecting a suitable and effective model, we can take a moment to observe the dataset we are working on. Random forest seems to be the model to favor given the high-dimensionality of the dataset.

# %% [markdown]
# ### Final Model Choice

# %% [markdown]
# For our final model, we have chosen the Random Forest algorithm based on several reasons:
# 1. **Robustness to Overfitting:** Random Forest, with its ensemble approach of using multiple decision trees, tends to be more robust against overfitting compared to individual decision trees.
# 2. **Ability to Handle Non-linear Relationships:** When relationships between features and the response variable are complex and nonlinear, which is likely true in this case
# 3. **Feature Importance:** Random Forest provides insights into feature importance, which can be valuable for understanding the driving factors behind the predictions
# 4. **Versatility:** It performs well on both classification and regression tasks and can handle both categorical and continuous data, which we have
#
# The implementation plan for the Random Forest model includes:
# 1. **Data Imputation:** Similar to our baseline model, we use a KNN Imputer with n_neighbors=1 for handling missing values
# 2. **Model Training:** We train our model using the Random Forest regressor. Here, we have set max_depth=12 to control the depth of the trees, preventing them from becoming too complex and overfitting.
# 3. **Evaluation:** The performance of the baseline model is assessed using R^2 and MSE scores

# %% [markdown]
# # Part 3: Selected Model Tuning

# %% [markdown]
# ## 3.1 Tuning Roadmap

# %% [markdown]
# We will proceed with the following steps to tune our model:
# 1. **Cross-Validation:** Instead of a single train-test split, we will use cross-validation to get a more reliable estimate of model performance.
# 2. **Hyperparameter Tuning:**
#     - **Number of Trees (`n_estimators`):** Increasing the number of trees in the forest can improve the model's performance, but up to a certain point. After a certain number, the benefits in accuracy become minimal, so it's a trade-off between performance and computational cost.
#     - **Maximum Depth of Trees (`max_depth`):** Controls the depth of each tree. Deeper trees can model more complex patterns but can also lead to overfitting. Try various depths, including `None`, which allows trees to expand until all leaves are pure or until they contain less than `min_samples_split` samples.
#     - **Minimum Samples Split (`min_samples_split`):** The minimum number of samples required to split an internal node. Higher values prevent the model from learning overly specific patterns, lower values allow the model to capture more information about the data.
#     - **Minimum Samples Leaf (`min_samples_leaf`):** The minimum number of samples required to be at a leaf node. Similar to `min_samples_split`, it can help control overfitting.
#     - **Max Features (`max_features`):** The number of features to consider when looking for the best split. Try different values like `sqrt`, `log2`, or even `None`.
# 3. **Grid Search:** Use `GridSearchCV` from `sklearn.model_selection` to search across a grid of hyperparameters systematically.
# 4. **Feature Importance Analysis:** After fitting the model, we will examine which features are most important. This will give insights into whether some features should be dropped or if feature engineering could be beneficial.
# 5. **Post-tuning Evaluation:** After tuning, we will evaluate the model again with our test set or a validation set to see if there's an improvement in performance.

# %% [markdown]
# ## 3.2 Cross-Validation Setup

# %%
# # Start timing
# cv_start_time = time.time()

# # Perform cross-validation
# cv_scores = cross_val_score(rf, X_train, y_train, cv=5)  # 5-fold cross-validation

# # End timing
# cv_end_time = time.time()
# cv_time = cv_end_time - cv_start_time

# # Create a dictionary to store the cross-validation scores and the time
# cv_info = {
#     'cv_scores': cv_scores,
#     'mean_cv_score': cv_scores.mean(),
#     'cv_time': cv_time
# }

# # Pickle the dictionary
# with open('cv_info.pkl', 'wb') as file:
#     pickle.dump(cv_info, file)

# print(f"Cross-validation scores and time saved. The process took {cv_time} seconds.")

# %%
# Load the pickled cross-validation information
with open('cv_info.pkl', 'rb') as file:
    cv_info = pickle.load(file)

# Extract the cross-validation scores, mean score, and time
cv_scores = cv_info['cv_scores']
mean_cv_score = cv_info['mean_cv_score']
cv_time = cv_info['cv_time']

# Print the extracted information
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {mean_cv_score}")
print(f"Time taken for cross-validation: {cv_time} seconds")
# Out:
# Cross-validation scores: [0.22202157 0.23810989 0.22762797 0.25182231 0.25051422]
# Mean cross-validation score: 0.2380191921968678
# Time taken for cross-validation: 277.9136188030243 seconds

# %% [markdown]
# ## 3.3 Hyperparameter Tuning

# %%
# We tried to use grid search but this takes forever to run. 
# So we decided to go with randomized search, which is significantly faster.

# param_grid = {
#     'model__n_estimators': [100, 200, 300],  # Number of trees
#     'model__max_depth': [10, 20, 30],        # Maximum depth of trees
#     'model__min_samples_split': [2, 5, 10],  # Minimum number of samples required to split a node
#     'model__min_samples_leaf': [1, 2, 4],    # Minimum number of samples required at a leaf node
# }

# %%
# grid_search_start_time = time.time()

# grid_search = GridSearchCV(rf, param_grid, cv=5, n_jobs=-1, verbose=0)
# grid_search.fit(X_train, y_train)

# grid_search_end_time = time.time()
# grid_search_time = grid_search_end_time - grid_search_start_time

# grid_search_info = {
#     'grid_search': grid_search,
#     'grid_search_time': grid_search_time
# }

# # Save the grid search object to a file
# with open('grid_search_info.pkl', 'wb') as file:
#     pickle.dump(grid_search_info, file)

# print(f"Grid search object and time saved. The process took {grid_search_time} seconds.")

# %%
param_random = {
    'model__n_estimators': [100, 200, 300, 400, 500],
    'model__max_depth': [10, 20, 30, 40, 50],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4],
}

# %%
# # Create the RandomizedSearchCV object
# random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_random,
#                                    n_iter=100, cv=5, verbose=2, random_state=123, n_jobs=-1)

# # Start timing
# random_search_start_time = time.time()

# # Perform the random search
# random_search.fit(X_train, y_train)

# # End timing
# random_search_end_time = time.time()
# random_search_time = random_search_end_time - random_search_start_time

# # Create a dictionary to store the random search object and the time
# random_search_info = {
#     'random_search': random_search,
#     'random_search_time': random_search_time
# }

# # Pickle the dictionary
# with open('random_search_info.pkl', 'wb') as file:
#     pickle.dump(random_search_info, file)

# print("Random search object and time saved.")

# %%
# Print the best parameters and the time taken

with open('random_search_info.pkl', 'rb') as file:
    random_search_info = pickle.load(file)

random_search = random_search_info['random_search']
random_search_time = random_search_info['random_search_time']
best_param = random_search.best_params_
best_score = random_search.best_score_

print("Best parameters found: ", random_search.best_params_)
print(f"Randomized search completed in {random_search_time:.4f} seconds")
# Out:
# Best parameters found:  {'model__n_estimators': 500, 'model__min_samples_split': 2, 'model__min_samples_leaf': 4, 'model__max_depth': 40}
# Randomized search completed in 10131.6960 seconds

# %% [markdown]
# ## 3.4 Comparison of Baseline Model with Tuned Model

# %%
best_model = random_search.best_estimator_
best_rf_acc = best_model.score(X_test, y_test)
y_test_best_rf_pred = best_model.predict(X_test)
mse_best_rf = mean_squared_error(y_test, y_test_best_rf_pred)

# %%
# Print R^2 and MSE for each model
print(f"\n{'Model':<30} {'R^2 Score':<20} {'MSE':<20} {'Training Time (s)':<20}")
print("-" * 120)
print(f"{'Baseline Random Forest':30} {rf_acc:.4f} {'':<13} {mse_rf:.4f} {'':<10} {rf_time:.4f}")
print(f"{'Tuned Random Forest':<30} {best_rf_acc:.4f} {'':<13} {mse_best_rf:.4f}{'':<11} {random_search_time:.4f} (the whole process of random search)")
# Out:
# Model                          R^2 Score            MSE                  Training Time (s)
# ------------------------------------------------------------------------------------------------------------------------
# Baseline Random Forest         0.2427               1155.9393            71.9160
# Tuned Random Forest            0.2528               1140.5043            10131.6960 (the whole process of random search)

# %% [markdown]
# ## 3.5 Feature Importance Analysis

# %%
importances = best_model.named_steps['model'].feature_importances_
feature_names = X_train.columns
feature_importances = sorted(zip(importances, feature_names), reverse=True)
print("Feature importances:")
for importance, name in feature_importances:
    print(f"{name}: {importance:.4f}")
# Out:
# Feature importances:
# year_2017: 0.0750
# eps_diluted: 0.0459
# weighted_average_shs_out: 0.0270
# eps: 0.0229
# operating_cash_flow_growth: 0.0206
# gross_margin: 0.0205
# revenue_growth: 0.0198
# receivables_growth: 0.0197
# year_2016: 0.0195
# asset_turnover: 0.0194
# gross_profit_growth: 0.0193
# operating_income_growth: 0.0190
# total_liabilities: 0.0179
# ebitda: 0.0172
# issuance_(buybacks)_of_shares: 0.0171
# operating_cash_flow: 0.0168
# cash_and_cash_equivalents: 0.0163
# net_cash_flow_/_change_in_cash: 0.0160
# retained_earnings_(deficit): 0.0158
# total_shareholders_equity: 0.0155
# stock-based_compensation: 0.0154
# year_2015: 0.0151
# free_cash_flow: 0.0147
# r&d_expenses: 0.0140
# year_2018: 0.0138
# income_tax_expense: 0.0134
# investing_cash_flow: 0.0132
# financing_cash_flow: 0.0132
# payables: 0.0130
# weighted_average_shs_out_(dil): 0.0126
# total_assets: 0.0125
# issuance_(repayment)_of_debt: 0.0122
# sg&a_expense: 0.0119
# property,_plant_&_equipment_net: 0.0119
# net_profit_margin: 0.0118
# tangible_asset_value: 0.0118
# intangibles_to_total_assets: 0.0115
# capex_to_operating_cash_flow: 0.0113
# capital_expenditure: 0.0110
# gross_profit: 0.0110
# other_comprehensive_income: 0.0109
# interest_expense: 0.0108
# ebit_margin: 0.0108
# inventories: 0.0107
# sector_Energy: 0.0105
# depreciation_&_amortization: 0.0101
# effect_of_forex_changes_on_cash: 0.0100
# investments: 0.0100
# eps_diluted_growth: 0.0099
# deferred_revenue: 0.0097
# eps_growth: 0.0097
# earnings_before_tax_margin: 0.0092
# operating_income: 0.0092
# tax_liabilities: 0.0086
# goodwill_and_intangible_assets: 0.0083
# operating_expenses: 0.0082
# days_of_inventory_outstanding: 0.0079
# investment_purchases_and_sales: 0.0078
# tax_assets: 0.0078
# average_receivables: 0.0076
# total_debt: 0.0075
# days_sales_outstanding: 0.0074
# ebit: 0.0071
# long-term_debt: 0.0071
# dividend_payments: 0.0069
# receivables: 0.0066
# earnings_before_tax: 0.0064
# cost_of_revenue: 0.0062
# revenue: 0.0060
# acquisitions_and_disposals: 0.0058
# consolidated_income: 0.0058
# net_income_com: 0.0058
# sector_Healthcare: 0.0051
# net_income: 0.0041
# sector_Technology: 0.0024
# sector_Industrials: 0.0022
# sector_Consumer Cyclical: 0.0016
# sector_Consumer Defensive: 0.0006
# sector_Utilities: 0.0004
# sector_Financial Services: 0.0004
# sector_Real Estate: 0.0002
# sector_Communication Services: 0.0001

# %%
# Select the top 20 features
top_features = feature_importances[:20]

# Separating the importances and feature names for plotting
importances_sorted, feature_names_sorted = zip(*top_features)

# Create a figure and axes object
fig, ax = plt.subplots(figsize=(10, 8))

# Plotting
bars = ax.barh(feature_names_sorted, importances_sorted)

# Set font size for various elements
ax.set_xlabel('Importance', fontsize=14)  # Adjust the fontsize as needed
ax.set_ylabel('Feature', fontsize=14)  # Adjust the fontsize as needed
ax.set_title('Top 20 Feature Importances', fontsize=16)  # Adjust the fontsize as needed

# Set font size for tick labels on both axes
ax.tick_params(axis='both', labelsize=12)  # Adjust the fontsize as needed

# Invert y-axis
ax.invert_yaxis()

# Show the plot
plt.show()

# %%
# seems like something happened in 2017...

# %% [markdown]
# ## 3.6 Remodeling with Top Features

# %%
# Extract the top 20 feature names
top_20_feature_names = [name for importance, name in feature_importances[:20]]

# Create a new dataset with only these features
X_train_top20 = X_train[top_20_feature_names]
X_test_top20 = X_test[top_20_feature_names]

# Re-fit the original rf model to this new dataset
rf.fit(X_train_top20, y_train)

# Evaluate the model with the reduced dataset
rf_acc_top20 = rf.score(X_test_top20, y_test)
y_test_rf_pred_top20 = rf.predict(X_test_top20)
mse_rf_top20 = mean_squared_error(y_test, y_test_rf_pred_top20)

print(f"Accuracy of random forest with top 20 features: {rf_acc_top20:.4f}")
print(f"Mean Squared Error of random forest with top 20 features: {mse_rf_top20:.4f}")
# Out:
# Accuracy of random forest with top 20 features: 0.1519
# Mean Squared Error of random forest with top 20 features: 1294.4781

# %%
# Print R^2 and MSE for each model
print(f"\n{'Model':<20} {'R^2 Score':<20} {'MSE':<20}")
print("-" * 60)
print(f"{'Baseline Random Forest w/ All Features':<20} {rf_acc:.4f} {'':<13} {mse_rf:.4f}")
print(f"{'Random Forest w/ Top 20 Features':<20} {rf_acc_top20:.4f} {'':<13} {mse_rf_top20:.4f}")
# Out:
# Model                R^2 Score            MSE
# ------------------------------------------------------------
# Baseline Random Forest w/ All Features 0.2427               1155.9393
# Random Forest w/ Top 20 Features 0.1519               1294.4781

# %%
# So looks like using only top 20 is worse, let's see if keeping more features will be better?

# %%
# Extract the top 50 feature names
top_50_feature_names = [name for importance, name in feature_importances[:50]]

# Create a new dataset with only these features
X_train_top50 = X_train[top_50_feature_names]
X_test_top50 = X_test[top_50_feature_names]

# Re-fit the original rf model to this new dataset
rf.fit(X_train_top50, y_train)

# Evaluate the model with the reduced dataset
rf_acc_top50 = rf.score(X_test_top50, y_test)
y_test_rf_pred_top50 = rf.predict(X_test_top50)
mse_rf_top50 = mean_squared_error(y_test, y_test_rf_pred_top50)

print(f"Accuracy of random forest with top 50 features: {rf_acc_top50:.4f}")
print(f"Mean Squared Error of random forest with top 50 features: {mse_rf_top50:.4f}")
# Out:
# Accuracy of random forest with top 50 features: 0.2326
# Mean Squared Error of random forest with top 50 features: 1171.3012

# %%
# Print R^2 and MSE for each model
print(f"\n{'Model':<20} {'R^2 Score':<20} {'MSE':<20}")
print("-" * 60)
print(f"{'Baseline Random Forest w/ All Features':<20} {rf_acc:.4f} {'':<13} {mse_rf:.4f}")
print(f"{'Random Forest w/ Top 50 Features':<20} {rf_acc_top50:.4f} {'':<13} {mse_rf_top50:.4f}")
# Out:
# Model                R^2 Score            MSE
# ------------------------------------------------------------
# Baseline Random Forest w/ All Features 0.2427               1155.9393
# Random Forest w/ Top 50 Features 0.2326               1171.3012

# %%
# Still doesn't look better. Since we have 84 features, further cutting brings diminishing return. So we decide to keep using all features
# Note that one might argue since they give pretty close result, you should aim for a simpler model (with fewer features).
# This is a personal choice -- we just think that a lot of features got used a bit for a similar amount 
# so it's hard to choose which to drop and which to keep -- might introduce bias

# %% [markdown]
# # Neural Network

# %%
#!pip install tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Assuming X and y are your features and target variable
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scale features (Neural networks perform better with scaled data)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define the model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))  # Single output neuron for regression

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train_scaled, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model
mse = model.evaluate(X_test_scaled, y_test)
print(f'Test MSE: {mse}')

# %% [markdown]
# # Part 4: Ensemble Model

# %%
# for random forest, we are using the tuned one from before `best_model`
# `n_estimators` we are using the one from tuned random forest model
# time constraint, not tuning xgb amd lightgbm here
xgboost = xgb.XGBRegressor(n_estimators=300, random_state=123)
lightgbm = lgb.LGBMRegressor(n_estimators=300, random_state=123)

# %% [markdown]
# ## 4.2 XGBoost & LightGBM

# %%
# Initialize XGBoost Regressor
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 300)

# Train the model
xg_reg.fit(X_train, y_train)

# Predict on test data
xg_pred = xg_reg.predict(X_test)

# Evaluate performance
xg_mse = mean_squared_error(y_test, xg_pred)
xg_r2 = r2_score(y_test, xg_pred)
print(f'XGBoost MSE: {xg_mse}, R2: {xg_r2}')

# %% [markdown]
# ## 4.1 Initialize Base Models

# %% [markdown]
# ## 4.2 Create Ensemble Model

# %%
# Create ensemble model
ensemble = VotingRegressor(estimators=[
    ('random_forest', best_model), 
    ('xgboost', xgboost), 
    ('lightgbm', lightgbm)
])

# Train ensemble model
ensemble.fit(X_train, y_train)

# %%
# Predict on test set
y_ensemble_pred = ensemble.predict(X_test)

# Calculate mean squared error
ensemble_mse = mean_squared_error(y_test, y_ensemble_pred)
print(f'Ensemble model MSE: {ensemble_mse}')
