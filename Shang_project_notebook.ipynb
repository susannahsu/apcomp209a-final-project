# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 45px" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png"> CS109A Introduction to Data Science:
# ## APCOMP 209a Final Project
#
# **Harvard University**<br/>
# **Fall 2023**<br/>
# **Instructors**: Pavlos Protopapas and Kevin Rader<br/>
# **Group Members**: Davide Bray, Regina Lin, Shang Wang, Susannah Su
#
# <hr style="height:2.4pt">

# %%
# RUN THIS CELL 
import requests
from IPython.core.display import HTML
styles = requests.get(
    "https://raw.githubusercontent.com/Harvard-IACS/2021-CS109A/master/"
    "themes/static/css/cs109.css"
).text
HTML(styles)
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #63ACBE;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #f8b4ab;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# }
#
# div.exercise-r {
# 	background-color: #ffd0d0;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# }
#
#
# span.sub-q {
# 	font-weight: bold;
# }
# div.theme {
# 	background-color: #63ACBE;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
#     padding-top: 5px;
#     padding-bottom: 5px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
# header {
#    padding-top: 35px;
#     padding-bottom: 35px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# span.emph {
# 	color: #601A4A;
# 	font-weight: bold;
# }
#
# </style>

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import re
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils import resample
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# <a id="contents"></a>
#
# ## Notebook contents

# %% [markdown]
# - [**Data description**](#data_description)
# - [**Problem Statement**](#problem_statement)
# - [**Project Organization**](#project_organization)
#
# - [**Question 2: Interpretable modeling [18 pts]**](#part2)
#
# - [**Question 3: Harvard and Yale? [30 pts]**](#part3)
#
# - [**Question 4: Building predictive models for admitted [24 pts]**](#part4)
#
# - [**Question 5: Evaluating results [12 pts]**](#part5)

# %% [markdown]
# <a id="data_description"></a>
#
# ## Data description
# [Return to contents](#contents)

# %% [markdown]
#  (From Kaggle, see https://www.kaggle.com/datasets/cnic92/200-financial-indicators-of-us-stocks-20142018?select=2018_Financial_Data.csv)
#
#  There are in total 5 datasets: `2014_Financial_Data.csv`, `2015_Financial_Data.csv`, `2016_Financial_Data.csv`, `2017_Financial_Data.csv`, `2018_Financial_Data.csv`.
#
# Each dataset contains 200+ financial indicators, that are commonly found in the 10-K filings each publicly traded company releases yearly, for a plethora of US stocks (on average, 4k stocks are listed in each dataset).
#
# The dataset was built by the author leveraging Financial Modeling Prep API and pandas_datareader.
#
# #### Important remarks regarding the datasets
# 1. Some financial indicator values are missing (`nan` cells), so the user can select the best technique to clean each dataset (`dropna`, `fillna`, etc.).
# 2. There are outliers, meaning extreme values that are probably caused by mistypings. Also in this case, the user can choose how to clean each dataset (have a look at the 1% - 99% percentile values).
# 3. The third-to-last column, `Sector`, lists the sector of each stock. Indeed, in the US stock market each company is part of a sector that classifies it in a macro-area. Since all the sectors have been collected (Basic Materials, Communication Services, Consumer Cyclical, Consumer Defensive, Energy, Financial Services, Healthcare, Industrial, Real Estate, Technology and Utilities), the user has the option to perform per-sector analyses and comparisons.
# 4. The second-to-last column, `PRICE VAR [%]`, lists the percent price variation of each stock for the year. For example, if we consider the dataset `2015_Financial_Data.csv`, we will have:
#     - 200+ financial indicators for the year 2015;
#     - percent price variation for the year 2016 (meaning from the first trading day on Jan 2016 to the last trading day on Dec 2016).
#
# 5. The last column, `class`, lists a binary classification for each stock, where
#     - for each stock, if the `PRICE VAR [%]` value is positive, `class = 1`. From a trading perspective, the `1` identifies those stocks that an hypothetical trader should **BUY** at the start of the year and sell at the end of the year for a profit.
#     - for each stock, if the `PRICE VAR [%]` value is negative, `class = 0`. From a trading perspective, the `0` identifies those stocks that an hypothetical trader should **NOT BUY**, since their value will decrease, meaning a loss of capital.
#
# The columns `PRICE VAR [%]` and `class` make possible to use the datasets for both classification and regression tasks:
# - If the we wish to train a machine learning model so that it learns to classify those stocks that in buy-worthy and not buy-worthy, it is possible to get the targets from the class column;
# - If the we wish to train a machine learning model so that it learns to predict the future value of a stock, it is possible to get the targets from the `PRICE VAR [%]` column.

# %% [markdown]
# <a id="problem_statement"></a>
#
# ## Problem Statement
#
# [Return to contents](#contents)

# %% [markdown]
# This project seeks to develop a machine learning model that predicts stock price variations using a range of financial indicators, without relying on individual stock identifiers (tickers). The aim is to uncover general patterns in the stock market that transcend company-specific characteristics, thereby creating a broadly applicable predictive tool. The challenge involves accurately capturing the complex dynamics of the market using available financial data, and ensuring that the model is robust and generalizable across various stocks and market conditions.
#
# The project will begin with a simple baseline model, then advance to more sophisticated algorithms to improve prediction accuracy. Success will be measured by the model's ability to reliably predict stock price changes, providing a valuable asset for investors and analysts in making informed financial decisions. This endeavor is poised to enhance understanding and forecasting of market behaviors using machine learning techniques.

# %% [markdown]
# <a id="project_organization"></a>
#
# ## Project Organization
#
# [Return to contents](#contents)

# %% [markdown]
# ### Part 0: Data Preprocessing & Feature Selection / Exploratory Data Analysis

# %% [markdown]
# #### Overview
# This foundational part focuses on preparing the dataset for various analyses and model building in the subsequent parts. The processes conducted here are crucial for ensuring the quality and effectiveness of the models and analyses.
#
# #### Methodology
# 1. **Basic Processing**
# * Load the dataset and rename the columns for clarity.
# * Separate predictors and target variables (`price_var20xx`, `class20xx`, `xx` correspond to the year).
# * Preselection of predictors based on industry knowledge and relevance.
# * Train-test splitting first to prevent data leakage.
# * Scaling of features to normalize data.
#
# 2. **EDA**
# * Statistical summary of datasets to understand distributions and central tendencies.
# * Visualization of data distributions and relationships (e.g., histograms, scatter plots).
# * Correlation analysis to identify highly correlated features.
# * Identification of trends and patterns specific to sectors.
#
# 3. **Handle Missingness**
# * Examine nullness.
# * K-NN imputation to handle missing values without making assumptions about the underlying distribution of the variables.
#
# 4. **Dimentionality Reduction**
# * Apply principle component analysis (PCA) to reduce dimentionality.

# %% [markdown]
# ### Part 1: Baseline Model Selection and Evaluation

# %% [markdown]
# #### Objective
# To establish a simple yet effective baseline model for predicting stock performance.
#
# #### Methodology
# 1. **Model Selection and Building**
# * Start with a simple mean/median model as a baseline.
#     - Mean/median prediction model
#     - Multiple linear regression
#     - Single decision tree
# * Train the model on our dataset and perform an initial evaluation using $MSE$.
#
# 2. **Cross Validations**
# * Implement basic cross-validation (like k-fold CV) to assess the model’s performance more reliably.
#
# 3. **Interim Interpretation**
# * Provide an initial interpretation of the model's performance, focusing on its strengths and limitations based on the evaluation metrics.
# * Select the baseline model.

# %% [markdown]
# ### Part 2: More Complex Models

# %% [markdown]
# #### Objective
# The objective of this stage is to explore and evaluate more sophisticated machine learning models beyond the baseline model. These models are expected to capture complex patterns and relationships in the data that the baseline model might miss. The goal is to improve prediction accuracy and reliability in forecasting stock performance, while also gaining deeper insights into how different financial indicators influence stock prices.
#
# #### Methodology
# 1. **Selection of More Complex Models and Building**
# * Identify a set of more complex models:
#     - Ridge regression
#     - LASSO regression
#     - Elastic net regression
#     - Random forest regressors
#     - Gradient boosting
# * Train the model on our dataset and perform an initial evaluation using $MSE$.
#
# 2. **Cross Validations**
# * Implement basic cross-validation (like k-fold CV) to assess the model’s performance more reliably.
# * Include a basic hyperparameter tuning to find a reasonably good configuration for each model, while avoiding extensive optimization at this stage.
#
# 3. **Performance Evaluation and Final Model Selection**
# * Evaluate the tuned models using $MSE$.
# * Compare the complex models with the baseline model.
# * Select the final model.

# %% [markdown]
# ### Part 3: Network Analysis of Stock Market Interdependencies

# %% [markdown]
# #### Objective
# Analyze the network of interdependencies among stocks or sectors.
#
# #### Methodology
# 1. **Network Construction**
# * Construct a network graph based on the relationships derived from the preprocessed data.
#
# 2. **Network Analysis**
# * Centrality measures to identify influential stocks.
# * Community detection to find clusters of interrelated stocks.
# * Dynamic analysis over different years to observe changes.
#
# 3. **Evaluation**
# * Evaluate the network’s insights on stock market dynamics.

# %% [markdown]
# <a id="project_organization"></a>
#
# ## Part 0: Data Preprocessing & Feature Selection / Exploratory Data Analysis
#
# [Return to contents](#contents)

# %% [markdown]
# ### Basic Processing

# %%
# Load raw data
df2014 = pd.read_csv('data/2014_Financial_Data.csv')
df2015 = pd.read_csv('data/2015_Financial_Data.csv')
df2016 = pd.read_csv('data/2016_Financial_Data.csv')
df2017 = pd.read_csv('data/2017_Financial_Data.csv')
df2018 = pd.read_csv('data/2018_Financial_Data.csv')

# %%
# Inspect how does it look like -- 
# The "Unnamed: 0" column is probably stock ticker
df2014.head()
# Out:
#   Unnamed: 0       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0         PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1       VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2         KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3        RAD  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4        GIS  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
#
#    R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# 0  0.000000e+00  2.146100e+10        2.146100e+10      1.391000e+10
# 1  1.083303e+08  3.441414e+08        7.939267e+08      1.345959e+08
# 2  0.000000e+00  1.519600e+10        1.751200e+10      2.725000e+09
# 3  0.000000e+00  6.561162e+09        6.586482e+09      7.372520e+08
# 4  0.000000e+00  3.474300e+09        3.412400e+09      2.957400e+09
#
#    Interest Expense  Earnings before Tax  Income Tax Expense  \
# 0      7.090000e+08         1.449400e+10        2.851000e+09
# 1      1.214869e+07         1.753823e+08        3.955957e+07
# 2      4.430000e+08         2.270000e+09        7.510000e+08
# 3      4.245910e+08         2.502180e+08        8.040000e+05
# 4      3.024000e+08         2.707700e+09        8.833000e+08
#
#    Net Income - Non-Controlling int  Net Income - Discontinued ops  \
# 0                      1.420000e+08                  -1.127000e+09
# 1                     -1.431918e+07                   0.000000e+00
# 2                      1.200000e+07                   0.000000e+00
# 3                      0.000000e+00                   0.000000e+00
# 4                      3.690000e+07                   0.000000e+00
#
#      Net Income  Preferred Dividends  Net Income Com     EPS  EPS Diluted  \
# 0  1.164300e+10                  0.0    1.164300e+10  4.1900        4.010
# 1  1.358227e+08                  0.0    1.358227e+08  0.2396        0.226
# 2  1.519000e+09                  0.0    1.519000e+09  1.4700        1.450
# 3  2.494140e+08           33998000.0    2.154160e+08  4.6000        4.600
# 4  1.824400e+09                  0.0    1.824400e+09  2.9000        2.830
#
#    Weighted Average Shs Out  Weighted Average Shs Out (Dil)  \
# 0              2.705960e+09                    2.705960e+09
# 1                       NaN                    1.829362e+07
# 2              1.033053e+09                    1.028000e+09
# 3              4.832628e+07                    4.832628e+07
# 4              6.144922e+08                    6.144922e+08
#
#    Dividend per Share  Gross Margin  EBITDA Margin  EBIT Margin  \
# 0               2.448        0.4754         0.2470       0.2043
# 1               0.000        0.2487         0.0107       0.0502
# 2               0.307        0.2057         0.0450       0.0276
# 3               0.000        0.2869         0.0420       0.0264
# 4               1.550        0.3557         0.2010       0.1681
#
#    Profit Margin  Free Cash Flow margin        EBITDA          EBIT  \
# 0         0.1560                 0.1359  1.834400e+10  1.520300e+10
# 1         0.0058                 0.0704  2.456858e+08  1.875310e+08
# 2         0.0150                 0.0126  4.416000e+09  2.713000e+09
# 3         0.0080                 0.0144  1.078550e+09  6.748090e+08
# 4         0.1020                 0.1052  3.595500e+09  3.010100e+09
#
#    Consolidated Income  Earnings Before Tax Margin  Net Profit Margin  \
# 0         1.178500e+10                      0.1948             0.1565
# 1         1.215036e+08                      0.0470             0.0364
# 2         1.531000e+09                      0.0231             0.0154
# 3         2.494140e+08                      0.0098             0.0098
# 4         1.861300e+09                      0.1512             0.1019
#
#    Cash and cash equivalents  Short-term investments  \
# 0               8.558000e+09            2.128000e+09
# 1               7.735149e+08            6.083852e+08
# 2               4.010000e+08            0.000000e+00
# 3               1.464060e+08            0.000000e+00
# 4               8.673000e+08            0.000000e+00
#
#    Cash and short-term investments   Receivables   Inventories  \
# 0                     1.068600e+10  6.386000e+09  6.759000e+09
# 1                     1.381900e+09  1.169487e+07  5.793193e+08
# 2                     4.010000e+08  1.116000e+09  5.651000e+09
# 3                     1.464060e+08  9.490620e+08  2.993948e+09
# 4                     8.673000e+08  1.483600e+09  1.559400e+09
#
#    Total current assets  Property, Plant & Equipment Net  \
# 0          3.161700e+10                     2.230400e+10
# 1          2.134397e+09                     3.085975e+08
# 2          8.830000e+09                     1.689300e+10
# 3          4.285125e+09                     1.957329e+09
# 4          4.393500e+09                     3.941900e+09
#
#    Goodwill and Intangible Assets  Long-term investments    Tax assets  \
# 0                    8.454700e+10           0.000000e+00  1.092000e+09
# 1                    1.906587e+08           6.299354e+07  3.764110e+07
# 2                    2.837000e+09           0.000000e+00  0.000000e+00
# 3                    4.312270e+08           0.000000e+00  0.000000e+00
# 4                    1.366480e+10           0.000000e+00  7.410000e+07
#
#    Total non-current assets  Total assets      Payables  Short-term debt  \
# 0              1.126490e+11  1.442660e+11  8.461000e+09     1.560600e+10
# 1              6.022904e+08  2.736687e+09  1.000491e+09     0.000000e+00
# 2              2.045100e+10  2.928100e+10  4.881000e+09     1.657000e+09
# 3              2.659746e+09  6.944871e+09  1.292419e+09     4.917400e+07
# 4              1.875220e+10  2.314570e+10  1.611300e+09     2.362300e+09
#
#    Total current liabilities  Long-term debt    Total debt  Deferred revenue  \
# 0               3.372600e+10    1.981100e+10  3.541700e+10      0.000000e+00
# 1               1.639537e+09    6.223741e+08  6.223741e+08      3.141104e+07
# 2               1.070500e+10    9.653000e+09  1.131000e+10      0.000000e+00
# 3               2.507452e+09    5.707969e+09  5.757143e+09      0.000000e+00
# 4               5.423500e+09    6.423500e+09  8.785800e+09      0.000000e+00
#
#    Tax Liabilities  Deposit Liabilities  Total non-current liabilities  \
# 0     1.021800e+10                  0.0                   4.056400e+10
# 1     0.000000e+00                  0.0                   6.615567e+08
# 2     1.629000e+09                  0.0                   1.318100e+10
# 3     0.000000e+00                  0.0                   6.551121e+09
# 4     1.666000e+09                  0.0                   9.732700e+09
#
#    Total liabilities  Other comprehensive income  Retained earnings (deficit)  \
# 0       7.429000e+10               -7.662000e+09                 8.499000e+10
# 1       2.301093e+09               -1.729254e+06                 4.285438e+06
# 2       2.388600e+10               -4.640000e+08                 1.098100e+10
# 3       9.058573e+09               -3.733400e+07                -7.515848e+09
# 4       1.515620e+10               -1.340300e+09                 1.178720e+10
#
#    Total shareholders equity   Investments      Net Debt  Other Assets  \
# 0               6.997600e+10  2.128000e+09  2.473100e+10  7.786000e+09
# 1               4.123545e+08  6.713788e+08           NaN           NaN
# 2               5.384000e+09  0.000000e+00  1.090900e+10  1.662000e+09
# 3              -2.113702e+09  0.000000e+00  5.610737e+09  1.957090e+08
# 4               6.534800e+09  0.000000e+00  7.918500e+09  4.832000e+08
#
#    Other Liabilities  Depreciation & Amortization  Stock-based compensation  \
# 0       9.659000e+09                 3.141000e+09              3.600000e+08
# 1       6.390460e+08                 5.815483e+07              3.640523e+07
# 2       4.167000e+09                 1.703000e+09              1.070000e+08
# 3       1.165859e+09                 4.037410e+08             -1.047100e+07
# 4       1.449900e+09                 5.854000e+08              3.920000e+07
#
#    Operating Cash Flow  Capital Expenditure  Acquisitions and disposals  \
# 0         1.395800e+10        -3.848000e+09               -2.400000e+07
# 1         5.267456e+08        -2.637046e+08               -1.922552e+08
# 2         3.573000e+09        -2.330000e+09               -2.344000e+09
# 3         7.020460e+08        -3.338700e+08                0.000000e+00
# 4         2.541000e+09        -6.569000e+08                6.670000e+07
#
#    Investment purchases and sales  Investing Cash flow  \
# 0                   -8.050000e+08        -4.100000e+09
# 1                   -2.126447e+08        -6.866936e+08
# 2                    0.000000e+00        -4.771000e+09
# 3                    4.115500e+07        -3.649240e+08
# 4                    2.930000e+07        -5.618000e+08
#
#    Issuance (repayment) of debt  Issuance (buybacks) of shares  \
# 0                  3.543000e+09                  -3.911000e+09
# 1                  6.193268e+08                   1.767840e+06
# 2                  2.093000e+09                  -4.130000e+08
# 3                 -2.954350e+08                   3.321700e+07
# 4                  8.011000e+08                  -1.637200e+09
#
#    Dividend payments  Financing Cash Flow  Effect of forex changes on cash  \
# 0      -6.911000e+09        -7.279000e+09                     3.900000e+07
# 1       0.000000e+00         6.219136e+08                    -1.564869e+07
# 2      -3.190000e+08         1.361000e+09                     0.000000e+00
# 3       0.000000e+00        -3.201680e+08                     0.000000e+00
# 4      -9.833000e+08        -1.824100e+09                    -2.920000e+07
#
#    Net cash flow / Change in cash  Free Cash Flow  Net Cash/Marketcap  \
# 0                    2.618000e+09    1.011000e+10             -0.1163
# 1                    4.463169e+08    2.630410e+08              0.0956
# 2                    1.630000e+08    1.243000e+09             -0.5969
# 3                    1.695400e+07    3.681760e+08             -0.8822
# 4                    1.259000e+08    1.884100e+09             -0.2376
#
#    priceBookValueRatio  priceToBookRatio  priceToSalesRatio  \
# 0               3.0391            0.0000             2.8583
# 1                  NaN               NaN             0.0443
# 2               3.3579            7.0982             0.1858
# 3               0.0000            0.0000             0.2491
# 4               5.1004            0.0000             1.8610
#
#    priceEarningsRatio  priceToFreeCashFlowsRatio  \
# 0             18.7566                    21.0348
# 1             81.5526                     1.3589
# 2             12.0340                    14.6302
# 3             28.6087                    17.2736
# 4             18.7034                    17.6902
#
#    priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# 0                         15.2358           12.977501
# 1                             NaN            0.678615
# 2                          5.1147            0.000000
# 3                          9.0589            0.000000
# 4                         13.1169           10.952350
#
#    priceEarningsToGrowthRatio  priceSalesRatio  dividendYield  \
# 0                   15.557842         2.434644       0.038153
# 1                    2.631793         0.095727      -0.000000
# 2                    0.000000         0.000000            NaN
# 3                    0.000000         0.000000            NaN
# 4                   15.254287         1.553911       0.035332
#
#    enterpriseValueMultiple  priceFairValue  ebitperRevenue  ebtperEBIT  \
# 0                11.421116        2.588601        0.204339    0.953364
# 1                 7.136538        0.866869        0.050221    0.935218
# 2                 2.276721        0.000000        0.027578    0.836712
# 3                 5.428005             NaN        0.026436    0.370798
# 4                 9.767966        4.258726        0.168072    0.899538
#
#    niperEBT  grossProfitMargin  operatingProfitMargin  pretaxProfitMargin  \
# 0  0.803298           0.475410                    1.0            0.186960
# 1  0.774438           0.248657                    1.0            0.036045
# 2  0.669163           0.205713                    1.0            0.027700
# 3  0.996787           0.286908                    1.0            0.028882
# 4  0.673782           0.355664                    1.0            0.165129
#
#    netProfitMargin  effectiveTaxRate  returnOnAssets  returnOnEquity  \
# 0         0.156490          0.196702          0.5765          0.1664
# 1         0.036373          0.225562          0.0403          0.3294
# 2         0.015441          0.330837          0.1011          0.2821
# 3         0.009771          0.003213          0.0668         -0.1180
# 4         0.101867          0.326218          0.6265          0.2792
#
#    returnOnCapitalEmployed  nIperEBT  eBTperEBIT  eBITperRevenue  \
# 0                   0.0753  0.803298    0.953364        0.204339
# 1                   0.0000  0.774438    0.935218        0.050221
# 2                   0.0859  0.669163    0.836712        0.027578
# 3                   0.1062  0.996787    0.370798        0.026436
# 4                   0.1041  0.673782    0.899538        0.168072
#
#    payablesTurnover  inventoryTurnover  fixedAssetTurnover  assetTurnover  \
# 0            1.5648            10.8869            3.335769       0.515721
# 1               NaN                NaN           12.100383       1.364477
# 2            4.9593            18.2227            5.823418       3.359687
# 3            4.9289             8.3030           13.041452       3.675578
# 4            2.8234            11.5363            4.543393       0.773777
#
#    currentRatio  quickRatio  cashRatio  daysOfSalesOutstanding  \
# 0        0.9370    0.506197   0.253751                -63.2087
# 1        0.2102    0.849993   0.471789                -75.3670
# 2        0.8250    0.141709   0.037459                -26.3971
# 3        1.7090    0.436885   0.058388                -60.0346
# 4        0.8100    0.433465   0.159915                -49.3233
#
#    daysOfInventoryOutstanding  operatingCycle  daysOfPayablesOutstanding  \
# 0                     31.3287             NaN                    41.5084
# 1                      1.1431             NaN                    97.7945
# 2                      4.1407             NaN                    18.1099
# 3                     13.5706             NaN                    18.4802
# 4                     30.2360             NaN                    32.8385
#
#    cashConversionCycle  debtRatio  debtEquityRatio  \
# 0                  NaN     0.2455           0.5061
# 1                  NaN     0.2274           1.5093
# 2                  NaN     0.3863           2.1007
# 3                  NaN     0.8290          -2.7237
# 4                  NaN     0.3796           1.3445
#
#    longtermDebtToCapitalization  totalDebtToCapitalization  interestCoverage  \
# 0                      0.220644                   0.336047           21.4429
# 1                      0.601485                   0.601485           15.4363
# 2                      0.641950                   0.677489            6.1242
# 3                      1.588076                   1.580139            1.5893
# 4                      0.495705                   0.573463            9.9540
#
#    cashFlowToDebtRatio  companyEquityMultiplier  operatingCashFlowPerShare  \
# 0             0.394105                 2.061650                     5.1582
# 1             0.846349                 6.636734                    35.6714
# 2             0.315915                 5.438522                     3.4757
# 3             0.121943                      NaN                    14.5272
# 4             0.289217                 3.541914                     4.1351
#
#    freeCashFlowPerShare  cashPerShare  payoutRatio  \
# 0                 3.964        3.1626        0.584
# 1                22.976       52.3827        0.000
# 2                 0.837        0.3901        0.209
# 3                 0.557        3.0295        0.000
# 4                 3.624        1.4114        0.534
#
#    operatingCashFlowSalesRatio  freeCashFlowOperatingCashFlowRatio  \
# 0                     0.187605                            0.724316
# 1                     0.141062                            0.499370
# 2                     0.036320                            0.347887
# 3                     0.027503                            0.524433
# 4                     0.141879                            0.741480
#
#    cashFlowCoverageRatios  shortTermCoverageRatios  \
# 0                0.394105                 0.894400
# 1                0.846349                      NaN
# 2                0.315915                 2.156307
# 3                0.121943                14.276772
# 4                0.289217                 1.075647
#
#    capitalExpenditureCoverageRatios  dividendpaidAndCapexCoverageRatios  \
# 0                          3.627339                            1.297332
# 1                          1.997484                            1.997484
# 2                          1.533476                            1.348811
# 3                          2.102753                            2.102753
# 4                          3.868169                            1.549201
#
#    dividendPayoutRatio  Revenue per Share  Net Income per Share  \
# 0             0.593576            27.4952                4.3027
# 1            -0.000000           252.8778                9.1980
# 2             0.210007            95.6955                1.4776
# 3            -0.000000           528.2098                5.1610
# 4             0.538972            29.1454                2.9690
#
#    Operating Cash Flow per Share  Free Cash Flow per Share  Cash per Share  \
# 0                         5.1582                     3.964          3.1626
# 1                        35.6714                    22.976         52.3827
# 2                         3.4757                     0.837          0.3901
# 3                        14.5272                     0.557          3.0295
# 4                         4.1351                     3.624          1.4114
#
#    Book Value per Share  Tangible Book Value per Share  \
# 0               25.8600                        22.0690
# 1                0.7278                         4.4939
# 2                5.2370                        25.7240
# 3              -43.7380                       134.7850
# 4               10.6340                        15.4290
#
#    Shareholders Equity per Share  Interest Debt per Share    Market Cap  \
# 0                        25.8600                  13.0885  2.126614e+11
# 1                        27.9248                  42.1474  6.253200e+09
# 2                         5.2374                  11.0019  1.827470e+10
# 3                       -43.7381                 119.1307  6.359738e+09
# 4                        10.6345                  14.2977  3.333006e+10
#
#    Enterprise Value  PE ratio  Price to Sales Ratio  POCF ratio  PFCF ratio  \
# 0      2.373924e+11   18.7566                2.8583     15.2358     21.0348
# 1               NaN   81.5526                0.0443         NaN      1.3589
# 2      2.918370e+10   12.0340                0.1858      5.1147     14.6302
# 3      1.197048e+10   28.6087                0.2491      9.0589     17.2736
# 4      4.124856e+10   18.7034                1.8610     13.1169     17.6902
#
#    PB ratio  PTB ratio  EV to Sales  Enterprise Value over EBITDA  \
# 0    3.0391     0.0000       3.1907                       12.9411
# 1       NaN        NaN          NaN                           NaN
# 2    3.3579     7.0982       0.2967                        6.6086
# 3    0.0000     0.0000       0.4689                       11.0987
# 4    5.1004     0.0000       2.3032                       11.4723
#
#    EV to Operating cash flow  EV to Free cash flow  Earnings Yield  \
# 0                    17.0076               23.4810          0.0533
# 1                        NaN                   NaN          0.0123
# 2                     8.1678               23.4784          0.0831
# 3                    17.0508               32.5129          0.0350
# 4                    16.2332               21.8930          0.0535
#
#    Free Cash Flow Yield  Debt to Equity  Debt to Assets  Net Debt to EBITDA  \
# 0                0.0475          0.5061          0.2455              1.3482
# 1                   NaN          1.5093          0.2274                 NaN
# 2                0.0680          2.1007          0.3863              2.4703
# 3                0.0579         -2.7237          0.8290              5.2021
# 4                0.0565          1.3445          0.3796              2.2023
#
#    Current ratio  Interest Coverage  Income Quality  Dividend Yield  \
# 0         0.9370            21.4429          1.1988          0.0311
# 1         0.2102            15.4363          3.8782          0.0000
# 2         0.8250             6.1242          2.3522          0.0174
# 3         1.7090             1.5893          3.2590          0.0000
# 4         0.8100             9.9540          1.3928          0.0286
#
#    Payout Ratio  SG&A to Revenue  R&D to Revenue  Intangibles to Total Assets  \
# 0         0.584           0.2885           0.000                       0.5860
# 1         0.000           0.0922           0.029                       0.0697
# 2         0.209           0.1545           0.000                       0.0969
# 3         0.000           0.2570           0.000                       0.0621
# 4         0.534           0.1940           0.000                       0.5904
#
#    Capex to Operating Cash Flow  Capex to Revenue  Capex to Depreciation  \
# 0                        0.2757            0.0517                -1.2251
# 1                        0.5006            0.0706                -4.5345
# 2                        0.6521            0.0237                -1.3682
# 3                        0.4756            0.0131                -0.8269
# 4                        0.2585            0.0367                -1.1221
#
#    Stock-based compensation to Revenue  Graham Number    ROIC  \
# 0                               0.0048        49.3756  0.0753
# 1                               0.0097            NaN  0.0000
# 2                               0.0011        13.2000  0.0859
# 3                              -0.0004         0.0000  0.1062
# 4                               0.0022        26.3414  0.1041
#
#    Return on Tangible Assets  Graham Net-Net  Working Capital  \
# 0                     0.5765         -0.2007    -2.109000e+09
# 1                     0.0403          0.0534     3.065163e+09
# 2                     0.1011         -0.8239    -1.875000e+09
# 3                     0.0668         -0.7506     1.777673e+09
# 4                     0.6265         -0.3229    -1.030000e+09
#
#    Tangible Asset Value  Net Current Asset Value  Invested Capital  \
# 0          5.971900e+10            -4.267300e+10      5.285200e+10
# 1          2.546029e+09            -1.666966e+08      7.553510e+08
# 2          2.644400e+10            -1.505600e+10      2.664800e+10
# 3          6.513644e+09            -4.773448e+09      9.616929e+09
# 4          9.480900e+09            -1.076270e+10      1.197590e+10
#
#    Average Receivables  Average Payables  Average Inventory  \
# 0         6.447000e+09      8.619000e+09       6.834000e+09
# 1                  NaN               NaN                NaN
# 2         1.083500e+09      4.682500e+09       5.398500e+09
# 3         9.392690e+08      1.338532e+09       3.074345e+09
# 4         1.465000e+09      1.517250e+09       1.552450e+09
#
#    Days Sales Outstanding  Days Payables Outstanding  \
# 0                 31.3287                    41.5084
# 1                  1.1431                    97.7945
# 2                  4.1407                    18.1099
# 3                 13.5706                    18.4802
# 4                 30.2360                    32.8385
#
#    Days of Inventory on Hand  Receivables Turnover  Payables Turnover  \
# 0                   -63.2087               11.5404             1.5648
# 1                   -75.3670                   NaN                NaN
# 2                   -26.3971               90.7937             4.9593
# 3                   -60.0346               27.1769             4.9289
# 4                   -49.3233               12.2250             2.8234
#
#    Inventory Turnover     ROE  Capex per Share  Gross Profit Growth  \
# 0             10.8869  0.1664          -1.4220              -0.1185
# 1                 NaN  0.3294         -17.8582               1.2489
# 2             18.2227  0.2821          -2.2665               0.0173
# 3              8.3030 -0.1180          -6.9087               0.0007
# 4             11.5363  0.2792          -1.0690              -0.0084
#
#    EBIT Growth  Operating Income Growth  Net Income Growth  EPS Growth  \
# 0      -0.0001                   0.0067             0.0293      0.0371
# 1       1.6142                   1.9463             1.5649      1.4625
# 2      -0.0145                  -0.0141             0.0147      0.0576
# 3       0.2904                   0.1113             1.0043      0.9167
# 4       0.0332                   0.0370            -0.0166      0.0140
#
#    EPS Diluted Growth  Weighted Average Shares Growth  \
# 0              0.0389                         -0.0127
# 1              1.4646                          0.0184
# 2              0.0469                         -0.0356
# 3              0.9167                          0.0694
# 4              0.0143                         -0.0468
#
#    Weighted Average Shares Diluted Growth  Dividends per Share Growth  \
# 0                                     NaN                      0.0699
# 1                                  0.0195                      0.0000
# 2                                 -0.0317                      0.2429
# 3                                     NaN                      0.0000
# 4                                     NaN                      0.1742
#
#    Operating Cash Flow growth  Free Cash Flow growth  \
# 0                     -0.0615                -0.0695
# 1                      0.2134                -0.3626
# 2                      0.2095                 0.3935
# 3                     -0.1434                -0.2691
# 4                     -0.1316                -0.1936
#
#    10Y Revenue Growth (per Share)  5Y Revenue Growth (per Share)  \
# 0                          0.0323                         0.0088
# 1                             NaN                            NaN
# 2                          0.1027                         0.1038
# 3                         -0.0195                        -0.0290
# 4                          0.0704                         0.0567
#
#    3Y Revenue Growth (per Share)  10Y Operating CF Growth (per Share)  \
# 0                        -0.0182                               0.0355
# 1                            NaN                                  NaN
# 2                         0.1399                               0.0889
# 3                        -0.0230                               0.0513
# 4                         0.0773                               0.0782
#
#    5Y Operating CF Growth (per Share)  3Y Operating CF Growth (per Share)  \
# 0                              0.0015                              0.0260
# 1                                 NaN                                 NaN
# 2                              0.0937                              0.0946
# 3                              0.1164                              0.1777
# 4                              0.0828                              0.1991
#
#    10Y Net Income Growth (per Share)  5Y Net Income Growth (per Share)  \
# 0                             0.0603                           -0.0137
# 1                                NaN                               NaN
# 2                             0.2272                            0.0906
# 3                             0.0480                            0.0000
# 4                             0.0776                            0.0841
#
#    3Y Net Income Growth (per Share)  \
# 0                            0.0060
# 1                               NaN
# 2                            0.1892
# 3                            0.0000
# 4                            0.0177
#
#    10Y Shareholders Equity Growth (per Share)  \
# 0                                      0.1442
# 1                                         NaN
# 2                                      0.0676
# 3                                      0.0000
# 4                                      0.0427
#
#    5Y Shareholders Equity Growth (per Share)  \
# 0                                     0.0353
# 1                                        NaN
# 2                                     0.0558
# 3                                     0.0000
# 4                                     0.0623
#
#    3Y Shareholders Equity Growth (per Share)  \
# 0                                     0.0201
# 1                                        NaN
# 2                                     0.0789
# 3                                     0.0000
# 4                                     0.0217
#
#    10Y Dividend per Share Growth (per Share)  \
# 0                                     0.1013
# 1                                        NaN
# 2                                     0.0000
# 3                                     0.0000
# 4                                     0.1092
#
#    5Y Dividend per Share Growth (per Share)  \
# 0                                    0.0834
# 1                                       NaN
# 2                                    0.1215
# 3                                    0.0000
# 4                                    0.1250
#
#    3Y Dividend per Share Growth (per Share)  Receivables growth  \
# 0                                    0.0751             -0.0187
# 1                                       NaN                 NaN
# 2                                    0.1633              0.0618
# 3                                    0.0000              0.0211
# 4                                    0.1144              0.0257
#
#    Inventory Growth  Asset Growth  Book Value per Share Growth  Debt Growth  \
# 0           -0.0217        0.0359                       0.0316       0.1228
# 1               NaN           NaN                          NaN          NaN
# 2            0.0981        0.1886                       0.3268       0.2738
# 3           -0.0510       -0.0189                       0.1963      -0.0458
# 4            0.0090        0.0215                       0.0274       0.1025
#
#    R&D Expense Growth  SG&A Expenses Growth              Sector  \
# 0              0.0000               -0.1746  Consumer Defensive
# 1              1.6484                1.7313  Consumer Defensive
# 2              0.0000                0.0234  Consumer Defensive
# 3              0.0000               -0.0060  Consumer Defensive
# 4              0.0000               -0.0220  Consumer Defensive
#
#    2015 PRICE VAR [%]  Class
# 0           -9.323276      0
# 1          -25.512193      0
# 2           33.118297      1
# 3            2.752291      1
# 4           12.897715      1

# %%
# Check that the df of different years all have same columns
# They do -- they all have 225 coloumns
print(df2014.columns, '\n')
print(df2015.columns, '\n')
print(df2016.columns, '\n')
print(df2017.columns, '\n')
print(df2018.columns, '\n')
# Out:
# Index(['Unnamed: 0', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2015 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)
#
# Index(['Unnamed: 0', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2016 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)
#
# Index(['Unnamed: 0', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2017 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)
#
# Index(['Unnamed: 0', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2018 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)
#
# Index(['Unnamed: 0', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2019 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)

# %%
# Function to convert camel case to snake case and handle pre-existing underscores
def camel_to_snake(name):
    # Insert an underscore between lowercase followed by uppercase
    s1 = re.sub('([a-z])([A-Z])', r'\1_\2', name)
    # Handle pre-existing underscores (avoid double underscores)
    s2 = re.sub('_+', '_', s1)
    return s2.lower()

# %%
# Then convert any camelCase to snake_case
df2014.columns = [camel_to_snake(col) for col in df2014.columns]
df2015.columns = [camel_to_snake(col) for col in df2015.columns]
df2016.columns = [camel_to_snake(col) for col in df2016.columns]
df2017.columns = [camel_to_snake(col) for col in df2017.columns]
df2018.columns = [camel_to_snake(col) for col in df2018.columns]

# %%
# Renaming columns to follow industry practice
df2014.columns = [col.replace(' ', '_').lower() for col in df2014.columns]
df2015.columns = [col.replace(' ', '_').lower() for col in df2015.columns]
df2016.columns = [col.replace(' ', '_').lower() for col in df2016.columns]
df2017.columns = [col.replace(' ', '_').lower() for col in df2017.columns]
df2018.columns = [col.replace(' ', '_').lower() for col in df2018.columns]

# %%
# Rename the first column as 'ticker'
df2014.rename(columns={'unnamed:_0': 'ticker'}, inplace=True)
df2015.rename(columns={'unnamed:_0': 'ticker'}, inplace=True)
df2016.rename(columns={'unnamed:_0': 'ticker'}, inplace=True)
df2017.rename(columns={'unnamed:_0': 'ticker'}, inplace=True)
df2018.rename(columns={'unnamed:_0': 'ticker'}, inplace=True)

# %%
# Rename successfully
df2014.head()
# Out:
#   ticker       revenue  revenue_growth  cost_of_revenue  gross_profit  \
# 0     PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1   VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2     KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3    RAD  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4    GIS  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
#
#    r&d_expenses  sg&a_expense  operating_expenses  operating_income  \
# 0  0.000000e+00  2.146100e+10        2.146100e+10      1.391000e+10
# 1  1.083303e+08  3.441414e+08        7.939267e+08      1.345959e+08
# 2  0.000000e+00  1.519600e+10        1.751200e+10      2.725000e+09
# 3  0.000000e+00  6.561162e+09        6.586482e+09      7.372520e+08
# 4  0.000000e+00  3.474300e+09        3.412400e+09      2.957400e+09
#
#    interest_expense  earnings_before_tax  income_tax_expense  \
# 0      7.090000e+08         1.449400e+10        2.851000e+09
# 1      1.214869e+07         1.753823e+08        3.955957e+07
# 2      4.430000e+08         2.270000e+09        7.510000e+08
# 3      4.245910e+08         2.502180e+08        8.040000e+05
# 4      3.024000e+08         2.707700e+09        8.833000e+08
#
#    net_income_-_non-controlling_int  net_income_-_discontinued_ops  \
# 0                      1.420000e+08                  -1.127000e+09
# 1                     -1.431918e+07                   0.000000e+00
# 2                      1.200000e+07                   0.000000e+00
# 3                      0.000000e+00                   0.000000e+00
# 4                      3.690000e+07                   0.000000e+00
#
#      net_income  preferred_dividends  net_income_com     eps  eps_diluted  \
# 0  1.164300e+10                  0.0    1.164300e+10  4.1900        4.010
# 1  1.358227e+08                  0.0    1.358227e+08  0.2396        0.226
# 2  1.519000e+09                  0.0    1.519000e+09  1.4700        1.450
# 3  2.494140e+08           33998000.0    2.154160e+08  4.6000        4.600
# 4  1.824400e+09                  0.0    1.824400e+09  2.9000        2.830
#
#    weighted_average_shs_out  weighted_average_shs_out_(dil)  \
# 0              2.705960e+09                    2.705960e+09
# 1                       NaN                    1.829362e+07
# 2              1.033053e+09                    1.028000e+09
# 3              4.832628e+07                    4.832628e+07
# 4              6.144922e+08                    6.144922e+08
#
#    dividend_per_share  gross_margin  ebitda_margin  ebit_margin  \
# 0               2.448        0.4754         0.2470       0.2043
# 1               0.000        0.2487         0.0107       0.0502
# 2               0.307        0.2057         0.0450       0.0276
# 3               0.000        0.2869         0.0420       0.0264
# 4               1.550        0.3557         0.2010       0.1681
#
#    profit_margin  free_cash_flow_margin        ebitda          ebit  \
# 0         0.1560                 0.1359  1.834400e+10  1.520300e+10
# 1         0.0058                 0.0704  2.456858e+08  1.875310e+08
# 2         0.0150                 0.0126  4.416000e+09  2.713000e+09
# 3         0.0080                 0.0144  1.078550e+09  6.748090e+08
# 4         0.1020                 0.1052  3.595500e+09  3.010100e+09
#
#    consolidated_income  earnings_before_tax_margin  net_profit_margin  \
# 0         1.178500e+10                      0.1948             0.1565
# 1         1.215036e+08                      0.0470             0.0364
# 2         1.531000e+09                      0.0231             0.0154
# 3         2.494140e+08                      0.0098             0.0098
# 4         1.861300e+09                      0.1512             0.1019
#
#    cash_and_cash_equivalents  short-term_investments  \
# 0               8.558000e+09            2.128000e+09
# 1               7.735149e+08            6.083852e+08
# 2               4.010000e+08            0.000000e+00
# 3               1.464060e+08            0.000000e+00
# 4               8.673000e+08            0.000000e+00
#
#    cash_and_short-term_investments   receivables   inventories  \
# 0                     1.068600e+10  6.386000e+09  6.759000e+09
# 1                     1.381900e+09  1.169487e+07  5.793193e+08
# 2                     4.010000e+08  1.116000e+09  5.651000e+09
# 3                     1.464060e+08  9.490620e+08  2.993948e+09
# 4                     8.673000e+08  1.483600e+09  1.559400e+09
#
#    total_current_assets  property,_plant_&_equipment_net  \
# 0          3.161700e+10                     2.230400e+10
# 1          2.134397e+09                     3.085975e+08
# 2          8.830000e+09                     1.689300e+10
# 3          4.285125e+09                     1.957329e+09
# 4          4.393500e+09                     3.941900e+09
#
#    goodwill_and_intangible_assets  long-term_investments    tax_assets  \
# 0                    8.454700e+10           0.000000e+00  1.092000e+09
# 1                    1.906587e+08           6.299354e+07  3.764110e+07
# 2                    2.837000e+09           0.000000e+00  0.000000e+00
# 3                    4.312270e+08           0.000000e+00  0.000000e+00
# 4                    1.366480e+10           0.000000e+00  7.410000e+07
#
#    total_non-current_assets  total_assets      payables  short-term_debt  \
# 0              1.126490e+11  1.442660e+11  8.461000e+09     1.560600e+10
# 1              6.022904e+08  2.736687e+09  1.000491e+09     0.000000e+00
# 2              2.045100e+10  2.928100e+10  4.881000e+09     1.657000e+09
# 3              2.659746e+09  6.944871e+09  1.292419e+09     4.917400e+07
# 4              1.875220e+10  2.314570e+10  1.611300e+09     2.362300e+09
#
#    total_current_liabilities  long-term_debt    total_debt  deferred_revenue  \
# 0               3.372600e+10    1.981100e+10  3.541700e+10      0.000000e+00
# 1               1.639537e+09    6.223741e+08  6.223741e+08      3.141104e+07
# 2               1.070500e+10    9.653000e+09  1.131000e+10      0.000000e+00
# 3               2.507452e+09    5.707969e+09  5.757143e+09      0.000000e+00
# 4               5.423500e+09    6.423500e+09  8.785800e+09      0.000000e+00
#
#    tax_liabilities  deposit_liabilities  total_non-current_liabilities  \
# 0     1.021800e+10                  0.0                   4.056400e+10
# 1     0.000000e+00                  0.0                   6.615567e+08
# 2     1.629000e+09                  0.0                   1.318100e+10
# 3     0.000000e+00                  0.0                   6.551121e+09
# 4     1.666000e+09                  0.0                   9.732700e+09
#
#    total_liabilities  other_comprehensive_income  retained_earnings_(deficit)  \
# 0       7.429000e+10               -7.662000e+09                 8.499000e+10
# 1       2.301093e+09               -1.729254e+06                 4.285438e+06
# 2       2.388600e+10               -4.640000e+08                 1.098100e+10
# 3       9.058573e+09               -3.733400e+07                -7.515848e+09
# 4       1.515620e+10               -1.340300e+09                 1.178720e+10
#
#    total_shareholders_equity   investments      net_debt  other_assets  \
# 0               6.997600e+10  2.128000e+09  2.473100e+10  7.786000e+09
# 1               4.123545e+08  6.713788e+08           NaN           NaN
# 2               5.384000e+09  0.000000e+00  1.090900e+10  1.662000e+09
# 3              -2.113702e+09  0.000000e+00  5.610737e+09  1.957090e+08
# 4               6.534800e+09  0.000000e+00  7.918500e+09  4.832000e+08
#
#    other_liabilities  depreciation_&_amortization  stock-based_compensation  \
# 0       9.659000e+09                 3.141000e+09              3.600000e+08
# 1       6.390460e+08                 5.815483e+07              3.640523e+07
# 2       4.167000e+09                 1.703000e+09              1.070000e+08
# 3       1.165859e+09                 4.037410e+08             -1.047100e+07
# 4       1.449900e+09                 5.854000e+08              3.920000e+07
#
#    operating_cash_flow  capital_expenditure  acquisitions_and_disposals  \
# 0         1.395800e+10        -3.848000e+09               -2.400000e+07
# 1         5.267456e+08        -2.637046e+08               -1.922552e+08
# 2         3.573000e+09        -2.330000e+09               -2.344000e+09
# 3         7.020460e+08        -3.338700e+08                0.000000e+00
# 4         2.541000e+09        -6.569000e+08                6.670000e+07
#
#    investment_purchases_and_sales  investing_cash_flow  \
# 0                   -8.050000e+08        -4.100000e+09
# 1                   -2.126447e+08        -6.866936e+08
# 2                    0.000000e+00        -4.771000e+09
# 3                    4.115500e+07        -3.649240e+08
# 4                    2.930000e+07        -5.618000e+08
#
#    issuance_(repayment)_of_debt  issuance_(buybacks)_of_shares  \
# 0                  3.543000e+09                  -3.911000e+09
# 1                  6.193268e+08                   1.767840e+06
# 2                  2.093000e+09                  -4.130000e+08
# 3                 -2.954350e+08                   3.321700e+07
# 4                  8.011000e+08                  -1.637200e+09
#
#    dividend_payments  financing_cash_flow  effect_of_forex_changes_on_cash  \
# 0      -6.911000e+09        -7.279000e+09                     3.900000e+07
# 1       0.000000e+00         6.219136e+08                    -1.564869e+07
# 2      -3.190000e+08         1.361000e+09                     0.000000e+00
# 3       0.000000e+00        -3.201680e+08                     0.000000e+00
# 4      -9.833000e+08        -1.824100e+09                    -2.920000e+07
#
#    net_cash_flow_/_change_in_cash  free_cash_flow  net_cash/marketcap  \
# 0                    2.618000e+09    1.011000e+10             -0.1163
# 1                    4.463169e+08    2.630410e+08              0.0956
# 2                    1.630000e+08    1.243000e+09             -0.5969
# 3                    1.695400e+07    3.681760e+08             -0.8822
# 4                    1.259000e+08    1.884100e+09             -0.2376
#
#    price_book_value_ratio  price_to_book_ratio  price_to_sales_ratio  \
# 0                  3.0391               0.0000                2.8583
# 1                     NaN                  NaN                0.0443
# 2                  3.3579               7.0982                0.1858
# 3                  0.0000               0.0000                0.2491
# 4                  5.1004               0.0000                1.8610
#
#    price_earnings_ratio  price_to_free_cash_flows_ratio  \
# 0               18.7566                         21.0348
# 1               81.5526                          1.3589
# 2               12.0340                         14.6302
# 3               28.6087                         17.2736
# 4               18.7034                         17.6902
#
#    price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# 0                              15.2358              12.977501
# 1                                  NaN               0.678615
# 2                               5.1147               0.000000
# 3                               9.0589               0.000000
# 4                              13.1169              10.952350
#
#    price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# 0                       15.557842           2.434644        0.038153
# 1                        2.631793           0.095727       -0.000000
# 2                        0.000000           0.000000             NaN
# 3                        0.000000           0.000000             NaN
# 4                       15.254287           1.553911        0.035332
#
#    enterprise_value_multiple  price_fair_value  ebitper_revenue  ebtper_ebit  \
# 0                  11.421116          2.588601         0.204339     0.953364
# 1                   7.136538          0.866869         0.050221     0.935218
# 2                   2.276721          0.000000         0.027578     0.836712
# 3                   5.428005               NaN         0.026436     0.370798
# 4                   9.767966          4.258726         0.168072     0.899538
#
#    niper_ebt  gross_profit_margin  operating_profit_margin  \
# 0   0.803298             0.475410                      1.0
# 1   0.774438             0.248657                      1.0
# 2   0.669163             0.205713                      1.0
# 3   0.996787             0.286908                      1.0
# 4   0.673782             0.355664                      1.0
#
#    pretax_profit_margin  net_profit_margin  effective_tax_rate  \
# 0              0.186960           0.156490            0.196702
# 1              0.036045           0.036373            0.225562
# 2              0.027700           0.015441            0.330837
# 3              0.028882           0.009771            0.003213
# 4              0.165129           0.101867            0.326218
#
#    return_on_assets  return_on_equity  return_on_capital_employed  n_iper_ebt  \
# 0            0.5765            0.1664                      0.0753    0.803298
# 1            0.0403            0.3294                      0.0000    0.774438
# 2            0.1011            0.2821                      0.0859    0.669163
# 3            0.0668           -0.1180                      0.1062    0.996787
# 4            0.6265            0.2792                      0.1041    0.673782
#
#    e_btper_ebit  e_bitper_revenue  payables_turnover  inventory_turnover  \
# 0      0.953364          0.204339             1.5648             10.8869
# 1      0.935218          0.050221                NaN                 NaN
# 2      0.836712          0.027578             4.9593             18.2227
# 3      0.370798          0.026436             4.9289              8.3030
# 4      0.899538          0.168072             2.8234             11.5363
#
#    fixed_asset_turnover  asset_turnover  current_ratio  quick_ratio  \
# 0              3.335769        0.515721         0.9370     0.506197
# 1             12.100383        1.364477         0.2102     0.849993
# 2              5.823418        3.359687         0.8250     0.141709
# 3             13.041452        3.675578         1.7090     0.436885
# 4              4.543393        0.773777         0.8100     0.433465
#
#    cash_ratio  days_of_sales_outstanding  days_of_inventory_outstanding  \
# 0    0.253751                   -63.2087                        31.3287
# 1    0.471789                   -75.3670                         1.1431
# 2    0.037459                   -26.3971                         4.1407
# 3    0.058388                   -60.0346                        13.5706
# 4    0.159915                   -49.3233                        30.2360
#
#    operating_cycle  days_of_payables_outstanding  cash_conversion_cycle  \
# 0              NaN                       41.5084                    NaN
# 1              NaN                       97.7945                    NaN
# 2              NaN                       18.1099                    NaN
# 3              NaN                       18.4802                    NaN
# 4              NaN                       32.8385                    NaN
#
#    debt_ratio  debt_equity_ratio  longterm_debt_to_capitalization  \
# 0      0.2455             0.5061                         0.220644
# 1      0.2274             1.5093                         0.601485
# 2      0.3863             2.1007                         0.641950
# 3      0.8290            -2.7237                         1.588076
# 4      0.3796             1.3445                         0.495705
#
#    total_debt_to_capitalization  interest_coverage  cash_flow_to_debt_ratio  \
# 0                      0.336047            21.4429                 0.394105
# 1                      0.601485            15.4363                 0.846349
# 2                      0.677489             6.1242                 0.315915
# 3                      1.580139             1.5893                 0.121943
# 4                      0.573463             9.9540                 0.289217
#
#    company_equity_multiplier  operating_cash_flow_per_share  \
# 0                   2.061650                         5.1582
# 1                   6.636734                        35.6714
# 2                   5.438522                         3.4757
# 3                        NaN                        14.5272
# 4                   3.541914                         4.1351
#
#    free_cash_flow_per_share  cash_per_share  payout_ratio  \
# 0                     3.964          3.1626         0.584
# 1                    22.976         52.3827         0.000
# 2                     0.837          0.3901         0.209
# 3                     0.557          3.0295         0.000
# 4                     3.624          1.4114         0.534
#
#    operating_cash_flow_sales_ratio  free_cash_flow_operating_cash_flow_ratio  \
# 0                         0.187605                                  0.724316
# 1                         0.141062                                  0.499370
# 2                         0.036320                                  0.347887
# 3                         0.027503                                  0.524433
# 4                         0.141879                                  0.741480
#
#    cash_flow_coverage_ratios  short_term_coverage_ratios  \
# 0                   0.394105                    0.894400
# 1                   0.846349                         NaN
# 2                   0.315915                    2.156307
# 3                   0.121943                   14.276772
# 4                   0.289217                    1.075647
#
#    capital_expenditure_coverage_ratios  \
# 0                             3.627339
# 1                             1.997484
# 2                             1.533476
# 3                             2.102753
# 4                             3.868169
#
#    dividendpaid_and_capex_coverage_ratios  dividend_payout_ratio  \
# 0                                1.297332               0.593576
# 1                                1.997484              -0.000000
# 2                                1.348811               0.210007
# 3                                2.102753              -0.000000
# 4                                1.549201               0.538972
#
#    revenue_per_share  net_income_per_share  operating_cash_flow_per_share  \
# 0            27.4952                4.3027                         5.1582
# 1           252.8778                9.1980                        35.6714
# 2            95.6955                1.4776                         3.4757
# 3           528.2098                5.1610                        14.5272
# 4            29.1454                2.9690                         4.1351
#
#    free_cash_flow_per_share  cash_per_share  book_value_per_share  \
# 0                     3.964          3.1626               25.8600
# 1                    22.976         52.3827                0.7278
# 2                     0.837          0.3901                5.2370
# 3                     0.557          3.0295              -43.7380
# 4                     3.624          1.4114               10.6340
#
#    tangible_book_value_per_share  shareholders_equity_per_share  \
# 0                        22.0690                        25.8600
# 1                         4.4939                        27.9248
# 2                        25.7240                         5.2374
# 3                       134.7850                       -43.7381
# 4                        15.4290                        10.6345
#
#    interest_debt_per_share    market_cap  enterprise_value  pe_ratio  \
# 0                  13.0885  2.126614e+11      2.373924e+11   18.7566
# 1                  42.1474  6.253200e+09               NaN   81.5526
# 2                  11.0019  1.827470e+10      2.918370e+10   12.0340
# 3                 119.1307  6.359738e+09      1.197048e+10   28.6087
# 4                  14.2977  3.333006e+10      4.124856e+10   18.7034
#
#    price_to_sales_ratio  pocf_ratio  pfcf_ratio  pb_ratio  ptb_ratio  \
# 0                2.8583     15.2358     21.0348    3.0391     0.0000
# 1                0.0443         NaN      1.3589       NaN        NaN
# 2                0.1858      5.1147     14.6302    3.3579     7.0982
# 3                0.2491      9.0589     17.2736    0.0000     0.0000
# 4                1.8610     13.1169     17.6902    5.1004     0.0000
#
#    ev_to_sales  enterprise_value_over_ebitda  ev_to_operating_cash_flow  \
# 0       3.1907                       12.9411                    17.0076
# 1          NaN                           NaN                        NaN
# 2       0.2967                        6.6086                     8.1678
# 3       0.4689                       11.0987                    17.0508
# 4       2.3032                       11.4723                    16.2332
#
#    ev_to_free_cash_flow  earnings_yield  free_cash_flow_yield  debt_to_equity  \
# 0               23.4810          0.0533                0.0475          0.5061
# 1                   NaN          0.0123                   NaN          1.5093
# 2               23.4784          0.0831                0.0680          2.1007
# 3               32.5129          0.0350                0.0579         -2.7237
# 4               21.8930          0.0535                0.0565          1.3445
#
#    debt_to_assets  net_debt_to_ebitda  current_ratio  interest_coverage  \
# 0          0.2455              1.3482         0.9370            21.4429
# 1          0.2274                 NaN         0.2102            15.4363
# 2          0.3863              2.4703         0.8250             6.1242
# 3          0.8290              5.2021         1.7090             1.5893
# 4          0.3796              2.2023         0.8100             9.9540
#
#    income_quality  dividend_yield  payout_ratio  sg&a_to_revenue  \
# 0          1.1988          0.0311         0.584           0.2885
# 1          3.8782          0.0000         0.000           0.0922
# 2          2.3522          0.0174         0.209           0.1545
# 3          3.2590          0.0000         0.000           0.2570
# 4          1.3928          0.0286         0.534           0.1940
#
#    r&d_to_revenue  intangibles_to_total_assets  capex_to_operating_cash_flow  \
# 0           0.000                       0.5860                        0.2757
# 1           0.029                       0.0697                        0.5006
# 2           0.000                       0.0969                        0.6521
# 3           0.000                       0.0621                        0.4756
# 4           0.000                       0.5904                        0.2585
#
#    capex_to_revenue  capex_to_depreciation  \
# 0            0.0517                -1.2251
# 1            0.0706                -4.5345
# 2            0.0237                -1.3682
# 3            0.0131                -0.8269
# 4            0.0367                -1.1221
#
#    stock-based_compensation_to_revenue  graham_number    roic  \
# 0                               0.0048        49.3756  0.0753
# 1                               0.0097            NaN  0.0000
# 2                               0.0011        13.2000  0.0859
# 3                              -0.0004         0.0000  0.1062
# 4                               0.0022        26.3414  0.1041
#
#    return_on_tangible_assets  graham_net-net  working_capital  \
# 0                     0.5765         -0.2007    -2.109000e+09
# 1                     0.0403          0.0534     3.065163e+09
# 2                     0.1011         -0.8239    -1.875000e+09
# 3                     0.0668         -0.7506     1.777673e+09
# 4                     0.6265         -0.3229    -1.030000e+09
#
#    tangible_asset_value  net_current_asset_value  invested_capital  \
# 0          5.971900e+10            -4.267300e+10      5.285200e+10
# 1          2.546029e+09            -1.666966e+08      7.553510e+08
# 2          2.644400e+10            -1.505600e+10      2.664800e+10
# 3          6.513644e+09            -4.773448e+09      9.616929e+09
# 4          9.480900e+09            -1.076270e+10      1.197590e+10
#
#    average_receivables  average_payables  average_inventory  \
# 0         6.447000e+09      8.619000e+09       6.834000e+09
# 1                  NaN               NaN                NaN
# 2         1.083500e+09      4.682500e+09       5.398500e+09
# 3         9.392690e+08      1.338532e+09       3.074345e+09
# 4         1.465000e+09      1.517250e+09       1.552450e+09
#
#    days_sales_outstanding  days_payables_outstanding  \
# 0                 31.3287                    41.5084
# 1                  1.1431                    97.7945
# 2                  4.1407                    18.1099
# 3                 13.5706                    18.4802
# 4                 30.2360                    32.8385
#
#    days_of_inventory_on_hand  receivables_turnover  payables_turnover  \
# 0                   -63.2087               11.5404             1.5648
# 1                   -75.3670                   NaN                NaN
# 2                   -26.3971               90.7937             4.9593
# 3                   -60.0346               27.1769             4.9289
# 4                   -49.3233               12.2250             2.8234
#
#    inventory_turnover     roe  capex_per_share  gross_profit_growth  \
# 0             10.8869  0.1664          -1.4220              -0.1185
# 1                 NaN  0.3294         -17.8582               1.2489
# 2             18.2227  0.2821          -2.2665               0.0173
# 3              8.3030 -0.1180          -6.9087               0.0007
# 4             11.5363  0.2792          -1.0690              -0.0084
#
#    ebit_growth  operating_income_growth  net_income_growth  eps_growth  \
# 0      -0.0001                   0.0067             0.0293      0.0371
# 1       1.6142                   1.9463             1.5649      1.4625
# 2      -0.0145                  -0.0141             0.0147      0.0576
# 3       0.2904                   0.1113             1.0043      0.9167
# 4       0.0332                   0.0370            -0.0166      0.0140
#
#    eps_diluted_growth  weighted_average_shares_growth  \
# 0              0.0389                         -0.0127
# 1              1.4646                          0.0184
# 2              0.0469                         -0.0356
# 3              0.9167                          0.0694
# 4              0.0143                         -0.0468
#
#    weighted_average_shares_diluted_growth  dividends_per_share_growth  \
# 0                                     NaN                      0.0699
# 1                                  0.0195                      0.0000
# 2                                 -0.0317                      0.2429
# 3                                     NaN                      0.0000
# 4                                     NaN                      0.1742
#
#    operating_cash_flow_growth  free_cash_flow_growth  \
# 0                     -0.0615                -0.0695
# 1                      0.2134                -0.3626
# 2                      0.2095                 0.3935
# 3                     -0.1434                -0.2691
# 4                     -0.1316                -0.1936
#
#    10y_revenue_growth_(per_share)  5y_revenue_growth_(per_share)  \
# 0                          0.0323                         0.0088
# 1                             NaN                            NaN
# 2                          0.1027                         0.1038
# 3                         -0.0195                        -0.0290
# 4                          0.0704                         0.0567
#
#    3y_revenue_growth_(per_share)  10y_operating_cf_growth_(per_share)  \
# 0                        -0.0182                               0.0355
# 1                            NaN                                  NaN
# 2                         0.1399                               0.0889
# 3                        -0.0230                               0.0513
# 4                         0.0773                               0.0782
#
#    5y_operating_cf_growth_(per_share)  3y_operating_cf_growth_(per_share)  \
# 0                              0.0015                              0.0260
# 1                                 NaN                                 NaN
# 2                              0.0937                              0.0946
# 3                              0.1164                              0.1777
# 4                              0.0828                              0.1991
#
#    10y_net_income_growth_(per_share)  5y_net_income_growth_(per_share)  \
# 0                             0.0603                           -0.0137
# 1                                NaN                               NaN
# 2                             0.2272                            0.0906
# 3                             0.0480                            0.0000
# 4                             0.0776                            0.0841
#
#    3y_net_income_growth_(per_share)  \
# 0                            0.0060
# 1                               NaN
# 2                            0.1892
# 3                            0.0000
# 4                            0.0177
#
#    10y_shareholders_equity_growth_(per_share)  \
# 0                                      0.1442
# 1                                         NaN
# 2                                      0.0676
# 3                                      0.0000
# 4                                      0.0427
#
#    5y_shareholders_equity_growth_(per_share)  \
# 0                                     0.0353
# 1                                        NaN
# 2                                     0.0558
# 3                                     0.0000
# 4                                     0.0623
#
#    3y_shareholders_equity_growth_(per_share)  \
# 0                                     0.0201
# 1                                        NaN
# 2                                     0.0789
# 3                                     0.0000
# 4                                     0.0217
#
#    10y_dividend_per_share_growth_(per_share)  \
# 0                                     0.1013
# 1                                        NaN
# 2                                     0.0000
# 3                                     0.0000
# 4                                     0.1092
#
#    5y_dividend_per_share_growth_(per_share)  \
# 0                                    0.0834
# 1                                       NaN
# 2                                    0.1215
# 3                                    0.0000
# 4                                    0.1250
#
#    3y_dividend_per_share_growth_(per_share)  receivables_growth  \
# 0                                    0.0751             -0.0187
# 1                                       NaN                 NaN
# 2                                    0.1633              0.0618
# 3                                    0.0000              0.0211
# 4                                    0.1144              0.0257
#
#    inventory_growth  asset_growth  book_value_per_share_growth  debt_growth  \
# 0           -0.0217        0.0359                       0.0316       0.1228
# 1               NaN           NaN                          NaN          NaN
# 2            0.0981        0.1886                       0.3268       0.2738
# 3           -0.0510       -0.0189                       0.1963      -0.0458
# 4            0.0090        0.0215                       0.0274       0.1025
#
#    r&d_expense_growth  sg&a_expenses_growth              sector  \
# 0              0.0000               -0.1746  Consumer Defensive
# 1              1.6484                1.7313  Consumer Defensive
# 2              0.0000                0.0234  Consumer Defensive
# 3              0.0000               -0.0060  Consumer Defensive
# 4              0.0000               -0.0220  Consumer Defensive
#
#    2015_price_var_[%]  class
# 0           -9.323276      0
# 1          -25.512193      0
# 2           33.118297      1
# 3            2.752291      1
# 4           12.897715      1

# %% [markdown]
# ### Examine Nullness (Preliminary)

# %% [markdown]
# From below we see that our data set does have quite a few missing values. We will handle the missingness using imputation methods later.

# %%
df2014.isnull().sum()
# Out:
# ticker                                           0
# revenue                                         44
# revenue_growth                                 236
# cost_of_revenue                                 74
# gross_profit                                    52
# r&d_expenses                                   136
# sg&a_expense                                    59
# operating_expenses                              63
# operating_income                                55
# interest_expense                                63
# earnings_before_tax                             80
# income_tax_expense                              66
# net_income_-_non-controlling_int               149
# net_income_-_discontinued_ops                  149
# net_income                                      23
# preferred_dividends                            149
# net_income_com                                  15
# eps                                             72
# eps_diluted                                     84
# weighted_average_shs_out                       236
# weighted_average_shs_out_(dil)                 110
# dividend_per_share                             149
# gross_margin                                    47
# ebitda_margin                                  202
# ebit_margin                                     50
# profit_margin                                  201
# free_cash_flow_margin                          159
# ebitda                                          64
# ebit                                             4
# consolidated_income                             23
# earnings_before_tax_margin                      47
# net_profit_margin                               57
# cash_and_cash_equivalents                       58
# short-term_investments                         933
# cash_and_short-term_investments                930
# receivables                                     59
# inventories                                    115
# total_current_assets                           871
# property,_plant_&_equipment_net                 88
# goodwill_and_intangible_assets                  35
# long-term_investments                          912
# tax_assets                                     133
# total_non-current_assets                       908
# total_assets                                    33
# payables                                        90
# short-term_debt                                898
# total_current_liabilities                      879
# long-term_debt                                 854
# total_debt                                      78
# deferred_revenue                               136
# tax_liabilities                                131
# deposit_liabilities                            183
# total_non-current_liabilities                  911
# total_liabilities                               39
# other_comprehensive_income                      73
# retained_earnings_(deficit)                    164
# total_shareholders_equity                       33
# investments                                    124
# net_debt                                      1277
# other_assets                                  1274
# other_liabilities                              830
# depreciation_&_amortization                     43
# stock-based_compensation                        68
# operating_cash_flow                             40
# capital_expenditure                             52
# acquisitions_and_disposals                     124
# investment_purchases_and_sales                  22
# investing_cash_flow                             25
# issuance_(repayment)_of_debt                    61
# issuance_(buybacks)_of_shares                  108
# dividend_payments                              142
# financing_cash_flow                             11
# effect_of_forex_changes_on_cash                 83
# net_cash_flow_/_change_in_cash                  15
# free_cash_flow                                  47
# net_cash/marketcap                             349
# price_book_value_ratio                         659
# price_to_book_ratio                            659
# price_to_sales_ratio                           181
# price_earnings_ratio                           181
# price_to_free_cash_flows_ratio                 181
# price_to_operating_cash_flows_ratio            338
# price_cash_flow_ratio                         1053
# price_earnings_to_growth_ratio                1296
# price_sales_ratio                              396
# dividend_yield                                 688
# enterprise_value_multiple                      944
# price_fair_value                               428
# ebitper_revenue                                346
# ebtper_ebit                                   1118
# niper_ebt                                     1243
# gross_profit_margin                            346
# operating_profit_margin                        346
# pretax_profit_margin                           346
# net_profit_margin                              346
# effective_tax_rate                            1243
# return_on_assets                               995
# return_on_equity                               192
# return_on_capital_employed                     987
# n_iper_ebt                                    1243
# e_btper_ebit                                  1118
# e_bitper_revenue                               346
# payables_turnover                              781
# inventory_turnover                             306
# fixed_asset_turnover                           345
# asset_turnover                                 173
# current_ratio                                  967
# quick_ratio                                    972
# cash_ratio                                     972
# days_of_sales_outstanding                      182
# days_of_inventory_outstanding                  181
# operating_cycle                               3807
# days_of_payables_outstanding                   181
# cash_conversion_cycle                         3807
# debt_ratio                                     185
# debt_equity_ratio                              185
# longterm_debt_to_capitalization                282
# total_debt_to_capitalization                   269
# interest_coverage                              172
# cash_flow_to_debt_ratio                       1596
# company_equity_multiplier                      376
# operating_cash_flow_per_share                  230
# free_cash_flow_per_share                       229
# cash_per_share                                 232
# payout_ratio                                   207
# operating_cash_flow_sales_ratio                346
# free_cash_flow_operating_cash_flow_ratio      1016
# cash_flow_coverage_ratios                     1596
# short_term_coverage_ratios                    1956
# capital_expenditure_coverage_ratios            421
# dividendpaid_and_capex_coverage_ratios         293
# dividend_payout_ratio                         1296
# revenue_per_share                              227
# net_income_per_share                           227
# operating_cash_flow_per_share                  218
# free_cash_flow_per_share                       217
# cash_per_share                                 232
# book_value_per_share                           231
# tangible_book_value_per_share                  231
# shareholders_equity_per_share                  232
# interest_debt_per_share                        231
# market_cap                                     298
# enterprise_value                               654
# pe_ratio                                       154
# price_to_sales_ratio                           154
# pocf_ratio                                     315
# pfcf_ratio                                     154
# pb_ratio                                       644
# ptb_ratio                                      644
# ev_to_sales                                    654
# enterprise_value_over_ebitda                   654
# ev_to_operating_cash_flow                      654
# ev_to_free_cash_flow                           654
# earnings_yield                                 154
# free_cash_flow_yield                           315
# debt_to_equity                                 185
# debt_to_assets                                 185
# net_debt_to_ebitda                            1424
# current_ratio                                  988
# interest_coverage                              144
# income_quality                                 156
# dividend_yield                                 154
# payout_ratio                                   186
# sg&a_to_revenue                                156
# r&d_to_revenue                                 162
# intangibles_to_total_assets                    173
# capex_to_operating_cash_flow                   144
# capex_to_revenue                               156
# capex_to_depreciation                          158
# stock-based_compensation_to_revenue            165
# graham_number                                  644
# roic                                           987
# return_on_tangible_assets                      995
# graham_net-net                                 315
# working_capital                                987
# tangible_asset_value                           173
# net_current_asset_value                        958
# invested_capital                               185
# average_receivables                            288
# average_payables                               288
# average_inventory                              288
# days_sales_outstanding                         182
# days_payables_outstanding                      182
# days_of_inventory_on_hand                      183
# receivables_turnover                           306
# payables_turnover                              781
# inventory_turnover                             306
# roe                                            193
# capex_per_share                                218
# gross_profit_growth                            231
# ebit_growth                                    231
# operating_income_growth                        231
# net_income_growth                              243
# eps_growth                                     282
# eps_diluted_growth                             293
# weighted_average_shares_growth                 336
# weighted_average_shares_diluted_growth        1049
# dividends_per_share_growth                     237
# operating_cash_flow_growth                     232
# free_cash_flow_growth                          238
# 10y_revenue_growth_(per_share)                1547
# 5y_revenue_growth_(per_share)                 1037
# 3y_revenue_growth_(per_share)                  733
# 10y_operating_cf_growth_(per_share)           1536
# 5y_operating_cf_growth_(per_share)            1031
# 3y_operating_cf_growth_(per_share)             726
# 10y_net_income_growth_(per_share)             1547
# 5y_net_income_growth_(per_share)              1037
# 3y_net_income_growth_(per_share)               733
# 10y_shareholders_equity_growth_(per_share)    1585
# 5y_shareholders_equity_growth_(per_share)     1064
# 3y_shareholders_equity_growth_(per_share)      796
# 10y_dividend_per_share_growth_(per_share)     1465
# 5y_dividend_per_share_growth_(per_share)       952
# 3y_dividend_per_share_growth_(per_share)       600
# receivables_growth                             290
# inventory_growth                               290
# asset_growth                                   290
# book_value_per_share_growth                    369
# debt_growth                                    302
# r&d_expense_growth                             247
# sg&a_expenses_growth                           243
# sector                                           0
# 2015_price_var_[%]                               0
# class                                            0
# dtype: int64

# %%
df2015.isnull().sum()
# Out:
# ticker                                           0
# revenue                                         67
# revenue_growth                                 340
# cost_of_revenue                                193
# gross_profit                                    65
# r&d_expenses                                   265
# sg&a_expense                                   170
# operating_expenses                             174
# operating_income                                42
# interest_expense                               175
# earnings_before_tax                            103
# income_tax_expense                             151
# net_income_-_non-controlling_int               287
# net_income_-_discontinued_ops                  287
# net_income                                     165
# preferred_dividends                            287
# net_income_com                                 119
# eps                                             96
# eps_diluted                                     90
# weighted_average_shs_out                       117
# weighted_average_shs_out_(dil)                 250
# dividend_per_share                             287
# gross_margin                                    73
# ebitda_margin                                  341
# ebit_margin                                    174
# profit_margin                                  341
# free_cash_flow_margin                          293
# ebitda                                         198
# ebit                                           122
# consolidated_income                            166
# earnings_before_tax_margin                      71
# net_profit_margin                              191
# cash_and_cash_equivalents                       65
# short-term_investments                         237
# cash_and_short-term_investments                175
# receivables                                     43
# inventories                                    188
# total_current_assets                           199
# property,_plant_&_equipment_net                155
# goodwill_and_intangible_assets                 119
# long-term_investments                          207
# tax_assets                                     233
# total_non-current_assets                      1029
# total_assets                                    88
# payables                                       158
# short-term_debt                                236
# total_current_liabilities                      200
# long-term_debt                                  60
# total_debt                                     186
# deferred_revenue                               234
# tax_liabilities                                232
# deposit_liabilities                            282
# total_non-current_liabilities                 1033
# total_liabilities                              109
# other_comprehensive_income                     180
# retained_earnings_(deficit)                     45
# total_shareholders_equity                      103
# investments                                    203
# net_debt                                      1432
# other_assets                                  1428
# other_liabilities                              173
# depreciation_&_amortization                    141
# stock-based_compensation                       185
# operating_cash_flow                             64
# capital_expenditure                            132
# acquisitions_and_disposals                     232
# investment_purchases_and_sales                 147
# investing_cash_flow                            119
# issuance_(repayment)_of_debt                   164
# issuance_(buybacks)_of_shares                  213
# dividend_payments                              250
# financing_cash_flow                             26
# effect_of_forex_changes_on_cash                192
# net_cash_flow_/_change_in_cash                  36
# free_cash_flow                                 168
# net_cash/marketcap                             480
# price_book_value_ratio                         799
# price_to_book_ratio                            799
# price_to_sales_ratio                           280
# price_earnings_ratio                           279
# price_to_free_cash_flows_ratio                 279
# price_to_operating_cash_flows_ratio            455
# price_cash_flow_ratio                         1197
# price_earnings_to_growth_ratio                1647
# price_sales_ratio                              502
# dividend_yield                                 501
# enterprise_value_multiple                     1224
# price_fair_value                               553
# ebitper_revenue                                393
# ebtper_ebit                                   1425
# niper_ebt                                     1557
# gross_profit_margin                            393
# operating_profit_margin                        393
# pretax_profit_margin                           393
# net_profit_margin                              393
# effective_tax_rate                            1557
# return_on_assets                              1130
# return_on_equity                               303
# return_on_capital_employed                    1125
# n_iper_ebt                                    1557
# e_btper_ebit                                  1425
# e_bitper_revenue                               393
# payables_turnover                              908
# inventory_turnover                             393
# fixed_asset_turnover                           438
# asset_turnover                                 249
# current_ratio                                  307
# quick_ratio                                    304
# cash_ratio                                     304
# days_of_sales_outstanding                      281
# days_of_inventory_outstanding                  216
# operating_cycle                               4118
# days_of_payables_outstanding                   281
# cash_conversion_cycle                         4118
# debt_ratio                                     303
# debt_equity_ratio                              303
# longterm_debt_to_capitalization                307
# total_debt_to_capitalization                   282
# interest_coverage                              251
# cash_flow_to_debt_ratio                        939
# company_equity_multiplier                      490
# operating_cash_flow_per_share                  334
# free_cash_flow_per_share                       334
# cash_per_share                                 334
# payout_ratio                                   315
# operating_cash_flow_sales_ratio                393
# free_cash_flow_operating_cash_flow_ratio      1091
# cash_flow_coverage_ratios                      939
# short_term_coverage_ratios                    1925
# capital_expenditure_coverage_ratios            523
# dividendpaid_and_capex_coverage_ratios         383
# dividend_payout_ratio                         1647
# revenue_per_share                              339
# net_income_per_share                           339
# operating_cash_flow_per_share                  334
# free_cash_flow_per_share                       334
# cash_per_share                                 335
# book_value_per_share                           335
# tangible_book_value_per_share                  335
# shareholders_equity_per_share                  335
# interest_debt_per_share                        336
# market_cap                                     439
# enterprise_value                               811
# pe_ratio                                       279
# price_to_sales_ratio                           280
# pocf_ratio                                     455
# pfcf_ratio                                     279
# pb_ratio                                       799
# ptb_ratio                                      799
# ev_to_sales                                    812
# enterprise_value_over_ebitda                   811
# ev_to_operating_cash_flow                      811
# ev_to_free_cash_flow                           811
# earnings_yield                                 279
# free_cash_flow_yield                           455
# debt_to_equity                                 303
# debt_to_assets                                 303
# net_debt_to_ebitda                            1596
# current_ratio                                 1126
# interest_coverage                              251
# income_quality                                 283
# dividend_yield                                 279
# payout_ratio                                   315
# sg&a_to_revenue                                284
# r&d_to_revenue                                 295
# intangibles_to_total_assets                    255
# capex_to_operating_cash_flow                   250
# capex_to_revenue                               280
# capex_to_depreciation                          284
# stock-based_compensation_to_revenue            299
# graham_number                                  800
# roic                                          1125
# return_on_tangible_assets                     1130
# graham_net-net                                 458
# working_capital                               1125
# tangible_asset_value                           255
# net_current_asset_value                        299
# invested_capital                               303
# average_receivables                            371
# average_payables                               371
# average_inventory                              372
# days_sales_outstanding                         198
# days_payables_outstanding                      282
# days_of_inventory_on_hand                      282
# receivables_turnover                           392
# payables_turnover                              908
# inventory_turnover                             393
# roe                                            304
# capex_per_share                                334
# gross_profit_growth                            314
# ebit_growth                                    318
# operating_income_growth                        314
# net_income_growth                              347
# eps_growth                                     385
# eps_diluted_growth                             397
# weighted_average_shares_growth                 432
# weighted_average_shares_diluted_growth        1089
# dividends_per_share_growth                     345
# operating_cash_flow_growth                     315
# free_cash_flow_growth                          346
# 10y_revenue_growth_(per_share)                1737
# 5y_revenue_growth_(per_share)                 1214
# 3y_revenue_growth_(per_share)                  819
# 10y_operating_cf_growth_(per_share)           1726
# 5y_operating_cf_growth_(per_share)            1207
# 3y_operating_cf_growth_(per_share)             812
# 10y_net_income_growth_(per_share)             1737
# 5y_net_income_growth_(per_share)              1214
# 3y_net_income_growth_(per_share)               819
# 10y_shareholders_equity_growth_(per_share)    1766
# 5y_shareholders_equity_growth_(per_share)     1252
# 3y_shareholders_equity_growth_(per_share)      867
# 10y_dividend_per_share_growth_(per_share)     1646
# 5y_dividend_per_share_growth_(per_share)      1104
# 3y_dividend_per_share_growth_(per_share)       675
# receivables_growth                             368
# inventory_growth                               369
# asset_growth                                   369
# book_value_per_share_growth                    458
# debt_growth                                    399
# r&d_expense_growth                             351
# sg&a_expenses_growth                           347
# sector                                           0
# 2016_price_var_[%]                               0
# class                                            0
# dtype: int64

# %%
df2016.isnull().sum()
# Out:
# ticker                                           0
# revenue                                        489
# revenue_growth                                 649
# cost_of_revenue                                640
# gross_profit                                   492
# r&d_expenses                                   713
# sg&a_expense                                   613
# operating_expenses                             620
# operating_income                               465
# interest_expense                               620
# earnings_before_tax                            531
# income_tax_expense                             596
# net_income_-_non-controlling_int               738
# net_income_-_discontinued_ops                  738
# net_income                                     606
# preferred_dividends                            738
# net_income_com                                 558
# eps                                            522
# eps_diluted                                    515
# weighted_average_shs_out                       527
# weighted_average_shs_out_(dil)                 690
# dividend_per_share                             738
# gross_margin                                   499
# ebitda_margin                                  794
# ebit_margin                                    621
# profit_margin                                  794
# free_cash_flow_margin                          745
# ebitda                                         643
# ebit                                           564
# consolidated_income                            607
# earnings_before_tax_margin                     497
# net_profit_margin                              637
# cash_and_cash_equivalents                      493
# short-term_investments                         642
# cash_and_short-term_investments                584
# receivables                                    466
# inventories                                    637
# total_current_assets                           615
# property,_plant_&_equipment_net                603
# goodwill_and_intangible_assets                 561
# long-term_investments                          631
# tax_assets                                     678
# total_non-current_assets                      1508
# total_assets                                   528
# payables                                       606
# short-term_debt                                651
# total_current_liabilities                      615
# long-term_debt                                 463
# total_debt                                     623
# deferred_revenue                               678
# tax_liabilities                                675
# deposit_liabilities                            730
# total_non-current_liabilities                 1511
# total_liabilities                              551
# other_comprehensive_income                     617
# retained_earnings_(deficit)                    454
# total_shareholders_equity                      546
# investments                                    653
# net_debt                                      1945
# other_assets                                  1935
# other_liabilities                              580
# depreciation_&_amortization                    585
# stock-based_compensation                       630
# operating_cash_flow                            486
# capital_expenditure                            576
# acquisitions_and_disposals                     684
# investment_purchases_and_sales                 589
# investing_cash_flow                            555
# issuance_(repayment)_of_debt                   610
# issuance_(buybacks)_of_shares                  665
# dividend_payments                              703
# financing_cash_flow                            446
# effect_of_forex_changes_on_cash                639
# net_cash_flow_/_change_in_cash                 457
# free_cash_flow                                 613
# net_cash/marketcap                             954
# price_book_value_ratio                        1296
# price_to_book_ratio                           1296
# price_to_sales_ratio                           732
# price_earnings_ratio                           731
# price_to_free_cash_flows_ratio                 731
# price_to_operating_cash_flows_ratio            927
# price_cash_flow_ratio                         1708
# price_earnings_to_growth_ratio                2214
# price_sales_ratio                              965
# dividend_yield                                 964
# enterprise_value_multiple                     1751
# price_fair_value                              1057
# ebitper_revenue                                851
# ebtper_ebit                                   1987
# niper_ebt                                     2089
# gross_profit_margin                            851
# operating_profit_margin                        851
# pretax_profit_margin                           851
# net_profit_margin                              851
# effective_tax_rate                            2089
# return_on_assets                              1607
# return_on_equity                               746
# return_on_capital_employed                    1602
# n_iper_ebt                                    2089
# e_btper_ebit                                  1987
# e_bitper_revenue                               851
# payables_turnover                             1342
# inventory_turnover                             748
# fixed_asset_turnover                           906
# asset_turnover                                 700
# current_ratio                                  721
# quick_ratio                                    719
# cash_ratio                                     719
# days_of_sales_outstanding                      726
# days_of_inventory_outstanding                  640
# operating_cycle                               4792
# days_of_payables_outstanding                   726
# cash_conversion_cycle                         4792
# debt_ratio                                     740
# debt_equity_ratio                              740
# longterm_debt_to_capitalization                764
# total_debt_to_capitalization                   740
# interest_coverage                              705
# cash_flow_to_debt_ratio                       1388
# company_equity_multiplier                     1000
# operating_cash_flow_per_share                  768
# free_cash_flow_per_share                       768
# cash_per_share                                 770
# payout_ratio                                   768
# operating_cash_flow_sales_ratio                851
# free_cash_flow_operating_cash_flow_ratio      1590
# cash_flow_coverage_ratios                     1388
# short_term_coverage_ratios                    2417
# capital_expenditure_coverage_ratios           1020
# dividendpaid_and_capex_coverage_ratios         868
# dividend_payout_ratio                         2214
# revenue_per_share                              774
# net_income_per_share                           774
# operating_cash_flow_per_share                  768
# free_cash_flow_per_share                       768
# cash_per_share                                 770
# book_value_per_share                           771
# tangible_book_value_per_share                  771
# shareholders_equity_per_share                  770
# interest_debt_per_share                        771
# market_cap                                     899
# enterprise_value                              1308
# pe_ratio                                       730
# price_to_sales_ratio                           731
# pocf_ratio                                     927
# pfcf_ratio                                     730
# pb_ratio                                      1295
# ptb_ratio                                     1295
# ev_to_sales                                   1309
# enterprise_value_over_ebitda                  1308
# ev_to_operating_cash_flow                     1308
# ev_to_free_cash_flow                          1308
# earnings_yield                                 730
# free_cash_flow_yield                           927
# debt_to_equity                                 740
# debt_to_assets                                 740
# net_debt_to_ebitda                            2115
# current_ratio                                 1603
# interest_coverage                              703
# income_quality                                 726
# dividend_yield                                 730
# payout_ratio                                   768
# sg&a_to_revenue                                726
# r&d_to_revenue                                 740
# intangibles_to_total_assets                    708
# capex_to_operating_cash_flow                   696
# capex_to_revenue                               724
# capex_to_depreciation                          729
# stock-based_compensation_to_revenue            744
# graham_number                                 1296
# roic                                          1602
# return_on_tangible_assets                     1607
# graham_net-net                                 918
# working_capital                               1602
# tangible_asset_value                           708
# net_current_asset_value                        719
# invested_capital                               740
# average_receivables                            640
# average_payables                               725
# average_inventory                              725
# days_sales_outstanding                         620
# days_payables_outstanding                      726
# days_of_inventory_on_hand                      726
# receivables_turnover                           664
# payables_turnover                             1342
# inventory_turnover                             748
# roe                                            746
# capex_per_share                                768
# gross_profit_growth                            634
# ebit_growth                                    719
# operating_income_growth                        629
# net_income_growth                              752
# eps_growth                                     671
# eps_diluted_growth                             671
# weighted_average_shares_growth                 868
# weighted_average_shares_diluted_growth         830
# dividends_per_share_growth                     772
# operating_cash_flow_growth                     652
# free_cash_flow_growth                          775
# 10y_revenue_growth_(per_share)                2273
# 5y_revenue_growth_(per_share)                 1680
# 3y_revenue_growth_(per_share)                 1273
# 10y_operating_cf_growth_(per_share)           2260
# 5y_operating_cf_growth_(per_share)            1672
# 3y_operating_cf_growth_(per_share)            1263
# 10y_net_income_growth_(per_share)             2273
# 5y_net_income_growth_(per_share)              1680
# 3y_net_income_growth_(per_share)              1273
# 10y_shareholders_equity_growth_(per_share)    2286
# 5y_shareholders_equity_growth_(per_share)     1741
# 3y_shareholders_equity_growth_(per_share)     1303
# 10y_dividend_per_share_growth_(per_share)     2210
# 5y_dividend_per_share_growth_(per_share)      1545
# 3y_dividend_per_share_growth_(per_share)      1130
# receivables_growth                             640
# inventory_growth                               725
# asset_growth                                   722
# book_value_per_share_growth                    873
# debt_growth                                    796
# r&d_expense_growth                             772
# sg&a_expenses_growth                           756
# sector                                           0
# 2017_price_var_[%]                               0
# class                                            0
# dtype: int64

# %%
df2017.isnull().sum()
# Out:
# ticker                                           0
# revenue                                        525
# revenue_growth                                 724
# cost_of_revenue                                679
# gross_profit                                   534
# r&d_expenses                                   787
# sg&a_expense                                   661
# operating_expenses                             661
# operating_income                               504
# interest_expense                               677
# earnings_before_tax                            579
# income_tax_expense                             635
# net_income_-_non-controlling_int               835
# net_income_-_discontinued_ops                  835
# net_income                                     620
# preferred_dividends                            835
# net_income_com                                 582
# eps                                            546
# eps_diluted                                    540
# weighted_average_shs_out                       548
# weighted_average_shs_out_(dil)                 687
# dividend_per_share                             835
# gross_margin                                   529
# ebitda_margin                                  802
# ebit_margin                                    655
# profit_margin                                  802
# free_cash_flow_margin                          840
# ebitda                                         666
# ebit                                           592
# consolidated_income                            620
# earnings_before_tax_margin                     529
# net_profit_margin                              661
# cash_and_cash_equivalents                      514
# short-term_investments                         721
# cash_and_short-term_investments                667
# receivables                                    499
# inventories                                    694
# total_current_assets                           652
# property,_plant_&_equipment_net                644
# goodwill_and_intangible_assets                 580
# long-term_investments                          702
# tax_assets                                     727
# total_non-current_assets                      1536
# total_assets                                   548
# payables                                       642
# short-term_debt                                707
# total_current_liabilities                      650
# long-term_debt                                 501
# total_debt                                     653
# deferred_revenue                               728
# tax_liabilities                                724
# deposit_liabilities                            827
# total_non-current_liabilities                 1538
# total_liabilities                              570
# other_comprehensive_income                     648
# retained_earnings_(deficit)                    483
# total_shareholders_equity                      566
# investments                                    729
# net_debt                                      1951
# other_assets                                  1911
# other_liabilities                              600
# depreciation_&_amortization                    613
# stock-based_compensation                       666
# operating_cash_flow                            520
# capital_expenditure                            619
# acquisitions_and_disposals                     776
# investment_purchases_and_sales                 609
# investing_cash_flow                            580
# issuance_(repayment)_of_debt                   658
# issuance_(buybacks)_of_shares                  737
# dividend_payments                              814
# financing_cash_flow                            470
# effect_of_forex_changes_on_cash                706
# net_cash_flow_/_change_in_cash                 486
# free_cash_flow                                 644
# net_cash/marketcap                            1075
# price_book_value_ratio                        1409
# price_to_book_ratio                           1409
# price_to_sales_ratio                           835
# price_earnings_ratio                           833
# price_to_free_cash_flows_ratio                 833
# price_to_operating_cash_flows_ratio           1039
# price_cash_flow_ratio                         1850
# price_earnings_to_growth_ratio                2264
# price_sales_ratio                             1042
# dividend_yield                                 886
# enterprise_value_multiple                     1800
# price_fair_value                              1076
# ebitper_revenue                                925
# ebtper_ebit                                   2036
# niper_ebt                                     2145
# gross_profit_margin                            925
# operating_profit_margin                        925
# pretax_profit_margin                           925
# net_profit_margin                              925
# effective_tax_rate                            2145
# return_on_assets                              1697
# return_on_equity                               841
# return_on_capital_employed                    1693
# n_iper_ebt                                    2145
# e_btper_ebit                                  2036
# e_bitper_revenue                               925
# payables_turnover                             1402
# inventory_turnover                             826
# fixed_asset_turnover                          1001
# asset_turnover                                 792
# current_ratio                                  819
# quick_ratio                                    814
# cash_ratio                                     814
# days_of_sales_outstanding                      817
# days_of_inventory_outstanding                  727
# operating_cycle                               4955
# days_of_payables_outstanding                   815
# cash_conversion_cycle                         4955
# debt_ratio                                     835
# debt_equity_ratio                              835
# longterm_debt_to_capitalization                809
# total_debt_to_capitalization                   792
# interest_coverage                              813
# cash_flow_to_debt_ratio                       1468
# company_equity_multiplier                     1031
# operating_cash_flow_per_share                  842
# free_cash_flow_per_share                       841
# cash_per_share                                 842
# payout_ratio                                   844
# operating_cash_flow_sales_ratio                925
# free_cash_flow_operating_cash_flow_ratio      1731
# cash_flow_coverage_ratios                     1468
# short_term_coverage_ratios                    2520
# capital_expenditure_coverage_ratios           1117
# dividendpaid_and_capex_coverage_ratios         961
# dividend_payout_ratio                         2264
# revenue_per_share                              847
# net_income_per_share                           848
# operating_cash_flow_per_share                  842
# free_cash_flow_per_share                       841
# cash_per_share                                 842
# book_value_per_share                           842
# tangible_book_value_per_share                  842
# shareholders_equity_per_share                  842
# interest_debt_per_share                        842
# market_cap                                    1007
# enterprise_value                              1423
# pe_ratio                                       833
# price_to_sales_ratio                           835
# pocf_ratio                                    1039
# pfcf_ratio                                     833
# pb_ratio                                      1409
# ptb_ratio                                     1409
# ev_to_sales                                   1425
# enterprise_value_over_ebitda                  1424
# ev_to_operating_cash_flow                     1424
# ev_to_free_cash_flow                          1424
# earnings_yield                                 833
# free_cash_flow_yield                          1039
# debt_to_equity                                 835
# debt_to_assets                                 835
# net_debt_to_ebitda                            2201
# current_ratio                                 1694
# interest_coverage                              813
# income_quality                                 819
# dividend_yield                                 832
# payout_ratio                                   844
# sg&a_to_revenue                                820
# r&d_to_revenue                                 832
# intangibles_to_total_assets                    815
# capex_to_operating_cash_flow                   792
# capex_to_revenue                               815
# capex_to_depreciation                          818
# stock-based_compensation_to_revenue            839
# graham_number                                 1411
# roic                                          1693
# return_on_tangible_assets                     1697
# graham_net-net                                1027
# working_capital                               1693
# tangible_asset_value                           815
# net_current_asset_value                        811
# invested_capital                               835
# average_receivables                            705
# average_payables                               811
# average_inventory                              813
# days_sales_outstanding                         710
# days_payables_outstanding                      815
# days_of_inventory_on_hand                      817
# receivables_turnover                           719
# payables_turnover                             1402
# inventory_turnover                             826
# roe                                            841
# capex_per_share                                842
# gross_profit_growth                            704
# ebit_growth                                    825
# operating_income_growth                        685
# net_income_growth                              810
# eps_growth                                     714
# eps_diluted_growth                             707
# weighted_average_shares_growth                 897
# weighted_average_shares_diluted_growth         772
# dividends_per_share_growth                     852
# operating_cash_flow_growth                     722
# free_cash_flow_growth                          852
# 10y_revenue_growth_(per_share)                2322
# 5y_revenue_growth_(per_share)                 1621
# 3y_revenue_growth_(per_share)                 1209
# 10y_operating_cf_growth_(per_share)           2310
# 5y_operating_cf_growth_(per_share)            1613
# 3y_operating_cf_growth_(per_share)            1201
# 10y_net_income_growth_(per_share)             2322
# 5y_net_income_growth_(per_share)              1621
# 3y_net_income_growth_(per_share)              1209
# 10y_shareholders_equity_growth_(per_share)    2348
# 5y_shareholders_equity_growth_(per_share)     1670
# 3y_shareholders_equity_growth_(per_share)     1245
# 10y_dividend_per_share_growth_(per_share)     2274
# 5y_dividend_per_share_growth_(per_share)      1469
# 3y_dividend_per_share_growth_(per_share)      1083
# receivables_growth                             703
# inventory_growth                               811
# asset_growth                                   792
# book_value_per_share_growth                    893
# debt_growth                                    854
# r&d_expense_growth                             850
# sg&a_expenses_growth                           828
# sector                                           0
# 2018_price_var_[%]                               0
# class                                            0
# dtype: int64

# %%
df2018.isnull().sum()
# Out:
# ticker                                           0
# revenue                                         46
# revenue_growth                                 139
# cost_of_revenue                                185
# gross_profit                                    64
# r&d_expenses                                   237
# sg&a_expense                                   166
# operating_expenses                             184
# operating_income                                35
# interest_expense                               184
# earnings_before_tax                             71
# income_tax_expense                             140
# net_income_-_non-controlling_int               250
# net_income_-_discontinued_ops                  250
# net_income                                     151
# preferred_dividends                            250
# net_income_com                                 117
# eps                                             65
# eps_diluted                                     63
# weighted_average_shs_out                        66
# weighted_average_shs_out_(dil)                 200
# dividend_per_share                             250
# gross_margin                                    51
# ebitda_margin                                  308
# ebit_margin                                    174
# profit_margin                                  306
# free_cash_flow_margin                          254
# ebitda                                         183
# ebit                                           143
# consolidated_income                            151
# earnings_before_tax_margin                      51
# net_profit_margin                              176
# cash_and_cash_equivalents                       49
# short-term_investments                         179
# cash_and_short-term_investments                119
# receivables                                     38
# inventories                                    197
# total_current_assets                           185
# property,_plant_&_equipment_net                169
# goodwill_and_intangible_assets                 142
# long-term_investments                          181
# tax_assets                                     212
# total_non-current_assets                      1041
# total_assets                                   108
# payables                                       174
# short-term_debt                                214
# total_current_liabilities                      184
# long-term_debt                                  30
# total_debt                                     168
# deferred_revenue                               210
# tax_liabilities                                209
# deposit_liabilities                            248
# total_non-current_liabilities                 1043
# total_liabilities                              127
# other_comprehensive_income                     158
# retained_earnings_(deficit)                     21
# total_shareholders_equity                      124
# investments                                    209
# net_debt                                       254
# other_assets                                   208
# other_liabilities                              159
# depreciation_&_amortization                    146
# stock-based_compensation                       184
# operating_cash_flow                             58
# capital_expenditure                            144
# acquisitions_and_disposals                     217
# investment_purchases_and_sales                 147
# investing_cash_flow                            126
# issuance_(repayment)_of_debt                   175
# issuance_(buybacks)_of_shares                  219
# dividend_payments                              247
# financing_cash_flow                             19
# effect_of_forex_changes_on_cash                174
# net_cash_flow_/_change_in_cash                  24
# free_cash_flow                                 167
# net_cash/marketcap                             498
# price_book_value_ratio                         830
# price_to_book_ratio                            830
# price_to_sales_ratio                           255
# price_earnings_ratio                           252
# price_to_free_cash_flows_ratio                 253
# price_to_operating_cash_flows_ratio            461
# price_cash_flow_ratio                         1256
# price_earnings_to_growth_ratio                1658
# price_sales_ratio                              452
# dividend_yield                                 259
# enterprise_value_multiple                     1225
# price_fair_value                               460
# ebitper_revenue                                347
# ebtper_ebit                                   1441
# niper_ebt                                     1561
# gross_profit_margin                            347
# operating_profit_margin                        347
# pretax_profit_margin                           347
# net_profit_margin                              347
# effective_tax_rate                            1561
# return_on_assets                              1106
# return_on_equity                               256
# return_on_capital_employed                    1102
# n_iper_ebt                                    1561
# e_btper_ebit                                  1441
# e_bitper_revenue                               347
# payables_turnover                              478
# inventory_turnover                             239
# fixed_asset_turnover                           444
# asset_turnover                                 230
# current_ratio                                  251
# quick_ratio                                    249
# cash_ratio                                     249
# days_of_sales_outstanding                      236
# days_of_inventory_outstanding                  145
# operating_cycle                               4386
# days_of_payables_outstanding                   234
# cash_conversion_cycle                         4386
# debt_ratio                                     251
# debt_equity_ratio                              251
# longterm_debt_to_capitalization                227
# total_debt_to_capitalization                   209
# interest_coverage                              246
# cash_flow_to_debt_ratio                        885
# company_equity_multiplier                      438
# operating_cash_flow_per_share                  251
# free_cash_flow_per_share                       252
# cash_per_share                                 251
# payout_ratio                                   256
# operating_cash_flow_sales_ratio                347
# free_cash_flow_operating_cash_flow_ratio      1160
# cash_flow_coverage_ratios                      885
# short_term_coverage_ratios                    1926
# capital_expenditure_coverage_ratios            568
# dividendpaid_and_capex_coverage_ratios         415
# dividend_payout_ratio                         1658
# revenue_per_share                              256
# net_income_per_share                           257
# operating_cash_flow_per_share                  251
# free_cash_flow_per_share                       252
# cash_per_share                                 251
# book_value_per_share                           252
# tangible_book_value_per_share                  252
# shareholders_equity_per_share                  251
# interest_debt_per_share                        251
# market_cap                                     428
# enterprise_value                               844
# pe_ratio                                       252
# price_to_sales_ratio                           255
# pocf_ratio                                     461
# pfcf_ratio                                     253
# pb_ratio                                       830
# ptb_ratio                                      830
# ev_to_sales                                    847
# enterprise_value_over_ebitda                   846
# ev_to_operating_cash_flow                      846
# ev_to_free_cash_flow                           846
# earnings_yield                                 252
# free_cash_flow_yield                           461
# debt_to_equity                                 251
# debt_to_assets                                 251
# net_debt_to_ebitda                             379
# current_ratio                                 1105
# interest_coverage                              246
# income_quality                                 236
# dividend_yield                                 251
# payout_ratio                                   256
# sg&a_to_revenue                                238
# r&d_to_revenue                                 248
# intangibles_to_total_assets                    246
# capex_to_operating_cash_flow                   228
# capex_to_revenue                               234
# capex_to_depreciation                          236
# stock-based_compensation_to_revenue            256
# graham_number                                  832
# roic                                          1102
# return_on_tangible_assets                     1106
# graham_net-net                                 448
# working_capital                               1103
# tangible_asset_value                           246
# net_current_asset_value                        244
# invested_capital                               252
# average_receivables                            125
# average_payables                               231
# average_inventory                              233
# days_sales_outstanding                         129
# days_payables_outstanding                      234
# days_of_inventory_on_hand                      236
# receivables_turnover                           132
# payables_turnover                              478
# inventory_turnover                             239
# roe                                            256
# capex_per_share                                251
# gross_profit_growth                            125
# ebit_growth                                    248
# operating_income_growth                        109
# net_income_growth                              230
# eps_growth                                     131
# eps_diluted_growth                             125
# weighted_average_shares_growth                 275
# weighted_average_shares_diluted_growth         182
# dividends_per_share_growth                     263
# operating_cash_flow_growth                     142
# free_cash_flow_growth                          263
# 10y_revenue_growth_(per_share)                1653
# 5y_revenue_growth_(per_share)                  849
# 3y_revenue_growth_(per_share)                  432
# 10y_operating_cf_growth_(per_share)           1646
# 5y_operating_cf_growth_(per_share)             841
# 3y_operating_cf_growth_(per_share)             431
# 10y_net_income_growth_(per_share)             1653
# 5y_net_income_growth_(per_share)               849
# 3y_net_income_growth_(per_share)               432
# 10y_shareholders_equity_growth_(per_share)    1695
# 5y_shareholders_equity_growth_(per_share)      883
# 3y_shareholders_equity_growth_(per_share)      432
# 10y_dividend_per_share_growth_(per_share)     1582
# 5y_dividend_per_share_growth_(per_share)       708
# 3y_dividend_per_share_growth_(per_share)       325
# receivables_growth                             124
# inventory_growth                               232
# asset_growth                                   214
# book_value_per_share_growth                    271
# debt_growth                                    264
# r&d_expense_growth                             259
# sg&a_expenses_growth                           248
# sector                                           0
# 2019_price_var_[%]                               0
# class                                            0
# dtype: int64

# %% [markdown]
# ### Exploration of Predictors and Targets / Pre-Selection of Predictors

# %% [markdown]
# From investopidia: https://www.investopedia.com/articles/basics/04/100804.asp

# %% [markdown]
# Stock prices are ultimately determined by supply and demand, which are influenced by both fundamental and technical factors.

# %% [markdown]
# #### Fundamental factors

# %% [markdown]
# Fundamental factors relate to a company's financial performance, especially earnings. The earnings per share (EPS) represents the owner's proportional share of earnings. The P/E ratio expresses the valuation multiple, i.e. how much an investor is willing to pay for those future earnings. Earnings can also be measured by cash flow per share or dividends per share. The valuation multiple depends on the expected earnings growth rate and the discount rate, which represents inflation and the perceived riskiness of the stock. Higher expected growth leads to a higher multiple, while higher risk or inflation leads to a lower multiple.

# %% [markdown]
# #### Technical factors

# %% [markdown]
# Technical factors are from external market conditions that drive supply and demand. Historically, low inflation boosts multiples while high inflation lowers them. Deflation hurts pricing power. Stocks tend to move with the overall market and their industry peers, and stocks compete with other asset classes like bonds and commodities. Regarding investors, middle-aged investors tend to invest more in stocks. Furthermore, stocks build momentum or revert to the mean. Large cap stocks have high liquidity while small caps often have a liquidity discount. Finally, unforeseen positive or negative events impact sentiment, and psychology often weighs more heavily than fundamentals in the short term. Behavioral finance aims to explain irrational market behavior.

# %% [markdown]
# #### Reconciliation

# %% [markdown]
# While technicals often dominate in the short run, fundamentals determine long-term prices. Different investors weigh the factors differently, but both play a critical role in the complicated dynamics of supply, demand, and human psychology. We decide to have the following categories of predictors and cross-check and see if our datasets include them:
#
# **Fundamentals**
# * Earnings Per Share (EPS) and Diluted EPS: Directly related to earnings power
# * Revenue, Net Income, Gross Profit, Operating Income, Earnings Before Tax: Critical components of earnings base
# * Revenue Growth, EPS Growth, Net Income Growth: Reflect expected earnings growth
# * P/E Ratio, P/S Ratio, P/B Ratio, Dividend Yield: Valuation multiples based on earnings
# * Dividends Per Share: Important for mature dividend-paying companies
#
# **Technical Factors**
# * Market Capitalization: Relates to liquidity and size
# * Trading Volume: Reflects liquidity and investor interest
# * Total Debt, Long Term Debt, Debt-to-Equity, Net Debt to EBITDA: Influence risk profile and cost of capital
# * Operating Cash Flow, Free Cash Flow, Capital Expenditures, Cash & Cash Equivalents: Reflect ability to generate cash
#
# **Market Sentiment**
# * EV/EBITDA, EV/Sales, Earnings Yield, FCF Yield: May capture some market sentiment
# * General Financial Health: Current Ratio, Quick Ratio: Assess short-term liquidity
# * Net Profit Margin, ROA, ROE: Show how efficiently company is run
# * Asset Turnover, Inventory Turnover, Receivables Turnover: Reflect asset utilization
# * Total Assets, Total Liabilities, Total Debt, Net Debt: consolidated metrics
#
# **Sector Information**
# * Sector: Captures industry-specific effects

# %% [markdown]
# By carefully selecting the most relevant predictors based on the Investopedia framework, we have reduced the number of features in our dataset **from 223 down to 46**. This significant reduction will allow us to focus on the core factors driving stock prices (as well as whether or not a stock is buy-worthy).

# %% [markdown]
# #### Separate Predictors and Targets

# %%
predictors2014 = df2014.drop(columns=['class', '2015_price_var_[%]'])
class2014 = df2014[['class']]
price_var2014=df2014[['2015_price_var_[%]']]

# %%
predictors2014.head()
# Out:
#   ticker       revenue  revenue_growth  cost_of_revenue  gross_profit  \
# 0     PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1   VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2     KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3    RAD  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4    GIS  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
#
#    r&d_expenses  sg&a_expense  operating_expenses  operating_income  \
# 0  0.000000e+00  2.146100e+10        2.146100e+10      1.391000e+10
# 1  1.083303e+08  3.441414e+08        7.939267e+08      1.345959e+08
# 2  0.000000e+00  1.519600e+10        1.751200e+10      2.725000e+09
# 3  0.000000e+00  6.561162e+09        6.586482e+09      7.372520e+08
# 4  0.000000e+00  3.474300e+09        3.412400e+09      2.957400e+09
#
#    interest_expense  earnings_before_tax  income_tax_expense  \
# 0      7.090000e+08         1.449400e+10        2.851000e+09
# 1      1.214869e+07         1.753823e+08        3.955957e+07
# 2      4.430000e+08         2.270000e+09        7.510000e+08
# 3      4.245910e+08         2.502180e+08        8.040000e+05
# 4      3.024000e+08         2.707700e+09        8.833000e+08
#
#    net_income_-_non-controlling_int  net_income_-_discontinued_ops  \
# 0                      1.420000e+08                  -1.127000e+09
# 1                     -1.431918e+07                   0.000000e+00
# 2                      1.200000e+07                   0.000000e+00
# 3                      0.000000e+00                   0.000000e+00
# 4                      3.690000e+07                   0.000000e+00
#
#      net_income  preferred_dividends  net_income_com     eps  eps_diluted  \
# 0  1.164300e+10                  0.0    1.164300e+10  4.1900        4.010
# 1  1.358227e+08                  0.0    1.358227e+08  0.2396        0.226
# 2  1.519000e+09                  0.0    1.519000e+09  1.4700        1.450
# 3  2.494140e+08           33998000.0    2.154160e+08  4.6000        4.600
# 4  1.824400e+09                  0.0    1.824400e+09  2.9000        2.830
#
#    weighted_average_shs_out  weighted_average_shs_out_(dil)  \
# 0              2.705960e+09                    2.705960e+09
# 1                       NaN                    1.829362e+07
# 2              1.033053e+09                    1.028000e+09
# 3              4.832628e+07                    4.832628e+07
# 4              6.144922e+08                    6.144922e+08
#
#    dividend_per_share  gross_margin  ebitda_margin  ebit_margin  \
# 0               2.448        0.4754         0.2470       0.2043
# 1               0.000        0.2487         0.0107       0.0502
# 2               0.307        0.2057         0.0450       0.0276
# 3               0.000        0.2869         0.0420       0.0264
# 4               1.550        0.3557         0.2010       0.1681
#
#    profit_margin  free_cash_flow_margin        ebitda          ebit  \
# 0         0.1560                 0.1359  1.834400e+10  1.520300e+10
# 1         0.0058                 0.0704  2.456858e+08  1.875310e+08
# 2         0.0150                 0.0126  4.416000e+09  2.713000e+09
# 3         0.0080                 0.0144  1.078550e+09  6.748090e+08
# 4         0.1020                 0.1052  3.595500e+09  3.010100e+09
#
#    consolidated_income  earnings_before_tax_margin  net_profit_margin  \
# 0         1.178500e+10                      0.1948             0.1565
# 1         1.215036e+08                      0.0470             0.0364
# 2         1.531000e+09                      0.0231             0.0154
# 3         2.494140e+08                      0.0098             0.0098
# 4         1.861300e+09                      0.1512             0.1019
#
#    cash_and_cash_equivalents  short-term_investments  \
# 0               8.558000e+09            2.128000e+09
# 1               7.735149e+08            6.083852e+08
# 2               4.010000e+08            0.000000e+00
# 3               1.464060e+08            0.000000e+00
# 4               8.673000e+08            0.000000e+00
#
#    cash_and_short-term_investments   receivables   inventories  \
# 0                     1.068600e+10  6.386000e+09  6.759000e+09
# 1                     1.381900e+09  1.169487e+07  5.793193e+08
# 2                     4.010000e+08  1.116000e+09  5.651000e+09
# 3                     1.464060e+08  9.490620e+08  2.993948e+09
# 4                     8.673000e+08  1.483600e+09  1.559400e+09
#
#    total_current_assets  property,_plant_&_equipment_net  \
# 0          3.161700e+10                     2.230400e+10
# 1          2.134397e+09                     3.085975e+08
# 2          8.830000e+09                     1.689300e+10
# 3          4.285125e+09                     1.957329e+09
# 4          4.393500e+09                     3.941900e+09
#
#    goodwill_and_intangible_assets  long-term_investments    tax_assets  \
# 0                    8.454700e+10           0.000000e+00  1.092000e+09
# 1                    1.906587e+08           6.299354e+07  3.764110e+07
# 2                    2.837000e+09           0.000000e+00  0.000000e+00
# 3                    4.312270e+08           0.000000e+00  0.000000e+00
# 4                    1.366480e+10           0.000000e+00  7.410000e+07
#
#    total_non-current_assets  total_assets      payables  short-term_debt  \
# 0              1.126490e+11  1.442660e+11  8.461000e+09     1.560600e+10
# 1              6.022904e+08  2.736687e+09  1.000491e+09     0.000000e+00
# 2              2.045100e+10  2.928100e+10  4.881000e+09     1.657000e+09
# 3              2.659746e+09  6.944871e+09  1.292419e+09     4.917400e+07
# 4              1.875220e+10  2.314570e+10  1.611300e+09     2.362300e+09
#
#    total_current_liabilities  long-term_debt    total_debt  deferred_revenue  \
# 0               3.372600e+10    1.981100e+10  3.541700e+10      0.000000e+00
# 1               1.639537e+09    6.223741e+08  6.223741e+08      3.141104e+07
# 2               1.070500e+10    9.653000e+09  1.131000e+10      0.000000e+00
# 3               2.507452e+09    5.707969e+09  5.757143e+09      0.000000e+00
# 4               5.423500e+09    6.423500e+09  8.785800e+09      0.000000e+00
#
#    tax_liabilities  deposit_liabilities  total_non-current_liabilities  \
# 0     1.021800e+10                  0.0                   4.056400e+10
# 1     0.000000e+00                  0.0                   6.615567e+08
# 2     1.629000e+09                  0.0                   1.318100e+10
# 3     0.000000e+00                  0.0                   6.551121e+09
# 4     1.666000e+09                  0.0                   9.732700e+09
#
#    total_liabilities  other_comprehensive_income  retained_earnings_(deficit)  \
# 0       7.429000e+10               -7.662000e+09                 8.499000e+10
# 1       2.301093e+09               -1.729254e+06                 4.285438e+06
# 2       2.388600e+10               -4.640000e+08                 1.098100e+10
# 3       9.058573e+09               -3.733400e+07                -7.515848e+09
# 4       1.515620e+10               -1.340300e+09                 1.178720e+10
#
#    total_shareholders_equity   investments      net_debt  other_assets  \
# 0               6.997600e+10  2.128000e+09  2.473100e+10  7.786000e+09
# 1               4.123545e+08  6.713788e+08           NaN           NaN
# 2               5.384000e+09  0.000000e+00  1.090900e+10  1.662000e+09
# 3              -2.113702e+09  0.000000e+00  5.610737e+09  1.957090e+08
# 4               6.534800e+09  0.000000e+00  7.918500e+09  4.832000e+08
#
#    other_liabilities  depreciation_&_amortization  stock-based_compensation  \
# 0       9.659000e+09                 3.141000e+09              3.600000e+08
# 1       6.390460e+08                 5.815483e+07              3.640523e+07
# 2       4.167000e+09                 1.703000e+09              1.070000e+08
# 3       1.165859e+09                 4.037410e+08             -1.047100e+07
# 4       1.449900e+09                 5.854000e+08              3.920000e+07
#
#    operating_cash_flow  capital_expenditure  acquisitions_and_disposals  \
# 0         1.395800e+10        -3.848000e+09               -2.400000e+07
# 1         5.267456e+08        -2.637046e+08               -1.922552e+08
# 2         3.573000e+09        -2.330000e+09               -2.344000e+09
# 3         7.020460e+08        -3.338700e+08                0.000000e+00
# 4         2.541000e+09        -6.569000e+08                6.670000e+07
#
#    investment_purchases_and_sales  investing_cash_flow  \
# 0                   -8.050000e+08        -4.100000e+09
# 1                   -2.126447e+08        -6.866936e+08
# 2                    0.000000e+00        -4.771000e+09
# 3                    4.115500e+07        -3.649240e+08
# 4                    2.930000e+07        -5.618000e+08
#
#    issuance_(repayment)_of_debt  issuance_(buybacks)_of_shares  \
# 0                  3.543000e+09                  -3.911000e+09
# 1                  6.193268e+08                   1.767840e+06
# 2                  2.093000e+09                  -4.130000e+08
# 3                 -2.954350e+08                   3.321700e+07
# 4                  8.011000e+08                  -1.637200e+09
#
#    dividend_payments  financing_cash_flow  effect_of_forex_changes_on_cash  \
# 0      -6.911000e+09        -7.279000e+09                     3.900000e+07
# 1       0.000000e+00         6.219136e+08                    -1.564869e+07
# 2      -3.190000e+08         1.361000e+09                     0.000000e+00
# 3       0.000000e+00        -3.201680e+08                     0.000000e+00
# 4      -9.833000e+08        -1.824100e+09                    -2.920000e+07
#
#    net_cash_flow_/_change_in_cash  free_cash_flow  net_cash/marketcap  \
# 0                    2.618000e+09    1.011000e+10             -0.1163
# 1                    4.463169e+08    2.630410e+08              0.0956
# 2                    1.630000e+08    1.243000e+09             -0.5969
# 3                    1.695400e+07    3.681760e+08             -0.8822
# 4                    1.259000e+08    1.884100e+09             -0.2376
#
#    price_book_value_ratio  price_to_book_ratio  price_to_sales_ratio  \
# 0                  3.0391               0.0000                2.8583
# 1                     NaN                  NaN                0.0443
# 2                  3.3579               7.0982                0.1858
# 3                  0.0000               0.0000                0.2491
# 4                  5.1004               0.0000                1.8610
#
#    price_earnings_ratio  price_to_free_cash_flows_ratio  \
# 0               18.7566                         21.0348
# 1               81.5526                          1.3589
# 2               12.0340                         14.6302
# 3               28.6087                         17.2736
# 4               18.7034                         17.6902
#
#    price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# 0                              15.2358              12.977501
# 1                                  NaN               0.678615
# 2                               5.1147               0.000000
# 3                               9.0589               0.000000
# 4                              13.1169              10.952350
#
#    price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# 0                       15.557842           2.434644        0.038153
# 1                        2.631793           0.095727       -0.000000
# 2                        0.000000           0.000000             NaN
# 3                        0.000000           0.000000             NaN
# 4                       15.254287           1.553911        0.035332
#
#    enterprise_value_multiple  price_fair_value  ebitper_revenue  ebtper_ebit  \
# 0                  11.421116          2.588601         0.204339     0.953364
# 1                   7.136538          0.866869         0.050221     0.935218
# 2                   2.276721          0.000000         0.027578     0.836712
# 3                   5.428005               NaN         0.026436     0.370798
# 4                   9.767966          4.258726         0.168072     0.899538
#
#    niper_ebt  gross_profit_margin  operating_profit_margin  \
# 0   0.803298             0.475410                      1.0
# 1   0.774438             0.248657                      1.0
# 2   0.669163             0.205713                      1.0
# 3   0.996787             0.286908                      1.0
# 4   0.673782             0.355664                      1.0
#
#    pretax_profit_margin  net_profit_margin  effective_tax_rate  \
# 0              0.186960           0.156490            0.196702
# 1              0.036045           0.036373            0.225562
# 2              0.027700           0.015441            0.330837
# 3              0.028882           0.009771            0.003213
# 4              0.165129           0.101867            0.326218
#
#    return_on_assets  return_on_equity  return_on_capital_employed  n_iper_ebt  \
# 0            0.5765            0.1664                      0.0753    0.803298
# 1            0.0403            0.3294                      0.0000    0.774438
# 2            0.1011            0.2821                      0.0859    0.669163
# 3            0.0668           -0.1180                      0.1062    0.996787
# 4            0.6265            0.2792                      0.1041    0.673782
#
#    e_btper_ebit  e_bitper_revenue  payables_turnover  inventory_turnover  \
# 0      0.953364          0.204339             1.5648             10.8869
# 1      0.935218          0.050221                NaN                 NaN
# 2      0.836712          0.027578             4.9593             18.2227
# 3      0.370798          0.026436             4.9289              8.3030
# 4      0.899538          0.168072             2.8234             11.5363
#
#    fixed_asset_turnover  asset_turnover  current_ratio  quick_ratio  \
# 0              3.335769        0.515721         0.9370     0.506197
# 1             12.100383        1.364477         0.2102     0.849993
# 2              5.823418        3.359687         0.8250     0.141709
# 3             13.041452        3.675578         1.7090     0.436885
# 4              4.543393        0.773777         0.8100     0.433465
#
#    cash_ratio  days_of_sales_outstanding  days_of_inventory_outstanding  \
# 0    0.253751                   -63.2087                        31.3287
# 1    0.471789                   -75.3670                         1.1431
# 2    0.037459                   -26.3971                         4.1407
# 3    0.058388                   -60.0346                        13.5706
# 4    0.159915                   -49.3233                        30.2360
#
#    operating_cycle  days_of_payables_outstanding  cash_conversion_cycle  \
# 0              NaN                       41.5084                    NaN
# 1              NaN                       97.7945                    NaN
# 2              NaN                       18.1099                    NaN
# 3              NaN                       18.4802                    NaN
# 4              NaN                       32.8385                    NaN
#
#    debt_ratio  debt_equity_ratio  longterm_debt_to_capitalization  \
# 0      0.2455             0.5061                         0.220644
# 1      0.2274             1.5093                         0.601485
# 2      0.3863             2.1007                         0.641950
# 3      0.8290            -2.7237                         1.588076
# 4      0.3796             1.3445                         0.495705
#
#    total_debt_to_capitalization  interest_coverage  cash_flow_to_debt_ratio  \
# 0                      0.336047            21.4429                 0.394105
# 1                      0.601485            15.4363                 0.846349
# 2                      0.677489             6.1242                 0.315915
# 3                      1.580139             1.5893                 0.121943
# 4                      0.573463             9.9540                 0.289217
#
#    company_equity_multiplier  operating_cash_flow_per_share  \
# 0                   2.061650                         5.1582
# 1                   6.636734                        35.6714
# 2                   5.438522                         3.4757
# 3                        NaN                        14.5272
# 4                   3.541914                         4.1351
#
#    free_cash_flow_per_share  cash_per_share  payout_ratio  \
# 0                     3.964          3.1626         0.584
# 1                    22.976         52.3827         0.000
# 2                     0.837          0.3901         0.209
# 3                     0.557          3.0295         0.000
# 4                     3.624          1.4114         0.534
#
#    operating_cash_flow_sales_ratio  free_cash_flow_operating_cash_flow_ratio  \
# 0                         0.187605                                  0.724316
# 1                         0.141062                                  0.499370
# 2                         0.036320                                  0.347887
# 3                         0.027503                                  0.524433
# 4                         0.141879                                  0.741480
#
#    cash_flow_coverage_ratios  short_term_coverage_ratios  \
# 0                   0.394105                    0.894400
# 1                   0.846349                         NaN
# 2                   0.315915                    2.156307
# 3                   0.121943                   14.276772
# 4                   0.289217                    1.075647
#
#    capital_expenditure_coverage_ratios  \
# 0                             3.627339
# 1                             1.997484
# 2                             1.533476
# 3                             2.102753
# 4                             3.868169
#
#    dividendpaid_and_capex_coverage_ratios  dividend_payout_ratio  \
# 0                                1.297332               0.593576
# 1                                1.997484              -0.000000
# 2                                1.348811               0.210007
# 3                                2.102753              -0.000000
# 4                                1.549201               0.538972
#
#    revenue_per_share  net_income_per_share  operating_cash_flow_per_share  \
# 0            27.4952                4.3027                         5.1582
# 1           252.8778                9.1980                        35.6714
# 2            95.6955                1.4776                         3.4757
# 3           528.2098                5.1610                        14.5272
# 4            29.1454                2.9690                         4.1351
#
#    free_cash_flow_per_share  cash_per_share  book_value_per_share  \
# 0                     3.964          3.1626               25.8600
# 1                    22.976         52.3827                0.7278
# 2                     0.837          0.3901                5.2370
# 3                     0.557          3.0295              -43.7380
# 4                     3.624          1.4114               10.6340
#
#    tangible_book_value_per_share  shareholders_equity_per_share  \
# 0                        22.0690                        25.8600
# 1                         4.4939                        27.9248
# 2                        25.7240                         5.2374
# 3                       134.7850                       -43.7381
# 4                        15.4290                        10.6345
#
#    interest_debt_per_share    market_cap  enterprise_value  pe_ratio  \
# 0                  13.0885  2.126614e+11      2.373924e+11   18.7566
# 1                  42.1474  6.253200e+09               NaN   81.5526
# 2                  11.0019  1.827470e+10      2.918370e+10   12.0340
# 3                 119.1307  6.359738e+09      1.197048e+10   28.6087
# 4                  14.2977  3.333006e+10      4.124856e+10   18.7034
#
#    price_to_sales_ratio  pocf_ratio  pfcf_ratio  pb_ratio  ptb_ratio  \
# 0                2.8583     15.2358     21.0348    3.0391     0.0000
# 1                0.0443         NaN      1.3589       NaN        NaN
# 2                0.1858      5.1147     14.6302    3.3579     7.0982
# 3                0.2491      9.0589     17.2736    0.0000     0.0000
# 4                1.8610     13.1169     17.6902    5.1004     0.0000
#
#    ev_to_sales  enterprise_value_over_ebitda  ev_to_operating_cash_flow  \
# 0       3.1907                       12.9411                    17.0076
# 1          NaN                           NaN                        NaN
# 2       0.2967                        6.6086                     8.1678
# 3       0.4689                       11.0987                    17.0508
# 4       2.3032                       11.4723                    16.2332
#
#    ev_to_free_cash_flow  earnings_yield  free_cash_flow_yield  debt_to_equity  \
# 0               23.4810          0.0533                0.0475          0.5061
# 1                   NaN          0.0123                   NaN          1.5093
# 2               23.4784          0.0831                0.0680          2.1007
# 3               32.5129          0.0350                0.0579         -2.7237
# 4               21.8930          0.0535                0.0565          1.3445
#
#    debt_to_assets  net_debt_to_ebitda  current_ratio  interest_coverage  \
# 0          0.2455              1.3482         0.9370            21.4429
# 1          0.2274                 NaN         0.2102            15.4363
# 2          0.3863              2.4703         0.8250             6.1242
# 3          0.8290              5.2021         1.7090             1.5893
# 4          0.3796              2.2023         0.8100             9.9540
#
#    income_quality  dividend_yield  payout_ratio  sg&a_to_revenue  \
# 0          1.1988          0.0311         0.584           0.2885
# 1          3.8782          0.0000         0.000           0.0922
# 2          2.3522          0.0174         0.209           0.1545
# 3          3.2590          0.0000         0.000           0.2570
# 4          1.3928          0.0286         0.534           0.1940
#
#    r&d_to_revenue  intangibles_to_total_assets  capex_to_operating_cash_flow  \
# 0           0.000                       0.5860                        0.2757
# 1           0.029                       0.0697                        0.5006
# 2           0.000                       0.0969                        0.6521
# 3           0.000                       0.0621                        0.4756
# 4           0.000                       0.5904                        0.2585
#
#    capex_to_revenue  capex_to_depreciation  \
# 0            0.0517                -1.2251
# 1            0.0706                -4.5345
# 2            0.0237                -1.3682
# 3            0.0131                -0.8269
# 4            0.0367                -1.1221
#
#    stock-based_compensation_to_revenue  graham_number    roic  \
# 0                               0.0048        49.3756  0.0753
# 1                               0.0097            NaN  0.0000
# 2                               0.0011        13.2000  0.0859
# 3                              -0.0004         0.0000  0.1062
# 4                               0.0022        26.3414  0.1041
#
#    return_on_tangible_assets  graham_net-net  working_capital  \
# 0                     0.5765         -0.2007    -2.109000e+09
# 1                     0.0403          0.0534     3.065163e+09
# 2                     0.1011         -0.8239    -1.875000e+09
# 3                     0.0668         -0.7506     1.777673e+09
# 4                     0.6265         -0.3229    -1.030000e+09
#
#    tangible_asset_value  net_current_asset_value  invested_capital  \
# 0          5.971900e+10            -4.267300e+10      5.285200e+10
# 1          2.546029e+09            -1.666966e+08      7.553510e+08
# 2          2.644400e+10            -1.505600e+10      2.664800e+10
# 3          6.513644e+09            -4.773448e+09      9.616929e+09
# 4          9.480900e+09            -1.076270e+10      1.197590e+10
#
#    average_receivables  average_payables  average_inventory  \
# 0         6.447000e+09      8.619000e+09       6.834000e+09
# 1                  NaN               NaN                NaN
# 2         1.083500e+09      4.682500e+09       5.398500e+09
# 3         9.392690e+08      1.338532e+09       3.074345e+09
# 4         1.465000e+09      1.517250e+09       1.552450e+09
#
#    days_sales_outstanding  days_payables_outstanding  \
# 0                 31.3287                    41.5084
# 1                  1.1431                    97.7945
# 2                  4.1407                    18.1099
# 3                 13.5706                    18.4802
# 4                 30.2360                    32.8385
#
#    days_of_inventory_on_hand  receivables_turnover  payables_turnover  \
# 0                   -63.2087               11.5404             1.5648
# 1                   -75.3670                   NaN                NaN
# 2                   -26.3971               90.7937             4.9593
# 3                   -60.0346               27.1769             4.9289
# 4                   -49.3233               12.2250             2.8234
#
#    inventory_turnover     roe  capex_per_share  gross_profit_growth  \
# 0             10.8869  0.1664          -1.4220              -0.1185
# 1                 NaN  0.3294         -17.8582               1.2489
# 2             18.2227  0.2821          -2.2665               0.0173
# 3              8.3030 -0.1180          -6.9087               0.0007
# 4             11.5363  0.2792          -1.0690              -0.0084
#
#    ebit_growth  operating_income_growth  net_income_growth  eps_growth  \
# 0      -0.0001                   0.0067             0.0293      0.0371
# 1       1.6142                   1.9463             1.5649      1.4625
# 2      -0.0145                  -0.0141             0.0147      0.0576
# 3       0.2904                   0.1113             1.0043      0.9167
# 4       0.0332                   0.0370            -0.0166      0.0140
#
#    eps_diluted_growth  weighted_average_shares_growth  \
# 0              0.0389                         -0.0127
# 1              1.4646                          0.0184
# 2              0.0469                         -0.0356
# 3              0.9167                          0.0694
# 4              0.0143                         -0.0468
#
#    weighted_average_shares_diluted_growth  dividends_per_share_growth  \
# 0                                     NaN                      0.0699
# 1                                  0.0195                      0.0000
# 2                                 -0.0317                      0.2429
# 3                                     NaN                      0.0000
# 4                                     NaN                      0.1742
#
#    operating_cash_flow_growth  free_cash_flow_growth  \
# 0                     -0.0615                -0.0695
# 1                      0.2134                -0.3626
# 2                      0.2095                 0.3935
# 3                     -0.1434                -0.2691
# 4                     -0.1316                -0.1936
#
#    10y_revenue_growth_(per_share)  5y_revenue_growth_(per_share)  \
# 0                          0.0323                         0.0088
# 1                             NaN                            NaN
# 2                          0.1027                         0.1038
# 3                         -0.0195                        -0.0290
# 4                          0.0704                         0.0567
#
#    3y_revenue_growth_(per_share)  10y_operating_cf_growth_(per_share)  \
# 0                        -0.0182                               0.0355
# 1                            NaN                                  NaN
# 2                         0.1399                               0.0889
# 3                        -0.0230                               0.0513
# 4                         0.0773                               0.0782
#
#    5y_operating_cf_growth_(per_share)  3y_operating_cf_growth_(per_share)  \
# 0                              0.0015                              0.0260
# 1                                 NaN                                 NaN
# 2                              0.0937                              0.0946
# 3                              0.1164                              0.1777
# 4                              0.0828                              0.1991
#
#    10y_net_income_growth_(per_share)  5y_net_income_growth_(per_share)  \
# 0                             0.0603                           -0.0137
# 1                                NaN                               NaN
# 2                             0.2272                            0.0906
# 3                             0.0480                            0.0000
# 4                             0.0776                            0.0841
#
#    3y_net_income_growth_(per_share)  \
# 0                            0.0060
# 1                               NaN
# 2                            0.1892
# 3                            0.0000
# 4                            0.0177
#
#    10y_shareholders_equity_growth_(per_share)  \
# 0                                      0.1442
# 1                                         NaN
# 2                                      0.0676
# 3                                      0.0000
# 4                                      0.0427
#
#    5y_shareholders_equity_growth_(per_share)  \
# 0                                     0.0353
# 1                                        NaN
# 2                                     0.0558
# 3                                     0.0000
# 4                                     0.0623
#
#    3y_shareholders_equity_growth_(per_share)  \
# 0                                     0.0201
# 1                                        NaN
# 2                                     0.0789
# 3                                     0.0000
# 4                                     0.0217
#
#    10y_dividend_per_share_growth_(per_share)  \
# 0                                     0.1013
# 1                                        NaN
# 2                                     0.0000
# 3                                     0.0000
# 4                                     0.1092
#
#    5y_dividend_per_share_growth_(per_share)  \
# 0                                    0.0834
# 1                                       NaN
# 2                                    0.1215
# 3                                    0.0000
# 4                                    0.1250
#
#    3y_dividend_per_share_growth_(per_share)  receivables_growth  \
# 0                                    0.0751             -0.0187
# 1                                       NaN                 NaN
# 2                                    0.1633              0.0618
# 3                                    0.0000              0.0211
# 4                                    0.1144              0.0257
#
#    inventory_growth  asset_growth  book_value_per_share_growth  debt_growth  \
# 0           -0.0217        0.0359                       0.0316       0.1228
# 1               NaN           NaN                          NaN          NaN
# 2            0.0981        0.1886                       0.3268       0.2738
# 3           -0.0510       -0.0189                       0.1963      -0.0458
# 4            0.0090        0.0215                       0.0274       0.1025
#
#    r&d_expense_growth  sg&a_expenses_growth              sector
# 0              0.0000               -0.1746  Consumer Defensive
# 1              1.6484                1.7313  Consumer Defensive
# 2              0.0000                0.0234  Consumer Defensive
# 3              0.0000               -0.0060  Consumer Defensive
# 4              0.0000               -0.0220  Consumer Defensive

# %%
class2014.head()
# Out:
#    class
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1

# %%
price_var2014.head()
# Out:
#    2015_price_var_[%]
# 0           -9.323276
# 1          -25.512193
# 2           33.118297
# 3            2.752291
# 4           12.897715

# %%
predictors2015 = df2015.drop(columns=['class', '2016_price_var_[%]'])
class2015 = df2015[['class']]
price_var2015 = df2015[['2016_price_var_[%]']]

# %%
predictors2016 = df2016.drop(columns=['class', '2017_price_var_[%]'])
class2016 = df2016[['class']]
price_var2016 = df2016[['2017_price_var_[%]']]

# %%
predictors2017 = df2017.drop(columns=['class', '2018_price_var_[%]'])
class2017 = df2017[['class']]
price_var2017 = df2017[['2018_price_var_[%]']]

# %%
predictors2018 = df2018.drop(columns=['class', '2019_price_var_[%]'])
class2018 = df2018[['class']]
price_var2018 = df2018[['2019_price_var_[%]']]

# %%
pd.set_option('display.max_seq_items', None)
print(predictors2014.columns)
# Out:
# Index(['ticker', 'revenue', 'revenue_growth', 'cost_of_revenue',
#        'gross_profit', 'r&d_expenses', 'sg&a_expense', 'operating_expenses',
#        'operating_income', 'interest_expense', 'earnings_before_tax',
#        'income_tax_expense', 'net_income_-_non-controlling_int',
#        'net_income_-_discontinued_ops', 'net_income', 'preferred_dividends',
#        'net_income_com', 'eps', 'eps_diluted', 'weighted_average_shs_out',
#        'weighted_average_shs_out_(dil)', 'dividend_per_share', 'gross_margin',
#        'ebitda_margin', 'ebit_margin', 'profit_margin',
#        'free_cash_flow_margin', 'ebitda', 'ebit', 'consolidated_income',
#        'earnings_before_tax_margin', 'net_profit_margin',
#        'cash_and_cash_equivalents', 'short-term_investments',
#        'cash_and_short-term_investments', 'receivables', 'inventories',
#        'total_current_assets', 'property,_plant_&_equipment_net',
#        'goodwill_and_intangible_assets', 'long-term_investments', 'tax_assets',
#        'total_non-current_assets', 'total_assets', 'payables',
#        'short-term_debt', 'total_current_liabilities', 'long-term_debt',
#        'total_debt', 'deferred_revenue', 'tax_liabilities',
#        'deposit_liabilities', 'total_non-current_liabilities',
#        'total_liabilities', 'other_comprehensive_income',
#        'retained_earnings_(deficit)', 'total_shareholders_equity',
#        'investments', 'net_debt', 'other_assets', 'other_liabilities',
#        'depreciation_&_amortization', 'stock-based_compensation',
#        'operating_cash_flow', 'capital_expenditure',
#        'acquisitions_and_disposals', 'investment_purchases_and_sales',
#        'investing_cash_flow', 'issuance_(repayment)_of_debt',
#        'issuance_(buybacks)_of_shares', 'dividend_payments',
#        'financing_cash_flow', 'effect_of_forex_changes_on_cash',
#        'net_cash_flow_/_change_in_cash', 'free_cash_flow',
#        'net_cash/marketcap', 'price_book_value_ratio', 'price_to_book_ratio',
#        'price_to_sales_ratio', 'price_earnings_ratio',
#        'price_to_free_cash_flows_ratio', 'price_to_operating_cash_flows_ratio',
#        'price_cash_flow_ratio', 'price_earnings_to_growth_ratio',
#        'price_sales_ratio', 'dividend_yield', 'enterprise_value_multiple',
#        'price_fair_value', 'ebitper_revenue', 'ebtper_ebit', 'niper_ebt',
#        'gross_profit_margin', 'operating_profit_margin',
#        'pretax_profit_margin', 'net_profit_margin', 'effective_tax_rate',
#        'return_on_assets', 'return_on_equity', 'return_on_capital_employed',
#        'n_iper_ebt', 'e_btper_ebit', 'e_bitper_revenue', 'payables_turnover',
#        'inventory_turnover', 'fixed_asset_turnover', 'asset_turnover',
#        'current_ratio', 'quick_ratio', 'cash_ratio',
#        'days_of_sales_outstanding', 'days_of_inventory_outstanding',
#        'operating_cycle', 'days_of_payables_outstanding',
#        'cash_conversion_cycle', 'debt_ratio', 'debt_equity_ratio',
#        'longterm_debt_to_capitalization', 'total_debt_to_capitalization',
#        'interest_coverage', 'cash_flow_to_debt_ratio',
#        'company_equity_multiplier', 'operating_cash_flow_per_share',
#        'free_cash_flow_per_share', 'cash_per_share', 'payout_ratio',
#        'operating_cash_flow_sales_ratio',
#        'free_cash_flow_operating_cash_flow_ratio', 'cash_flow_coverage_ratios',
#        'short_term_coverage_ratios', 'capital_expenditure_coverage_ratios',
#        'dividendpaid_and_capex_coverage_ratios', 'dividend_payout_ratio',
#        'revenue_per_share', 'net_income_per_share',
#        'operating_cash_flow_per_share', 'free_cash_flow_per_share',
#        'cash_per_share', 'book_value_per_share',
#        'tangible_book_value_per_share', 'shareholders_equity_per_share',
#        'interest_debt_per_share', 'market_cap', 'enterprise_value', 'pe_ratio',
#        'price_to_sales_ratio', 'pocf_ratio', 'pfcf_ratio', 'pb_ratio',
#        'ptb_ratio', 'ev_to_sales', 'enterprise_value_over_ebitda',
#        'ev_to_operating_cash_flow', 'ev_to_free_cash_flow', 'earnings_yield',
#        'free_cash_flow_yield', 'debt_to_equity', 'debt_to_assets',
#        'net_debt_to_ebitda', 'current_ratio', 'interest_coverage',
#        'income_quality', 'dividend_yield', 'payout_ratio', 'sg&a_to_revenue',
#        'r&d_to_revenue', 'intangibles_to_total_assets',
#        'capex_to_operating_cash_flow', 'capex_to_revenue',
#        'capex_to_depreciation', 'stock-based_compensation_to_revenue',
#        'graham_number', 'roic', 'return_on_tangible_assets', 'graham_net-net',
#        'working_capital', 'tangible_asset_value', 'net_current_asset_value',
#        'invested_capital', 'average_receivables', 'average_payables',
#        'average_inventory', 'days_sales_outstanding',
#        'days_payables_outstanding', 'days_of_inventory_on_hand',
#        'receivables_turnover', 'payables_turnover', 'inventory_turnover',
#        'roe', 'capex_per_share', 'gross_profit_growth', 'ebit_growth',
#        'operating_income_growth', 'net_income_growth', 'eps_growth',
#        'eps_diluted_growth', 'weighted_average_shares_growth',
#        'weighted_average_shares_diluted_growth', 'dividends_per_share_growth',
#        'operating_cash_flow_growth', 'free_cash_flow_growth',
#        '10y_revenue_growth_(per_share)', '5y_revenue_growth_(per_share)',
#        '3y_revenue_growth_(per_share)', '10y_operating_cf_growth_(per_share)',
#        '5y_operating_cf_growth_(per_share)',
#        '3y_operating_cf_growth_(per_share)',
#        '10y_net_income_growth_(per_share)', '5y_net_income_growth_(per_share)',
#        '3y_net_income_growth_(per_share)',
#        '10y_shareholders_equity_growth_(per_share)',
#        '5y_shareholders_equity_growth_(per_share)',
#        '3y_shareholders_equity_growth_(per_share)',
#        '10y_dividend_per_share_growth_(per_share)',
#        '5y_dividend_per_share_growth_(per_share)',
#        '3y_dividend_per_share_growth_(per_share)', 'receivables_growth',
#        'inventory_growth', 'asset_growth', 'book_value_per_share_growth',
#        'debt_growth', 'r&d_expense_growth', 'sg&a_expenses_growth', 'sector'],
#       dtype='object')

# %%
# Reset option to avoid potential performance issues in other parts
pd.reset_option('display.max_seq_items')

# %% [markdown]
# #### Initial Filtering of Predictors

# %% [markdown]
# Based on Investopedia, we decide to keep the following predictors --

# %% [markdown]
# ##### Fundamental Factors

# %% [markdown]
# 1. EPS (`eps`, `eps_diluted`): Include as it directly relates to earnings power.
# 2. Revenue and Profitability (`revenue`, `net_income`, `gross_profit`, `operating_income`, `earnings_before_tax`): These are critical components of the earnings base.
# 3. Growth Metrics (`revenue_growth`, `eps_growth`, `net_income_growth`): These are reflective of the expected growth in earnings.
# 4. Valuation Metrics (`pe_ratio`, `price_to_sales_ratio`, `pb_ratio`, `dividend_yield`): They are essential for understanding how the market values the earnings and assets of a company.
# 5. Dividends (`dividend_per_share`, `dividends_per_share_growth`): Important for mature companies where dividends are a significant factor.

# %% [markdown]
# ##### Technical Factors

# %% [markdown]
# 1. Market Cap (`market_cap`): Relates to liquidity and the size of the company.
# 2. Trading Volume (not explicitly listed, but can be derived or included as a data point): Reflects liquidity and investor interest.
# 3. Debt and Capital Structure (`total_debt`, `long-term_debt`, `debt_to_equity`, `net_debt_to_ebitda`): These can influence a company's risk profile and cost of capital.
# 4. Investment and Cash Flow (`operating_cash_flow`, `free_cash_flow`, `capital_expenditure`, `cash_and_cash_equivalents`): Reflects the company’s ability to generate cash and fund operations.

# %% [markdown]
# ##### Market Sentiment

# %% [markdown]
# 1. Price Volatility and Ratios (`enterprise_value_over_ebitda`, `ev_to_sales`, `earnings_yield`, `free_cash_flow_yield`): These might capture some elements of market sentiment.
# 2. Investor Sentiment Indicators (not listed, but could include news sentiment analysis or social media sentiment data): These would represent the behavioral aspect of the market.

# %% [markdown]
# ##### General Financial Health Indicators

# %% [markdown]
# 1. Liquidity Ratios (`current_ratio`, `quick_ratio`): To assess the company's ability to meet short-term obligations.
# 2. Profitability Ratios (`net_profit_margin`, `return_on_assets`, `return_on_equity`): Indicative of how efficiently a company is run.
# 3. Efficiency Ratios (`asset_turnover`, `inventory_turnover`, `receivables_turnover`): Reflective of how well the company utilizes its assets.

# %% [markdown]
# ##### Remove Redundant or Highly Correlated Predictors

# %% [markdown]
# * Remove items that are variations of the same measure (e.g., `weighted_average_shs_out` and `weighted_average_shs_out_(dil)`; just keep one).
# * Combine growth metrics into a single predictor if they are highly correlated (e.g., `5y_revenue_growth_(per_share)` and `3y_revenue_growth_(per_share)` might be combined).
# Use consolidated metrics rather than broken-down values when they convey the same information (e.g., `total_assets`, `total_liabilities`, `total_debt`).

# %% [markdown]
# ##### Sector Information

# %% [markdown]
# * Sector (`sector`): This categorical variable can capture industry-specific effects.

# %% [markdown]
# ##### Filter Predictors

# %%
# Define lists of predictors for each category

fundamental_factors = [
    'eps', 'eps_diluted', 'revenue', 'net_income', 'gross_profit',
    'operating_income', 'earnings_before_tax', 'dividend_per_share',
    'revenue_growth', 'eps_growth', 'net_income_growth',
    'pe_ratio', 'price_to_sales_ratio', 'pb_ratio', 'dividend_yield'
]

technical_factors = [
    'market_cap',
    'total_debt', 'long-term_debt', 'debt_to_equity', 'net_debt_to_ebitda',
    'operating_cash_flow', 'free_cash_flow', 'capital_expenditure',
    'cash_and_cash_equivalents'
]

market_sentiment = [
    'enterprise_value_over_ebitda', 'ev_to_sales', 'earnings_yield', 'free_cash_flow_yield'
]

gen_fin_health = [
    'current_ratio', 'quick_ratio', 'net_profit_margin', 'return_on_assets', 'return_on_equity',
    'asset_turnover', 'inventory_turnover', 'receivables_turnover', 
    'total_assets', 'total_liabilities', 'total_debt', 'net_debt'
]

sector_info = [
    'sector'
]

# Combine all the lists into one
all_selected_columns = (
    fundamental_factors + technical_factors +
    market_sentiment + gen_fin_health + sector_info
)

# %%
def pre_filter_predictor(df, columns):
    """
    Extract a subset of columns from a DataFrame safely, ensuring no duplicate columns in output.

    Only includes unique columns in the provided list if they exist in the DataFrame.
    Removes duplicate columns from the DataFrame itself.
    Returns a tuple with the subset DataFrame and a set of missing column names.

    Parameters:
    - df (pandas.DataFrame): The DataFrame to subset.
    - columns (list): Column names to include in the subset.

    Returns:
    - (pandas.DataFrame, set): A tuple with the subset DataFrame and a set of missing columns.
    """

    # Extract existing columns
    existing_columns = [col for col in columns if col in df.columns]
    
    # Create subset DataFrame and identify missing columns
    subset_df = df[existing_columns]

    # Ensure no duplicates in the output DataFrame
    subset_df = subset_df.loc[:, ~subset_df.columns.duplicated()]

    return subset_df, set(columns) - set(existing_columns)

# %%
predictors2014_selected, predictors2014_missing_col = pre_filter_predictor(predictors2014, all_selected_columns)

# %%
# Successful!
predictors2014_missing_col
# Out:
# set()

# %%
predictors2015_selected, predictors2015_missing_col = pre_filter_predictor(predictors2015, all_selected_columns)

# %%
predictors2015_selected.shape[1]
# Out:
# 40

# %%
# Successful!
predictors2015_missing_col
# Out:
# set()

# %%
predictors2016_selected, predictors2016_missing_col = pre_filter_predictor(predictors2016, all_selected_columns)

# %%
predictors2016_selected.shape[1]
# Out:
# 40

# %%
# Successful!
predictors2016_missing_col
# Out:
# set()

# %%
predictors2017_selected, predictors2017_missing_col = pre_filter_predictor(predictors2017, all_selected_columns)

# %%
predictors2017_selected.shape[1]
# Out:
# 40

# %%
# Successful!
predictors2017_missing_col
# Out:
# set()

# %%
predictors2018_selected, predictors2018_missing_col = pre_filter_predictor(predictors2018, all_selected_columns)

# %%
predictors2018_selected.shape[1]
# Out:
# 40

# %%
# Successful!
predictors2018_missing_col
# Out:
# set()

# %% [markdown]
# **So we have reduce the number of predictors in each dataset from 223 to 40! This still seems a bit too many so we will use PCA to help us further reduce the number of predictors.**

# %% [markdown]
# ### Data Types

# %% [markdown]
# We see that basically all of the predictors, except `sector`, are of type `float`. We use `predictors2014` as an example to show this:

# %%
predictors2014_selected.dtypes
# Out:
# eps                             float64
# eps_diluted                     float64
# revenue                         float64
# net_income                      float64
# gross_profit                    float64
# operating_income                float64
# earnings_before_tax             float64
# dividend_per_share              float64
# revenue_growth                  float64
# eps_growth                      float64
# net_income_growth               float64
# pe_ratio                        float64
# price_to_sales_ratio            float64
# pb_ratio                        float64
# dividend_yield                  float64
# market_cap                      float64
# total_debt                      float64
# long-term_debt                  float64
# debt_to_equity                  float64
# net_debt_to_ebitda              float64
# operating_cash_flow             float64
# free_cash_flow                  float64
# capital_expenditure             float64
# cash_and_cash_equivalents       float64
# enterprise_value_over_ebitda    float64
# ev_to_sales                     float64
# earnings_yield                  float64
# free_cash_flow_yield            float64
# current_ratio                   float64
# quick_ratio                     float64
# net_profit_margin               float64
# return_on_assets                float64
# return_on_equity                float64
# asset_turnover                  float64
# inventory_turnover              float64
# receivables_turnover            float64
# total_assets                    float64
# total_liabilities               float64
# net_debt                        float64
# sector                           object
# dtype: object

# %% [markdown]
# Our two types of targets, `class20xx` and `price_var20xx` are both numerical.

# %%
class2014.dtypes
# Out:
# class    int64
# dtype: object

# %%
price_var2014.dtypes
# Out:
# 2015_price_var_[%]    float64
# dtype: object

# %% [markdown]
# ### Examine Nullness after Pre-Selection of Predictors

# %% [markdown]
# #### Check Percentage of Missing Data for Each Predictor and Target

# %% [markdown]
# * None of the target variables has missing values, which is good.
# * Most predictors have a small percentage of missing values ($< 20\%$), with a few exceptions each year. We will drop the exceptions across all 4 datasets to ensure a uniform structure of our datasets (if the percentage of missingness is $> 41\%$).
#
# **Note:** The value $41\%$ is a subjective choice after examining the overall missingness to ensure we can keep most of the predictors to avoid losing useful data. This will require more advance consideration in the type of missingness of the data, but with time constraint we will make the decision for now and this could be an area of enhancement for further development of the project.

# %%
# Check the percentage of missing data in each column
missing_2014 = predictors2014_selected.isnull().mean() * 100
print(missing_2014)
# Out:
# eps                              1.890756
# eps_diluted                      2.205882
# revenue                          1.155462
# net_income                       0.603992
# gross_profit                     1.365546
# operating_income                 1.444328
# earnings_before_tax              2.100840
# dividend_per_share               3.912815
# revenue_growth                   6.197479
# eps_growth                       7.405462
# net_income_growth                6.381303
# pe_ratio                         4.044118
# price_to_sales_ratio             4.753151
# pb_ratio                        16.911765
# dividend_yield                  18.067227
# market_cap                       7.825630
# total_debt                       2.048319
# long-term_debt                  22.426471
# debt_to_equity                   4.858193
# net_debt_to_ebitda              37.394958
# operating_cash_flow              1.050420
# free_cash_flow                   1.234244
# capital_expenditure              1.365546
# cash_and_cash_equivalents        1.523109
# enterprise_value_over_ebitda    17.174370
# ev_to_sales                     17.174370
# earnings_yield                   4.044118
# free_cash_flow_yield             8.272059
# current_ratio                   25.393908
# quick_ratio                     25.525210
# net_profit_margin                1.496849
# return_on_assets                26.129202
# return_on_equity                 5.042017
# asset_turnover                   4.543067
# inventory_turnover               8.035714
# receivables_turnover             8.035714
# total_assets                     0.866597
# total_liabilities                1.024160
# net_debt                        33.534664
# sector                           0.000000
# dtype: float64

# %%
# Print values that are greater than 41%
print(missing_2014[missing_2014 > 41])
# Out:
# Series([], dtype: float64)

# %%
class2014.isnull().sum()
# Out:
# class    0
# dtype: int64

# %%
price_var2014.isnull().sum()
# Out:
# 2015_price_var_[%]    0
# dtype: int64

# %%
missing_2015 = predictors2015_selected.isnull().mean() * 100
print(missing_2015)
# Out:
# eps                              2.330097
# eps_diluted                      2.184466
# revenue                          1.626214
# net_income                       4.004854
# gross_profit                     1.577670
# operating_income                 1.019417
# earnings_before_tax              2.500000
# dividend_per_share               6.966019
# revenue_growth                   8.252427
# eps_growth                       9.344660
# net_income_growth                8.422330
# pe_ratio                         6.771845
# price_to_sales_ratio             6.796117
# pb_ratio                        19.393204
# dividend_yield                  12.160194
# market_cap                      10.655340
# total_debt                       4.514563
# long-term_debt                   1.456311
# debt_to_equity                   7.354369
# net_debt_to_ebitda              38.737864
# operating_cash_flow              1.553398
# free_cash_flow                   4.077670
# capital_expenditure              3.203883
# cash_and_cash_equivalents        1.577670
# enterprise_value_over_ebitda    19.684466
# ev_to_sales                     19.708738
# earnings_yield                   6.771845
# free_cash_flow_yield            11.043689
# current_ratio                    7.451456
# quick_ratio                      7.378641
# net_profit_margin                4.635922
# return_on_assets                27.427184
# return_on_equity                 7.354369
# asset_turnover                   6.043689
# inventory_turnover               9.538835
# receivables_turnover             9.514563
# total_assets                     2.135922
# total_liabilities                2.645631
# net_debt                        34.757282
# sector                           0.000000
# dtype: float64

# %%
# Print values that are greater than 41%
print(missing_2015[missing_2015 > 41])
# Out:
# Series([], dtype: float64)

# %%
class2015.isnull().sum()
# Out:
# class    0
# dtype: int64

# %%
price_var2015.isnull().sum()
# Out:
# 2016_price_var_[%]    0
# dtype: int64

# %%
missing_2016 = predictors2016_selected.isnull().mean() * 100
print(missing_2016)
# Out:
# eps                             10.881801
# eps_diluted                     10.735877
# revenue                         10.193871
# net_income                      12.632896
# gross_profit                    10.256410
# operating_income                 9.693558
# earnings_before_tax             11.069418
# dividend_per_share              15.384615
# revenue_growth                  13.529289
# eps_growth                      13.987909
# net_income_growth               15.676464
# pe_ratio                        15.217844
# price_to_sales_ratio            15.259537
# pb_ratio                        26.996039
# dividend_yield                  20.095893
# market_cap                      18.740880
# total_debt                      12.987284
# long-term_debt                   9.651866
# debt_to_equity                  15.426308
# net_debt_to_ebitda              44.090056
# operating_cash_flow             10.131332
# free_cash_flow                  12.778820
# capital_expenditure             12.007505
# cash_and_cash_equivalents       10.277257
# enterprise_value_over_ebitda    27.267042
# ev_to_sales                     27.287888
# earnings_yield                  15.217844
# free_cash_flow_yield            19.324578
# current_ratio                   15.030227
# quick_ratio                     14.988535
# net_profit_margin               13.279133
# return_on_assets                33.500104
# return_on_equity                15.551386
# asset_turnover                  14.592454
# inventory_turnover              15.593079
# receivables_turnover            13.841985
# total_assets                    11.006879
# total_liabilities               11.486346
# net_debt                        40.546175
# sector                           0.000000
# dtype: float64

# %%
# Print values that are greater than 41%
print(missing_2016[missing_2016 > 41])
# Out:
# net_debt_to_ebitda    44.090056
# dtype: float64

# %%
class2016.isnull().sum()
# Out:
# class    0
# dtype: int64

# %%
price_var2016.isnull().sum()
# Out:
# 2017_price_var_[%]    0
# dtype: int64

# %%
missing_2017 = predictors2017_selected.isnull().mean() * 100
print(missing_2017)
# Out:
# eps                             11.008065
# eps_diluted                     10.887097
# revenue                         10.584677
# net_income                      12.500000
# gross_profit                    10.766129
# operating_income                10.161290
# earnings_before_tax             11.673387
# dividend_per_share              16.834677
# revenue_growth                  14.596774
# eps_growth                      14.395161
# net_income_growth               16.330645
# pe_ratio                        16.794355
# price_to_sales_ratio            16.834677
# pb_ratio                        28.407258
# dividend_yield                  17.862903
# market_cap                      20.302419
# total_debt                      13.165323
# long-term_debt                  10.100806
# debt_to_equity                  16.834677
# net_debt_to_ebitda              44.375000
# operating_cash_flow             10.483871
# free_cash_flow                  12.983871
# capital_expenditure             12.479839
# cash_and_cash_equivalents       10.362903
# enterprise_value_over_ebitda    28.709677
# ev_to_sales                     28.729839
# earnings_yield                  16.794355
# free_cash_flow_yield            20.947581
# current_ratio                   16.512097
# quick_ratio                     16.411290
# net_profit_margin               13.326613
# return_on_assets                34.213710
# return_on_equity                16.955645
# asset_turnover                  15.967742
# inventory_turnover              16.653226
# receivables_turnover            14.495968
# total_assets                    11.048387
# total_liabilities               11.491935
# net_debt                        39.334677
# sector                           0.000000
# dtype: float64

# %%
# Print values that are greater than 41%
print(missing_2017[missing_2017 > 41])
# Out:
# net_debt_to_ebitda    44.375
# dtype: float64

# %%
class2017.isnull().sum()
# Out:
# class    0
# dtype: int64

# %%
price_var2017.isnull().sum()
# Out:
# 2018_price_var_[%]    0
# dtype: int64

# %%
missing_2018 = predictors2018_selected.isnull().mean() * 100
print(missing_2018)
# Out:
# eps                              1.479964
# eps_diluted                      1.434426
# revenue                          1.047359
# net_income                       3.438069
# gross_profit                     1.457195
# operating_income                 0.796903
# earnings_before_tax              1.616576
# dividend_per_share               5.692168
# revenue_growth                   3.164845
# eps_growth                       2.982696
# net_income_growth                5.236794
# pe_ratio                         5.737705
# price_to_sales_ratio             5.806011
# pb_ratio                        18.897996
# dividend_yield                   5.897086
# market_cap                       9.744991
# total_debt                       3.825137
# long-term_debt                   0.683060
# debt_to_equity                   5.714936
# net_debt_to_ebitda               8.629326
# operating_cash_flow              1.320583
# free_cash_flow                   3.802368
# capital_expenditure              3.278689
# cash_and_cash_equivalents        1.115665
# enterprise_value_over_ebitda    19.262295
# ev_to_sales                     19.285064
# earnings_yield                   5.737705
# free_cash_flow_yield            10.496357
# current_ratio                    5.714936
# quick_ratio                      5.669399
# net_profit_margin                4.007286
# return_on_assets                25.182149
# return_on_equity                 5.828780
# asset_turnover                   5.236794
# inventory_turnover               5.441712
# receivables_turnover             3.005464
# total_assets                     2.459016
# total_liabilities                2.891621
# net_debt                         5.783242
# sector                           0.000000
# dtype: float64

# %%
# Print values that are greater than 41%
print(missing_2018[missing_2018 > 41])
# Out:
# Series([], dtype: float64)

# %%
class2018.isnull().sum()
# Out:
# class    0
# dtype: int64

# %%
price_var2018.isnull().sum()
# Out:
# 2019_price_var_[%]    0
# dtype: int64

# %% [markdown]
# #### Visualization of Missingness

# %% [markdown]
# Here we use the `missingno` (missing "no") library to visualize the patterns of missing data.

# %% [markdown]
# **Interpretation Strategies:**
# * Randomness: If the missingness appears random without a discernible pattern across the matrix plot, it may suggest that the data is Missing Completely At Random (MCAR).
# * Patterns or Bands: Systematic patterns or bands in the matrix plot may suggest that the data is Missing At Random (MAR) where missingness is systematic and related to other observed variables.
# * Blocks: If you see blocks of white in the matrix plot, this suggests that there might be groups of data that are Missing Not At Random (MNAR), indicating a potential inherent problem with the data collection process.
# * Correlation in Heatmap: High correlation in the heatmap suggests that the missingness of one variable is not independent of another, which is common with MAR or MNAR.

# %%
# Visualize the missingness pattern
msno.matrix(predictors2014_selected)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(predictors2015_selected)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(predictors2016_selected)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(predictors2017_selected)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(predictors2018_selected)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(predictors2014_selected)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(predictors2015_selected)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(predictors2016_selected)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(predictors2017_selected)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(predictors2018_selected)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Dropping Predictors with $> 41\%$ Missingness

# %% [markdown]
# After dropping, we only have $39$ predictors left.

# %%
predictor2014_dropped = predictors2014_selected.drop('net_debt_to_ebitda', axis=1)
predictor2015_dropped = predictors2015_selected.drop('net_debt_to_ebitda', axis=1)
predictor2016_dropped = predictors2016_selected.drop('net_debt_to_ebitda', axis=1)
predictor2017_dropped = predictors2017_selected.drop('net_debt_to_ebitda', axis=1)
predictor2018_dropped = predictors2018_selected.drop('net_debt_to_ebitda', axis=1)

# %% [markdown]
# ### Train Test Set Split

# %% [markdown]
# We split the data into training and testing sets first to ensure that the model is evaluated on data it hasn't seen during training.

# %%
# Split the data into training and test sets
X_2014_train, X_2014_test, y_2014_train, y_2014_test = train_test_split(predictor2014_dropped, 
                                                                        price_var2014, 
                                                                        test_size=0.2, 
                                                                        random_state=42)

X_2015_train, X_2015_test, y_2015_train, y_2015_test = train_test_split(predictor2015_dropped, 
                                                                        price_var2015, 
                                                                        test_size=0.2, 
                                                                        random_state=42)

X_2016_train, X_2016_test, y_2016_train, y_2016_test = train_test_split(predictor2016_dropped, 
                                                                        price_var2016, 
                                                                        test_size=0.2, 
                                                                        random_state=42)

X_2017_train, X_2017_test, y_2017_train, y_2017_test = train_test_split(predictor2017_dropped, 
                                                                        price_var2017, 
                                                                        test_size=0.2, 
                                                                        random_state=42)

X_2018_train, X_2018_test, y_2018_train, y_2018_test = train_test_split(predictor2018_dropped, 
                                                                        price_var2018, 
                                                                        test_size=0.2, 
                                                                        random_state=42)

# %%
X_2014_train.shape, X_2014_test.shape, y_2014_train.shape, y_2014_test.shape
# Out:
# ((3046, 39), (762, 39), (3046, 1), (762, 1))

# %% [markdown]
# ### Data Scaling

# %% [markdown]
# We first scale the data (numerical predictors) as they are on very different scales. Since K-NN is a distance based algorith, scaling before imputing is better.

# %%
def scale_train_test(X_train, X_test):
    """
    Scales the numerical columns of training and test sets and combines them back 
    with the categorical data.

    Parameters:
    X_train (pd.DataFrame): The training set DataFrame.
    X_test (pd.DataFrame): The test set DataFrame.

    Returns:
    pd.DataFrame, pd.DataFrame: Scaled versions of X_train and X_test.
    """
    # Identify numerical columns
    numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns

    # Separate numerical and categorical data
    X_train_numerical = X_train[numerical_cols]
    X_train_categorical = X_train.drop(columns=numerical_cols)
    X_test_numerical = X_test[numerical_cols]
    X_test_categorical = X_test.drop(columns=numerical_cols)

    # Fit the scaler using only the training data
    scaler = StandardScaler().fit(X_train_numerical)

    # Apply the scaler to the numerical data
    X_train_numerical_scaled = scaler.transform(X_train_numerical)
    X_test_numerical_scaled = scaler.transform(X_test_numerical)

    # Convert the scaled arrays back to pandas DataFrame
    X_train_numerical_scaled_df = pd.DataFrame(X_train_numerical_scaled, columns=numerical_cols, index=X_train.index)
    X_test_numerical_scaled_df = pd.DataFrame(X_test_numerical_scaled, columns=numerical_cols, index=X_test.index)

    # Combine the scaled numerical data with the original categorical data
    X_train_scaled = pd.concat([X_train_numerical_scaled_df, X_train_categorical], axis=1)
    X_test_scaled = pd.concat([X_test_numerical_scaled_df, X_test_categorical], axis=1)

    return X_train_scaled, X_test_scaled, scaler

# %%
# Scale the train and test sets
X_2014_train_scaled, X_2014_test_scaled, X_2014_scaler = scale_train_test(X_2014_train, X_2014_test)
X_2015_train_scaled, X_2015_test_scaled, X_2015_scaler = scale_train_test(X_2015_train, X_2015_test)
X_2016_train_scaled, X_2016_test_scaled, X_2016_scaler = scale_train_test(X_2016_train, X_2016_test)
X_2017_train_scaled, X_2017_test_scaled, X_2017_scaler = scale_train_test(X_2017_train, X_2017_test)
X_2018_train_scaled, X_2018_test_scaled, X_2018_scaler = scale_train_test(X_2018_train, X_2018_test)

# %%
X_2014_train_scaled.shape, X_2014_test_scaled.shape
# Out:
# ((3046, 39), (762, 39))

# %% [markdown]
# ### K-NN Imputation

# %% [markdown]
# From the previous examination we found that the only categorical predictor `sector` doesn't have missing values. Hence, for imputation, we only have to focus on imputating the numerical predictors.

# %%
def separate_and_impute(X_train, X_test, n_neighbors=5):
    """
    Separates the numerical and categorical columns, applies KNN imputation to the 
    numerical columns, and then combines them back with the categorical data.

    Parameters:
    X_train (pd.DataFrame): The training set DataFrame.
    X_test (pd.DataFrame): The test set DataFrame.
    n_neighbors (int): The number of neighbors to use for KNN imputation.

    Returns:
    pd.DataFrame, pd.DataFrame: Imputed versions of X_train and X_test.
    """
    # Identify numerical columns
    numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns

    # Separate numerical and categorical data
    X_train_num = X_train[numerical_cols]
    X_train_cat = X_train.drop(columns=numerical_cols)
    X_test_num = X_test[numerical_cols]
    X_test_cat = X_test.drop(columns=numerical_cols)

    # Initialize and fit the KNN imputer
    knn_imputer = KNNImputer(n_neighbors=n_neighbors)
    X_train_num_imputed = knn_imputer.fit_transform(X_train_num)
    X_test_num_imputed = knn_imputer.transform(X_test_num)

    # Convert the imputed arrays back to pandas DataFrames
    X_train_num_imputed_df = pd.DataFrame(X_train_num_imputed, columns=X_train_num.columns)
    X_test_num_imputed_df = pd.DataFrame(X_test_num_imputed, columns=X_test_num.columns)

    # Combine the imputed numerical data with the original categorical data
    X_train_imputed = pd.concat([X_train_num_imputed_df, X_train_cat.reset_index(drop=True)], axis=1)
    X_test_imputed = pd.concat([X_test_num_imputed_df, X_test_cat.reset_index(drop=True)], axis=1)

    return X_train_imputed, X_test_imputed

# %%
X_2014_train_scaled_imp, X_2014_test_scaled_imp = separate_and_impute(X_2014_train_scaled, X_2014_test_scaled)
X_2015_train_scaled_imp, X_2015_test_scaled_imp = separate_and_impute(X_2015_train_scaled, X_2015_test_scaled)
X_2016_train_scaled_imp, X_2016_test_scaled_imp = separate_and_impute(X_2016_train_scaled, X_2016_test_scaled)
X_2017_train_scaled_imp, X_2017_test_scaled_imp = separate_and_impute(X_2017_train_scaled, X_2017_test_scaled)
X_2018_train_scaled_imp, X_2018_test_scaled_imp = separate_and_impute(X_2018_train_scaled, X_2018_test_scaled)

# %%
X_2014_train_scaled_imp.isnull().sum()
# Out:
# eps                             0
# eps_diluted                     0
# revenue                         0
# net_income                      0
# gross_profit                    0
# operating_income                0
# earnings_before_tax             0
# dividend_per_share              0
# revenue_growth                  0
# eps_growth                      0
# net_income_growth               0
# pe_ratio                        0
# price_to_sales_ratio            0
# pb_ratio                        0
# dividend_yield                  0
# market_cap                      0
# total_debt                      0
# long-term_debt                  0
# debt_to_equity                  0
# operating_cash_flow             0
# free_cash_flow                  0
# capital_expenditure             0
# cash_and_cash_equivalents       0
# enterprise_value_over_ebitda    0
# ev_to_sales                     0
# earnings_yield                  0
# free_cash_flow_yield            0
# current_ratio                   0
# quick_ratio                     0
# net_profit_margin               0
# return_on_assets                0
# return_on_equity                0
# asset_turnover                  0
# inventory_turnover              0
# receivables_turnover            0
# total_assets                    0
# total_liabilities               0
# net_debt                        0
# sector                          0
# dtype: int64

# %%
X_2014_test_scaled_imp.isnull().sum()
# Out:
# eps                             0
# eps_diluted                     0
# revenue                         0
# net_income                      0
# gross_profit                    0
# operating_income                0
# earnings_before_tax             0
# dividend_per_share              0
# revenue_growth                  0
# eps_growth                      0
# net_income_growth               0
# pe_ratio                        0
# price_to_sales_ratio            0
# pb_ratio                        0
# dividend_yield                  0
# market_cap                      0
# total_debt                      0
# long-term_debt                  0
# debt_to_equity                  0
# operating_cash_flow             0
# free_cash_flow                  0
# capital_expenditure             0
# cash_and_cash_equivalents       0
# enterprise_value_over_ebitda    0
# ev_to_sales                     0
# earnings_yield                  0
# free_cash_flow_yield            0
# current_ratio                   0
# quick_ratio                     0
# net_profit_margin               0
# return_on_assets                0
# return_on_equity                0
# asset_turnover                  0
# inventory_turnover              0
# receivables_turnover            0
# total_assets                    0
# total_liabilities               0
# net_debt                        0
# sector                          0
# dtype: int64

# %%
X_2015_train_scaled_imp.isnull().sum()
# Out:
# eps                             0
# eps_diluted                     0
# revenue                         0
# net_income                      0
# gross_profit                    0
# operating_income                0
# earnings_before_tax             0
# dividend_per_share              0
# revenue_growth                  0
# eps_growth                      0
# net_income_growth               0
# pe_ratio                        0
# price_to_sales_ratio            0
# pb_ratio                        0
# dividend_yield                  0
# market_cap                      0
# total_debt                      0
# long-term_debt                  0
# debt_to_equity                  0
# operating_cash_flow             0
# free_cash_flow                  0
# capital_expenditure             0
# cash_and_cash_equivalents       0
# enterprise_value_over_ebitda    0
# ev_to_sales                     0
# earnings_yield                  0
# free_cash_flow_yield            0
# current_ratio                   0
# quick_ratio                     0
# net_profit_margin               0
# return_on_assets                0
# return_on_equity                0
# asset_turnover                  0
# inventory_turnover              0
# receivables_turnover            0
# total_assets                    0
# total_liabilities               0
# net_debt                        0
# sector                          0
# dtype: int64

# %%
X_2015_test_scaled_imp.isnull().sum()
# Out:
# eps                             0
# eps_diluted                     0
# revenue                         0
# net_income                      0
# gross_profit                    0
# operating_income                0
# earnings_before_tax             0
# dividend_per_share              0
# revenue_growth                  0
# eps_growth                      0
# net_income_growth               0
# pe_ratio                        0
# price_to_sales_ratio            0
# pb_ratio                        0
# dividend_yield                  0
# market_cap                      0
# total_debt                      0
# long-term_debt                  0
# debt_to_equity                  0
# operating_cash_flow             0
# free_cash_flow                  0
# capital_expenditure             0
# cash_and_cash_equivalents       0
# enterprise_value_over_ebitda    0
# ev_to_sales                     0
# earnings_yield                  0
# free_cash_flow_yield            0
# current_ratio                   0
# quick_ratio                     0
# net_profit_margin               0
# return_on_assets                0
# return_on_equity                0
# asset_turnover                  0
# inventory_turnover              0
# receivables_turnover            0
# total_assets                    0
# total_liabilities               0
# net_debt                        0
# sector                          0
# dtype: int64

# %%
X_2016_train_scaled_imp.isnull().sum()
# Out:
# eps                             0
# eps_diluted                     0
# revenue                         0
# net_income                      0
# gross_profit                    0
# operating_income                0
# earnings_before_tax             0
# dividend_per_share              0
# revenue_growth                  0
# eps_growth                      0
# net_income_growth               0
# pe_ratio                        0
# price_to_sales_ratio            0
# pb_ratio                        0
# dividend_yield                  0
# market_cap                      0
# total_debt                      0
# long-term_debt                  0
# debt_to_equity                  0
# operating_cash_flow             0
# free_cash_flow                  0
# capital_expenditure             0
# cash_and_cash_equivalents       0
# enterprise_value_over_ebitda    0
# ev_to_sales                     0
# earnings_yield                  0
# free_cash_flow_yield            0
# current_ratio                   0
# quick_ratio                     0
# net_profit_margin               0
# return_on_assets                0
# return_on_equity                0
# asset_turnover                  0
# inventory_turnover              0
# receivables_turnover            0
# total_assets                    0
# total_liabilities               0
# net_debt                        0
# sector                          0
# dtype: int64

# %%
X_2016_test_scaled_imp.isnull().sum()
# Out:
# eps                             0
# eps_diluted                     0
# revenue                         0
# net_income                      0
# gross_profit                    0
# operating_income                0
# earnings_before_tax             0
# dividend_per_share              0
# revenue_growth                  0
# eps_growth                      0
# net_income_growth               0
# pe_ratio                        0
# price_to_sales_ratio            0
# pb_ratio                        0
# dividend_yield                  0
# market_cap                      0
# total_debt                      0
# long-term_debt                  0
# debt_to_equity                  0
# operating_cash_flow             0
# free_cash_flow                  0
# capital_expenditure             0
# cash_and_cash_equivalents       0
# enterprise_value_over_ebitda    0
# ev_to_sales                     0
# earnings_yield                  0
# free_cash_flow_yield            0
# current_ratio                   0
# quick_ratio                     0
# net_profit_margin               0
# return_on_assets                0
# return_on_equity                0
# asset_turnover                  0
# inventory_turnover              0
# receivables_turnover            0
# total_assets                    0
# total_liabilities               0
# net_debt                        0
# sector                          0
# dtype: int64

# %%
X_2017_train_scaled_imp.isnull().sum()
# Out:
# eps                             0
# eps_diluted                     0
# revenue                         0
# net_income                      0
# gross_profit                    0
# operating_income                0
# earnings_before_tax             0
# dividend_per_share              0
# revenue_growth                  0
# eps_growth                      0
# net_income_growth               0
# pe_ratio                        0
# price_to_sales_ratio            0
# pb_ratio                        0
# dividend_yield                  0
# market_cap                      0
# total_debt                      0
# long-term_debt                  0
# debt_to_equity                  0
# operating_cash_flow             0
# free_cash_flow                  0
# capital_expenditure             0
# cash_and_cash_equivalents       0
# enterprise_value_over_ebitda    0
# ev_to_sales                     0
# earnings_yield                  0
# free_cash_flow_yield            0
# current_ratio                   0
# quick_ratio                     0
# net_profit_margin               0
# return_on_assets                0
# return_on_equity                0
# asset_turnover                  0
# inventory_turnover              0
# receivables_turnover            0
# total_assets                    0
# total_liabilities               0
# net_debt                        0
# sector                          0
# dtype: int64

# %%
X_2017_test_scaled_imp.isnull().sum()
# Out:
# eps                             0
# eps_diluted                     0
# revenue                         0
# net_income                      0
# gross_profit                    0
# operating_income                0
# earnings_before_tax             0
# dividend_per_share              0
# revenue_growth                  0
# eps_growth                      0
# net_income_growth               0
# pe_ratio                        0
# price_to_sales_ratio            0
# pb_ratio                        0
# dividend_yield                  0
# market_cap                      0
# total_debt                      0
# long-term_debt                  0
# debt_to_equity                  0
# operating_cash_flow             0
# free_cash_flow                  0
# capital_expenditure             0
# cash_and_cash_equivalents       0
# enterprise_value_over_ebitda    0
# ev_to_sales                     0
# earnings_yield                  0
# free_cash_flow_yield            0
# current_ratio                   0
# quick_ratio                     0
# net_profit_margin               0
# return_on_assets                0
# return_on_equity                0
# asset_turnover                  0
# inventory_turnover              0
# receivables_turnover            0
# total_assets                    0
# total_liabilities               0
# net_debt                        0
# sector                          0
# dtype: int64

# %%
X_2018_train_scaled_imp.isnull().sum()
# Out:
# eps                             0
# eps_diluted                     0
# revenue                         0
# net_income                      0
# gross_profit                    0
# operating_income                0
# earnings_before_tax             0
# dividend_per_share              0
# revenue_growth                  0
# eps_growth                      0
# net_income_growth               0
# pe_ratio                        0
# price_to_sales_ratio            0
# pb_ratio                        0
# dividend_yield                  0
# market_cap                      0
# total_debt                      0
# long-term_debt                  0
# debt_to_equity                  0
# operating_cash_flow             0
# free_cash_flow                  0
# capital_expenditure             0
# cash_and_cash_equivalents       0
# enterprise_value_over_ebitda    0
# ev_to_sales                     0
# earnings_yield                  0
# free_cash_flow_yield            0
# current_ratio                   0
# quick_ratio                     0
# net_profit_margin               0
# return_on_assets                0
# return_on_equity                0
# asset_turnover                  0
# inventory_turnover              0
# receivables_turnover            0
# total_assets                    0
# total_liabilities               0
# net_debt                        0
# sector                          0
# dtype: int64

# %%
X_2018_test_scaled_imp.isnull().sum()
# Out:
# eps                             0
# eps_diluted                     0
# revenue                         0
# net_income                      0
# gross_profit                    0
# operating_income                0
# earnings_before_tax             0
# dividend_per_share              0
# revenue_growth                  0
# eps_growth                      0
# net_income_growth               0
# pe_ratio                        0
# price_to_sales_ratio            0
# pb_ratio                        0
# dividend_yield                  0
# market_cap                      0
# total_debt                      0
# long-term_debt                  0
# debt_to_equity                  0
# operating_cash_flow             0
# free_cash_flow                  0
# capital_expenditure             0
# cash_and_cash_equivalents       0
# enterprise_value_over_ebitda    0
# ev_to_sales                     0
# earnings_yield                  0
# free_cash_flow_yield            0
# current_ratio                   0
# quick_ratio                     0
# net_profit_margin               0
# return_on_assets                0
# return_on_equity                0
# asset_turnover                  0
# inventory_turnover              0
# receivables_turnover            0
# total_assets                    0
# total_liabilities               0
# net_debt                        0
# sector                          0
# dtype: int64

# %% [markdown]
# ### One-Hot Encoding

# %%
X_2014_train_final = pd.get_dummies(X_2014_train_scaled_imp, columns=['sector'])
X_2014_test_final = pd.get_dummies(X_2014_test_scaled_imp, columns=['sector'])

X_2015_train_final = pd.get_dummies(X_2015_train_scaled_imp, columns=['sector'])
X_2015_test_final = pd.get_dummies(X_2015_test_scaled_imp, columns=['sector'])

X_2016_train_final = pd.get_dummies(X_2016_train_scaled_imp, columns=['sector'])
X_2016_test_final = pd.get_dummies(X_2016_test_scaled_imp, columns=['sector'])

X_2017_train_final = pd.get_dummies(X_2017_train_scaled_imp, columns=['sector'])
X_2017_test_final = pd.get_dummies(X_2017_test_scaled_imp, columns=['sector'])

X_2018_train_final = pd.get_dummies(X_2018_train_scaled_imp, columns=['sector'])
X_2018_test_final = pd.get_dummies(X_2018_test_scaled_imp, columns=['sector'])

X_2014_train_final.shape, X_2014_test_final.shape
# Out:
# ((3046, 49), (762, 49))

# %% [markdown]
# ### Principle Component Analysis (PCA)

# %%
variance_threshold = 0.90
n_to_plot = 45

# %%
def opt_pca_components(X_train, n_to_plot, variance_threshold):
    """
    Fits PCA to the training data, plots the cumulative explained variance ratio, 
    and determines the optimal number of components based on the variance threshold.

    Parameters:
    X_train: Training data.
    n_to_plot: Number of principal components to consider in the plot.
    variance_threshold: Cumulative variance threshold to determine the optimal number of components.

    Returns:
    n_components: Optimal number of principal components based on the variance threshold.
    """

    # Fit PCA on the training data
    pca = PCA().fit(X_train)

    # Plot the cumulative explained variance ratio
    plt.plot(range(1, n_to_plot + 1), np.cumsum(pca.explained_variance_ratio_[:n_to_plot]), 'o:')
    plt.xlabel('Number of Components')
    plt.ylabel('Cumulative Explained Variance Ratio')
    plt.title(f'Principal Components Analysis')

    # Determine the optimal number of components
    n_components = np.where(np.cumsum(pca.explained_variance_ratio_) >= variance_threshold)[0][0] + 1

    # Print and return the optimal number of components
    print(f"Best number of components: {n_components}")
    return n_components

# %%
n_comp_2014 = opt_pca_components(X_2014_train_final, n_to_plot, variance_threshold)
# Out:
# Best number of components: 21

# %%
n_comp_2015 = opt_pca_components(X_2015_train_final, n_to_plot, variance_threshold)
# Out:
# Best number of components: 22

# %%
n_comp_2016 = opt_pca_components(X_2016_train_final, n_to_plot, variance_threshold)
# Out:
# Best number of components: 23

# %%
n_comp_2017 = opt_pca_components(X_2017_train_final, n_to_plot, variance_threshold)
# Out:
# Best number of components: 24

# %%
n_comp_2018 = opt_pca_components(X_2018_train_final, n_to_plot, variance_threshold)
# Out:
# Best number of components: 24

# %% [markdown]
# The largest best number of components is $24$ (both $2017$ and $2018$), so we will proceed with $24$ principle components.

# %%
best_n = 24
column_names = [f'pc_{i+1}' for i in range(best_n)]

# %%
pca2014 = PCA(n_components=best_n)
X_2014_train_pca = pca2014.fit_transform(X_2014_train_final)
X_2014_test_pca = pca2014.transform(X_2014_test_final)

# Convert to pandas DataFrame
X_2014_train_pca_df = pd.DataFrame(X_2014_train_pca, columns=column_names)
X_2014_test_pca_df = pd.DataFrame(X_2014_test_pca, columns=column_names)

# %%
X_2014_train_pca_df.head()
# Out:
#        pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0 -0.318047 -0.727744  0.207045 -0.061955 -0.064621 -0.025415 -0.093222
# 1 -0.157760 -0.609286  0.213914 -0.100369 -0.092689 -0.018671 -0.148357
# 2 -0.356733 -0.767112  0.212177  0.059177 -0.124818 -0.039409  0.028786
# 3 -0.427165 -0.828536  0.198866  0.219801 -0.178454 -0.053410  0.208651
# 4  1.157460  0.107799  0.151956 -0.288601 -0.091605 -0.013628 -0.219523
#
#        pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0  0.190632 -0.034339 -0.008350  0.080868 -0.054621  0.129162 -0.244744
# 1 -0.054952  0.242982 -0.125756  0.025902 -0.101056  0.099592 -0.128991
# 2  0.289830 -0.257956  0.064240 -0.019368 -0.145744 -0.065224 -0.045955
# 3  0.304359 -0.803354  0.265107 -0.035905  0.019847  0.145534 -0.252389
# 4 -0.126604  0.197906 -0.080495  0.020110 -0.042035  0.060246 -0.082181
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0  0.770149  0.133345  0.397928 -0.118636 -0.196658  0.039723  0.010137
# 1 -0.186509  0.062618  0.296946 -0.112474 -0.160035  0.080130 -0.142238
# 2 -0.003830 -0.112793 -0.334468  0.196750  0.144196 -0.145583  0.129005
# 3  0.191523 -0.243050 -0.898344  0.427854  0.383744 -0.430831 -0.396474
# 4 -0.192606  0.053317  0.361107 -0.132942 -0.167593  0.122599 -0.128002
#
#       pc_22     pc_23     pc_24
# 0  0.111131 -0.186345  0.049580
# 1  0.006104 -0.008668  0.194648
# 2 -0.043834 -0.230534  0.014512
# 3 -1.291664 -0.074273 -0.060205
# 4  0.065818  0.039411  0.141945

# %%
X_2014_test_pca_df.head()
# Out:
#        pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0 -0.838574  0.848982 -1.111580  1.663652 -2.050043 -0.007563  1.166132
# 1 -0.306915 -0.705015  0.193967 -0.035081 -0.081773 -0.031229 -0.063956
# 2  1.078194  0.083047  0.162226 -0.302422 -0.088807 -0.013582 -0.251848
# 3 -0.200593 -0.666954  0.173867  0.195874 -0.243456 -0.025870  0.136709
# 4 -1.518220  1.147823 -0.973417  0.065512 -0.104117 -0.030486  0.022183
#
#         pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0 -23.494605  1.731058 -0.140113  1.875913 -1.235789  0.421010  0.232129
# 1  -0.039796 -0.244842  0.109524  0.004930  0.715264  0.129432  0.216877
# 2   0.028114  0.300722 -0.157152 -0.023049 -0.168973 -0.012540 -0.042583
# 3  -1.789964 -0.127558  0.039185  0.003983 -0.130243 -0.165605  0.165306
# 4  -0.020100 -0.236736  0.056703 -0.113804 -0.005435 -0.248326  0.235332
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0 -0.049077  0.525268 -0.450568 -0.099264  0.092718 -0.148836 -3.505947
# 1 -0.292291  0.134468  0.265556 -0.053988 -0.104470  0.099468 -0.002939
# 2 -0.164511  0.038082  0.387369 -0.155816 -0.189248  0.128016 -0.141897
# 3  0.018110 -0.057953 -0.307161  0.256511  0.204842 -0.172950 -0.252597
# 4  0.121536 -0.029623 -0.321232 -0.313066 -0.214067  0.016474 -0.070667
#
#       pc_22      pc_23     pc_24
# 0  3.053742  11.800228  0.832885
# 1  0.008472  -0.093814  0.152283
# 2  0.012804  -0.065212  0.195909
# 3  0.322930   1.273727  0.284627
# 4 -0.012136   0.142709 -1.126175

# %%
pca2015 = PCA(n_components=best_n)
X_2015_train_pca = pca2015.fit_transform(X_2015_train_final)
X_2015_test_pca = pca2015.transform(X_2015_test_final)

# Convert to pandas DataFrame
X_2015_train_pca_df = pd.DataFrame(X_2015_train_pca, columns=column_names)
X_2015_test_pca_df = pd.DataFrame(X_2015_test_pca, columns=column_names)

# %%
X_2015_train_pca_df.head()
# Out:
#        pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0 -0.602205 -0.071405 -0.016652 -0.049920 -0.074018 -0.054147  0.012431
# 1 -0.539645 -0.049504 -0.105706 -0.048044 -0.068278 -0.070262 -0.185777
# 2 -0.543580 -0.060730  0.053606 -0.052862 -0.096424 -0.090242  0.444893
# 3 -0.598112 -0.065185 -0.039152 -0.041561 -0.055762 -0.063097 -0.179873
# 4 -0.573346 -0.041774 -0.060620 -0.050167 -0.091664 -0.082412  0.325567
#
#        pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0  0.042484 -0.083893 -0.060254 -0.068325  0.223606  0.055791 -0.137880
# 1  0.037269  0.034520 -0.106465 -0.015536 -0.060977 -0.041994 -0.021788
# 2  0.002996 -0.004760 -0.052126 -0.044414 -0.028705 -0.040672 -0.049343
# 3  0.051479  0.032977 -0.103655 -0.087412 -0.123415 -0.063243  0.031510
# 4  0.050018  0.051951 -0.074992 -0.035636 -0.071543 -0.028981 -0.000856
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0 -0.054126 -0.016432 -0.024048  0.003865  0.001868  0.248422 -0.000113
# 1 -0.123286 -0.010433 -0.039651  0.034065 -0.007142  0.064850  0.012343
# 2  0.315506  0.217618 -0.070074 -0.032693 -0.023438 -0.069993 -0.049986
# 3 -0.106292 -0.005504 -0.030350  0.016697  0.004877 -0.040591  0.013424
# 4 -0.124477 -0.019240 -0.033084  0.032202 -0.011882 -0.067438  0.026284
#
#       pc_22     pc_23     pc_24
# 0 -0.041247 -0.001893  0.077517
# 1 -0.029147 -0.244990  0.032406
# 2 -0.052971  0.441635  0.025730
# 3 -0.000562 -0.203361  0.063311
# 4 -0.005841 -0.573832  0.057505

# %%
X_2015_test_pca_df.head()
# Out:
#        pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0 -0.663638 -0.081718 -0.168382  0.272909  1.653260 -0.055349 -0.050039
# 1  0.413483 -0.023694 -0.556018 -0.058357 -0.064548 -0.063267 -0.192934
# 2 -0.600937 -0.061133 -0.019465 -0.031450 -0.049773 -0.124833  0.013726
# 3 -0.612334 -0.067737 -0.016893 -0.048876 -0.078996 -0.035525  0.178370
# 4 -0.589257 -0.066492  0.002198 -0.050530 -0.084208 -0.069525  0.199854
#
#        pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0  0.088219 -0.019155 -0.066164 -0.171898 -0.130487 -0.053893  0.062154
# 1  0.406521  0.108029 -0.195556  0.593668 -0.109994 -0.070336  0.018796
# 2  0.046064 -0.045077 -0.084871 -0.072004  0.024898 -0.012838 -0.023883
# 3  0.047901 -0.011909 -0.093512 -0.086513 -0.093173 -0.071850 -0.014615
# 4  0.043534 -0.039076 -0.067588 -0.080479  0.005145 -0.023261 -0.063919
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0 -0.107711 -0.002953 -0.040727 -0.007637  0.010553 -0.152802  0.192212
# 1 -0.106829 -0.020672 -0.045632  0.018335 -0.000191 -0.022246  0.021968
# 2 -0.060690 -0.043582 -0.031744 -0.009128 -0.000388 -0.018782 -0.012464
# 3 -0.031451 -0.037476 -0.033318  0.040921  0.010231 -0.163358 -0.004219
# 4  0.000950 -0.051901 -0.026313  0.036763 -0.001306 -0.165965 -0.025288
#
#       pc_22     pc_23     pc_24
# 0  0.082836 -0.281711  0.070732
# 1 -0.063376 -0.262262 -0.769363
# 2  0.011611 -0.013365  0.060025
# 3 -0.050601 -0.009226  0.082991
# 4 -0.075382  0.190316  0.026708

# %%
pca2016 = PCA(n_components=best_n)
X_2016_train_pca = pca2016.fit_transform(X_2016_train_final)
X_2016_test_pca = pca2016.transform(X_2016_test_final)

# Convert to pandas DataFrame
X_2016_train_pca_df = pd.DataFrame(X_2016_train_pca, columns=column_names)
X_2016_test_pca_df = pd.DataFrame(X_2016_test_pca, columns=column_names)

# %%
X_2016_train_pca_df.head()
# Out:
#        pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0 -0.620900 -0.062279 -0.043118 -0.194695 -0.036583  0.013572 -0.025442
# 1 -0.547087 -0.003037 -0.191134  0.000928 -0.028580  0.024228 -0.106914
# 2  4.964774 -0.611618  1.540619 -1.872932  0.058745  0.033435  0.657171
# 3  1.890806 -0.267099  0.601824 -0.847591  0.008635  0.008079  0.208174
# 4 -0.691921 -0.048218 -0.085534 -0.161639 -0.038639  0.008140 -0.059949
#
#        pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0 -0.133947  0.010324 -0.342166  0.389113  0.097856 -0.101195 -0.083203
# 1  0.002945  0.050205  0.063981 -0.068761 -0.057460  0.013769 -0.014117
# 2 -0.589060 -0.516636 -0.234853 -0.085387  0.059675 -0.677772  0.508142
# 3 -0.190270 -0.192225 -0.045133 -0.171682 -0.037721 -0.326748  0.276719
# 4 -0.118161  0.041895 -0.349881  0.410004  0.104874 -0.064522 -0.104717
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0 -0.238712 -0.156643  0.161419 -0.395438 -0.046118  0.197101 -0.093674
# 1  0.083538 -0.069793 -0.065546 -0.221153 -0.007764  0.072704 -0.022977
# 2  0.426216 -0.078116 -0.047537 -0.114507  0.257630  0.052482  0.036534
# 3  0.143786 -0.159976 -0.000328 -0.105891  0.075639 -0.009022 -0.039374
# 4 -0.223934 -0.145086  0.128099 -0.402725 -0.052000  0.203108 -0.107609
#
#       pc_22     pc_23     pc_24
# 0 -0.030804  0.006258 -0.051810
# 1  0.013207  0.039244  0.013939
# 2 -0.025481  0.037787 -0.263050
# 3  0.067682  0.030595  0.028916
# 4 -0.010867  0.006718 -0.039193

# %%
X_2016_test_pca_df.head()
# Out:
#        pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0 -0.737985 -0.033842 -0.093879 -0.007607 -0.017989 -0.032595 -0.025657
# 1 -0.827315 -1.375686  5.352996  5.161845 -0.094603 -0.100323 -0.286980
# 2  6.438182 -0.621494  1.562837 -1.937215  0.063263  0.071122  0.068963
# 3 -0.689569 -0.018091 -0.095986  0.070354 -0.009886 -0.147876  0.005965
# 4 -0.320790 -0.061011 -0.023497 -0.152489 -0.019325 -0.095077 -0.007069
#
#        pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0 -0.079922 -0.078269 -0.078098  0.013692  0.026412 -0.079885  0.003061
# 1  0.253340  0.217293 -0.275265 -0.723324 -0.168213  0.060510  0.162382
# 2  0.168048  0.589929  0.260707 -0.086001  0.047910 -0.560915  0.464251
# 3 -0.073554 -0.184510  0.169986 -0.352940 -0.073793 -0.046969  0.245026
# 4 -0.111377 -0.106515 -0.073633  0.004191 -0.010607 -0.046119 -0.023013
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0 -0.132421  0.043148 -0.076610  0.026759 -0.017237 -0.056713 -0.087063
# 1  0.353577 -0.038895 -1.007681 -0.404492  0.131047  0.092801 -0.042499
# 2  0.398317 -0.047862  0.058170  0.012665  0.008979 -0.050677 -0.004383
# 3 -0.049220 -0.152012 -0.093569  0.196146  0.013846 -0.208172 -0.000586
# 4  0.305746  0.091158  0.072236 -0.018941  0.034224  0.017110 -0.034614
#
#       pc_22     pc_23     pc_24
# 0 -0.007351 -0.022468 -0.007099
# 1 -0.288539 -3.502314 -0.077915
# 2  0.004717  0.048357 -0.271459
# 3  0.109476 -0.007687  0.008985
# 4  0.025320  0.027165  0.005263

# %%
pca2017 = PCA(n_components=best_n)
X_2017_train_pca = pca2017.fit_transform(X_2017_train_final)
X_2017_test_pca = pca2017.transform(X_2017_test_final)

# Convert to pandas DataFrame
X_2017_train_pca_df = pd.DataFrame(X_2016_train_pca, columns=column_names)
X_2017_test_pca_df = pd.DataFrame(X_2016_test_pca, columns=column_names)

# %%
X_2017_train_pca_df.head()
# Out:
#        pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0 -0.620900 -0.062279 -0.043118 -0.194695 -0.036583  0.013572 -0.025442
# 1 -0.547087 -0.003037 -0.191134  0.000928 -0.028580  0.024228 -0.106914
# 2  4.964774 -0.611618  1.540619 -1.872932  0.058745  0.033435  0.657171
# 3  1.890806 -0.267099  0.601824 -0.847591  0.008635  0.008079  0.208174
# 4 -0.691921 -0.048218 -0.085534 -0.161639 -0.038639  0.008140 -0.059949
#
#        pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0 -0.133947  0.010324 -0.342166  0.389113  0.097856 -0.101195 -0.083203
# 1  0.002945  0.050205  0.063981 -0.068761 -0.057460  0.013769 -0.014117
# 2 -0.589060 -0.516636 -0.234853 -0.085387  0.059675 -0.677772  0.508142
# 3 -0.190270 -0.192225 -0.045133 -0.171682 -0.037721 -0.326748  0.276719
# 4 -0.118161  0.041895 -0.349881  0.410004  0.104874 -0.064522 -0.104717
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0 -0.238712 -0.156643  0.161419 -0.395438 -0.046118  0.197101 -0.093674
# 1  0.083538 -0.069793 -0.065546 -0.221153 -0.007764  0.072704 -0.022977
# 2  0.426216 -0.078116 -0.047537 -0.114507  0.257630  0.052482  0.036534
# 3  0.143786 -0.159976 -0.000328 -0.105891  0.075639 -0.009022 -0.039374
# 4 -0.223934 -0.145086  0.128099 -0.402725 -0.052000  0.203108 -0.107609
#
#       pc_22     pc_23     pc_24
# 0 -0.030804  0.006258 -0.051810
# 1  0.013207  0.039244  0.013939
# 2 -0.025481  0.037787 -0.263050
# 3  0.067682  0.030595  0.028916
# 4 -0.010867  0.006718 -0.039193

# %%
X_2017_test_pca_df.head()
# Out:
#        pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0 -0.737985 -0.033842 -0.093879 -0.007607 -0.017989 -0.032595 -0.025657
# 1 -0.827315 -1.375686  5.352996  5.161845 -0.094603 -0.100323 -0.286980
# 2  6.438182 -0.621494  1.562837 -1.937215  0.063263  0.071122  0.068963
# 3 -0.689569 -0.018091 -0.095986  0.070354 -0.009886 -0.147876  0.005965
# 4 -0.320790 -0.061011 -0.023497 -0.152489 -0.019325 -0.095077 -0.007069
#
#        pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0 -0.079922 -0.078269 -0.078098  0.013692  0.026412 -0.079885  0.003061
# 1  0.253340  0.217293 -0.275265 -0.723324 -0.168213  0.060510  0.162382
# 2  0.168048  0.589929  0.260707 -0.086001  0.047910 -0.560915  0.464251
# 3 -0.073554 -0.184510  0.169986 -0.352940 -0.073793 -0.046969  0.245026
# 4 -0.111377 -0.106515 -0.073633  0.004191 -0.010607 -0.046119 -0.023013
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0 -0.132421  0.043148 -0.076610  0.026759 -0.017237 -0.056713 -0.087063
# 1  0.353577 -0.038895 -1.007681 -0.404492  0.131047  0.092801 -0.042499
# 2  0.398317 -0.047862  0.058170  0.012665  0.008979 -0.050677 -0.004383
# 3 -0.049220 -0.152012 -0.093569  0.196146  0.013846 -0.208172 -0.000586
# 4  0.305746  0.091158  0.072236 -0.018941  0.034224  0.017110 -0.034614
#
#       pc_22     pc_23     pc_24
# 0 -0.007351 -0.022468 -0.007099
# 1 -0.288539 -3.502314 -0.077915
# 2  0.004717  0.048357 -0.271459
# 3  0.109476 -0.007687  0.008985
# 4  0.025320  0.027165  0.005263

# %%
pca2018 = PCA(n_components=best_n)
X_2018_train_pca = pca2018.fit_transform(X_2018_train_final)
X_2018_test_pca = pca2018.transform(X_2018_test_final)

# Convert to pandas DataFrame
X_2018_train_pca_df = pd.DataFrame(X_2018_train_pca, columns=column_names)
X_2018_test_pca_df = pd.DataFrame(X_2018_test_pca, columns=column_names)

# %%
X_2018_train_pca_df.head()
# Out:
#         pc_1       pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0  -0.445742   0.054424 -0.056665 -0.057307 -0.056119 -0.027507 -0.116798
# 1  -0.205252  -0.101952 -0.183131 -0.053651 -0.075327  0.047391 -0.108843
# 2  27.496124  18.336658 -1.180690  0.067187 -0.151196  0.071801  0.077095
# 3  -0.661515   0.016647 -0.129145 -0.020041 -0.042403 -0.034460  0.055718
# 4  -0.504720  -0.028226 -0.174344 -0.033765 -0.088638 -0.032033 -0.019819
#
#        pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0  0.177437  0.164501  0.263890 -0.426808  0.031197 -0.125605  0.328948
# 1 -0.197759  0.204134  0.487112 -0.793532  0.891092 -0.214846  0.198457
# 2 -0.305569  0.719051  1.084240  1.447486 -0.210851  0.143916  0.009179
# 3 -0.146325  0.037932 -0.311410  0.241846 -0.042588  0.063815 -0.205221
# 4 -0.022391 -0.183011 -0.068305  0.414986  0.342078  0.195971  0.105206
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0 -0.105185 -0.459794  0.201048  0.109074 -0.016161 -0.317621  0.234046
# 1 -0.634902 -1.452838  1.402160  0.448526 -0.477274  0.017828  0.145702
# 2 -0.477006  1.531831  0.746883 -0.736029 -0.523649  0.430780 -2.153826
# 3  0.115522  0.296010 -0.229709 -0.101200 -0.003927  0.090751 -0.096738
# 4  0.173244  0.299413 -0.183678 -0.262785  0.244440  0.103644 -0.089923
#
#       pc_22     pc_23     pc_24
# 0 -0.003608 -0.445404 -0.024192
# 1 -0.075144 -0.187519 -0.006696
# 2  0.010665 -3.340186  0.053627
# 3 -0.310472  0.084776  0.027262
# 4 -0.054846  0.075182 -0.001811

# %%
X_2018_test_pca_df.head()
# Out:
#        pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0 -0.659257 -0.311734 -0.442660 -0.059086 -0.189225  0.047804  0.061511
# 1 -0.702524  0.081797 -0.087880 -0.028296 -0.031362 -0.036395 -0.013129
# 2 -0.696056 -0.037007 -0.150602 -0.030623 -0.001975 -0.026980  0.040860
# 3  0.597114 -0.255878 -0.084079 -0.071197 -0.078009 -0.008416 -0.191236
# 4 -0.706459  0.209936 -0.007099 -0.058102  0.006248 -0.058588 -0.133588
#
#        pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0 -1.331794  0.841731 -1.290374  1.877986  1.199037  0.567313 -0.592621
# 1  0.122236 -0.247013 -0.078813  0.080044 -0.042516  0.050786 -0.185807
# 2 -0.387730  0.207382 -0.550866  0.641723 -0.069484  0.084576 -0.098588
# 3  0.031155  0.611533  1.315317 -0.108389  0.185035 -0.072456  0.171439
# 4  0.262529 -0.027186  0.086410 -0.676097 -0.458467 -0.173768 -0.104445
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0  0.015799  0.005711  0.665055 -0.657526 -0.287835  0.812369 -0.170738
# 1  0.132637  0.265610 -0.209409 -0.140158  0.021965 -0.078288 -0.095059
# 2  0.007925  0.331893 -0.246961  0.039636 -0.024227  0.614452 -0.105243
# 3 -0.201882 -0.496407  0.478020  0.087728 -0.170147 -0.146757  1.092297
# 4  0.106055  0.143073 -0.345133  0.062940  0.019683 -0.418682 -0.037147
#
#       pc_22     pc_23     pc_24
# 0  2.066941  0.375508 -0.028103
# 1  0.123773  0.059519  0.010346
# 2 -0.618690  0.154046  0.021739
# 3  0.133763 -1.971661  0.001791
# 4  0.146099 -0.075971  0.036178

# %% [markdown]
# <a id="project_organization"></a>
#
# ## Part 1: Stock Performance Prediction Model
#
# [Return to contents](#contents)

# %% [markdown]
# ### Cleaned Datasets Available

# %% [markdown]
# #### Predictors
#
# **Scaled, imputed, not encoded**
# * `X_2014_train_scaled_imp`
# * `X_2014_test_scaled_imp`
# * `X_2015_train_scaled_imp`
# * `X_2015_test_scaled_imp`
# * `X_2016_train_scaled_imp`
# * `X_2016_test_scaled_imp`
# * `X_2017_train_scaled_imp`
# * `X_2017_test_scaled_imp`
# * `X_2018_train_scaled_imp`
# * `X_2018_test_scaled_imp`
#
# **Scaled, imputed, encoded**
# * `X_2014_train_final`
# * `X_2014_test_final`
# * `X_2015_train_final`
# * `X_2015_test_final`
# * `X_2016_train_final`
# * `X_2016_test_final`
# * `X_2017_train_final`
# * `X_2017_test_final`
# * `X_2018_train_final`
# * `X_2018_test_final`
#
# **Principle components**
# * `X_2014_train_pca_df`
# * `X_2014_test_pca_df`
# * `X_2015_train_pca_df`
# * `X_2015_test_pca_df`
# * `X_2016_train_pca_df`
# * `X_2016_test_pca_df`
# * `X_2017_train_pca_df`
# * `X_2017_test_pca_df`
# * `X_2018_train_pca_df`
# * `X_2018_test_pca_df`

# %% [markdown]
# #### Targets
# We will only use `price_var20xx` since we are focusing on regression problems.
# * `class2014`
# * `price_var2014`
# * `class2015`
# * `price_var2015`
# * `class2016`
# * `price_var2016`
# * `class2017`
# * `price_var2017`
# * `class2018`
# * `price_var2018`

# %% [markdown]
# ### Baseline Model Candidates

# %%
X_2014_train_pca_df.head()
# Out:
#        pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0 -0.318047 -0.727744  0.207045 -0.061955 -0.064621 -0.025415 -0.093222
# 1 -0.157760 -0.609286  0.213914 -0.100369 -0.092689 -0.018671 -0.148357
# 2 -0.356733 -0.767112  0.212177  0.059177 -0.124818 -0.039409  0.028786
# 3 -0.427165 -0.828536  0.198866  0.219801 -0.178454 -0.053410  0.208651
# 4  1.157460  0.107799  0.151956 -0.288601 -0.091605 -0.013628 -0.219523
#
#        pc_8      pc_9     pc_10     pc_11     pc_12     pc_13     pc_14  \
# 0  0.190632 -0.034339 -0.008350  0.080868 -0.054621  0.129162 -0.244744
# 1 -0.054952  0.242982 -0.125756  0.025902 -0.101056  0.099592 -0.128991
# 2  0.289830 -0.257956  0.064240 -0.019368 -0.145744 -0.065224 -0.045955
# 3  0.304359 -0.803354  0.265107 -0.035905  0.019847  0.145534 -0.252389
# 4 -0.126604  0.197906 -0.080495  0.020110 -0.042035  0.060246 -0.082181
#
#       pc_15     pc_16     pc_17     pc_18     pc_19     pc_20     pc_21  \
# 0  0.770149  0.133345  0.397928 -0.118636 -0.196658  0.039723  0.010137
# 1 -0.186509  0.062618  0.296946 -0.112474 -0.160035  0.080130 -0.142238
# 2 -0.003830 -0.112793 -0.334468  0.196750  0.144196 -0.145583  0.129005
# 3  0.191523 -0.243050 -0.898344  0.427854  0.383744 -0.430831 -0.396474
# 4 -0.192606  0.053317  0.361107 -0.132942 -0.167593  0.122599 -0.128002
#
#       pc_22     pc_23     pc_24
# 0  0.111131 -0.186345  0.049580
# 1  0.006104 -0.008668  0.194648
# 2 -0.043834 -0.230534  0.014512
# 3 -1.291664 -0.074273 -0.060205
# 4  0.065818  0.039411  0.141945

# %%
y_2014_train.head()
# Out:
#       2015_price_var_[%]
# 3329           36.978515
# 2980           -3.468209
# 1350          -18.990290
# 3789          -94.272727
# 246           -29.679142

# %% [markdown]
# #### Mean/Median Prediction Model

# %%
# Compute the mean and median of the training set response variable
mean_train = y_2014_train['2015_price_var_[%]'].mean()
median_train = y_2014_train['2015_price_var_[%]'].median()

# Create predictions for the test set using the mean and median
mean_predictions = np.full(shape=y_2014_test.shape, fill_value=mean_train)
median_predictions = np.full(shape=y_2014_test.shape, fill_value=median_train)

# Calculate the Mean Squared Error for both sets of predictions
mse_mean = mean_squared_error(y_2014_test, mean_predictions)
mse_median = mean_squared_error(y_2014_test, median_predictions)

print("2014 Mean Squared Error for Mean Predictions:", mse_mean)
print("2014 Mean Squared Error for Median Predictions:", mse_median)
# Out:
# 2014 Mean Squared Error for Mean Predictions: 673096847.9032288
# 2014 Mean Squared Error for Median Predictions: 674378927.5876353

# %%
# Compute the mean and median of the training set response variable
mean_train = y_2015_train['2016_price_var_[%]'].mean()
median_train = y_2015_train['2016_price_var_[%]'].median()

# Create predictions for the test set using the mean and median
mean_predictions = np.full(shape=y_2015_test.shape, fill_value=mean_train)
median_predictions = np.full(shape=y_2015_test.shape, fill_value=median_train)

# Calculate the Mean Squared Error for both sets of predictions
mse_mean = mean_squared_error(y_2015_test, mean_predictions)
mse_median = mean_squared_error(y_2015_test, median_predictions)

print("2015 Mean Squared Error for Mean Predictions:", mse_mean)
print("2015 Mean Squared Error for Median Predictions:", mse_median)
# Out:
# 2015 Mean Squared Error for Mean Predictions: 18786.108050983414
# 2015 Mean Squared Error for Median Predictions: 9271.631708854718

# %%
# Compute the mean and median of the training set response variable
mean_train = y_2016_train['2017_price_var_[%]'].mean()
median_train = y_2016_train['2017_price_var_[%]'].median()

# Create predictions for the test set using the mean and median
mean_predictions = np.full(shape=y_2016_test.shape, fill_value=mean_train)
median_predictions = np.full(shape=y_2016_test.shape, fill_value=median_train)

# Calculate the Mean Squared Error for both sets of predictions
mse_mean = mean_squared_error(y_2016_test, mean_predictions)
mse_median = mean_squared_error(y_2016_test, median_predictions)

print("2016 Mean Squared Error for Mean Predictions:", mse_mean)
print("2016 Mean Squared Error for Median Predictions:", mse_median)
# Out:
# 2016 Mean Squared Error for Mean Predictions: 299728.1249304051
# 2016 Mean Squared Error for Median Predictions: 126199.96481751128

# %%
# Compute the mean and median of the training set response variable
mean_train = y_2017_train['2018_price_var_[%]'].mean()
median_train = y_2017_train['2018_price_var_[%]'].median()

# Create predictions for the test set using the mean and median
mean_predictions = np.full(shape=y_2017_test.shape, fill_value=mean_train)
median_predictions = np.full(shape=y_2017_test.shape, fill_value=median_train)

# Calculate the Mean Squared Error for both sets of predictions
mse_mean = mean_squared_error(y_2017_test, mean_predictions)
mse_median = mean_squared_error(y_2017_test, median_predictions)

print("2017 Mean Squared Error for Mean Predictions:", mse_mean)
print("2017 Mean Squared Error for Median Predictions:", mse_median)
# Out:
# 2017 Mean Squared Error for Mean Predictions: 1553176.5079701256
# 2017 Mean Squared Error for Median Predictions: 1553251.9512157538

# %%
# Compute the mean and median of the training set response variable
mean_train = y_2018_train['2019_price_var_[%]'].mean()
median_train = y_2018_train['2019_price_var_[%]'].median()

# Create predictions for the test set using the mean and median
mean_predictions = np.full(shape=y_2018_test.shape, fill_value=mean_train)
median_predictions = np.full(shape=y_2018_test.shape, fill_value=median_train)

# Calculate the Mean Squared Error for both sets of predictions
mse_mean = mean_squared_error(y_2018_test, mean_predictions)
mse_median = mean_squared_error(y_2018_test, median_predictions)

print("2018 Mean Squared Error for Mean Predictions:", mse_mean)
print("2018 Mean Squared Error for Median Predictions:", mse_median)
# Out:
# 2018 Mean Squared Error for Mean Predictions: 19983.383225076435
# 2018 Mean Squared Error for Median Predictions: 20000.964579535117

# %% [markdown]
# #### Polynomial Regression Model

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
degree = 2  # can change this to a different degree as needed
poly_features = PolynomialFeatures(degree=degree)

# %%
X_train_poly_2014 = poly_features.fit_transform(X_2014_train_pca)
X_test_poly_2014 = poly_features.transform(X_2014_test_pca)
model = LinearRegression()
model.fit(X_train_poly_2014, y_2014_train)
y_pred = model.predict(X_test_poly_2014)
mse = mean_squared_error(y_2014_test, y_pred)
print("2014 Mean Squared Error for Polynomial Regression:", mse)
# Out:
# 2014 Mean Squared Error for Polynomial Regression: 2386116441554901.5

# %%
X_train_poly_2015 = poly_features.fit_transform(X_2015_train_pca)
X_test_poly_2015 = poly_features.transform(X_2015_test_pca)
model = LinearRegression()
model.fit(X_train_poly_2015, y_2015_train)
y_pred = model.predict(X_test_poly_2015)
mse = mean_squared_error(y_2015_test, y_pred)
print("2015 Mean Squared Error for Polynomial Regression:", mse)
# Out:
# 2015 Mean Squared Error for Polynomial Regression: 7214619941.288045

# %%
X_train_poly_2016 = poly_features.fit_transform(X_2016_train_pca)
X_test_poly_2016 = poly_features.transform(X_2016_test_pca)
model = LinearRegression()
model.fit(X_train_poly_2016, y_2016_train)
y_pred = model.predict(X_test_poly_2016)
mse = mean_squared_error(y_2016_test, y_pred)
print("2016 Mean Squared Error for Polynomial Regression:", mse)
# Out:
# 2016 Mean Squared Error for Polynomial Regression: 209236248094.5444

# %%
X_train_poly_2017 = poly_features.fit_transform(X_2017_train_pca)
X_test_poly_2017 = poly_features.transform(X_2017_test_pca)
model = LinearRegression()
model.fit(X_train_poly_2017, y_2017_train)
y_pred = model.predict(X_test_poly_2017)
mse = mean_squared_error(y_2017_test, y_pred)
print("2017 Mean Squared Error for Polynomial Regression:", mse)
# Out:
# 2017 Mean Squared Error for Polynomial Regression: 122741122.5901976

# %%
X_train_poly_2018 = poly_features.fit_transform(X_2018_train_pca)
X_test_poly_2018 = poly_features.transform(X_2018_test_pca)
model = LinearRegression()
model.fit(X_train_poly_2018, y_2018_train)
y_pred = model.predict(X_test_poly_2018)
mse = mean_squared_error(y_2018_test, y_pred)
print("2018 Mean Squared Error for Polynomial Regression:", mse)
# Out:
# 2018 Mean Squared Error for Polynomial Regression: 724997929.6036315

# %% [markdown]
# ### More Complex Model Candidates

# %% [markdown]
# #### Ridge Regression

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
ridge_model = Ridge(alpha=1.0)  # alpha is the regularization strength
ridge_model.fit(X_train_poly_2014, y_2014_train)
y_pred_ridge = ridge_model.predict(X_test_poly_2014)
mse_ridge = mean_squared_error(y_2014_test, y_pred_ridge)
print("2014 Mean Squared Error for Ridge Regression:", mse_ridge)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/shangwang/Desktop/CS 209/apcomp209a-final-project-main/project_notebook.ipynb Cell 210 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/shangwang/Desktop/CS%20209/apcomp209a-final-project-main/project_notebook.ipynb#Y530sZmlsZQ%3D%3D?line=0'>1</a> ridge_model = Ridge(alpha=1.0)  # alpha is the regularization strength
# ----> <a href='vscode-notebook-cell:/Users/shangwang/Desktop/CS%20209/apcomp209a-final-project-main/project_notebook.ipynb#Y530sZmlsZQ%3D%3D?line=1'>2</a> ridge_model.fit(X_train_poly_2014, y_2014_train)
#       <a href='vscode-notebook-cell:/Users/shangwang/Desktop/CS%20209/apcomp209a-final-project-main/project_notebook.ipynb#Y530sZmlsZQ%3D%3D?line=2'>3</a> y_pred_ridge = ridge_model.predict(X_test_poly_2014)
#       <a href='vscode-notebook-cell:/Users/shangwang/Desktop/CS%20209/apcomp209a-final-project-main/project_notebook.ipynb#Y530sZmlsZQ%3D%3D?line=3'>4</a> mse_ridge = mean_squared_error(y_2014_test, y_pred_ridge)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1011, in Ridge.fit(self, X, y, sample_weight)
#    1002 _accept_sparse = _get_valid_accept_sparse(sparse.issparse(X), self.solver)
#    1003 X, y = self._validate_data(
#    1004     X,
#    1005     y,
#    (...)
#    1009     y_numeric=True,
#    1010 )
# -> 1011 return super().fit(X, y, sample_weight=sample_weight)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:782, in _BaseRidge.fit(self, X, y, sample_weight)
#     778     else:
#     779         # for dense matrices or when intercept is set to 0
#     780         params = {}
# --> 782     self.coef_, self.n_iter_ = _ridge_regression(
#     783         X,
#     784         y,
#     785         alpha=self.alpha,
#     786         sample_weight=sample_weight,
#     787         max_iter=self.max_iter,
#     788         tol=self.tol,
#     789         solver=solver,
#     790         positive=self.positive,
#     791         random_state=self.random_state,
#     792         return_n_iter=True,
#     793         return_intercept=False,
#     794         check_input=False,
#     795         **params,
#     796     )
#     797     self._set_intercept(X_offset, y_offset, X_scale)
#     799 return self
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:599, in _ridge_regression(X, y, alpha, sample_weight, solver, max_iter, tol, verbose, positive, random_state, return_n_iter, return_intercept, X_scale, X_offset, check_input)
#     597 else:
#     598     try:
# --> 599         coef = _solve_cholesky(X, y, alpha)
#     600     except linalg.LinAlgError:
#     601         # use SVD solver if matrix is singular
#     602         solver = "svd"
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:157, in _solve_cholesky(X, y, alpha)
#     155 if one_alpha:
#     156     A.flat[:: n_features + 1] += alpha[0]
# --> 157     return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
#     158 else:
#     159     coefs = np.empty([n_targets, n_features], dtype=X.dtype)
#
# TypeError: solve() got an unexpected keyword argument 'sym_pos'

# %% [markdown]
# #### Lasso Regression

# %%
lasso_model = Lasso(alpha=1.0)  # alpha is the regularization strength
lasso_model.fit(X_train_poly_2014, y_2014_train)
y_pred_lasso = lasso_model.predict(X_test_poly_2014)
mse_lasso = mean_squared_error(y_2014_test, y_pred_lasso)
print("2014 Mean Squared Error for Lasso Regression:", mse_lasso)
# Out:
# 2014 Mean Squared Error for Lasso Regression: 746148823759.9286
# /Users/shangwang/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.783e+10, tolerance: 5.882e+08
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# #### Elastic Net Regression

# %% [markdown]
# #### Random Forest Regressors

# %% [markdown]
# #### Gradient Boosting

# %% [markdown]
# ### Evaluation

# %% [markdown]
# <a id="project_organization"></a>
#
# ## Part 2: Network Analysis of Stock Market Interdependencies
#
# [Return to contents](#contents)
